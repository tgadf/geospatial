# %%
from timeUtils import clock, elapsed


from collections import OrderedDict
buildingMap = OrderedDict()
buildingMap["Church"] = "church"
buildingMap["Chapel"] = "church"
buildingMap["of God"] = "church"
buildingMap["Cathedral"] = "church"
buildingMap["of Christ"] = "church"
buildingMap["Kingdom Hall of"] = "church"
buildingMap["Chruch"] = "church"
buildingMap["Bank"]   = "bank"
buildingMap["School"] = "school"
buildingMap["Police"] = "policestation"
buildingMap["Museum"] = "museum"
buildingMap["Library"] = "library"
buildingMap["Hotel"]   = "hotel"
buildingMap["Motel"]   = "motel"
buildingMap["Inn"]     = "motel"
buildingMap["Restaurant"] = "restaurant"
buildingMap["Auto Sales"] = "auto"
buildingMap["Auto Care"] = "auto"
buildingMap["Visitor Center"] = "visitorcenter"
buildingMap["Visitors Center"] = "visitorcenter"
buildingMap["Post Office"] = "postoffice"
buildingMap["Libary"] = "library"
buildingMap["Sporting Goods"] = "retail"
buildingMap["Courthouse"] = "courthouse"
buildingMap["Campground"] = "campground"
buildingMap["Fire Department"] = "firestation"
buildingMap["Fire Station"] = "firestation"
buildingMap["Home Improvement"] = "hardware"
buildingMap["Safeway"] = "grocery"
buildingMap["Department Store"] = "retail"
buildingMap["General Store"] = "convenience"
buildingMap["Credit Union"] = "bank"
buildingMap["Parking Garage"] = "parking"
buildingMap["Self Parking"] = "parking"
buildingMap["County Jail"] = "prison"
buildingMap["Rental Car"] = "rentalcar"
buildingMap["Department of Motor Vehicles"] = "government"
buildingMap["Welcome Center"] = "government"
buildingMap["State Capitol"] = "government"
buildingMap["Chamber of Commerce"] = "government"
buildingMap["Town Hall"] = "government"
buildingMap["Federal Building"] = "government"
buildingMap["Governor's Mansion"] = "government"
buildingMap["Oil Change"] = "auto"
buildingMap["Supermarket"] = "grocery"
buildingMap["Pizza"] = "restaurant"
buildingMap["Pizzaria"] = "restaurant"
buildingMap["Community College"] = "college"
buildingMap["Tire Service"] = "auto"
buildingMap["Tire & Auto"] = "auto"
buildingMap["Tires"] = "auto"
buildingMap["Super 8"] = "motel"
buildingMap["Pharmacy"] = "pharmacy"
buildingMap["Postal Service"] = "postoffice"
buildingMap["Auto Service"] = "auto"
buildingMap["Auto Parts"] = "auto"
buildingMap["Cinema"] = "recreation"
buildingMap["Bar"] = "restaurant"
buildingMap["Grill"] = "restaurant"
buildingMap["College"] = "college"
buildingMap["Car Wash"] = "auto"
buildingMap[" Qwik "] = "convenience"
buildingMap["Storage"] = "storage"
buildingMap["Liquor"] = "commercial"
buildingMap["Wine"] = "commercial"
buildingMap["Clinic"] = "medical"
buildingMap["Hospital"] = "medical"
buildingMap["Medical"] = "medical"
buildingMap["Sheriff"] = "prison"
buildingMap["Parking"] = "parking"
buildingMap["Apartments"] = "apartments"
buildingMap["City Hall"] = "government"
buildingMap["Community Center"] = "civic"
buildingMap["Convention Center"] = "civic"
buildingMap["Civic Center"] = "civic"
buildingMap["Senior Center"] = "civic"
buildingMap["Student Center"] = "college"
buildingMap["Student Union"] = "college"
buildingMap["Health Center"] = "medical"
buildingMap["Toll Plaza"] = "road"
buildingMap["Residence Hall"] = "college"
buildingMap["Art Center"] = "civic"
buildingMap["Shopping Center"] = "mall"
buildingMap["Aquatic Center"] = "recreation"
buildingMap["Athletic Center"] = "recreation"
buildingMap["Hardware"] = "hardware"
buildingMap["Tower"] = "tower"


buildingConv = {}

buildingConv["building"] = "building"
buildingConv["house"] = "house"
buildingConv["apartments"] = "apartments"
buildingConv["roof"] = "roof"
buildingConv["shed"] = "shed"
buildingConv["residential"] = "residential"
buildingConv["school"] = "school"
buildingConv["garage"] = "garage"
buildingConv["retail"] = "retail"
buildingConv["commercial"] = "commercial"
buildingConv["church"] = "church"
buildingConv["static_caravan"] = "building"   # no idea?
buildingConv["industrial"] = "industrial"
buildingConv["garages"] = "garages"
buildingConv["shelter"] = "shelter"
buildingConv["farm_auxiliary"] = "farm"
buildingConv["motel"] = "motel"
buildingConv["hotel"] = "hotel"
buildingConv["office"] = "office"
buildingConv["hangar"] = "hangar"
buildingConv["university"] = "university"
buildingConv["restaurant"] = "restaurant"
buildingConv["bank"] = "bank"
buildingConv["stable"] = "stable"
buildingConv["college"] = "college"
buildingConv["firestation"] = "firestation"
buildingConv["warehouse"] = "warehouse"
buildingConv["dormitory"] = "dormitory"
buildingConv["government"] = "government"
buildingConv["ruins"] = "ruins"
buildingConv["terrace"] = "terrace"
buildingConv["postoffice"] = "postoffice"
buildingConv["museum"] = "museum"
buildingConv["public"] = "public"
buildingConv["hospital"] = "hospital"
buildingConv["library"] = "library"
buildingConv["storage"] = "storage"
buildingConv["greenhouse"] = "greenhouse"
buildingConv["carport"] = "carport"
buildingConv["civic"] = "civic"
buildingConv["visitorcenter"] = "visitorcenter"
buildingConv["bunker"] = "bunker"
buildingConv["parking_shelter"] = "parking"
buildingConv["farm"] = "farm"
buildingConv["vacant"] = "building"  # building
buildingConv["collapsed"] = "building" # building
buildingConv["barn"] = "barn"
buildingConv["train_station"] = "trainstation"
buildingConv["police"] = "policestation"
buildingConv["courthouse"] = "courthouse"
buildingConv["service"] = "service"
buildingConv["dugout"] = "recreation"  # recreation
buildingConv["no"] = "building"  # no idea?
buildingConv["construction"] = "construction"
buildingConv["auto"] = "auto"
buildingConv["canopy"] = "canopy"
buildingConv["grocery"] = "grocery"
buildingConv["stadium"] = "stadium"
buildingConv["empty"] = "building"   # building
buildingConv["grandstand"] = "recreation"  # recreation
buildingConv["military"] = "military"
buildingConv["cabin"] = "cabin"
buildingConv["yesGrace Lutheran Ch"] = "church" # church
buildingConv["recreation"] = "recreation"
buildingConv["hardware"] = "hardware"
buildingConv["pharmacy"] = "pharmacy"
buildingConv["prison"] = "prison"
buildingConv["supermarket"] = "supermarket"
buildingConv["chapel"] = "church" # church
buildingConv["tower"] = "tower"
buildingConv["parking"] = "parking"
buildingConv["mosque"] = "mosque"
buildingConv["convenience"] = "convenience"
buildingConv["manufacture"] = "manufacture"
buildingConv["kindergarten"] = "kindergarten"
buildingConv["storage_tank"] = "reservoir" # reservoir
buildingConv["slurry_tank"] = "reservoir"  # reservoir
buildingConv["y"] = "building"   # no idea?
buildingConv["transportation"] = "transportation"
buildingConv["gazebo"] = "gazebo"
buildingConv["pumphouse"] = "pumphouse"
buildingConv["fee station"] = "station" # station
buildingConv["administration"] = "administration"
buildingConv["business"] = "business"
buildingConv["res"] = "restaurant" # restaurant ?
buildingConv["laundromat"] = "laundromat"
buildingConv["ho"] = "building"   # building ?
buildingConv["Charter_School"] = "school"  # school
buildingConv["jail"] = "jail"
buildingConv["1y"] = "building"  # no idea
buildingConv["Chapel"] = "church"
buildingConv["monastery"] = "monastery"
buildingConv["trailer"] = "trailer"
buildingConv["Jail_House"] = "jail"
buildingConv["s"] = "building"  # no idea
buildingConv["hostel"] = "hostel"
buildingConv["balcony"] = "balcony"
buildingConv["yes;house"] = "house"  # house
buildingConv["suites"] = "suites"
buildingConv["bell_tower"] = "tower"   # tower
buildingConv["campground"] = "campground"
buildingConv["semidetached_house"] = "house"  # house
buildingConv["cowshed"] = "barn"  # barn
buildingConv["crossing"] = "crossing"
buildingConv["temple"] = "temple"
buildingConv["vehicle"] = "vehicle"
buildingConv["suite"] = "suite"

buildingConv["yurt"] = "building"   # no idea?
buildingConv["pharmacy"] = "pharmacy"
buildingConv["gazebo"] = "gazebo"
buildingConv["courthouse"] = "courthouse"
buildingConv["parking"] = "parking"
buildingConv["trank"] = "building"   # no idea?
buildingConv["fire_station"] = "firestation"
buildingConv["hangar"] = "hangar"
buildingConv["pavilion"] = "pavilion"
buildingConv["manufacture"] = "manufacture"
buildingConv["springhouse"] = "springhouse"
buildingConv["construction"] = "construction"
buildingConv["medical center"] = "medical"
buildingConv["dining"] = "restaurant"
buildingConv["bunker"] = "bunker"
buildingConv["tank"] = "reservoir"


buildingConv["supermarket"] = "grocery"
buildingConv["construction"] = "building"   # really?
buildingConv["*"] = "building"   # no idea
buildingConv["transportation"] = "transportation"
buildingConv["trainstation"] = "trainstation"
buildingConv["shelter"] = "shelter"
buildingConv["tomb"] = "cemetary"
buildingConv["healthcare"] = "healthcare"
buildingConv["ship"] = "ship"
buildingConv["hut"] = "building"  ## no odea
buildingConv["kindergarten"] = "school"
buildingConv["boathouse"] = "boathouse"
buildingConv["brewery"] = "brewery"
buildingConv["visitorcenter"] = "visitorcenter"
buildingConv["public_building"] = "public"  # public
buildingConv["monastery"] = "monastery"
buildingConv["roof;yes"] = "roof"  # roof
buildingConv["cinema"] = "cinema"
buildingConv["hardware"] = "hardware"
buildingConv["cathedral"] = "church"
buildingConv["carport"] = "carport"
buildingConv["benches for sports"] = "recreation"  #recreation
buildingConv["condominium"] = "condominium"
buildingConv["apart"] = "apartments"  # apartments
buildingConv["shop"] = "retail"   # retail
buildingConv["convenience"] = "convenience"
buildingConv["campground"] = "campground"
buildingConv["porch"] = "porch"
buildingConv["ruins"] = "ruins"
buildingConv["ticketing"] = "ticketing"
buildingConv["gathering"] = "gathering"
buildingConv["grocery"] = "grocery"
buildingConv["pavilion"] = "pavilion"
buildingConv["yes;apartments"] = "apartments"  # apartments
buildingConv["yes;dormitory"] = "dormitory"  # dormitory


buildingConv["building"] = "building"
buildingConv["detached"] = "detached"
buildingConv["garage"] = "garage"
buildingConv["residential"] = "residential"
buildingConv["house"] = "house"
buildingConv["apartments"] = "apartments"
buildingConv["commercial"] = "commercial"
buildingConv["industrial"] = "industrial"
buildingConv["school"] = "school"
buildingConv["church"] = "church"
buildingConv["roof"] = "roof"
buildingConv["greenhouse"] = "greenhouse"
buildingConv["silo"] = "silo"
buildingConv["reservoir"] = "reservoir"
buildingConv["shed"] = "shed"
buildingConv["restaurant"] = "restaurant"
buildingConv["retail"] = "retail"
buildingConv["bank"] = "bank"
buildingConv["motel"] = "motel"
buildingConv["hangar"] = "hangar"
buildingConv["hotel"] = "hotel"
buildingConv["office"] = "office"
buildingConv["university"] = "college"
buildingConv["library"] = "library"
buildingConv["barn"] = "barn"
buildingConv["postoffice"] = "postoffice"
buildingConv["warehouse"] = "warehouse"
buildingConv["auto"] = "auto"
buildingConv["hospital"] = "hospital"
buildingConv["cabin"] = "cabin"
buildingConv["garages"] = "garages"
buildingConv["terrace"] = "terrace"
buildingConv["dormitory"] = "dormitory"
buildingConv["public"] = "public"
buildingConv["farm"] = "farm"
buildingConv["firestation"] = "firestation"
buildingConv["museum"] = "museum"
buildingConv["college"] = "college"
buildingConv["recreation"] = "recreation"
buildingConv["grocery"] = "grocery"
buildingConv["courthouse"] = "courthouse"
buildingConv["government"] = "government"
buildingConv["police"] = "policestation"
buildingConv["storage"] = "storage"
buildingConv["visitorcenter"] = "visitorcenter"
buildingConv["prison"] = "prison"
buildingConv["pharmacy"] = "pharmacy"
buildingConv["dormitory;university"] = "dormitory" #
buildingConv["service"] = "service"
buildingConv["stable"] = "stable"
buildingConv["boathouse"] = "boathouse"
buildingConv["Clarifiers"] = "building" # ?
buildingConv["civic"] = "civic"
buildingConv["stadium"] = "stadium"
buildingConv["parking"] = "parking"
buildingConv["data_center"] = "building"  # ?
buildingConv["apartment"] = "apartment"
buildingConv["hardware"] = "hardware"
buildingConv["bleachers"] = "bleachers"
buildingConv["transportation"] = "transportation"
buildingConv["stands"] = "stands"
buildingConv["ruins"] = "ruins"
buildingConv["trainstation"] = "trainstation"
buildingConv["boat"] = "boat"
buildingConv["campground"] = "campground"
buildingConv["tower"] = "tower"
buildingConv["convenience"] = "convenience"
buildingConv["terminal"] = "terminal"
buildingConv["university;apartment"] = "college" #
buildingConv["Storage_Building"] = "storage"
buildingConv["Restroom"] = "restroom" #
buildingConv["cinema"] = "cinema"
buildingConv["manufacture"] = "manufacture"
buildingConv["Public_Works"] = "public" #
buildingConv["grain_silo"] = "reservoir"
buildingConv["home"] = "building"  #?
buildingConv["Bowling_Alley_(Enter"] = "commercial" # ?
buildingConv["kiosk"] = "convenience" #
buildingConv["Dorm"] = "dormitory" # dorm
buildingConv["Club_House"] = "building" # ?
buildingConv["Transportation_Broke"] = "building" #?
buildingConv["hallway"] = "building"  # ?
buildingConv["location?"] = "building" # ?
buildingConv["maintenance_shop"] = "building" #?
buildingConv["underground"] = "building" #?
buildingConv["loading ramp"] = "ramp" # ?
buildingConv["Cow Creek Road"] = "building" # ?
buildingConv["gymnasium"] = "recreation" # recreation
buildingConv["uyes"] = "building" # no idea?

buildingConv["detached"] = "building" #
buildingConv["occupied"] = "building" #
buildingConv["duplex"] = "house" #
buildingConv["Dormitory"] = "dormitory" #


buildingConv["water_tower"] = "tower" #
buildingConv["tower"] = "tower"
buildingConv["granary"] = "reservior"
buildingConv["disused"] = "building" #
buildingConv["No"] = "building" #
buildingConv["convenience"] = "convenience"
buildingConv["yb"] = "building" #
buildingConv["sports_centre"] = "recreation" #
buildingConv["residential;retail"] = "building" #
buildingConv["theatre"] = "theatre"
buildingConv["bridge"] = "bridge"
buildingConv["backshop"] = "commercial" #?
buildingConv["Cafeteria"] = "cafeteria" #
buildingConv["Gymnasium"] = "recreation" #
buildingConv["Auditorium"] = "theatre" #
buildingConv["Music_Building"] = "building" #
buildingConv["Maintenance_Building"] = "building" #
buildingConv["shed_and_seasonal_re"] = "recreation" #
buildingConv["parsonage"] = "parsonage"
buildingConv["military"] = "military"
buildingConv["mental_health_clinic"] = "medical" #
buildingConv["corn_crib"] = "reservior" #
buildingConv["chicken_coop"] = "farm" #
buildingConv["ship"] = "ship"
buildingConv["gazebo"] = "gazebo"
buildingConv["pump_house"] = "building" #
buildingConv["mall"] = "mall"
buildingConv["amphitheatre"] = "theatre"
buildingConv["lodge"] = "lodge"
buildingConv["maintenance"] = "maintenance"
buildingConv["clinic"] = "clinic"
buildingConv["factory"] = "factory"
buildingConv["carwash"] = "carwash"
buildingConv["commerical"] = "commerical"
buildingConv["abandoned"] = "abandoned"
buildingConv["billboard"] = "billboard"
buildingConv["concessions"] = "concessions"
buildingConv["Lighthouse_Carwash"] = "auto" #
buildingConv["cinema"] = "cinema"


buildingConv["outdoor_riding_arena"] = "recreation" #
buildingConv["ski_jump"] = "recreation" #
buildingConv["silo"] = "reservoir"
buildingConv["reservoir"] = "reservoir"
buildingConv["boathouse"] = "boathouse"
buildingConv["cinema"] = "cinema"
buildingConv["3"] = "building" #
buildingConv["temple"] = "temple"
buildingConv["brewery"] = "brewery"
buildingConv["Amoskeag_School"] = "school" #
buildingConv["bus_station"] = "busstation"
buildingConv["prison"] = "prison"
buildingConv["campground"] = "campground"
buildingConv["Ski_Jump"] = "recreation" #
buildingConv["radio_station"] = "radiostation" #
buildingConv["castle"] = "castle"
buildingConv["railway"] = "railway"
buildingConv["stadium"] = "stadium"
buildingConv["transportation"] = "transportation"
buildingConv["clubhouse"] = "clubhouse"
buildingConv["caboose"] = "caboose"
buildingConv["foundation"] = "foundation"
buildingConv["service"] = "service"
buildingConv["riding_hall"] = "recreation" #
buildingConv["tower"] = "tower"
buildingConv["residential_home_and"] = "house" #
buildingConv["barn_22_stalls"] = "barn" #

buildingConv["social_facility"] = "civic" #
buildingConv["main"] = "building" #
buildingConv["tower"] = "tower"
buildingConv["5"] = "building" #
buildingConv["drilling rig"] = "industrial" #
buildingConv["City_Services"] = "government" #

buildingConv["family_house"] = "house" #
buildingConv["railway_shed"] = "building" #
buildingConv["garages"] = "parking" #
buildingConv["tower_block"] = "tower" #
buildingConv["transmitter"] = "transmitter"
buildingConv["mil"] = "industrial" #
buildingConv["post office"] = "postoffice" #
buildingConv["strip mall"] = "mall" #
buildingConv["fire station"] = "firestation" #
buildingConv["swimming_pool"] = "recreation" #
buildingConv["House"] = "house" #
buildingConv["Yes"] = "building" #
buildingConv["sauna"] = "recreation" #

buildingConv["country_store"] = "convenience" #
buildingConv["grist_mill"] = "industrial" #
buildingConv["storage_units"] = "storage" #
buildingConv["power"] = "industrial" #
buildingConv["service_station"] = "fuel" #
buildingConv["cotton_gin"] = "industrial" #
buildingConv["rail_car"] = "building" #
buildingConv["apartment_office"] = "apartments" #
buildingConv["post_office"] = "postoffice"
buildingConv["city_hall"] = "civic" #
buildingConv["club_house"] = "recreation" #
buildingConv["municipal"] = "civic" #
buildingConv["commercial;yes"] = "commercial" #
buildingConv["Recreation"] = "recreation"
buildingConv["grange"] = "industrial" # 
buildingConv["abandoned"] = "building"
buildingConv["condominum"] = "condominum"
buildingConv["inn"] = "motel" #
buildingConv["railway_station"] = "railstation" #
buildingConv["mill"] = "industrial"#
buildingConv["Government"] = "government"
buildingConv["gazeebo"] = "gazeebo"
buildingConv["Historical_Caboose"] = "historical" #
buildingConv["sleeper_car"] = "historical" #
buildingConv["boxcar"] = "historical" #
buildingConv["train_wait_station"] = "railstation" #
buildingConv["car_repair"] = "auto"
buildingConv["company_store"] = "convenience"

buildingConv["Vacancy"] = "building" #
buildingConv["Shopping Center"] = "commercial" #
buildingConv["Dentist_Office"] = "medical" #
buildingConv["Manget Hall"] = "building" #
buildingConv["Bank"] = "bank" #

buildingConv["G"] = "building" #
buildingConv["Detached_Classroom"] = "school"
buildingConv["Pierce_County_Buildi"] = "government"
buildingConv["commercial;residenti"] = "commercial"
buildingConv["National_Guard"] = "government"
buildingConv["bridge;roof"] = "bridge"
buildingConv["Masonic"] = "building"
buildingConv["retail;shed;yes"] = "retail"
buildingConv["Tyler King's House"] = "building"
buildingConv["Retirement_Community"] = "apartments"
buildingConv["Clinic"] = "medical"
buildingConv["shed;retail"] = "building"
buildingConv["Security"] = "building"
buildingConv["Planetarium"] = "museum"
buildingConv["Theater,_Esvelt_Gall"] = "theatre"
buildingConv["ROO"] = "building"
buildingConv["Covered_Basketball_C"] = "recreation"
buildingConv["Firestone"] = "auto"
buildingConv["Sleep number, t-mobi"] = "commercial"

buildingConv["Yes,_College"] = "college"
buildingConv["Iona_College_Dorm"] = "dormitory"
buildingConv["Maintenence Shed"] = "buiding"
buildingConv["Skating_Rink"] = "recreation"
buildingConv["mixed use"] = "building"
buildingConv["Health_Center"] = "medical"
buildingConv["Leonard"] = "building"
buildingConv["yes;retail"] = "retail"
buildingConv["Fire_Department"] = "firestation"
buildingConv["bath house"] = "commercial"
buildingConv["FBO_hangar"] = "hangar"
buildingConv["Aircraft_Hangar"] = "hangar"
buildingConv["Bed_and_Breakfast"] = "commercial"
buildingConv["yes;fraternity_house"] = "fraternity"
buildingConv["Suite_212,_Waverly_P"] = "suites"
buildingConv["yes;college"] = "college"
buildingConv["commercial;greenhous"] = "commercial"
buildingConv["Abandoned"] = "building"
buildingConv["Playground"] = "recreation"
buildingConv["Lighthouse"] = "lighthouse"
buildingConv["Changing_rooms/bathr"] = "recreation"

buildingConv["stadium seating"] = "stadium"
buildingConv["covered area"] = "building"
buildingConv["Airport Terminal Bui"] = "airport"
buildingConv["Bing"] = "building"
buildingConv["school; roof; school"] = "school"
buildingConv["Water_Treatment_Faci"] = "industrial"
buildingConv["Public_Safety"] = "building"
buildingConv["Natatorium"] = "recreation"
buildingConv["Learning_Center/_Day"] = "commercial"
buildingConv["Courthouse"] = "courthouse"
buildingConv["Charitable_Organizat"] = "building"
buildingConv["school;yes"] = "school"
buildingConv["Main_Building"] = "building"
buildingConv["H"] = "building"
buildingConv["Kennels"] = "commercial"
buildingConv["church;yes"] = "church"
buildingConv["Horse_facility"] = "recreation"
buildingConv["Retail"] = "retail"

buildingConv["Academic_Building"] = "college"
buildingConv["Commercial"] = "commercial"
buildingConv["Student_Center"] = "college"
buildingConv["Administrative_Build"] = "college"
buildingConv["Government_Facility"] = "government"
buildingConv["Casa hermana"] = "building"
buildingConv["commercial;education"] = "commercial"
buildingConv["Gazebo"] = "gazebo"
buildingConv["Athletic_Center"] = "recreation"
buildingConv["Commercial,_House_of"] = "commercial"
buildingConv["Gas_Station"] = "fuel"
buildingConv["Store"] = "commercial"
buildingConv["Fire_Station"] = "firestation"
buildingConv["City_Government_Offi"] = "government"
buildingConv["Bar,_Golfcourse"] = "recreation"
buildingConv["Laundry"] = "commercial"
buildingConv["YWCA"] = "recreation"
buildingConv["YMCA"] = "recreation"
buildingConv["yes;roof"] = "building"
buildingConv["Office_and_Residenti"] = "apartments"
buildingConv["Residential_Real_Est"] = "apartments"
buildingConv["Army_National_Guard"] = "military"
buildingConv["Business"] = "commercial"
buildingConv["Police_Department"] = "policestation"
buildingConv["North Parking Garage"] = "parking"
buildingConv["Carriage Lane"] = "stables"

buildingConv["office;clubhouse"] = "commercial"
buildingConv["added building based"] = "building"
buildingConv["office;yes"] = "commercial"
buildingConv["clubhouse;gym"] = "recreation"
buildingConv["gym;clubhouse"] = "recreation"
buildingConv["Student Commons"] = "collgee"
buildingConv["Engine_house"] = "building"
buildingConv["feed barn"] = "barn"
buildingConv["Herrick_Memorial_Cha"] = "building"
buildingConv["Classroom"] = "school"
buildingConv["Laboratory_and_Class"] = "college"
buildingConv["Mechanical_Room"] = "industrial"
buildingConv["Mechanical_room"] = "industrial"
buildingConv["Los_Angeles_County_P"] = "building"
buildingConv["Zap_House"] = "building"
buildingConv["Bayview South"] = "building"
buildingConv["Kresge Lounge"] = "building"
buildingConv["Office"] = "commercial"
buildingConv["Private_Home_Owners_"] = "house"
buildingConv["Dispatch"] = "government"
buildingConv["Urban_Pioneer"] = "building"
buildingConv["Social_Hall"] = "building"
buildingConv["Hacienda Casita"] = "building"
buildingConv["Public_Use"] = "civic"
buildingConv["Historic"] = "historic"
buildingConv["apartments;commerica"] = "apartments"
buildingConv["Cultural_Center"] = "civic"
buildingConv["Learning_Resource_Ce"] = "commercial"
buildingConv["Administration_Build"] = "college"
buildingConv["Special_Programs_and"] = "building"
buildingConv["Student_Services-Cou"] = "college"
buildingConv["Student_Services_-_L"] = "college"
buildingConv["Interim_Performing_A"] = "college"
buildingConv["Technical(T)_Buildin"] = "industrial"
buildingConv["Maintenance_&_Operat"] = "industrial"
buildingConv["Fitness_Center"] = "recreation"
buildingConv["Science(S)_Building"] = "college"
buildingConv["Business(B)-Building"] = "college"
buildingConv["D-Building"] = "college"
buildingConv["Athletic_field_house"] = "recreation"
buildingConv["Cabin"] = "house"
buildingConv["from old sat image"] = "building"
buildingConv["Museum"] = "museum"
buildingConv["Long_Beach_Public_Li"] = "library"
buildingConv["house; commercial"] = "commercial"
buildingConv["Structure added, not"] = "building"
buildingConv["residential;house"] = "house"
buildingConv["Rangeview_Dormitory"] = "dormitory"
buildingConv["commercial;house"] = "commercial"
buildingConv["yes;retail;commercia"] = "commercial"
buildingConv["razed building"] = "building"
buildingConv["Home"] = "house"
buildingConv["yes;office"] = "commercial"

buildingConv["Dugout"] = "recreation"
buildingConv["Hardware"] = "hardware"
buildingConv["University_Office_Bu"] = "college"
buildingConv["Boat_House"] = "recreation"
buildingConv["Station"] = "building"
buildingConv["Hotel/Motel"] = "motel"
buildingConv["Park_Maintenance"] = "recreation"
buildingConv["university library"] = "college"

buildingConv["Brewery"] = "brewery"
buildingConv["Ice_Skating_Rink"] = "recreation"
buildingConv["Skyway"] = "building"
buildingConv["Liquor_Store"] = "commercial"
buildingConv["commercial;apartment"] = "commercial"
buildingConv["Outdoor_Stage"] = "theatre"
buildingConv["Resort"] = "commercial"
buildingConv["Motel_And_RV_Park"] = "motel"
buildingConv["Drive_Through"] = "fastfood"
buildingConv["yes;terrace;house"] = "house"

buildingConv["block house"] = "house"
buildingConv["Red_Barn"] = "barn"
buildingConv["School"] = "school"
buildingConv["Cafe"] = "commercial"

buildingConv["storage tank"] = "reservoir"
buildingConv["detached;yes"] = "building"
buildingConv["university;yes"] = "college"
buildingConv["Gym"] = "recreation"
buildingConv["shopping center"] = "commercial"
buildingConv["Forum"] = "theatre"
buildingConv["Religious"] = "church"
buildingConv["Medical"] = "medical"
buildingConv["Office_Building"] = "commercial"
buildingConv["Nursery_School"] = "school"
buildingConv["retail; yes"] = "retail"
buildingConv["Apartment_Homes"] = "apartments"
buildingConv["retail;residential"] = "retail"
buildingConv["Mixed_use"] = "building"
buildingConv["Mixed_Use"] = "building"
buildingConv["Bath_House"] = "recreation"
buildingConv["Military"] = "military"
buildingConv["Maestro's Cafe"] = "restaurant"
buildingConv["Turf_Field"] = "recreation"
buildingConv["residential;commerci"] = "commercial"
buildingConv["Kwick_Stop_Coin_Op_L"] = "convenience"
buildingConv["yes;church"] = "church"
buildingConv["yes;terrace"] = "house"
buildingConv["yes;garage"] = "parking"
buildingConv["sports_centre;yes"] = "recreation"

buildingConv["Educational"] = "school"
buildingConv["Residential_co-op"] = "residential"
buildingConv["Spartan_Stadium"] = "stadium"
buildingConv["Roof"] = "building"
buildingConv["Abandoned_House"] = "house"
buildingConv["Convent"] = "church"
buildingConv["parking structure"] = "parking"
buildingConv["Gym"] = "recreation"
buildingConv["Venue/Barn"] = "barn"
buildingConv["John Johnston House"] = "historical"

buildingConv["garage;house"] = "house"
buildingConv["house;garage"] = "house"
buildingConv["shed;house"] = "house"
buildingConv["Market"] = "grocery"
buildingConv["Grocery"] = "grocery"
buildingConv["Chabad_House"] = "historical"
buildingConv["Pavilion & Rest Room"] = "building"
buildingConv["contamination cell"] = "building"
buildingConv["yes;hospital"] = "medical"
buildingConv["shed;garage;house"] = "house"
buildingConv["shed;yes"] = "shed"
buildingConv["roof;hotel"] = "hotel"
buildingConv["Some_kind_of_structu"] = "building"
buildingConv["retail;yes"] = "retail"

buildingConv["ATM"] = "atm"
buildingConv["carport;garage"] = "house"
buildingConv["garage;shed"] = "parking"
buildingConv["house;carport"] = "house"

buildingConv["Residence_Hall"] = "dormitory"
buildingConv["retail; apartments"] = "apartments"
buildingConv["Depot"] = "reservoir"
buildingConv["Salt_Shed"] = "shed"
buildingConv["Shelter"] = "building"
buildingConv["commercial; condomin"] = "commercial"
buildingConv["yes;shed"] = "shed"
buildingConv["Clubhouse"] = "recreation"
buildingConv["Meat_Locker"] = "commercial"

buildingConv["college;yes"] = "college"
buildingConv["retail;roof"] = "retail"
buildingConv["Aquarium"] = "museum"
buildingConv["funeral home"] = "commercial"
buildingConv["Recreation_Center"] = "recreation"
buildingConv["Stan Hywet Hall Gree"] = "college"
buildingConv["Stan Hywet Hall Entr"] = "college"
buildingConv["Shelter_House"] = "college"
buildingConv["Ohio_University"] = "college"
buildingConv["warehouse;yes"] = "industrial"
buildingConv["industrial;yes"] = "industrial"
buildingConv["yes;hotel"] = "hotel"
buildingConv["LCC Trap House"] = "college"
buildingConv["gas station"] = "fuel"
buildingConv["Retail_Stand"] = "retail"
buildingConv["retirement home"] = "apartments"

buildingConv["gazebo;roof"] = "gazebo"
buildingConv["propane tank"] = "reservoir"
buildingConv["roof;public"] = "civic"
buildingConv["roof;office"] = "commercial"
buildingConv["roof;retail"] = "retail"
buildingConv["Meat_Packing"] = "industrial"
buildingConv["Slaughter_House"] = "industrial"
buildingConv["Meat_Processing"] = "industrial"
buildingConv["Mail_box_shed"] = "building"
buildingConv["Fraternity"] = "fraternity"
buildingConv["Ranch"] = "farm"
buildingConv["Lodge"] = "motel"
buildingConv["AMC Painting"] = "commercial"
buildingConv["Natural Grocers"] = "grocery"
buildingConv["Jiffy Lube"] = "auto"
buildingConv["IHOP"] = "fastfood"
buildingConv["apartments;office"] = "apartments"
buildingConv["Dining Hall"] = "college"

buildingConv["Kennel"] = "commercial"
buildingConv["Historical_House"] = "historical"

buildingConv["yes;commercial"] = "commercial"
buildingConv["retail;commercial"] = "commercial"
buildingConv["parking garage"] = "parking"
buildingConv["Tower 1"] = "tower"
buildingConv["tower 2"] = "tower"
buildingConv["NASA"] = "government"
buildingConv["John_McLain_LBRA Leg"] = "building"
buildingConv["Yes,_theme_park"] = "themepark"
buildingConv["Mobile Home"] = "house"
buildingConv["yes;motel"] = "motel"
buildingConv["yes;hotel;roof"] = "hotel"
buildingConv["Oratory"] = "theatre"
buildingConv["commercial;hangar;ye"] = "commercial"
buildingConv["hut;gazebo"] = "gazebo"
buildingConv["house;yes"] = "house"
buildingConv["tower 3"] = "tower"
buildingConv["House 1"] = "house"
buildingConv["Outside_seating_and_"] = "theatre"

buildingConv["Hanger"] = "hanger"
buildingConv["XP_&_FALCON_Hanger"] = "hanger"

buildingConv["fire department"] = "firestation"
buildingConv["Gate_House"] = "house"
buildingConv["Science Incubator"] = "building"
buildingConv["Healthrax"] = "medical"
buildingConv["University Doctors"] = "medical"
buildingConv["Urology Stuite"] = "medical"
buildingConv["Cardiology and Orthr"] = "medical"
buildingConv["Beacon Academy"] = "school"
buildingConv["Surgical Plus"] = "medical"
buildingConv["Nose and Sinus Cente"] = "medical"
buildingConv["Rehabilitation_Cente"] = "medical"
buildingConv["Day Care"] = "school"
buildingConv["Medical Holding Buil"] = "medical"
buildingConv["dormitory;yes"] = "dormitory"
buildingConv["Fire station"] = "firestation"
buildingConv["Borough Hall"] = "college"
buildingConv["Utilities"] = "industrial"
buildingConv["The Hangar"] = "hangar"
buildingConv["Elmer Times"] = "building"
buildingConv["Elmer Diner"] = "building"
buildingConv["Papa Luigi's"] = "restaurant"
buildingConv["Tractor supply"] = "commercial"
buildingConv["Elmer Post Office"] = "postoffice"
buildingConv["coffee shop"] = "fastfood"
buildingConv["Verizon Building"] = "commercial"
buildingConv["Fred Harz"] = "building"
buildingConv["antique auto repair"] = "auto"
buildingConv["schalick Tower"] = "tower"
buildingConv["government office"] = "government"
buildingConv["row homes"] = "house"
buildingConv["Tennis_courts"] = "recreation"
buildingConv["Municipal"] = "civic"
buildingConv["Picnic Pavilion"] = "civic"
buildingConv["Fire_House"] = "firestation"
buildingConv["Physical Plant (PP)"] = "industrial"
buildingConv["Lakeland Bank Pavili"] = "civic"
buildingConv["Rescue_Squad"] = "civic"
buildingConv["Tech 4"] = "building"
buildingConv["Tech 3"] = "building"
buildingConv["Morgan_Stanley_Data_"] = "commercial"

buildingConv["Art_Building"] = "college"
buildingConv["Pool_House"] = "building"
buildingConv["school, office"] = "school"
buildingConv["Composting_System"] = "industrial"
buildingConv["Under_Construction"] = "building"
buildingConv["Condominium"] = "apartments"

buildingConv["1500"] = "building"

buildingConv["childcare facility"] = "school"

buildingConv["yes;university"] = "college"
buildingConv["Student_Union"] = "college"
buildingConv["changing rooms"] = "recreation"
buildingConv["Pump House"] = "industrial"
buildingConv["gas pumps"] = "auto"
buildingConv["apartments;yes"] = "apartments"
buildingConv["apartments;bridge"] = "apartments"
buildingConv["Healthcare"] = "medical"
buildingConv["Pavilion"] = "theatre"
buildingConv["Rest_Area"] = "restarea"
buildingConv["Utility_Suubstation"] = "industrial"
buildingConv["Salon"] = "commercial"
buildingConv["Covered_Arena"] = "building"
buildingConv["Classrooms"] = "school"
buildingConv["Campus_Clinic,_Offic"] = "college"
buildingConv["Offices_&_Classrooms"] = "school"
buildingConv["Auditorium_&_Gym"] = "recreation"
buildingConv["Chufeteria_&_Offices"] = "building"
buildingConv["Library_&_Offices"] = "library"
buildingConv["Pre-School,_Offices_"] = "school"
buildingConv["Supplies"] = "commercial"
buildingConv["Maintenance"] = "industrial"
buildingConv["Theater"] = "theatre"
buildingConv["Dormitory_&_Classroo"] = "dormitory"
buildingConv["Heiau"] = "buiding"
buildingConv["Boxing_Gym"] = "recreation"
buildingConv["industrial hanger 13"] = "hanger"
buildingConv["hotel;apartments"] = "apartments"
buildingConv["Lucky Friday"] = "building"
buildingConv["apartments;yes"] = "apartments"
buildingConv["Department_Building"] = "building"
buildingConv["Lucky Dog"] = "building"
buildingConv["Faraday Hall"] = "college"
buildingConv["Yoga_Studio"] = "recreation"
buildingConv["Residential,_busines"] = "residential"
buildingConv["under construction"] = "building"
buildingConv["commercial;roof"] = "commercial"
buildingConv["barn;garage"] = "barn"
buildingConv["ruins;barn"] = "ruins"
buildingConv["office;company"] = "commercial"
buildingConv["commercial;office"] = "commercial"
buildingConv["Office_Space"] = "commercial"
buildingConv["Rec_Center"] = "recreation"
buildingConv["R3 Environmental"] = "commercial"
buildingConv["Mausoleum"] = "cemetary"
buildingConv["church;commercial"] = "church"
buildingConv["Hotel"] = "hotel"
buildingConv["Fort"] = "military"
buildingConv["library;yes"] = "library"
buildingConv["VFW"] = "military"
buildingConv["Kuipers Family Farm"] = "farm"
buildingConv["Funeral Home"] = "commercial"
buildingConv["trailer park"] = "residential"
buildingConv["Library"] = "library"
buildingConv["yes;yess"] = "building"
buildingConv["Mall"] = "mall"
buildingConv["commercial;service"] = "commercial"
buildingConv["Engineering_Building"] = "college"
buildingConv["Grounds"] = "building"
buildingConv["Nature-Center"] = "building"
buildingConv["Part_of_a_Business_C"] = "college"
buildingConv["Fraternal institutio"] = "building"
buildingConv["commercial;appartmen"] = "commercial"
buildingConv["group housing"] = "house"
buildingConv["Group Housing"] = "house"
buildingConv["historical house"] = "historical"
buildingConv["Hackerspace"] = "building"
buildingConv["office;commercial"] = "commercial"
buildingConv["Multi-tennant_Commer"] = "commercial"
buildingConv["Administrative_and_R"] = "school"
buildingConv["Utility"] = "industrial"
buildingConv["barn;house"] = "barn"
buildingConv["yes;government"] = "government"
buildingConv["Stands"] = "recreation"
buildingConv["Recording_Studio/Bar"] = "restaurant"
buildingConv["Car_Dealership"] = "commercial"
buildingConv["Home_Office"] = "house"
buildingConv["Fire_department"] = "firestation"
buildingConv["Law_Office"] = "commercial"
buildingConv["Refinery"] = "industrial"
buildingConv["Alan"] = "building"
buildingConv["Madison City Hall"] = "government"
buildingConv["boat storage house"] = "recreation"
buildingConv["roof;residential"] = "residential"
buildingConv["Livestock_Barn"] = "barn"
buildingConv["Instructional"] = "school"
buildingConv["concession stand"] = "recreation"
buildingConv["middle school"] = "school"
buildingConv["Medical Office"] = "medical"
buildingConv["University_Police_Of"] = "college"
buildingConv["Stable"] = "stable"
buildingConv["water treatment"] = "industrial"
buildingConv["Public_use"] = "civic"
buildingConv["apartments (2nd floo"] = "apartments"
buildingConv["Clothing"] = "retail"
buildingConv["Middle_School"] = "school"
buildingConv["Monument"] = "monument"
buildingConv["Ormiston"] = "building"
buildingConv["Campus_Library"] = "college"
buildingConv["Dining/Instructional"] = "building"
buildingConv["garage;yes"] = "parking"
buildingConv["residential;roof"] = "residential"
buildingConv["Sheffield_School_Com"] = "school"
buildingConv["High School"] = "school"
buildingConv["John Bartram's House"] = "historical"
buildingConv["Terminal A JetBlue P"] = "airport"
buildingConv["commercial;hotel"] = "commercial"
buildingConv["Industrial_Building"] = "industrial"
buildingConv["Building_can_be_seen"] = "building"
buildingConv["apartments;garages"] = "apartments"
buildingConv["hospital;roof"] = "medical"
buildingConv["Old_Wentworth_Elevat"] = "building"

buildingConv["Storage Units"] = "storage"
buildingConv["Townhome"] = "house"
buildingConv["ice rink"] = "recreation"
buildingConv["Spring Branch Home"] = "house"
buildingConv["Liberty Dialysis"] = "medical"
buildingConv["ski lodge"] = "recreation"
buildingConv["RV"] = "auto"
buildingConv["Townhouse"] = "house"
buildingConv["Airport"] = "airport"
buildingConv["business/Kavanaugh C"] = "commercial"
buildingConv["business/Food City,"] = "grocery"
buildingConv["Cuz's Tobacco"] = "commercial"
buildingConv["laundry mat"] = "laundry"
buildingConv["Rite-Aide"] = "convenience"
buildingConv["Advanced Auto Parts"] = "auto"
buildingConv["yes;hut"] = "building"
buildingConv["Telescope_Dome"] = "building"
buildingConv["Telescope_dome"] = "building"
buildingConv["Shoe_Attic,_Chef's_K"] = "commercial"
buildingConv["ROOF"] = "building"
buildingConv["Pumping_Station"] = "industrial"
buildingConv["Kiosk"] = "convenience"
buildingConv["Police Station"] = "policestation"
buildingConv["New Education Buildi"] = "college"
buildingConv["Mitchum Basketball P"] = "recreation"
buildingConv["Crime_Fighters_Car_W"] = "auto"
buildingConv["parking lot"] = "parking"

buildingConv["poultry_house"] = "farm"
buildingConv["mobile_home"] = "house"
buildingConv["mixed_use"] = "building"
buildingConv["parking_garage"] = "parking"
buildingConv["strip_mall"] = "mall"
buildingConv["lifeguard_tower"] = "tower"
buildingConv["central_office"] = "building"
buildingConv["shopping_center"] = "commercial"
buildingConv["trailer_park"] = "residential"
buildingConv["university_apartment"] = "dormitory"
buildingConv["farm_auxiliary"] = "farm"
buildingConv["gas_station"] = "fuel"
buildingConv["nursing_home"] = "apartments"
buildingConv["car_park"] = "auto"
buildingConv["stadium_seating"] = "stadium"
buildingConv["convention_center"] = "civic"
buildingConv["chicken_house"] = "farm"
buildingConv["boat_house"] = "recreation"
buildingConv["train_station"] = "trainstation"
buildingConv["place_of_worship"] = "church"
buildingConv["manufactured_home"] = "house"
buildingConv["camp_site"] = "recreation"
buildingConv["yes;roof"] = "building"
buildingConv["community_center"] = "civic"
buildingConv["floating_home"] = "house"
buildingConv["storage_tank"] = "reservoid"
buildingConv["main_terminal"] = "airport"
buildingConv["police_station"] = "policestation"
buildingConv["funeral_home"] = "commercial"
buildingConv["salt_dome"] = "reservoir"
buildingConv["pumping_station"] = "industrial"
buildingConv["control_tower"] = "tower"
buildingConv["power_station"] = "industrial"
buildingConv["historic_building"] = "historical"
buildingConv["cargo_terminal"] = "airport"
buildingConv["self_storage"] = "storage"
buildingConv["turning_circle"] = "road"
buildingConv["convention_centre"] = "civic"
buildingConv["printing_facility"] = "commercial"
buildingConv["shooting_stand"] = "recreation"
buildingConv["power_plant"] = "industrial"
buildingConv["fast_food"] = "fastfood"
buildingConv["water_tank"] = "reservoir"
buildingConv["exterior_walls_only"] = "building"
buildingConv["field_house"] = "recreation"
buildingConv["nonprofit_center"] = "building"
buildingConv["guy_wire_anchor"] = "building"
buildingConv["judging_booth"] = "building"
buildingConv["sports_complex"] = "recreation"
buildingConv["exhibition_hall"] = "civic"
buildingConv["drive_in_theatre"] = "theatre"
buildingConv["restored_replica"] = "building"
buildingConv["grocery_store"] = "grocery"
buildingConv["train_car"] = "building"
buildingConv["sports_hall"] = "recreation"
buildingConv["group_housing"] = "apartments"
buildingConv["wayside_shrine"] = "church"
buildingConv["garbage_shed"] = "industrial"
buildingConv["tech_cab"] = "building"
buildingConv["private_residence"] = "house"
buildingConv["retirement_home"] = "apartments"
buildingConv["concession_stand"] = "recreation"
buildingConv["art_studio"] = "commercial"
buildingConv["burial_vault"] = "cemetary"
buildingConv["airport_terminal"] = "airport"
buildingConv["engine_house"] = "industrial"
buildingConv["recreation_ground"] = "recreation"
buildingConv["sport_stand"] = "recreation"
buildingConv["conference_center"] = "civic"
buildingConv["dog_house"] = "building"
buildingConv["private_company"] = "commercial"
buildingConv["roof;yes"] = "building"
buildingConv["office;roof"] = "commercial"
buildingConv["Commercial"] = "commercial"
buildingConv["hangar_101"] = "hangar"
buildingConv["hangar_104"] = "hangar"
buildingConv["hangar_103"] = "hangar"
buildingConv["basketball_gym,_gymn"] = "recreation"
buildingConv["recreation_center"] = "recreation"
buildingConv["loading_dock"] = "recreation"
buildingConv["transformer_tower"] = "tower"
buildingConv["roof_overhang"] = "building"
buildingConv["rec_center"] = "building"
buildingConv["repair_shops"] = "commercial"
buildingConv["parking_structure"] = "parking"
buildingConv["multi_office"] = "commercial"
buildingConv["toll_booth"] = "road"
buildingConv["3425_Hilltop_Ave"] = "building"
buildingConv["community_centre"] = "civic"
buildingConv["future_classrooms"] = "school"
buildingConv["activity_center"] = "recreation"
buildingConv["pool_house"] = "recreation"
buildingConv["hall_of_residence"] = "dormitory"
buildingConv["academic_building"] = "college"
buildingConv["bus_stop"] = "busstop"
buildingConv["flour_mill"] = "industrial"
buildingConv["textile_mill"] = "industrial"
buildingConv["fixed_base_opperator"] = "building"
buildingConv["country_club"] = "recreation"
buildingConv["indoor_swimming_pool"] = "recreation"
buildingConv["partially_destroyed"] = "building"
buildingConv["outdoor_risers"] = "building"
buildingConv["dancing_school"] = "commercial"
buildingConv["university,office"] = "college"
buildingConv["waste_disposal"] = "industrial"
buildingConv["sugar_shack"] = "industrial"
buildingConv["data_centre"] = "commercial"
buildingConv["yes_but_the_burgee_b"] = "building"
buildingConv["food_and_drink"] = "fastfood"
buildingConv["derelict,_uninhabite"] = "building"
buildingConv["fire_department"] = "firestation"
buildingConv["aircraft_hangar"] = "hangar"
buildingConv["banquet_hall"] = "civic"
buildingConv["guard_shack"] = "military"
buildingConv["hangar_105"] = "hangar"
buildingConv["hangar_102"] = "hangar"
buildingConv["steam_plant"] = "industrial"
buildingConv["arts_centre"] = "civic"
buildingConv["amusement_ride"] = "recreation"
buildingConv["loafing_shed"] = "building"
buildingConv["observation_tower"] = "tower"
buildingConv["multi_level_parking"] = "parking"
buildingConv["rental_office"] = "building"
buildingConv["multi_purpose"] = "building"
buildingConv["meeting_room"] = "building"
buildingConv["laundry_room"] = "building"
buildingConv["press_box"] = "stadium"
buildingConv["mixd_use"] = "building"
buildingConv["gathering_place"] = "public"
buildingConv["snack_bar"] = "fastfood"
buildingConv["shipping_container"] = "industrial"
buildingConv["hunting_stand"] = "recreation"
buildingConv["day_care,_community_"] = "school"
buildingConv["hunting,_fishing,_ca"] = "recreation"
buildingConv["yes,_public_restroom"] = "public"
buildingConv["yes,_restroom_and_sh"] = "public"
buildingConv["health_House"] = "medical"
buildingConv["subway_entrance"] = "trainstation"
buildingConv["health_clinic"] = "medical"
buildingConv["bird_cages"] = "farm"
buildingConv["yes,_cabin"] = "house"
buildingConv["baseball_dugout"] = "recreation"
buildingConv["town_hall"] = "civic"
buildingConv["gate_house"] = "building"
buildingConv["bath_house"] = "recreation"
buildingConv["rest_room"] = "public"
buildingConv["bed_and_breakfast"] = "house"
buildingConv["fire_hydrant"] = "building"
buildingConv["aircraft_hanger"] = "hangar"
buildingConv["former_train_station"] = "trainstation"
buildingConv["drive-thru_atm"] = "bank"
buildingConv["public_restrooms"] = "public"
buildingConv["outdoor_structure"] = "building"
buildingConv["food_truck"] = "fastfood"
buildingConv["picnic_shelter"] = "public"
buildingConv["carriage_house"] = "barn"
buildingConv["police_dept"] = "policestation"
buildingConv["yes,_house,_resident"] = "house"
buildingConv["decorative_free_stan"] = "building"
buildingConv["commercial,_storage"] = "storage"
buildingConv["earthen_building"] = "building"
buildingConv["scoring_box"] = "recreation"
buildingConv["cow_barn"] = "barn"
buildingConv["changing_room"] = "public"
buildingConv["tree_house"] = "recreation"
buildingConv["yes,_house"] = "house"
buildingConv["television_station"] = "commercial"
buildingConv["amenity_center"] = "public"
buildingConv["car_wash"] = "auto"
buildingConv["potato_barn"] = "barn"
buildingConv["burned_down"] = "ruins"
buildingConv["weather_shelter"] = "building"
buildingConv["station_building"] = "building"
buildingConv["boiler_house"] = "industrial"
buildingConv["fee_booth"] = "road"
buildingConv["college_building"] = "college"
buildingConv["static_mobile_home"] = "house"
buildingConv["shed,_detached"] = "house"
buildingConv["parish_hall"] = "college"
buildingConv["storage_facility"] = "storage"
buildingConv["bus_shelter"] = "busstation"
buildingConv["salt_barn"] = "barn"
buildingConv["heritage_building"] = "college"
buildingConv["archaeological_site"] = "historical"
buildingConv["Historical"] = "historical"
buildingConv["Medical_Office"] = "medical"

buildingConv["None"] = "building"
buildingConv["farm_auxiliary"] = "farm"
buildingConv["train_station"] = "trainstation"
buildingConv["yes;roof"] = "building"
buildingConv["Ngroceryone"] = "grocery"
buildingConv["storage_tank"] = "reservior"
buildingConv["roof;yes"] = "building"
buildingConv["office;roof"] = "commercial"
buildingConv["Commercial"] = "commercial"
buildingConv["Historical"] = "historical"
buildingConv["Medical_Office"] = "medical"


_ = clock("Last Run")
# Out:
# Current Time is Mon Sep 17, 2018 15:12:48 for Last Run

# %%
commerce = {}
commerce["Wawa"] = "convenience"
commerce["McDonald's"] = "fastfood"
commerce["M&T Bank"] = "bank"
commerce["Walgreens"] = "pharmacy"
commerce["Burger King"] = "fastfood"
commerce["Dollar General"] = "retail"
commerce["Rite Aid"] = "pharmacy"
commerce["Arby's"] = "fastfood"
commerce["Shell"] = "fuel"
commerce["Applebee’s Neighborhood Grill & Bar"] = "restaurant"
commerce["Wells Fargo"] = "bank"
commerce["Lowe's"] = "hardware"
commerce["PNC Bank"] = "bank"
commerce["Hardee's"] = "fastfood"
commerce["Food Lion"] = "grocery"
commerce["Valero"] = "fuel"
commerce["WSFS Bank"] = "bank"
commerce["Giant"] = "grocery"
commerce["Dunkin' Donuts"] = "fastfood"
commerce["Long Neck Apartments"] = "apartments"
commerce["Grotto Pizza"] = "restaurant"
commerce["Home Depot"] = "retail"
commerce["7-Eleven"] = "convenience"
commerce["Advance Auto Parts"] = "auto"
commerce["Friendly's"] = "restaurant"
commerce["Ruby Tuesday"] = "restaurant"
commerce["BP"] = "fuel"
commerce["Verizon Wireless"] = "retail"
commerce["Citizens Bank"] = "bank"
commerce["Starbucks"] = "fastfood"
commerce["Atlantic Auto Repair"] = "auto"
commerce["Taco Bell"] = "fastfood"
commerce["AutoZone"] = "auto"
commerce["Bob Evans"] = "restaurant"
commerce["Fulton Bank"] = "bank"
commerce["KFC"] = "fastfood"
commerce["Dairy Queen"] = "fastfood"
commerce["TD Bank"] = "bank"
commerce["Family Dollar"] = "retail"
commerce["Wendy's"] = "fastfood"
commerce["Popeye's"] = "fastfood"
commerce["Tidemark Federal Credit Union"] = "bank"
commerce["County Bank"] = "bank"
commerce["Grace United Methodist Church"] = "church"
commerce["Verizon"] = "retail"

commerce["AT&T"] = "retail"

commerce["Hampton Inn"] = "hotel"
commerce["CVS Pharmacy"] = "pharmacy"
commerce["Gas Station"] = "fuel"
commerce["Holiday Inn Express"] = "hotel"
commerce["Auto Zone"] = "auto"
commerce["Sunoco"] = "fuel"
commerce["Shore Stop"] = "retail"
commerce["Nature Center"] = "grocery"
commerce["Kmart"] = "retail"
commerce["New Castle Court House Museum"] = "museum"
commerce["Nicola Pizza"] = "restaurant"
commerce["Kohl's"] = "retail"

commerce["CVS/Pharmacy"] = "pharmacy"
commerce["Domino's Pizza"] = "restaurant"
commerce["Walmart Supercenter"] = "retail"
commerce["Big Lots"] = "retail"
commerce["Lowes"] = "hardware"
commerce["IHOP"] = "restaurant"
commerce["Dunkin Donuts"] = "fastfood"
commerce["Pizza King"] = "restaurant"
commerce["Motel 6"] = "motel"

commerce["WSFS"] = "bank"
commerce["Comfort Suites"] = "motel"
commerce["Save-A-Lot"] = "retail"
commerce["Manlove Auto Parts"] = "auto"
commerce["Wash N Vac Car Wash"] = "auto"
commerce["Mattress Firm"] = "retail"
commerce["Diamond Furniture"] = "retail"
commerce["Bear Tire and Service"] = "auto"
commerce["Fuddruckers;Dunkin Donuts"] = "fastfood"
commerce["Courtyard Wilmington Brandywine"] = "hotel"
commerce["INN at Wilmington"] = "hotel"
commerce["Casual Carpets"] = "retail"
commerce["Safeway 4030"] = "grocery"

commerce["Pizza Hut"] = "restaurant"
commerce["Subway"] = "fastfood"
commerce["Oak Tree Inn"] = "motel"
commerce["Quality Inn"] = "motel"
commerce["Antler Inn"] = "motel"
commerce["O'Reilly Auto Parts"] = "auto"
commerce["NAPA Auto Parts"] = "auto"
commerce["Taco John's"] = "fastfood"
commerce["Days Inn"] = "motel"
commerce["Anglers Inn"] = "motel"
commerce["Warren Federal Credit Union"] = "bank"
commerce["Safeway"] = "grocery"
commerce["Holiday Inn"] = "hotel"
commerce["Albertsons"] = "grocery"
commerce["Chevron"] = "fuel"
commerce["Comfort Inn & Suites"] = "motel"
commerce["Parkway Inn"] = "motel"
commerce["Sears"] = "retail"
commerce["Post Office"] = "postoffice"
commerce["Menards"] = "retail"
commerce["Perkins"] = "restaurant"
commerce["Kwik Shop"] = "convenience"
commerce["US Post Office"] = "postoffice"
commerce["H&R Block"] = "commercial"
commerce["Big O Tires"] = "auto"
commerce["Taco Time"] = "fastfood"
commerce["Eastridge Mall"] = "mall"
commerce["Smith's Food and Drug"] = "grocery"
commerce["Safeway 0461"] = "grocery"
commerce["K-Mart"] = "retail"
commerce["Walgreen's"] = "pharmacy"
commerce["Walgreens Pharmacy"] = "pharmacy"
commerce["McDonald's Hamburgers"] = "fastfood"
commerce["Hampton Inn"] = "motel"
commerce["La Quinta Inn"] = "motel"
commerce["Outback Steakhouse"] = "restaurant"
commerce["Barnes & Noble"] = "retail"
commerce["Culver's"] = "fastfood"
commerce["Best Western"] = "motel"
commerce["Super 8"] = "motel"

commerce["Waffle House"] = "restaurant"
commerce["CVS"] = "pharmacy"
commerce["Zaxby's"] = "fastfood"
commerce["Publix"] = "grocery"
commerce["Whataburger"] = "fastfood"
commerce["BBVA Compass"] = "bank"
commerce["Sonic"] = "fastfood"
commerce["Chick-fil-A"] = "fastfood"
commerce["Jack's"] = "fastfood"
commerce["Piggly Wiggly"] = "grocery"
commerce["Sam's Club"] = "grocery"
commerce["Express Oil Change & Tire Engineers"] = "auto"
commerce["Circle K"] = "convenience"
commerce["Winn-Dixie"] = "grocery"
commerce["O'Charley's"] = "restaurant"
commerce["Target"] = "retail"
commerce["Krystal"] = "fastfood"
commerce["Captain D's"] = "fastfood"
commerce["Popeyes Louisiana Kitchen"] = "fastfood"
commerce["Winn Dixie"] = "grocery"
commerce["Papa John's"] = "restaurant"
commerce["Olive Garden"] = "restaurant"
commerce["Krispy Kreme"] = "fastfood"
commerce["Cracker Barrel"] = "restaurant"
commerce["Texaco"] = "fuel"
commerce["Longhorn Steakhouse"] = "restaurant"
commerce["Walmart Neighborhood Market"] = "retail"
commerce["Panera Bread"] = "restaurant"
commerce["Pep Boys"] = "auto"
commerce["Costco"] = "grocery"
commerce["Bojangles"] = "restaurant"
commerce["Hobby Lobby"] = "retail"
commerce["Texas Roadhouse"] = "restaurant"
commerce["Shoney's"] = "restaurant"
commerce["Exxon"] = "fuel"
commerce["Golden Corral"] = "restaurant"
commerce["Chili's"] = "restaurant"
commerce["Aldi"] = "grocery"
commerce["La Quinta"] = "motel"
commerce["Steak 'n Shake"] = "fastfood"
commerce["Belk"] = "retail"
commerce["Five Guys"] = "fastfood"
commerce["Old Navy"] = "retail"
commerce["The Home Depot"] = "hardware"
commerce["Chick-fil-a"] = "fastfood"
commerce["Goodyear"] = "auto"
commerce["U-Haul"] = "auto"
commerce["Howard Johnson"] = "motel"
commerce["Parking Garage"] = "parking"
commerce["YMCA"] = "center"
commerce["Pro Shop"] = "retail"
commerce["La-Z-Boy"] = "retail"
commerce["JCPenney"] = "retail"
commerce["AAMCO Transmissions & Total Car Care"] = "auto"

commerce["Popeyes Louisiana Chicken"] = "fastfood"

commerce["Phillips 66"] = "fuel"
commerce["The Fresh Market"] = "grocery"
commerce["Moe's Southwest Grill"] = "restaurant"
commerce["Best Buy"] = "retail"
commerce["Checkers"] = "restaurant"
commerce["Mellow Mushroom"] = "restaurant"
commerce["Little Caesars"] = "restaurant"
commerce["Church's Chicken"] = "fastfood"
commerce["China Buffet"] = "fastfood"
commerce["ABC Beverages"] = "grocery"
commerce["Red Lobster"] = "restaurant"
commerce["Ross"] = "retail"
commerce["Fuel City"] = "fuel"
commerce["Administrative Offices"] = "building"
commerce["Milner-Rushing Discount Drugs"] = "pharmacy"
commerce["Cook's Pest Control"] = "commercial"
commerce["Office Depot"] = "retail"
commerce["Matt's Ice Cream"] = "fastfood"
commerce["Dillard's"] = "retail"
commerce["Panda Express"] = "fastfood"
commerce["Firestone"] = "auto"
commerce["McDonalds"] = "fastfood"
commerce["ABC Select Spirits"] = "grocery"

commerce["QuikTrip"] = "auto"
commerce["Taco Bueno"] = "fastfood"
commerce["Conoco"] = "fuel"
commerce["Sonic Drive-In"] = "fastfood"
commerce["Schlotzsky's Deli"] = "fastfood"
commerce["Taco Mayo"] = "fastfood"
commerce["Hideaway Pizza"] = "restaurant"
commerce["Chase"] = "bank"
commerce["Sonic Drive In"] = "fastfood"
commerce["Carl's Jr."] = "fastfood"
commerce["Jiffy Lube"] = "auto"
commerce["Jack in the Box"] = "fastfood"
commerce["BancFirst"] = "bank"
commerce["Charlie's Chicken"] = "fastfood"
commerce["Flying J"] = "auto"
commerce["Walmart"] = "retail"
commerce["Auto Pride Car Wash"] = "auto"
commerce["Discount Tire"] = "auto"
commerce["EZ Mart"] = "convenience"
commerce["Autozone"] = "auto"
commerce["FedEx Office Print and Ship Center"] = "retail"
commerce["T-Mobile"] = "retail"
commerce["Taco Casa"] = "fastfood"
commerce["Mazzio's Pizza"] = "restaurant"
commerce["Fiesta Wash"] = "auto"
commerce["Daylight Donuts"] = "fastfood"
commerce["Logan's Roadhouse"] = "restaurant"
commerce["Denny's"] = "restaurant"
commerce["Sprint"] = "retail"
commerce["McAlister's Deli"] = "fastfood"
commerce["Buffalo Wild Wings"] = "restaurant"
commerce["Eagle Fuels"] = "fuel"
commerce["Philips 66"] = "fuel"
commerce["Simple Simon's Pizza"] = "restaurant"
commerce["Macaroni Grill"] = "restaurant"
commerce["Cheesecake Factory"] = "restaurant"
commerce["On The Border"] = "restaurant"

commerce["Western Convenience"] = "convenience"
commerce["Alta Convenience"] = "convenience"
commerce["Hy-Vee Gas Convenience Store"] = "convenience"
commerce["Shell Convenience Store"] = "convenience"

commerce["Smith's"] = "grocery"
commerce["In-N-Out Burger"] = "fastfood"
commerce["Speedee Mart"] = "convenience"
commerce["Buffet@Asia"] = "restaurant"
commerce["Tires Plus"] = "auto"
commerce["A&W"] = "grocery"
commerce["The Palazzo"] = "casino"
commerce["The Venetian Las Vegas"] = "casino"
commerce["Red Robin"] = "restaurant"
commerce["Harrah's Las Vegas"] = "casino"
commerce["Jimmy John's"] = "fastfood"
commerce["Grocery Outlet"] = "grocery"
commerce["7-11"] = "convenience"
commerce["Round Table Pizza"] = "restaurant"
commerce["Papa Murphy's"] = "fastfood"
commerce["Bellagio Las Vegas"] = "casino"
commerce["Bellagio Spa Tower"] = "casino"
commerce["Galleria at Sunset"] = "casino"
commerce["NoMad at Park MGM"] = "casino"
commerce["Le Boulevard At Paris"] = "casino"
commerce["Eiffel Tower"] = "casino"
commerce["Tropicana Las Vegas"] = "casino"
commerce["Luxor Las Vegas"] = "casino"
commerce["Mandalay Bay Resort & Casino"] = "casino"
commerce["Mandalay Bay Events Center"] = "casino"
commerce["The Cosmopolitan of Las Vegas"] = "casino"
commerce["MGM Grand Garden"] = "casino"
commerce["Showcase"] = "casino"
commerce["Polo Towers Suites"] = "casino"
commerce["MGM Grand Conference Center"] = "casino"
commerce["Rio Ipanema Tower"] = "casino"

commerce["Shaw's"] = "convenience"
commerce["Mobil"] = "fuel"
commerce["Gulf"] = "fuel"
commerce["KeyBank"] = "bank"
commerce["Aubuchon Hardware"] = "hardware"
commerce["Kinney Drugs"] = "pharmacy"
commerce["Pump Station"] = "fuel"
commerce["Henry's Diner"] = "restaurant"

commerce["Kroger"] = "grocery"
commerce["Kum & Go"] = "convenience"
commerce["Dollar Tree"] = "retail"
commerce["Candlewood Suites"] = "motel"
commerce["Pilot"] = "fuel"
commerce["Midas"] = "auto"
commerce["State Farm"] = "commercial"
commerce["Ashley HomeStore"] = "retail"
commerce["TJ Maxx"] = "retail"
commerce["Las Palmas"] = "restaurant"
commerce["LongHorn Steakhouse"] = "restaurant"
commerce["Slim Chickens"] = "fastfood"
commerce["Malco Razorback Cinema"] = "theatre"
commerce["A & E Auto Repair"] = "auto"
commerce["Kentucky Fried Chicken"] = "fastfood"
commerce["Citgo Gas Station"] = "fuel"
commerce["Citgo"] = "fuel"
commerce["Walmart Gas"] = "fuel"
commerce["Little Rock Marriott"] = "hotel"

commerce["Harris Teeter"] = "grocery"
commerce["SunTrust"] = "bank"
commerce["Sheetz"] = "fuel"
commerce["ABC Store"] = "grocery"
commerce["Ingles"] = "grocery"
commerce["ABC"] = "grocery"
commerce["Bojangles'"] = "fastfood"
commerce["Chipotle"] = "fastfood"
commerce["Lowes Foods"] = "grocery"
commerce["Ace Hardware"] = "hardware"
commerce["Staples"] = "retail"
commerce["Bojangle's"] = "fastfood"
commerce["Boost Mobile"] = "retail"
commerce["Sherwin Williams"] = "retail"
commerce["Bruegger's Bagels"] = "fastfood"
commerce["Speedway"] = "fuel"
commerce["BJ's Gas"] = "fuel"
commerce["KFC/Taco Bell"] = "fastfood"
commerce["Boston Market"] = "fastfood"
commerce["Hess"] = "fuel"
commerce["Quality Mart"] = "convenience"
commerce["Marathon"] = "fuel"
commerce["Jimmy John's Gourmet Sandwiches"] = "fastfood"
commerce["Hooters"] = "restaurant"
commerce["Great Clips"] = "retail"
commerce["Bi-Lo"] = "grocery"
commerce["Jersey Mike's Subs"] = "fastfood"
commerce["Autobell Car Wash"] = "auto"
commerce["NTB-National Tire & Battery"] = "auto"
commerce["Sherwin-Williams Paints"] = "retail"
commerce["Sherwin-Williams"] = "retail"
commerce["Firehouse Subs"] = "fastfood"
commerce["Whole Foods"] = "grocery"
commerce["Carrabba's Italian Grill"] = "restaurant"

commerce["Commercial Tire"] = "auto"
commerce["Fred Meyer"] = "retail"
commerce["Albertson's"] = "grocery"
commerce["Les Schwab Tire Center"] = "auto"
commerce["LDS Seminary"] = "church"
commerce["Jacksons Food Stores"] = "grocery"
commerce["Sizzler"] = "restaurant"
commerce["Winco Foods"] = "grocery"
commerce["Ridley's Family Market"] = "grocery"
commerce["Payless Shoe Source"] = "retail"
commerce["Radio Shack"] = "retail"
commerce["Bed Bath & Beyond"] = "retail"
commerce["Domino's"] = "restaurant"
commerce["Idaho Pizza Company"] = "restaurant"
commerce["Family Dollar Store"] = "retail"
commerce["Baskin-Robbin's"] = "fastfood"
commerce["Jack-in-the-Box"] = "fastfood"

commerce["Del Taco"] = "fastfood"
commerce["El Pollo Loco"] = "fastfood"
commerce["Goodwill"] = "retail"
commerce["Food Mart"] = "grocery"
commerce["Office Max"] = "retail"
commerce["Michaels"] = "retail"
commerce["Trader Joe's"] = "grocery"
commerce["Filiberto's Mexican Food"] = "restaurant"
commerce["Food City"] = "grocery"
commerce["Fry's Food and Drug"] = "pharmacy"
commerce["Sprouts Farmers Market"] = "grocery"
commerce["Chipotle Mexican Grill"] = "fastfood"
commerce["Petco"] = "retail"
commerce["Sweet Tomatoes"] = "restaurant"
commerce["7 eleven"] = "convenience"
commerce["Jack In The Box"] = "fastfood"
commerce["El Taco Tote"] = "fastfood"
commerce["Natural Grocers"] = "grocery"
commerce["Wallgreens"] = "pharmacy"
commerce["Federal Building"] = "government"

commerce["Meijer"] = "retail"
commerce["White Castle"] = "fastfood"
commerce["Family Video"] = "commercial"
commerce["McDonald’s"] = "fastfood"
commerce["Fazoli's"] = "fastfood"
commerce["Long John Silver's"] = "fastfood"
commerce["Preferred Auto"] = "auto"
commerce["Marathon Gas"] = "fuel"
commerce["Car wash"] = "auto"
commerce["Farmer's Market"] = "grocery"
commerce["Homewood Suites"] = "motel"
commerce["Thorntons"] = "fuel"
commerce["Einstein Bros. Bagels"] = "fastfood"
commerce["Steak & Shake"] = "fastfood"
commerce["Payless"] = "retail"
commerce["Mike's Car Wash"] = "auto"
commerce["Social Security Administration"] = "government"
commerce["Low Bob's Discount Tobacco"] = "grocery"
commerce["Starbucks Coffee"] = "fastfood"
commerce["Swifty Gas Station"] = "fuels"
commerce["Long John Silvers"] = "fastfood"
commerce["Steak-n-Shake"] = "fastfood"
commerce["Harley Davidson"] = "retail"
commerce["Wendy’s"] = "fastfood"
commerce["Kroger Fuel"] = "fuel"
commerce["Advance Auto"] = "auto"
commerce["Super Wash"] = "auto"
commerce["Insomnia Cookies"] = "fastfood"

commerce["Super Fuel Satellite"] = "fuel"
commerce["Fuel Farm Pump House"] = "fuel"
commerce["Price Chopper Fuel"] = "fuel"
commerce["Kroger Fuel Center"] = "fuel"
commerce["Walmart Fuel"] = "fuel"
commerce["Sam's Club Fuel Center"] = "fuel"
commerce["Fuel Tank"] = "fuel"
commerce["Fire Cache Fuel"] = "fuel"
commerce["Fry's Fuel"] = "fuel"
commerce["Kroger Fuel Center"] = "fuel"
commerce["Smith's Fuel Center"] = "fuel"

commerce["Tim Hortons"] = "convenience"
commerce["Big Boy"] = "fastfood"
commerce["Belle Tire"] = "auto"
commerce["Family Fare"] = "restaurant"
commerce["Meijer Gas"] = "fuel"
commerce["Meijer Gas Station"] = "fuel"
commerce["PetSmart"] = "retail"
commerce["Biggby Coffee"] = "fastfood"
commerce["Toys R Us"] = "retail"
commerce["Chili's Grill & Bar"] = "restaurant"
commerce["Leo's Coney Island"] = "restaurant"
commerce["Qdoba Mexican Grill"] = "fastfood"
commerce["Art Van Furniture"] = "retail"
commerce["Visitor Center"] = "government"
commerce["7/11"] = "convenience"
commerce["Big Apple Bagels"] = "fastfood"
commerce["Discount Tire Co."] = "auto"
commerce["Chicken Shack"] = "fastfood"
commerce["Chuck E. Cheese's"] = "restaurant"

commerce["Raising Cane's Chicken Fingers"] = "fastfood"
commerce["Super 1 Foods"] = "grocery"
commerce["Rotolo's"] = "restaurant"
commerce["La Carreta"] = "restaurant"
commerce["Rue 21"] = "retail"
commerce["The Crazy Lobster Bar & Grill"] = "restaurant"

commerce["RaceTrac"] = "fuel"
commerce["BB&T"] = "bank"
commerce["Pollo Tropical"] = "fastfood"
commerce["TGI Friday's"] = "restaurant"
commerce["Tire Kingdom"] = "auto"
commerce["Parking"] = "parking"
commerce["Miller's Ale House"] = "restaurant"
commerce["Sonny's BBQ"] = "restaurant"
commerce["Bonefish Grill"] = "restaurant"
commerce["ABC Liquors"] = "grocery"
commerce["Chick-Fil-A"] = "fastfood"
commerce["7 Eleven"] = "convenience"
commerce["Sears Auto Center"] = "auto"
commerce["Joe's Crab Shack"] = "restaurant"
commerce["Racetrac"] = "fuel"
commerce["Econo Lodge"] = "motel"
commerce["BJ's"] = "retail"
commerce["Ramada"] = "motel"
commerce["Elks Lodge"] = "motel"
commerce["T.G.I. Friday's"] = "restaurant"
commerce["CVS/pharmacy"] = "pharmacy"
commerce["Super Target"] = "retail"

commerce["Chicken House"] = "fastfood"
commerce["City Hall"] = "government"
commerce["Smoothie King"] = "fastfood"
commerce["Taco Mac"] = "fastfood"
commerce["Wingate by Wyndham"] = "hotel"
commerce["Travelodge"] = "motel"
commerce["Cheddar's Scratch Kitchen"] = "restaurant"
commerce["Cricket Wireless"] = "retail"
commerce["Macy's"] = "retail"
commerce["Sam's Club Gas"] = "fuel"

commerce["H-E-B"] = "fuel"
commerce["H-E-B Gas"] = "fuel"
commerce["H-E-B Car Wash"] = "fuel"
commerce["Taco Cabana"] = "fastfood"
commerce["Chicken Express"] = "fastfood"
commerce["H-E-B Plus!"] = "fuel"
commerce["Taco Villa"] = "fastfood"
commerce["Bill Miller Bar-B-Q"] = "fastfood"
commerce["Luby's"] = "restaurant"
commerce["P. Terry's Burger Stand"] = "fastfood"
commerce["Rudy's Country Store & Bar-B-Q"] = "restaurant"
commerce["Discount Tire Store"] = "auto"
commerce["Bush's Chicken"] = "fastfood"
commerce["Chuy's"] = "restaurant"
commerce["Jason's Deli"] = "fastfood"
commerce["Kwik Kar Lube & Tune"] = "auto"
commerce["Popeyes"] = "fastfood"
commerce["Fuddruckers"] = "restaurant"
commerce["Pier 1 Imports"] = "retail"
commerce["Christian Brothers Automotive"] = "auto"
commerce["Shipley's Donuts"] = "fastfood"
commerce["E-Z Mart"] = "convenience"
commerce["Wal-Mart"] = "retail"
commerce["Taco Palenque"] = "fastfood"
commerce["DQ"] = "fastfood"

commerce["Car Wash"] = "auto"
commerce["LA Fitness"] = "recreation"
commerce["QFC"] = "grocery"
commerce["Burgerville"] = "fastfood"
commerce["WinCo Foods"] = "grocery"
commerce["Brown Bear Car Wash"] = "auto"
commerce["Dutch Bros. Coffee"] = "fastfood"
commerce["Baskin-Robbins"] = "fastfood"
commerce["Bartell Drugs"] = "pharmacy"
commerce["Les Schwab"] = "auto"
commerce["BigFoot Java"] = "fastfood"
commerce["Anytime Fitness"] = "recreation"
commerce["24 Hour Fitness"] = "recreation"
commerce["MetroPCS"] = "retail"
commerce["Masonic Lodge"] = "recreation"
commerce["REI"] = "retail"
commerce["GameStop"] = "retail"
commerce["Extended Stay America"] = "motel"
commerce["Planned Parenthood"] = "medical"
commerce["Payless ShoeSource"] = "retail"
commerce["Tire Rama"] = "auto"
commerce["Gourmet Latte"] = "fastfood"
commerce["Enterprise"] = "auto"

commerce["Kwik Trip"] = "convenience"
commerce["Pick 'n Save"] = "retail"
commerce["Pick n Save"] = "retail"
commerce["ALDI"] = "grocery"
commerce["Woodman's"] = "grocery"
commerce["BP Shop"] = "fuel"
commerce["AmericInn"] = "motel"
commerce["Menard's"] = "hardware"
commerce["Colectivo Coffee"] = "fastfood"
commerce["Cousins Subs"] = "fastfood"
commerce["Noodles & Company"] = "fastfood"
commerce["Perkin's"] = "restaurant"
commerce["Michael's Frozen Custard"] = "fastfoods"
commerce["Courtyard by Marriott"] = "hotel"
commerce["La Petite Academy"] = "school"
commerce["Masonic Temple"] = "recreation"
commerce["Krist Food Mart"] = "convenience"
commerce["Milwaukee Burger Company"] = "fastfood"
commerce["Union Parking"] = "parking"
commerce["Garage"] = "parking"
commerce["Kwik Trip Car Wash"] = "auto"
commerce["Dick's Fresh Market"] = "grocery"
commerce["Van Horn Chrysler Dodge Jeep RAM of Manitowoc"] = "auto"
commerce["CarX"] = "auto"
commerce["Kopp's Custard"] = "fastfood"
commerce["General Store"] = "convenience"
commerce["Gym"] = "recreation"

commerce["Hardees"] = "fastfood"
commerce["Kroger Gas"] = "auto"
commerce["Wendys"] = "fastfood"
commerce["BJ's Wholesale Club"] = "retail"
commerce["Knights of Columbus"] = "recreation"
commerce["CarMax"] = "auto"
commerce["American Family Fitness"] = "recreation"
commerce["Burlington Coat Factory"] = "retail"
commerce["Merchant's Tire and Auto"] = "auto"
commerce["Raceway"] = "fuel"
commerce["WaWa"] = "fuel"
commerce["Merchant's Tire"] = "auto"
commerce["Rite-Aid"] = "pharmacy"
commerce["Roy Rogers"] = "fastfood"
commerce["TitleMax"] = "auto"
commerce["Short Pump Crossing"] = "fuel"
commerce["Kramer Tire"] = "auto"
commerce["Gold's Gym"] = "recreation"
commerce["Regal Cinemas"] = "recreation"
commerce["Title Max"] = "auto"
commerce["Kindercare"] = "school"
commerce["Child Development Center"] = "school"
commerce["General District Court"] = "government"
commerce["hhgregg"] = "retail"
commerce["Hyatt Place"] = "hotel"
commerce["Century 21"] = "retail"
commerce["Loan Max"] = "retail"
commerce["Hair Cuttery"] = "retail"

commerce["fuel"] = "fuel"
commerce["gas station"] = "fuel"
commerce["Backyard Burgers"] = "fastfood"
commerce["church"] = "church"
commerce["Weigel's"] = "convenience"
commerce["Sally Beauty Supply"] = "retail"
commerce["Lafayette Head Start Center"] = "school"
commerce["Git-N-Go"] = "convenience"
commerce["Chamber of Commerce"] = "government"
commerce["Huddle House"] = "restaurant"
commerce["Stein Mart"] = "retail"
commerce["sonic"] = "fastfood"
commerce["Shelby County Criminal Justice Center"] = "prison"
commerce["Wesley Foundation"] = "church"
commerce["Pilot Food Mart"] = "convenience"
commerce["Hard Rock Cafe"] = "restaurant"
commerce["Ben & Jerry's"] = "fastfood"
commerce["Buddy's Bar-B-Q"] = "fastfood"
commerce["Krispy Kreme Doughnuts"] = "fastfood"
commerce["USPS"] = "postoffice"
commerce["LeConte View Motor Lodge"] = "motel"

commerce["The UPS Store"] = "commercial"
commerce["Edward Jones"] = "commercial"
commerce["GNC"] = "retail"
commerce["Supercuts"] = "retail"
commerce["Jamba Juice"] = "fastfood"
commerce["FedEx Office"] = "commercial"
commerce["Postal Annex"] = "commercial"
commerce["Kaady Car Wash"] = "auto"
commerce["Cold Stone Creamery"] = "fastfood"
commerce["Taco Del Mar"] = "fastfood"
commerce["Lane Bryant"] = "retail"
commerce["Hertz"] = "auto"
commerce["Public Storage"] = "commercial"
commerce["Michael's"] = "retail"
commerce["Kaiser Permanente"] = "medical"
commerce["The Old Spaghetti Factory"] = "restaurant"

commerce["Nebraska Department of Health & Human Services"] = "government"
commerce["New Hampshire Department of Transportation"] = "government"
commerce["New Mexico Department of Agriculture"] = "government"
commerce["NMSU Department of Fire & Emergency Services"] = "college"
commerce["New York State Department of Transportation"] = "government"
commerce["North Carolina Department of Transportation"] = "government"
commerce["Oklahoma Department of Transportation"] = "government"
commerce["Oregon Department of Transportation"] = "government"
commerce["US Department of Agriculture"] = "government"
commerce["City of Orem Department of Public Safety"] = "government"
commerce["Department of Vermont Health Access"] = "government"
commerce["Virginia Department of Transportation"] = "government"
commerce["Washington State Department of Social and Health Services"] = "government"
commerce["Social & Health Services Department"] = "government"
commerce["Department of Health and Human Resources"] = "government"

commerce["Spring Creek Health & Rehab"] = "medical"
commerce["Lerner Health and Wellness Center"] = "medical"
commerce["AlegentHealth Amphitheatre"] = "theatre"
commerce["Rod Lee Bigelow Health Sciences Building"] = "college"
commerce["Claude I Howard Student Health Services"] = "college"
commerce["Christian Health Care Center"] = "medical"
commerce["Health and Social Services"] = "government"
commerce["Novant Health"] = "medical"
commerce["VA Health Care Center"] = "government"
commerce["Sanford Health Retention Center"] = "medical"
commerce["Fargo Cass Public Health"] = "government"
commerce["Healthy Pets Northwest"] = "medical"
commerce["Physicians Health Alliance"] = "medical"
commerce["eviCore Healthcare"] = "medical"
commerce["Intermountain Healthcare Ogden WorkMed"] = "medical"
commerce["Department of Vermont Health Access"] = "government"
commerce["Family Health Center"] = "medical"
commerce["Social & Health Services Department"] = "government"
commerce["Department of Health and Human Resources"] = "government"

commerce["Famous Dave's"] = "restaurant"
commerce["Gates Bar-B-Q"] = "restaurant"
commerce["Joe's Kansas City Bar-B-Que"] = "restaurant"
commerce["24/7 Travel Store"] = "convenience"
commerce["Dairy King"] = "fastfood"

commerce["Jet Splash Car Wash"] = "auto"
commerce["Crane Coffee"] = "fastfood"
commerce["OfficeMax"] = "retail"
commerce["Kearney Cinema 8"] = "recreation"
commerce["Kwik Stop"] = "convenience"
commerce["Tornado Wash"] = "auto"
commerce["Flag City Auto Wash"] = "auto"
commerce["Miracle Car & Van Wash"] = "auto"
commerce["Tiger Wash"] = "auto"
commerce["Allied Pressure Washers"] = "auto"
commerce["Mighty Wash"] = "auto"
commerce["Willy Wash"] = "auto"

commerce["Stop & Shop"] = "grocery"
commerce["Super Stop & Shop"] = "grocery"
commerce["Planet Fitness"] = "recreation"
commerce["Papa Gino's"] = "fastfood"
commerce["Stop and Shop"] = "grocery"

commerce["Cumberland Farms"] = "convenience"
commerce["Wegmans"] = "convenience"
commerce["Mavis Discount Tire"] = "auto"
commerce["HSBC"] = "bank"
commerce["Citibank"] = "bank"
commerce["Shoprite"] = "grocery"
commerce["Hess Express"] = "convenience"
commerce["711"] = "convenience"
commerce["Capital One"] = "bank"
commerce["ShopRite"] = "grocery"
commerce["Duane Reade"] = "pharmacy"
commerce["Tops Friendly Market"] = "convenience"
commerce["BJ's Wholesale"] = "retail"
commerce["King Kullen"] = "grocery"
commerce["Express Mart"] = "convenience"
commerce["EconoLodge"] = "motel"

commerce["Kroger Food & Drug"] = "grocery"
commerce["Steak ’n Shake"] = "fastfood"
commerce["Frisch’s Big Boy"] = "fastfood"
commerce["PNC"] = "bank"
commerce["Discount Drug Mart"] = "pharmacy"
commerce["Penske Truck Rental (Mr. Storage)"] = "auto"
commerce["Valvoline"] = "auto"
commerce["Lube Stop"] = "auto"
commerce["Extended StayAmerica"] = "motel"
commerce["Life Time Fitness"] = "recreation"
commerce["Frisch's Big Boy"] = "fastfood"
commerce["Enterprise Rent-A-Car"] = "auto"
commerce["Kohl’s"] = "retail"
commerce["Costco Wholesale"] = "retail"
commerce["Long John Silver’s"] = "fastfood"
commerce["Advanced Auto Parts"] = "auto"
commerce["O’Charley’s"] = "restaurant"
commerce["Kroger Marketplace"] = "grocery"
commerce["Sam’s Club"] = "retail"
commerce["Lowe’s"] = "hardware"
commerce["Car-X"] = "auto"
commerce["Culver’s"] = "fastfood"
commerce["The Cheesecake Factory"] = "restaurant"

commerce["66 Lube"] = "auto"

commerce["Bi-Mart"] = "grocery"
commerce["New Seasons Market"] = "grocery"
commerce["Sport Clips"] = "commercial"
commerce["Massage Envy"] = "commercial"
commerce["DMV"] = "government"
commerce["storage building"] = "commercial"
commerce["Men's Wearhouse"] = "retail"
commerce["Banfield Pet Hospital"] = "medical"
commerce["Fred Meyer Fuel"] = "fuel"
commerce["Chang's Mongolian Grill"] = "restaurant"
commerce["Jackson Hewitt"] = "commercial"
commerce["Peet's"] = "fastfood"
commerce["T.J. Maxx"] = "retail"

commerce["Outback"] = "restaurant"
commerce["Giant Gas"] = "fuel"
commerce["Giant Fuel"] = "fuel"

commerce["AMPM"] = "convenience"
commerce["Arco"] = "fuel"
commerce["76"] = "building"
commerce["Department of Motor Vehicles"] = "government"
commerce["Carl's Jr"] = "fastfood"
commerce["Mimi's Cafe"] = "fastfood"
commerce["ampm"] = "convenience"
commerce["Black Bear Diner"] = "fastfood"
commerce["Cost Plus World Market"] = "retail"
commerce["Carls Jr."] = "fastfood"
commerce["Sports Authority"] = "retail"
commerce["am pm"] = "convenience"
commerce["Fitness Center"] = "recreation"
commerce["Whole Foods Market"] = "grocery"

commerce["Ward Farmer's Market"] = "grocery"
commerce["The Marketplace at Kapolei"] = "grocery"
commerce["Down to Earth Market"] = "grocery"
commerce["Wada Forms Marketing Group"] = "grocery"
commerce["Scoresby Farms Market"] = "grocery"
commerce["Dara's Corner Market"] = "grocery"
commerce["Kremer’s Market"] = "grocery"
commerce["Graul's Market"] = "grocery"
commerce["Lucky's Market"] = "grocery"
commerce["Plum Market"] = "grocery"
commerce["Harding's Friendly Market"] = "grocery"
commerce["D&W Fresh Market"] = "grocery"
commerce["Kowalski's Market"] = "grocery"
commerce["Minneapolis Farmer's Market"] = "grocery"
commerce["Greer's Hurley Market"] = "grocery"
commerce["Pascagoula Flea Market and Collectible Emporium"] = "grocery"
commerce["Menagerie On Market"] = "grocery"
commerce["Straub's Market"] = "grocery"
commerce["Dorsey's Market"] = "grocery"
commerce["Winn-Dixie Marketplace"] = "grocery"
commerce["Fry's Marketplace"] = "grocery"
commerce["Wal-Mart Legal/Marketing/Data Center Building"] = "grocery"
commerce["Cabot Meat Market"] = "grocery"
commerce["Gelson's Market"] = "grocery"
commerce["99 Ranch Market"] = "grocery"
commerce["Riverfront Market"] = "grocery"
commerce["Market Place Garage"] = "grocery"
commerce["Rainbow Market"] = "grocery"
commerce["Harvest Market"] = "grocery"
commerce["ACME Markets"] = "grocery"
commerce["Acme Market"] = "grocery"
commerce["Albertson's Market"] = "grocery"
commerce["Ingles Markets"] = "grocery"
commerce["Sparkle Market"] = "grocery"
commerce["Armando & Sons Meat Market"] = "grocery"
commerce["Custer County Market"] = "grocery"
commerce["Mini Market"] = "grocery"
commerce["Central Market"] = "grocery"
commerce["La Michoacana Meat Market"] = "grocery"
commerce["Sprouts Farmer's Market"] = "grocery"
commerce["Salem Farmers Market"] = "grocery"
commerce["Metropolitan Market"] = "grocery"
commerce["Mini Market"] = "grocery"
commerce["Hungry Bear Market"] = "grocery"

commerce["Jewel-Osco"] = "grocery"
commerce["Auto Repair"] = "auto"
commerce["Portillo's"] = "fastfood"
commerce["Mariano's"] = "grocery"
commerce["Jewel"] = "grocery"
commerce["Giordano's"] = "restaurant"
commerce["Blain's Farm & Fleet"] = "retail"
commerce["Buona Beef"] = "fastfood"
commerce["Steak N Shake"] = "fastfood"
commerce["Jewel Osco"] = "grocery"
commerce["Mariano's Fresh Market"] = "grocery"
commerce["Toyota"] = "auto"
commerce["Oil Express"] = "auto"
commerce["Food 4 Less"] = "grocery"
commerce["Popeye's Chicken"] = "fastfood"
commerce["Audi"] = "auto"
commerce["Lou Malnati's Pizzeria"] = "restaurant"
commerce["Ultra Foods"] = "grocery"
commerce["Tilted Kilt"] = "restaurant"
commerce["Lone Star Steakhouse"] = "restaurant"
commerce["Pete's Fresh Market"] = "grocery"
commerce["Fire Station"] = "firestation"
commerce["MB Financial"] = "bank"
commerce["Qdoba"] = "fastfood"

commerce["Vons"] = "grocery"
commerce["Tops"] = "convenience"
commerce["Tops Friendly Markets"] = "convenience"

commerce["Mr. Tire"] = "auto"
commerce["Mobil Mart"] = "convenience"
commerce["Jehovah's Witnesses"] = "church"
commerce["Meineke"] = "auto"
commerce["YWCA"] = "recreation"
commerce["YMCA"] = "recreation"

commerce["Blake's Lotaburger"] = "fastfood"
commerce["Ruby Tuesday's"] = "restaurant"
commerce["Allsup's"] = "convenience"
commerce["Allsups"] = "convenience"
commerce["Allsup's Convenience Stores, Inc"] = "convenience"


commerce["Steak'n Shake"] = "fastfood"
commerce["Life Time Athletic"] = "recreation"

commerce["Snap Fitness"] = "recreation"
commerce["Rent-A-Center"] = "retail"
commerce["Jersey Mike's"] = "fastfood"
commerce["BedMart"] = "retail"

commerce["Kohls"] = "retail"
commerce["Jiffy Lube"] = "auto"
commerce["IHOP"] = "fastfood"

commerce["Dippin' Dots"] = "fastfood"
commerce["A&M U-STORE-IT"] = "storage"


commerce["Cargo Terminal"] = "airport"
commerce["Terminal 1 - A Gates"] = "airport"
commerce["Terminal 1 - C Gates"] = "airport"
commerce["Passenger Terminal"] = "airport"
commerce["Terminal de Carros Públicos"] = "airport"
commerce["Robinson Terminal"] = "airport"
commerce["Terminal"] = "airport"
commerce["North Terminal, Anchorage International Airport"] = "airport"
commerce["South Terminal, Anchorage International Airport"] = "airport"
commerce["UPS Terminal"] = "airport"
commerce["Central Arkansas Transit Authority Bus Terminal"] = "busstation"
commerce["Jackson-Evers International Airport Terminal"] = "airport"

commerce["Warehouse Market"] = "grocery"
commerce["Apple Market"] = "grocery"
commerce["Market of Choice"] = "grocery"
commerce["Weis Markets"] = "grocery"
commerce["Weis Market"] = "grocery"
commerce["Redner's Warehouse Market"] = "grocery"
commerce["Turkey Hill Minit Market"] = "Ngroceryone"
commerce["Dave's Marketplace"] = "grocery"
commerce["World Market"] = "grocery"
commerce["Rocky Top Market"] = "grocery"
commerce["Crossroads Market"] = "grocery"
commerce["Market Street"] = "grocery"
commerce["Lowe's Market"] = "grocery"
commerce["World Market"] = "grocery"
commerce["Smith's Marketplace"] = "grocery"
commerce["Fresh Market"] = "grocery"
commerce["City Market"] = "grocery"
commerce["World Market"] = "grocery"
commerce["My Goods Market"] = "grocery"
commerce["ROCS Local Market"] = "grocery"
commerce["Von Son Asian Market"] = "grocery"
commerce["Metro Market"] = "grocery"
commerce["Benedict's Market"] = "grocery"
commerce["River Market"] = "grocery"
commerce["City Market"] = "grocery"
commerce["Albertsons Market"] = "grocery"
commerce["Jenny's Market"] = "grocery"
commerce["Bodie's Dairy Market"] = "grocery"
commerce["City Market at O"] = "grocery"
commerce["Fresh Market"] = "grocery"
commerce["Malama Market"] = "grocery"
commerce["Prince Market"] = "grocery"
commerce["Short Stop Market"] = "grocery"
commerce["County Market"] = "grocery"
commerce["Hen House Market"] = "grocery"
commerce["Remke Markets"] = "grocery"
commerce["Market Basket"] = "grocery"
commerce["MOM's Organic Market"] = "grocery"
commerce["Market Basket"] = "grocery"
commerce["Star Market"] = "grocery"
commerce["GFS Marketplace"] = "grocery"
commerce["Apple Market"] = "grocery"

commerce["Red Arrow Diner"] = "restaurant"
commerce["Mandan Diner & Soda Fountain"] = "restaurant"
commerce["Silver Diner"] = "restaurant"
commerce["Penny's Diner"] = "restaurant"
commerce["Double T Diner"] = "restaurant"

commerce["Donald C Moyer Student Union"] = "college"
commerce["Student Union"] = "college"
commerce["Student Union"] = "college"
commerce["Student Residence"] = "domitory"
commerce["SDSU Student Union"] = "college"
commerce["David B. Miller Yellowjacket Student Union"] = "college"
commerce["Married Student Housing"] = "domitory"
commerce["Student Health Service and Counseling"] = "college"
commerce["Baptist Student Center"] = "college"
commerce["Student Union"] = "college"
commerce["McCollough Student Center"] = "college"
commerce["Student Recreation Center"] = "college"
commerce["Student Union"] = "college"
commerce["Student Recreation Center"] = "college"
commerce["Student Services"] = "college"
commerce["Student Center"] = "college"
commerce["Student Recreation Center"] = "college"
commerce["Student Center"] = "college"
commerce["Baptist Student Union"] = "college"
commerce["Student Recreation Center"] = "college"
commerce["Sam Bennion Student Union Buiding"] = "college"
commerce["Hixon Student Center"] = "college"
commerce["Student Union"] = "college"
commerce["Clark Student Housing"] = "college"
commerce["Student Center"] = "college"
commerce["Baptist Student Union"] = "college"
commerce["Student Recreation Center"] = "college"

commerce["Cottingham Hall"] = "college"
commerce["Cavanaugh Hall of Science"] = "college"
commerce["Alexandria Hall"] = "college"
commerce["Tudor Hall"] = "college"
commerce["Alexandria City Hall"] = "governemnt"
commerce["Nicholson Hall"] = "college"
commerce["Auburn City Hall"] = "government"
commerce["Dining Hall"] = "college"
commerce["Portland City Hall"] = "college"
commerce["Dining Hall"] = "college"
commerce["Chesapeake Hall"] = "college"
commerce["Wicomico Hall"] = "college"
commerce["Harford Hall"] = "college"
commerce["Kent Hall"] = "college"
commerce["Alumnae Hall"] = "college"
commerce["West Hall"] = "college"
commerce["Wright Hall"] = "college"
commerce["Alumni Hall"] = "college"
commerce["Fuller Hall"] = "college"
commerce["Morgan Hall"] = "college"
commerce["Dining Hall"] = "college"
commerce["Adams Hall"] = "college"
commerce["Conant Hall"] = "college"
commerce["Memorial Hall"] = "college"
commerce["University Hall"] = "college"
commerce["Symphony Hall"] = "college"
commerce["Old City Hall"] = "government"
commerce["St Joseph Hall"] = "college"
commerce["Dining Hall"] = "college"
commerce["Town Hall"] = "government"
commerce["Dining Hall"] = "college"
commerce["Heritage Hall"] = "college"
commerce["Centennial Hall"] = "college"
commerce["Olin Hall"] = "college"
commerce["Jackson City Hall"] = "government"
commerce["Thalia Mara Hall"] = "college"
commerce["Hallmark Cards"] = "commercial"
commerce["Dining Hall"] = "college"
commerce["Brown Hall"] = "college"
commerce["Kingdom Hall"] = "college"
commerce["Simkins Hallin"] = "college"
commerce["Hall Office Building"] = "building"

commerce["Reno Airport Parking"] = "parking"
commerce["Parking Deck"] = "parking"
commerce["Central Oklahoma Transportation and Parking Authority"] = "government"
commerce["Washington Parking Ramp"] = "parking"
commerce["Lincoln Parking Ramp"] = "parking"
commerce["Barclay Square Parking Area"] = "parking"
commerce["Charles Town Races and Slots Parking"] = "parking"
commerce["North Campus Parking Deck"] = "parking"
commerce["Hilton Hawaiian Village Parking"] = "parking"
commerce["Short Term Parking"] = "parking"

commerce["Party City"] = "commercial"
commerce["Bubble City Truck Stop"] = "auto"
commerce["Mandan City Hall and Municipal Court"] = "government"
commerce["East Providence City Hall"] = "government"
commerce["Cranston City Hall"] = "government"
commerce["ALEX AND ANI City Center"] = "government"
commerce["Rapid City Regional Airport"] = "airport"
commerce["Burlington City Hall"] = "government"
commerce["City Market"] = "grocery"
commerce["City Maintenance Shed"] = "government"
commerce["Magic City Enterprises"] = "building"
commerce["Cheyenne City Hall"] = "government"
commerce["Rainbow City Plaza"] = "building"
commerce["Historic City Hall"] = "historical"
commerce["Little Rock City Hall"] = "government"
commerce["Old City Hall"] = "historical"
commerce["City Cleaners"] = "commercial"
commerce["Idaho Falls City Hall"] = "government"
commerce["Idaho Falls City Hall Annex"] = "government"
commerce["Granite City"] = "restaurant"
commerce["City of Olathe"] = "government"
commerce["Olathe City Hall"] = "government"
commerce["City Sightseeing New Orleans Hop-On Hop-Off"] = "busstation"
commerce["Alexandria City Hall"] = "government"
commerce["Auburn City Hall"] = "government"
commerce["Portland City Hall"] = "government"
commerce["Old City Hall"] = "government"
commerce["City of Woodbury Public Works"] = "government"
commerce["City of Cleveland Hangar"] = "hangar"
commerce["Jackson City Hall"] = "government"

commerce["Powers Hall"] = "industrial"
commerce["Power Plant"] = "industrial"
commerce["Power House"] = "industrial"
commerce["Powerhouse Gym"] = "recreation"
commerce["Power House"] = "industrial"
commerce["Delta Electric Power Association"] = "industrial"
commerce["Mississippi Power"] = "industrial"
commerce["Power House"] = "industrial"
commerce["Hoover Dam Powerhouse"] = "industrial"
commerce["Emerson Power Transmission"] = "industrial"
commerce["Power Plant"] = "industrial"
commerce["Alabama Power"] = "industrial"
commerce["Alabama Power Appliance Center"] = "retail"
commerce["Bryans Island Power Sports"] = "industrial"
commerce["Alabama Power Company"] = "industrial"
commerce["Power Plant"] = "industrial"
commerce["Western Area Power Administration"] = "industrial"
commerce["Millstone Nuclear Power Plant"] = "industrial"
commerce["Capitol Power Plant"] = "industrial"
commerce["Hawaiian Electric Power Plant (1950's)"] = "industrial"
commerce["Idaho Falls Power"] = "industrial"
commerce["Bonneville Power Administration"] = "industrial"
commerce["Power House"] = "industrial"
commerce["Power Plant"] = "industrial"
commerce["Power Plant"] = "industrial"
commerce["NewPage Luke Mill Power Plant"] = "industrial"

commerce["Fishburne Parking Deck"] = "parking"
commerce["University Avenue Parking Ramp"] = "parking"
commerce["Oak Street Parking Ramp"] = "parking"
commerce["HCMC Parking Ramp"] = "parking"
commerce["Ferguson Parking Deck"] = "parking"
commerce["Close-In Parking"] = "parking"
commerce["Lot 50 Employee Parking"] = "parking"
commerce["Patient/Visitor Parking"] = "parking"
commerce["BLUE Parking"] = "parking"
commerce["ORANGE Parking"] = "parking"
commerce["GREEN Parking"] = "parking"
commerce["Wynn Employee Parking"] = "parking"
commerce["Employee Parking Lot"] = "parking"
commerce["Pier Village Customer Parking"] = "parking"
commerce["City Center Parking"] = "parking"
commerce["Municipal Parking"] = "parking"
commerce["Multilevel Parking"] = "parking"
commerce["Parking Services"] = "parking"
commerce["Myrtle Beach Public Parking"] = "parking"
commerce["Long Term Parking"] = "parking"
commerce["Hourly and Daily Parking"] = "parking"
commerce["Parking Services"] = "parking"
commerce["Convention Center Parking Deck"] = "parking"
commerce["Parking Booth"] = "parking"
commerce["NorthTown Mall Parking"] = "parking"
commerce["Tacoma Dome Station Parking"] = "parking"

commerce["P.F. Chang's"] = "restaurant"
commerce["Sleepy's"] = "commercial"
commerce["HomeGoods"] = "retail"
commerce["Pearle Vision"] = "commercial"
commerce["LensCrafters"] = "commercial"
commerce["Allstate Insurance"] = "commercial"
commerce["Allstate"] = "commercial"

commerce["Sullivan Tire"] = "auto"
commerce["Town Fair Tire"] = "auto"
commerce["Tire Warehouse"] = "auto"
commerce["Stratham Tire"] = "auto"
commerce["Goodyear Tire"] = "auto"
commerce["Northwest Tire"] = "auto"
commerce["Tire Discounters"] = "auto"
commerce["Tire Pros"] = "auto"
commerce["Town Fair Tire"] = "auto"
commerce["Kauffman Tire"] = "auto"
commerce["Tire Depot"] = "auto"
commerce["Graham Tire"] = "auto"
commerce["Tire Discounters"] = "auto"
commerce["Tire Warehouse"] = "auto"
commerce["Mr Tire"] = "auto"
commerce["Hogan Tire"] = "auto"
commerce["Sullivan Tire"] = "auto"
commerce["Town Fair Tire"] = "auto"
commerce["Pacer Tire"] = "auto"
commerce["NTB - National Tire & Battery"] = "auto"
commerce["Plaza Tire"] = "auto"

commerce["VIP Discount Auto Center"] = "auto"
commerce["VIP Discount Auto"] = "auto"
commerce["New England Auto Finance"] = "auto"
commerce["Wolfs Paw Auto & Fleet Repairs"] = "auto"
commerce["Uncle Bob's Auto And Truck Repair"] = "auto"
commerce["Western Auto"] = "auto"
commerce["Embassy Autowash"] = "auto"
commerce["Auto Stop"] = "auto"
commerce["Burnett Automotive"] = "auto"
commerce["JN Phillips Auto Glass"] = "auto"
commerce["Super Shine Auto Wash"] = "auto"
commerce["TRW Automotive"] = "auto"
commerce["Nissan Automotive Plant"] = "industrial"
commerce["Bolivar Auto"] = "auto"
commerce["Custom Complete Automotive"] = "auto"
commerce["A & D Auto Body Repair"] = "auto"
commerce["Jerry's Auto Electric"] = "auto"
commerce["Beauchamps Auto and Wrecker Service"] = "auto"
commerce["Autobahn"] = "auto"
commerce["Reicher's Tire and Auto"] = "auto"
commerce["Dave's Auto Express"] = "auto"
commerce["Omaha Auto Auction Ltd"] = "auto"
commerce["Auto Mart"] = "auto"
commerce["Dewey's Auto Detailing"] = "auto"
commerce["Bosque Auto Glass"] = "auto"
commerce["Baird's Auto"] = "auto"
commerce["Johnson Automotive"] = "auto"
commerce["Flag City Auto Wash"] = "auto"
commerce["University Park Auto Spa"] = "auto"
commerce["Advance Autoparts"] = "auto"
commerce["Frank's Auto Top & Upholstery"] = "auto"
commerce["Auto Choice"] = "auto"
commerce["Rushmore Automotive"] = "auto"
commerce["K & M Auto Repair"] = "auto"
commerce["Autozone Park"] = "auto"
commerce["Blackwell Automotive Inc."] = "auto"
commerce["Auto Check"] = "auto"
commerce["Dave's Canyon Auto"] = "auto"
commerce["Autoliv"] = "auto"
commerce["Fast Auto Loans"] = "auto"
commerce["Safelite Auto Glass"] = "auto"
commerce["Auto Connection"] = "auto"
commerce["Beckley Buick GMC Auto Mall"] = "auto"

commerce["Aspen Dental"] = "medical"
commerce["Gentle Dental"] = "medical"
commerce["Willamette Dental Group"] = "medical"
commerce["Dana Dental Arts"] = "medical"
commerce["Gentle Dental"] = "medical"
commerce["Dental Associates"] = "medical"
commerce["Comfort Dental"] = "medical"
commerce["Aspen Dental"] = "medical"

commerce["Concentra Urgent Care"] = "medical"
commerce["Albuquerque Health Care for the Homeless"] = "medical"
commerce["Sierra Health Care Center"] = "medical"
commerce["UNC Health Care"] = "medical"
commerce["Child Care Center"] = "school"
commerce["Zoom Care"] = "auto"
commerce["ZoomCare"] = "auto"
commerce["ManorCare Health Services"] = "medical"
commerce["Doctors Care"] = "medical"
commerce["Caretaker"] = "medical"
commerce["Valvoline Express Care"] = "auto"
commerce["Hartford Area Career and Technical Center"] = "medical"
commerce["KinderCare"] = "school"
commerce["KinderCare"] = "school"
commerce["Cheyenne Health Care Center"] = "medical"
commerce["Compass Urgent Care"] = "medical"
commerce["Banner Urgent Care"] = "medical"
commerce["Arkansas Department of Career Education Rehabilitation Services Division"] = "medical"
commerce["KinderCare"] = "school"
commerce["Abba Eye Care"] = "medical"
commerce["Community Care"] = "medical"
commerce["KinderCare Learning Center"] = "school"
commerce["Comprehensive Care"] = "medical"
commerce["Ambulatory Care Center"] = "medical"
commerce["KinderCare"] = "school"
commerce["Kinder Care"] = "school"

commerce["Best Friends Pet Care"] = "medical"
commerce["CareWell Urgent Care"] = "medical"
commerce["Urgent Care"] = "medical"
commerce["St. Luke's Urgent Care"] = "medical"
commerce["Avera Creighton Care Centre"] = "medical"
commerce["Building 25 - Outpatient Care & Emergency"] = "medical"
commerce["Douglas County Cavanaugh Care Center"] = "medical"
commerce["Armed Forces Career Center"] = "military"
commerce["Day Care Center"] = "school"
commerce["Urgent Care Centre / Occupational Medicine"] = "medical"
commerce["Animal Care Facility"] = "medical"
commerce["Southeast Region Career & Technology Center"] = "medical"
commerce["Meineke Car Care Center"] = "auto"
commerce["Urgent Care Extra"] = "medical"
commerce["Options Pregnancy Care"] = "medical"
commerce["Meineke Car Care Center"] = "auto"
commerce["Comfort Care Dental"] = "medical"
commerce["Family Eye Care Specialists"] = "medical"
commerce["(ACCS) Academic and Career Services Building"] = "college"
commerce["AFC Urgent Care"] = "medical"
commerce["Neibauer Dental Care"] = "medical"
commerce["Nicholas County Career and Technical Center"] = "government"
commerce["Oak Ridge Care Center"] = "auto"
commerce["Healthreach Urgent Care"] = "medical"


commerce["Costco Gasoline"] = "fuel"
commerce["Dunkin'Donuts"] = "fastfood"
commerce["Gap"] = "retail"
commerce["Quick Stop"] = "convenience"
commerce["Macy's Furniture Gallery"] = "retail"
commerce["Lord & Taylor"] = "retail"
commerce["Shop Rite"] = "grocery"
commerce["L.A. Fitness"] = "recreation"
commerce["Talbots"] = "retail"

commerce["Storage/ Office Bldg"] = "storage"
commerce["ezStorage"] = "storage"

commerce["America's Thrift Stores"] = "commercial"
commerce["Camp Store"] = "retail"
commerce["Compac Food Stores"] = "retail"
commerce["Priester's Country Retail Store"] = "retail"
commerce["The GCI Store"] = "retail"
commerce["Goldberg Cigar Store"] = "retail"
commerce["GCI Store"] = "retail"
commerce["Post Office/Store"] = "retail"
commerce["Corner Store"] = "convenience"
commerce["The Discovery Store"] = "retail"
commerce["The Furniture Store"] = "retail"
commerce["Corner Store"] = "convenience"
commerce["Western Convenience Store"] = "convenience"
commerce["ARC Thrift Store"] = "retail"
commerce["Schrader's Country Store"] = "convenience"
commerce["Diamond Shamrock Corner Store"] = "convenience"
commerce["Bob's Stores"] = "retail"
commerce["Camp Store"] = "retail"
commerce["Eice Store"] = "retail"
commerce["Salvation Army Thrift Store"] = "retail"
commerce["Goodwill Store"] = "retail"
commerce["Salvation Army Family Store"] = "retail"
commerce["Cowboys Food Stores"] = "retail"
commerce["Goodwill Store"] = "retail"
commerce["Paint Store"] = "retail"
commerce["Keleinpeter Store"] = "retail"
commerce["Salvation Army Thrift Store"] = "retail"
commerce["Gilsland Farm Audubon Center Nature Store and Educational Center"] = "farm"
commerce["Goodwill Store"] = "retail"
commerce["Lamb's Book & Bible Store"] = "retail"
commerce["L L Bean Home Store"] = "mall"
commerce["The Paper Store"] = "retail"
commerce["Snyder Drug Store"] = "pharmacy"
commerce["Salvation Army Thrift Store"] = "retail"
commerce["Clark Convenience Store"] = "convenience"


commerce["Faith Academy"] = "school"
commerce["Academy Sports + Outdoors"] = "retail"
commerce["Academy Sports & Outdoors"] = "retail"
commerce["Minnieland Academy"] = "school"
commerce["Berachah Academy"] = "school"
commerce["Academy Sports and Outdoors"] = "retail"
commerce["Innovations Academy"] = "school"
commerce["The King's Classical Academy"] = "school"
commerce["Academy Art Center"] = "school"
commerce["Academy"] = "school"
commerce["Henry Ford Academy"] = "school"
commerce["Coleman Freshman Academy"] = "school"
commerce["Academy Building"] = "school"
commerce["Academic Enrichment Center"] = "school"
commerce["Thurgood Marshall Academy"] = "school"
commerce["English for Academic Purpose"] = "school"
commerce["Dance Tech Academy"] = "school"
commerce["Dance Academy"] = "school"
commerce["Academic building"] = "school"
commerce["Academy House"] = "school"
commerce["Academic Center"] = "school"
commerce["Ribbens Academic Complex"] = "school"
commerce["Manhattan Gymnastics Academy"] = "recreation"
commerce["Landrum Academic Center"] = "school"
commerce["Academic Resource Center / PASS Office"] = "school"
commerce["Columbia Academy"] = "school"
commerce["New Horizon Academy"] = "school"

commerce["Raritan Toll Plaza"] = "road"
commerce["11 Toll Gate"] = "road"
commerce["Bergen Toll Plaza"] = "road"
commerce["Union Toll Plaza"] = "road"
commerce["Paramus Toll Plaza"] = "road"
commerce["Pomona/Airport Toll Entrance"] = "road"
commerce["Toll Plaza"] = "road"
commerce["Tolliver"] = "road"
commerce["Toll"] = "road"

commerce["University House"] = "college"
commerce["University Bookstore"] = "college"
commerce["University Village Phase II"] = "college"
commerce["University Village"] = "college"
commerce["University Mall"] = "mall"
commerce["First Universalist Parish of Derby Line"] = "church"
commerce["University Bookstore"] = "college"
commerce["University Station Professional Offices"] = "college"
commerce["University Services Building"] = "college"
commerce["University Center"] = "college"
commerce["Gibson University Center"] = "college"
commerce["University of Arkansas at Monticello Fine Arts Center"] = "college"
commerce["University of Connecticut"] = "college"
commerce["University of Delaware Botanic Gardens"] = "college"
commerce["De Paul University"] = "college"
commerce["University of Kansas - Lawrence Campus Landscape and Construction Building"] = "college"
commerce["University Center"] = "college"
commerce["Higgins University Center"] = "college"
commerce["University Hall"] = "college"
commerce["University Center"] = "college"
commerce["Delta State University Hangar"] = "hangar"
commerce["Montana State University"] = "college"
commerce["University of Alabama Recreation Center"] = "college"
commerce["Sitka Unitarian Universalist Fellowship Hall"] = "church"
commerce["University of California Washington Center"] = "college"
commerce["University Honors Program"] = "college"
commerce["Augusta University Student Center"] = "college"
commerce["University Theatre"] = "college"
commerce["University Park Mall"] = "mall"
commerce["University of Kentucky Extension Office"] = "college"
commerce["Kaplan University"] = "college"

commerce["Bismarck Civic Center"] = "civic"
commerce["West Warwick Civic Center"] = "civic"
commerce["Cheyenne Civic Center"] = "civic"
commerce["Pelham Civic Center"] = "civic"
commerce["William A. Egan Civic & Convention Center"] = "civic"
commerce["Civic Center"] = "civic"
commerce["Civic Center"] = "civic"
commerce["Valier Civic Center"] = "civic"
commerce["Marin County Civic Center"] = "civic"
commerce["Garcelon Civic Center"] = "civic"
commerce["Bloomington Civic Plaza"] = "civic"
commerce["Ocean Springs Civic Center"] = "civic"

commerce["Clark County Regional Justice Court"] = "government"
commerce["Linden Court Residence Halls"] = "dormitory"
commerce["Frenger Food Court"] = "mall"
commerce["Mandan City Hall and Municipal Court"] = "government"
commerce["Tulane Court Townhouses"] = "house"
commerce["Jack Stewart Racquetball Courts"] = "recreation"
commerce["Courtyard By Marriott"] = "hotel"
commerce["Colonial Court Apartments"] = "apartments"
commerce["Wyoming State Supreme Court"] = "government"
commerce["Courtyard by Marriott Tempe Downtown"] = "hotel"
commerce["Courtney Honda"] = "auto"
commerce["Courtyard Marriott"] = "hotel"
commerce["Family Court"] = "government"
commerce["Superior Court of the District of Columbia - Building A"] = "government"
commerce["Superior Court of the District of Columbia - Building B"] = "government"
commerce["United States Court of Military Appeals"] = "government"
commerce["Courtyard Village"] = "commercial"
commerce["US District Court Clerk"] = "government"
commerce["Fayette County Circuit Court"] = "government"
commerce["Fayette County District Court"] = "government"
commerce["Federal Court House"] = "government"
commerce["Courtyard Marriott"] = "hotel"
commerce["District Court of Maryland"] = "government"
commerce["Amber Court Apartments"] = "apartments"
commerce["Mississippi Supreme Court"] = "government"
commerce["United States District Court"] = "government"
commerce["Alabama Supreme Court"] = "government"
commerce["Dallas County Court House"] = "government"
commerce["Crawford County Court House"] = "government"
commerce["Kern County Court"] = "government"
commerce["Ali'iolani Hale (Hawaii Supreme Court)"] = "government"
commerce["Clearwater County Court House"] = "government"
commerce["Mc Clurg Court Center"] = "government"
commerce["Courtyard Cincinnati Covington"] = "hotel"
commerce["Courtney Farms"] = "farm"
commerce["Food Court"] = "fastfood"

commerce["Performing Arts Center"] = "civic"
commerce["Hughes Fine Arts Center"] = "civic"
commerce["Fine Arts Center"] = "civic"
commerce["Performing Arts Center"] = "civic"
commerce["Rotunda for Arts and Sciences"] = "college"
commerce["Performing Arts Center"] = "civic"
commerce["Michael's Arts and Crafts"] = "retail"
commerce["Monongalia Arts Center"] = "civic"
commerce["Alaska Center for the Performing Arts"] = "civic"
commerce["Performing Arts Center"] = "civic"
commerce["Fine Arts"] = "civic"
commerce["Arkansas Arts Center"] = "civic"
commerce["Arkadelphia Arts Center"] = "civic"
commerce["University of Arkansas at Monticello Fine Arts Center"] = "civic"
commerce["Performing Arts Center"] = "civic"
commerce["Center for the Arts"] = "civic"
commerce["Arts and Industries Building"] = "civic"
commerce["Weathersby Fine Arts Building"] = "civic"
commerce["Martin Performing Arts Center"] = "civic"
commerce["Citi Performing Arts Center"] = "civic"
commerce["Performing Arts Center"] = "civic"
commerce["Dollye M E Robinson Liberal Arts Building"] = "civic"
commerce["Arts Center of Mississippi"] = "civic"
commerce["Juneau Arts & Culture Center (JACC)"] = "civic"
commerce["Nelson Fine Arts Center"] = "civic"
commerce["Bushnell Center for the Performing Arts"] = "civic"
commerce["Austin Arts Center"] = "civic"
commerce["Studio Arts Building"] = "civic"
commerce["Woodruff Arts Center"] = "civic"
commerce["(CULI) Culinary Arts - 1310 University Drive"] = "college"
commerce["(PAAW) Public Affairs and Arts West Building"] = "civic"
commerce["(MORR ) Morrison Center for the Performing Arts"] = "civic"
commerce["Fine Arts Building"] = "civic"
commerce["Arts Building"] = "civic"
commerce["Arts & Communcations"] = "civic"
commerce["Armstrong Hall of Fine Arts"] = "civic"
commerce["Music and Dramatic Arts"] = "civic"
commerce["Center for The Arts"] = "civic"
commerce["Culinary Arts Annex"] = "college"
commerce["Mary O'Keefe Cultural Arts Center"] = "civic"
commerce["Fine Arts Building"] = "civic"

commerce["Greater Nashua Mental Health Center"] = "medical"
commerce["Albuquerque Health Care for the Homeless"] = "medical"
commerce["Sierra Health Care Center"] = "medical"
commerce["Domenici Center for Health Sciences Education"] = "medical"
commerce["Martin-Tyrrell-Washington District Health"] = "medical"
commerce["Health Lodge"] = "medical"
commerce["UNC Health Care"] = "medical"
commerce["Go Health"] = "medical"
commerce["ManorCare Health Services"] = "medical"
commerce["Student Health Service and Counseling"] = "medical"
commerce["Healthy Living"] = "medical"
commerce["Health Lodge"] = "medical"
commerce["Department of Social and Health Services"] = "college"
commerce["Aurora Health Center"] = "medical"
commerce["Animal Health Center"] = "medical"
commerce["HealthWorks"] = "medical"
commerce["Cheyenne Health Care Center"] = "medical"
commerce["Bradford Health Services"] = "medical"
commerce["Arctic Health Building"] = "medical"
commerce["Pendergraft Health Sciences"] = "medical"
commerce["Southwest Community Health Center"] = "medical"
commerce["Home Health Services by T.L.C. Inc."] = "medical"
commerce["Southwest Health Center - Unity Healthcare"] = "medical"
commerce["U.S. Department of Health and Human Services"] = "government"
commerce["Teton Healthcare"] = "medical"
commerce["Health Center"] = "medical"
commerce["Allied Health"] = "medical"
commerce["Department of Health and Human Services"] = "government"
commerce["MedStar Health"] = "medical"
commerce["Health Lodge"] = "medical"
commerce["Banner Health Center"] = "medical"
commerce["Sun Life Family Health Center"] = "medical"
commerce["Tate Healthcare Specialists"] = "medical"
commerce["Highland Healthcare & Rehabilitation Center"] = "medical"
commerce["Lonoke County Health Unit"] = "medical"
commerce["Salud Family Health Center"] = "medical"
commerce["UC Health Emergency Room"] = "medical"
commerce["Sport&Health"] = "medical"
commerce["Pan American Health Organization"] = "medical"
commerce["Student Health Services"] = "medical"
commerce["State Department of Health"] = "government"
commerce["Kapolei Health Center"] = "medical"
commerce["Aspen Home Health and Hospice"] = "medical"
commerce["Creekside Home Health & Hospice"] = "medical"
commerce["Union Health Service"] = "medical"
commerce["Wood Health Center"] = "medical"
commerce["Doermer Family Center For Health Education"] = "medical"
commerce["Genesis Health Club"] = "recreation"
commerce["Old Health Lodge"] = "medical"
commerce["Munson Army Health Center"] = "medical"
commerce["Student Health Center (C&L Infirmary)"] = "medical"
commerce["Basic Health & Fitness"] = "recreation"
commerce["City of Bangor-Health and Welfare"] = "medical"
commerce["West Health"] = "medical"
commerce["Singing River Health System Financial Services"] = "medical"
commerce["Burrell Behavioral Health"] = "medical"
commerce["Marga Hosaeus Health and Physical Education Complex"] = "medical"
commerce["Singing River Health System Financial Services"] = "medical"
commerce["Burrell Behavioral Health"] = "medical"

commerce["Lorien Health Systems"] = "medical"
commerce["Lakeland Behavioral Health System"] = "medical"
commerce["Health Scienes Center"] = "college"
commerce["DMS Health Technologies"] = "commercial"
commerce["Homer Community Mental Health"] = "medical"
commerce["Cardinal Health"] = "medical"
commerce["Oklahoma State Department of Health"] = "government"
commerce["Health & Fitness Center / Student Life Center"] = "college"
commerce["Healthworks Rehab and Fitness"] = "medical"
commerce["Healthreach Urgent Care"] = "medical"
commerce["City County Health"] = "medical"

commerce["Student Training and Research Center"] = "college"
commerce["Student Services Center Building"] = "college"
commerce["UNMC Student Life Center"] = "college"
commerce["Student Services Building"] = "college"
commerce["Pioneer Heights Student Housing"] = "college"
commerce["Student Recreational Facility"] = "college"
commerce["Student Services Building"] = "college"
commerce["Lutheran Student Association"] = "college"
commerce["Baptist Student Ministry"] = "college"
commerce["Bill Moore Student Success Center"] = "college"
commerce["Student-Athlete Success Center"] = "college"
commerce["Brown Center for Students of Color"] = "college"
commerce["Health & Fitness Center / Student Life Center"] = "college"
commerce["Vermont Student Assistance Corporation"] = "college"
commerce["WVU Student Recreation Center"] = "college"

commerce["Willson Hospice House"] = "medical"

commerce["Our Lady of Lourdes"] = "church"
commerce["Our Lady of Guadalupe"] = "church"
commerce["Our Lady of Guadalupe Parish"] = "church"
commerce["Our Lady of Belen"] = "church"
commerce["Our Lady of the Gulf"] = "church"
commerce["Our Lady Star of the Sea"] = "church"
commerce["Our Sisters of Mary"] = "church"

commerce["Caribou Coffee"] = "fastfood"
commerce["Aspen Coffee Company"] = "fastfood"
commerce["Coffee Rush"] = "fastfood"
commerce["EVP Coffee"] = "fastfood"
commerce["Dutch Bros Coffee"] = "fastfood"
commerce["Villa Coffeehouse"] = "fastfood"
commerce["Heine Brothers' Coffee"] = "fastfood"
commerce["Caribou Coffee"] = "fastfood"
commerce["Caribou Coffee"] = "fastfood"
commerce["Eclipse coffee & books"] = "fastfood"
commerce["Heritage Coffee Roasters"] = "fastfood"
commerce["Ebenezer's Coffee House"] = "fastfood"
commerce["Shelburne Falls Coffee Roasters"] = "fastfood"
commerce["Water Street Coffee Joint"] = "fastfood"
commerce["Dunn Bros Coffee"] = "fastfood"
commerce["Crows Coffee"] = "fastfood"

commerce["Embassy Suites"] = "hotel"

commerce["Community Center"] = "civic"
commerce["Community Center"] = "civic"
commerce["Community Building"] = "civic"
commerce["Phillis Wheatley Community Center"] = "civic"
commerce["Gayville Community Center"] = "civic"
commerce["Community Center"] = "civic"
commerce["Residential Learning Community"] = "civic"
commerce["United Jewish Community Center"] = "civic"
commerce["Brandermill Community Association"] = "civic"
commerce["Goodman Community Center"] = "civic"
commerce["Lander Community & Convention Center"] = "civic"
commerce["Boykin Community Center"] = "civic"
commerce["Ketchikan Indian Community"] = "civic"
commerce["Community Building"] = "civic"
commerce["Community Chest"] = "civic"
commerce["Southwest Community Health Center"] = "medical"
commerce["Elephant Community Center"] = "civic"
commerce["Community Care"] = "civic"
commerce["Northern View Community"] = "civic"
commerce["Jackson/Mann Community Center"] = "civic"
commerce["Clopton Community Center"] = "civic"
commerce["Ootenna Community Center"] = "civic"
commerce["Inupiat Community of the Arctic Slope"] = "civic"
commerce["Billie Spielman Community Center Services"] = "civic"
commerce["Elmwood Community Center"] = "civic"
commerce["Middlefield Community Center"] = "civic"
commerce["GW Community Policing Center"] = "civic"
commerce["Monticello Assisted Living Community"] = "civic"
commerce["North Street Community Center"] = "civic"
commerce["Natchitoches Community Care Center"] = "civic"
commerce["Border Area Community Arena"] = "civic"
commerce["New Ulm Community Center"] = "civic"
commerce["Senior Citizens Community Center"] = "civic"
commerce["Southeast Community Center"] = "parking"
commerce["Columbus Community Center"] = "parking"
commerce["Omaha Community Playhouse"] = "parking"
commerce["Odell Community Center"] = "parking"
commerce["Regency Lakeside Community Leasing Office & Clubhouse"] = "parking"
commerce["Pipal Park Community Center"] = "parking"
commerce["Montclair Community Center"] = "parking"
commerce["Jewish Community Center"] = "parking"
commerce["Community Center of Cloudcroft"] = "parking"
commerce["Jeanne Bellamah Community Center"] = "parking"
commerce["The Community Store"] = "parking"
commerce["Able Community Based Services"] = "parking"
commerce["CommunityCare of Oklahoma"] = "parking"
commerce["City of Stillwater Community Center"] = "parking"
commerce["Community Event Center"] = "parking"
commerce["Community Boating Center"] = "parking"
commerce["Freeman Community Center"] = "parking"
commerce["Syracuse Community Center"] = "parking"
commerce["J. Warren and Lois Mcclure Community Resource Center"] = "parking"
commerce["Burlington Community Boathouse"] = "parking"
commerce["Community Activities Center"] = "parking"

commerce["Blalock Seafood"] = "restaurant"
commerce["PeterPan Seafoods Dormitory"] = "restaurant"
commerce["CBY Seafood Processing"] = "restaurant"
commerce["Captain White Seafood City"] = "restaurant"
commerce["H Glenwoods Evans & Son Seafood"] = "restaurant"
commerce["Seafood Sam's"] = "restaurant"
commerce["Ocean Beauty Seafood"] = "restaurant"
commerce["False River Seafood"] = "restaurant"
commerce["Cajun Corner Seafood"] = "restaurant"
commerce["Mo's Seafood"] = "restaurant"
commerce["South Coast Seafood Company"] = "restaurant"


commerce["Delmonico's Italian Steakhouse"] = "restaurant"
commerce["Quaker Steak & Lube"] = "restaurant"
commerce["Saltgrass Steak House"] = "restaurant"
commerce["Freddy's Frozen Custard & Steakburgers"] = "restaurant"
commerce["Ponderosa Steakhouse"] = "restaurant"
commerce["Freddy's Frozen Custard & Steakburgers"] = "restaurant"
commerce["Freddy's Frozen Custard & Steakburgers"] = "restaurant"
commerce["Steak and Shake"] = "fastfood"
commerce["Kobe Japanese Steakhouse"] = "restaurant"
commerce["Longhorn Steak House"] = "restaurant"
commerce["Miyako Sushi & Steak House"] = "restaurant"
commerce["Scott's Steak House"] = "restaurant"
commerce["Trail Boss Steakhouse"] = "restaurant"
commerce["Cheryl's Steakhouse"] = "restaurant"
commerce["Freddy's Frozen Custard and Steakburgers"] = "restaurant"
commerce["Outback Steak House"] = "restaurant"
commerce["Lone Star Steak House"] = "restaurant"
commerce["Bugaboo Creek Steak House"] = "restaurant"
commerce["Long Horn Steak House"] = "restaurant"
commerce["Sagebrush Steakhouse"] = "restaurant"
commerce["Hoss's Steak & Sea House"] = "restaurant"
commerce["Hoss's Steak and Sea"] = "restaurant"
commerce["Steerfish Steak and Smoke"] = "restaurant"

commerce["Al's #1 Italian Beef"] = "fastfood"

commerce["Rita's Italian Ice"] = "fastfood"
commerce["Mazzio's Italian Eatery"] = "restaurant"
commerce["Mayflower Seafood"] = "restaurant"

commerce["New Jersey Motor Vehicle Commission"] = "government"
commerce["Deals Gap Motorcycle Resort"] = "auto"
commerce["Dakota Motor Sports"] = "auto"
commerce["Pantuso Motors"] = "auto"
commerce["Danny England Motors"] = "auto"
commerce["West Virginia Division of Motor Vehicles"] = "government"
commerce["Bennette's Motor World"] = "auto"
commerce["Motor Vehicle Division"] = "government"
commerce["St Anthony Motors"] = "auto"
commerce["Arnold Motor Supply"] = "auto"
commerce["Division of Motor Vehicles"] = "government"
commerce["Ezee Motor Company"] = "auto"
commerce["Bureau of Motor Vehicles"] = "government"
commerce["General Motors"] = "auto"
commerce["Strieter Motor Company"] = "auto"
commerce["Robbins Motor Company"] = "auto"
commerce["Crown Motors"] = "auto"
commerce["The Tire Choice"] = "auto"
commerce["Freedom Tire"] = "auto"
commerce["Tire World"] = "auto"
commerce["DIscount Tire"] = "auto"
commerce["Pascagoula Tire and Service"] = "auto"
commerce["Purcell Tire"] = "auto"
commerce["Reicher's Tire and Auto"] = "auto"
commerce["Frank's Tire #2"] = "auto"
commerce["Zeller Tire"] = "auto"
commerce["Martin Tire"] = "auto"
commerce["Bob Sumerel Tire & Service"] = "auto"
commerce["Tireman"] = "auto"
commerce["Transport Tire Inc."] = "auto"
commerce["TireWarehouse"] = "auto"
commerce["Great Western Tire"] = "auto"
commerce["National Tire and Battery"] = "auto"
commerce["Discount Tire Company"] = "auto"
commerce["Tread Quarters Discount Tire"] = "auto"
commerce["Tire Zone"] = "auto"
commerce["Elliott Tire & Service"] = "auto"

commerce["Automotive Collision Experts"] = "auto"
commerce["Network Automotive Service Center"] = "auto"
commerce["Big Ron's Auto Repair"] = "auto"
commerce["Carville's Auto Mart"] = "auto"
commerce["Auto World Specialists"] = "auto"
commerce["Sears Auto"] = "auto"
commerce["Chignoli Auto"] = "auto"
commerce["Auto Body"] = "auto"
commerce["Autobarn Nissan"] = "auto"
commerce["O'Brien's Auto Repair"] = "auto"
commerce["Auto Lab"] = "auto"
commerce["Precision Automotive"] = "auto"
commerce["Central Square Auto"] = "auto"
commerce["Auto Value"] = "auto"
commerce["Lindsey Auto Repair"] = "auto"
commerce["O'Reilly Automotive"] = "auto"
commerce["A & A Automotive"] = "auto"
commerce["Bentwrench Automotive"] = "auto"
commerce["Lindsey Auto Repair"] = "auto"
commerce["O'Reilly Automotive"] = "auto"
commerce["A & A Automotive"] = "auto"
commerce["Bentwrench Automotive"] = "auto"


commerce["New Mexico Human Services Department Income Support Division"] = "government"
commerce["Ohio Department of Transportation"] = "government"
commerce["(Closed) Donald Price Medium Security Facility, RI Department of Corrections"] = "government"
commerce["John J. Moran Medium Security Facility, RI Department of Corrections"] = "government"
commerce["Juvenile Corrections, RI Department of Youth, Children, and Families"] = "government"
commerce["Rhode Island Department of Transportation, Midstate Facility"] = "government"
commerce["Department of Buildings and Code"] = "government"
commerce["Texas Department of Transportation"] = "government"
commerce["Texas Department of Public Safety"] = "government"
commerce["Department of Workforce Services"] = "government"
commerce["Department of Social and Health Services"] = "government"
commerce["Wisconsin Department of Natural Resources"] = "government"
commerce["Arizona Department of Transportation"] = "government"
commerce["Arizona Department of Economic Security"] = "government"
commerce["Arkansas Department of Career Education Rehabilitation Services Division"] = "government"
commerce["Bridgeport Department of Parks and Recreation"] = "government"
commerce["U.S. Department of Health and Human Services"] = "government"
commerce["Frances Perkins Department of Labor Building"] = "government"
commerce["Grounds Department"] = "building"
commerce["Georgia Department of Revenue"] = "government"
commerce["DeKalb County Department of Watershed Management"] = "government"
commerce["Department of Labor and Industrial Relations"] = "government"
commerce["Idaho Department of Environmental Quality"] = "government"
commerce["Facilities Department"] = "building"
commerce["Kansas Department of Labor"] = "government"
commerce["Department of Health and Human Services"] = "government"
commerce["Physical Plant Department"] = "industrial"
commerce["Michigan Department of Natural Resources"] = "government"
commerce["Detroit Department of Transportation Administrative Offices"] = "government"
commerce["Minnesota Department of Natural Resources"] = "government"
commerce["Lauderdale County Sherriff's Department and Detention Facility"] = "policestation"
commerce["Agriculture & Commerce Department"] = "government"
commerce["Mississippi Department of Education"] = "government"
commerce["Mississippi Department of Transportation"] = "government"

commerce["Wakefield Department of Public Works"] = "government"
commerce["Employment Development Department"] = "government"
commerce["Delaware Department of Transportation"] = "government"
commerce["Oklahoma State Department of Health"] = "government"
commerce["Green County Highway Department"] = "government"
commerce["Wyoming State Department of Transportation Property Damage"] = "government"

commerce["Tuscaloosa Water Department"] = "government"
commerce["Honors Department"] = "college"
commerce["Alaska Department of Fish & Game"] = "government"
commerce["Bella Vista Village POA Water Department‎"] = "government"
commerce["County of Los Angeles - Department of Public Social Services"] = "government"
commerce["U.S. Department of State"] = "government"
commerce["Department of Athletics"] = "college"
commerce["Florida Department of Transportation"] = "government"
commerce["State Department of Health"] = "government"
commerce["Lanai Water Department"] = "government"
commerce["Hawaii Department of Education"] = "government"
commerce["Department of Kinesiology"] = "college"
commerce["Parks Department"] = "government"
commerce["Des Moines Fire and Rescue Department Station 4"] = "firestation"
commerce["Department of Public Works"] = "government"
commerce["Michigan Department of Transportation"] = "government"
commerce["Escanaba Department of Public Safety"] = "government"


commerce["Bass Pro Shops"] = "commercial"
commerce["Bass Pro"] = "commercial"
commerce["Toll Booth"] = "road"
commerce["RMC Parking Deck"] = "parking"
commerce["North ten Hoor Parking Deck"] = "parking"
commerce["South ten Hoor Parking Deck"] = "parking"
commerce["UAF CTC Parking"] = "parking"
commerce["Packard South Parking Structure"] = "parking"
commerce["Stadium Parking Structure"] = "parking"
commerce["10th St. Parking Structure"] = "parking"
commerce["Parking and Transportation Services Building"] = "parking"
commerce["Starvine Parking Deck"] = "parking"
commerce["Peavine Parking Deck"] = "parking"
commerce["Guest Parking"] = "parking"
commerce["Judiciary Complex Parking Structure"] = "parking"
commerce["Valet Parking"] = "parking"
commerce["Valet Parking"] = "parking"
commerce["Shady Grove Metro Station Parking"] = "parking"
commerce["Northern Parking Lot"] = "parking"

commerce["Wal-Mart Star Complex"] = "retail"
commerce["Wal-Mart North Data Center"] = "building"
commerce["Cabot Mart"] = "convenience"
commerce["Mini Mart"] = "convenience"
commerce["Bargain Mart"] = "convenience"
commerce["Carville's Auto Mart"] = "auto"
commerce["Mobile Mart"] = "convenience"
commerce["Bob's Carpet Mart"] = "retail"
commerce["Dion's Quik Mart"] = "convenience"
commerce["Wal Mart"] = "retail"
commerce["Milton Martin Toyota"] = "auto"
commerce["WalMart"] = "retail"
commerce["KMart"] = "retail"
commerce["Midget Mart"] = "convenience"
commerce["FAS Mart"] = "convenience"
commerce["StorageMart Office"] = "commercial"
commerce["Minit Mart"] = "convenience"
commerce["Nebraska Furniture Mart"] = "retail"
commerce["Saint Martins Headstart"] = "school"
commerce["Fivestar Food Mart"] = "convenience"
commerce["Rosie's Food Mart"] = "convenience"
commerce["Mallard Mart"] = "convenience"
commerce["Tiger Mart"] = "convenience"
commerce["Corner Mart"] = "convenience"
commerce["Exxon Tiger Mart"] = "fuel"
commerce["Jr. Food Mart"] = "convenience"
commerce["Campus Book Mart"] = "retail"
commerce["Beach Mini Mart"] = "convenience"
commerce["Quik Mart"] = "convenience"
commerce["Country Mart"] = "convenience"
commerce["Petro Mart"] = "fuel"
commerce["Moto Mart"] = "convenience"
commerce["Gas Mart USA"] = "fuel"
commerce["Jr. Food Mart"] = "fuel"

commerce["Greater Huntsville Humane Society"] = "commercial"
commerce["American Cancer Society - Hope Lodge"] = "medical"
commerce["National Geographic Society"] = "commercial"
commerce["Historical Society"] = "commercial"
commerce["Lucan Historical Society"] = "commercial"

commerce["Gazebo"] = "recreation"

commerce["Star Wash"] = "auto"
commerce["Washington Federal"] = "bank"
commerce["ProWash"] = "auto"
commerce["Washington Sports Club"] = "recreation"
commerce["The Washington Building"] = "government"
commerce["Walter E. Washington Convention Center"] = "civic"
commerce["University of California Washington Center"] = "college"
commerce["Washington Canoe Club"] = "civic"
commerce["Washington Square Mall"] = "mall"
commerce["South Blast Furnaces Washhouse"] = "industrial"
commerce["A&D Kwik Kar Wash"] = "auto"
commerce["Waterway Gas & Wash"] = "commercial"
commerce["Washington Dance Studio"] = "school"
commerce["Washington Monument"] = "government"
commerce["Wash Me"] = "auto"
commerce["Bus Wash Rack"] = "auto"

commerce["Rocky Mountain Wash"] = "auto"
commerce["KJ's Super Wash"] = "auto"

commerce["Peter Kiewit Lodge"] = "hotel"
commerce["Lee and Helen Sapp Riverview Lodge and Craft Center"] = "recreation"
commerce["Mallet Lodge"] = "hotel"
commerce["Durham Lodge & Birthday House"] = "hotel"
commerce["Repton Masonic Lodge"] = "recreation"
commerce["Washington Monument Lodge"] = "hotel"
commerce["Ecology Lodge"] = "hotel"
commerce["Dollar Mountain Lodge"] = "hotel"
commerce["Nelson Lodge"] = "hotel"
commerce["Grant Village Lodge"] = "hotel"
commerce["Old Faithful Lodge"] = "hotel"
commerce["Jackson Lake Lodge"] = "hotel"
commerce["Snowy Mountain Lodge"] = "hotel"
commerce["Alpenhof Lodge"] = "hotel"
commerce["Crystal Springs Lodge"] = "hotel"
commerce["Teton Mountain Lodge"] = "hotel"
commerce["Snake River Lodge and Spa"] = "hotel"
commerce["Cache Creek Lodge"] = "hotel"


commerce["Gas Express"] = "fuel"
commerce["Stub's Gas & Oil"] = "fuel"
commerce["Shell Gas"] = "fuel"
commerce["Hess Gas"] = "fuel"
commerce["B P Gas Station"] = "fuel"
commerce["Costco Gas"] = "fuel"
commerce["Gas Depot"] = "fuel"
commerce["Peoples Gas"] = "fuel"
commerce["Thornton's Gas Station"] = "fuel"
commerce["Hy-Vee Gas"] = "fuel"
commerce["BP Gas"] = "fuel"
commerce["Star Gas"] = "fuel"
commerce["Woody's Gas Express"] = "fuel"
commerce["Waterway Gas & Wash"] = "fuel"
commerce["Holiday Gas Station"] = "fuel"
commerce["Hy-Vee Gas"] = "fuel"
commerce["Lakes Gas"] = "fuel"
commerce["AirGas"] = "fuel"
commerce["Hy-Vee Gas"] = "fuel"
commerce["U-Gas"] = "fuel"
commerce["Gas Mart USA"] = "fuel"
commerce["AirGas"] = "fuel"

commerce["Uncle Ed's Oil Shoppe"] = "auto"
commerce["Fred Fuller Oil"] = "auto"
commerce["Cazenovia Lumber & Oil Co. Inc."] = "commercial"
commerce["Nichelson Oil, Inc"] = "commercial"
commerce["Oil Can Henry's"] = "commercial"
commerce["Meffert's Oil Co."] = "commercial"
commerce["Allegiant Oil"] = "commercial"

commerce["Quintard Mall"] = "mall"
commerce["Gadsden Mall"] = "mall"
commerce["McFarland Mall"] = "mall"
commerce["Bentley Mall"] = "mall"
commerce["Prescott Gateway Mall"] = "mall"
commerce["Superstition Springs Mall"] = "mall"
commerce["Power Square Mall"] = "mall"
commerce["Buckland Hills Mall"] = "mall"
commerce["Gwinnett Place Mall"] = "mall"
commerce["Lakeshore Mall"] = "mall"
commerce["North DeKalb Mall"] = "mall"
commerce["Northlake Mall"] = "mall"
commerce["Windward Mall"] = "mall"
commerce["Pearlridge Mall West"] = "mall"
commerce["Kahala Mall"] = "mall"
commerce["Karcher Mall"] = "mall"
commerce["Grand Teton Mall"] = "mall"
commerce["Silver Lake Mall"] = "mall"
commerce["Mallory House Assisted Living"] = "apartments"
commerce["Magic Valley Mall"] = "mall"
commerce["Washington Square Mall"] = "mall"
commerce["Wabash Landing Mall"] = "mall"
commerce["University Park Mall"] = "mall"
commerce["Oak Park Mall"] = "mall"
commerce["Towne West Mall"] = "mall"
commerce["Towne East Mall"] = "mall"
commerce["Cinemark Fayette Mall"] = "mall"
commerce["Florence Antique Mall"] = "mall"
commerce["Alexandria Mall"] = "mall"
commerce["Pecanland Mall"] = "mall"
commerce["Cortana Mall"] = "mall"
commerce["Mall of Louisiana"] = "mall"
commerce["Mallard Mart"] = "mall"
commerce["Bangor Mall"] = "mall"
commerce["Aroostook Centre Mall"] = "mall"
commerce["Airport Mall"] = "mall"
commerce["The Mall"] = "mall"
commerce["Allen Antique Mall"] = "mall"
commerce["Knollwood Mall"] = "mall"
commerce["Strip Mall"] = "mall"
commerce["Leigh Mall"] = "mall"
commerce["Metrocenter Mall"] = "mall"
commerce["Gallatin Valley Mall"] = "mall"
commerce["Rimrock Mall"] = "mall"
commerce["Leigh Mall"] = "mall"
commerce["Metrocenter Mall"] = "mall"

commerce["Salvation Army"] = "retail"
commerce["The Salvation Army"] = "retail"
commerce["Delaware Army National Guard"] = "military"
commerce["Salvation Army Thrift Store"] = "retail"
commerce["Salvation Army Family Store"] = "retail"
commerce["US Army Corps of Engineers Kansas City District"] = "military"
commerce["Munson Army Health Center"] = "medical"
commerce["Army Garage"] = "military"
commerce["U.S. Army Reserve Center"] = "military"
commerce["United States Army Corps of Engineers - New Olreans Distric (MVN)"] = "military"
commerce["Salvation Army Thrift Store"] = "retail"

commerce["Meadowood Mall"] = "mall"
commerce["Cottonwood Mall"] = "mall"
commerce["Mesilla Valley Mall"] = "mall"
commerce["Smith Haven Mall"] = "mall"
commerce["Buffalo Mall"] = "mall"
commerce["Gateway Fashion Mall"] = "mall"
commerce["Kirkwood Mall"] = "mall"
commerce["Prairie Hills Mall"] = "mall"
commerce["Western Hills Mall"] = "mall"
commerce["Point of View Mall"] = "mall"
commerce["Mall at Stonecrest"] = "mall"
commerce["Oakwood Mall"] = "mall"
commerce["King of Prussia Mall"] = "mall"
commerce["Plaza Guayama Mall"] = "mall"
commerce["Las Catalinas Mall"] = "mall"
commerce["TownePlace Suites Greenville Haywood Mall"] = "mall"
commerce["Northwoods Mall"] = "mall"
commerce["Rushmore Mall"] = "mall"
commerce["Eastgate Mall"] = "mall"
commerce["Layton Hills Mall"] = "mall"
commerce["Newgate Mall"] = "mall"
commerce["Blue Mall"] = "mall"
commerce["Diamond Run Mall"] = "mall"
commerce["Antique Mall"] = "mall"
commerce["Grand Central Mall"] = "mall"
commerce["Morgantown Mall"] = "mall"
commerce["Mountaineer Mall"] = "mall"
commerce["Meadowbrook Mall"] = "mall"
commerce["West Towne Mall"] = "mall"


commerce["Psi Upsilon"] = "fraternity"
commerce["Phi Kappa Psi"] = "fraternity"
commerce["Kappa Alpha House"] = "fraternity"
commerce["Alpha Gamma Rho House"] = "fraternity"
commerce["Alpha Xi Delta House"] = "fraternity"
commerce["Alpha Phi House"] = "fraternity"
commerce["Sigma Alpha Epsilon House"] = "fraternity"
commerce["Lambda Chi Alpha House"] = "fraternity"
commerce["Kappa Alpha Order"] = "fraternity"
commerce["Alpha Tau Omega"] = "fraternity"
commerce["Alpha Epsilon Pi"] = "fraternity"
commerce["Kappa Alpha"] = "fraternity"
commerce["Alpha Gamma Delta"] = "fraternity"
commerce["Alpha Xi Delta"] = "fraternity"
commerce["Pi Kappa Alpha"] = "fraternity"
commerce["Sigma Alpha Epsilon"] = "fraternity"
commerce["Kappa Alpha"] = "fraternity"
commerce["Alpha Gamma Rho"] = "fraternity"
commerce["Alpha Phi Alpha"] = "fraternity"
commerce["Lambda Chi Alpha"] = "fraternity"
commerce["Sigma Alpha"] = "fraternity"
commerce["Lamda Chi Alpha"] = "fraternity"
commerce["Lamda Chi Alpha"] = "fraternity"
commerce["Delta Gamma"] = "fraternity"
commerce["Alpha Gamma Rho House"] = "fraternity"
commerce["Alpha Gamma Delta"] = "fraternity"
commerce["Gamma Phi Beta"] = "fraternity"
commerce["Alpha Gamma Rho"] = "fraternity"
commerce["Phi Gamma Delta"] = "fraternity"
commerce["Theta Xi"] = "fraternity"
commerce["Phi Delta Theta"] = "fraternity"
commerce["Sigma Alpha Epsilon House"] = "fraternity"
commerce["Alpha Epsilon Pi"] = "fraternity"
commerce["Tau Kappa Epsilon"] = "fraternity"
commerce["Sigma Phi Epsilon"] = "fraternity"
commerce["Sigma Alpha Epsilon"] = "fraternity"
commerce["Delta Kappa Epsilon"] = "fraternity"
commerce["Delta Tau Delta"] = "fraternity"
commerce["Delta Hangar"] = "airport"
commerce["Delta Electric Power Association"] = "industrial"
commerce["Delta Zeta Sorority"] = "fraternity"
commerce["Alpha Delta Pi House"] = "fraternity"
commerce["Kappa Delta"] = "fraternity"
commerce["Delta Chi"] = "fraternity"

commerce["City Equipment Building"] = "government"
commerce["Fairbanks City Hall"] = "government"
commerce["New Sagaya City Market"] = "government"
commerce["City of Sitka Building"] = "government"
commerce["Hotel/City Office"] = "government"
commerce["City of Homer pumping station"] = "government"
commerce["City of Homer Water Plant"] = "government"
commerce["Bella Vista City Hall"] = "government"
commerce["Cabot City Hall"] = "government"
commerce["City National Pawn"] = "government"
commerce["Skate City"] = "government"
commerce["Hartford City Hall"] = "government"
commerce["New Haven City Hall"] = "government"
commerce["Groton City Municipal Building"] = "government"
commerce["Ringgold City Hall"] = "government"
commerce["Pearl City Shopping Center"] = "government"
commerce["Kapolei Hale (City Hall)"] = "government"
commerce["Orofino City Hall"] = "government"
commerce["Ankeny City Hall"] = "government"
commerce["US Army Corps of Engineers Kansas City District"] = "military"
commerce["Newport City Hall"] = "government"
commerce["Natchitoches City Hall"] = "government"
commerce["City of Bangor-Health and Welfare"] = "government"
commerce["Ocean Springs City Hall"] = "government"
commerce["Camper City"] = "government"
commerce["Boys and Girls Clubs of Greater Kansas City"] = "civic"
commerce["City Shop"] = "retail"
commerce["Ocean Springs City Hall"] = "government"
commerce["Kansas City Bier Company"] = "government"
commerce["Fort Mitchell City Hall"] = "government"
commerce["Warwick City Hall"] = "government"
commerce["Syracuse City Hall"] = "government"

commerce["Monte Sano Lodge"] = "hotel"
commerce["Pike's Waterfront Lodge"] = "hotel"
commerce["Day Lodge"] = "hotel"
commerce["Homer Elks Lodge 2127"] = "recreation"
commerce["Bright Angel Lodge"] = "hotel"
commerce["American Cancer Society - Hope Lodge"] = "medical"
commerce["Rock Creek Lodge"] = "hotel"
commerce["Boulder Lodge"] = "hotel"
commerce["Eagle Rock Lodge"] = "hotel"
commerce["GuestHouse Lodge Sandpoint"] = "hotel"
commerce["Kelly Canyon Ski Lodge"] = "hotel"
commerce["Lodge"] = "hotel"
commerce["The Craydor Ford Nature Lodge"] = "hotel"
commerce["Handicraft Lodge"] = "hotel"
commerce["Old Health Lodge"] = "hotel"
commerce["Lure Lodge"] = "hotel"
commerce["The Lodge"] = "hotel"
commerce["White Pine Lodge"] = "hotel"
commerce["Econo Lodge Central"] = "motel"
commerce["Caribou Highlands Lodge Executive Lodges"] = "hotel"
commerce["Masonic Temple McLeod Lodge #424"] = "recreation"
commerce["Elk's Lodge"] = "recreation"
commerce["Lake McDonald Lodge"] = "hotel"
commerce["Traveler's Lodge"] = "motel"
commerce["Many Glacier Lodge"] = "hotel"
commerce["Masonic Temple McLeod Lodge #424"] = "recreation"
commerce["Elk's Lodge"] = "recreation"
commerce["Pike's Waterfront Lodge"] = "hotel"
commerce["Day Lodge"] = "hotel"
commerce["Homer Elks Lodge 2127"] = "recreation"
commerce["Bright Angel Lodge"] = "hotel"
commerce["The Lodge Sasquatch Kitchen"] = "hotel"
commerce["Safari Lodge"] = "hotel"
commerce["The Lodge"] = "hotel"
commerce["Cabot Lodge #319"] = "hotel"
commerce["Rock Creek Lodge"] = "hotel"
commerce["Boulder Lodge"] = "hotel"
commerce["Main Lodge"] = "hotel"
commerce["McOmber Lodge"] = "hotel"
commerce["Mt. Rose Main Lodge"] = "hotel"
commerce["East Peak Lodge"] = "hotel"
commerce["Boulder Lodge"] = "hotel"
commerce["Econo Lodge Bellmawr"] = "motel"
commerce["The Lodge at Sierra Blanca"] = "hotel"
commerce["Base Lodge"] = "hotel"
commerce["Nature Lodge"] = "hotel"
commerce["The Lodge"] = "hotel"
commerce["Angry Beaver Lodge"] = "hotel"
commerce["Safari Lodge"] = "hotel"
commerce["Moose Lodge"] = "recreation"
commerce["The Lodge"] = "hotel"
commerce["Moose Lodge"] = "hotel"
commerce["Spearfish Canyon Lodge"] = "hotel"
commerce["Craft Lodge"] = "hotel"
commerce["Nature Lodge"] = "hotel"
commerce["Rock Crest Lodge and Cabin"] = "hotel"
commerce["EconoLodge Custer"] = "motel"
commerce["Lyons Lodge"] = "hotel"
commerce["Best Western Black Hills Lodge"] = "hotel"
commerce["Sherwood Lodge"] = "hotel"
commerce["Bell's Motor Lodge"] = "hotel"
commerce["Old Lodge"] = "hotel"
commerce["Econo Lodge Downtown"] = "hotel"
commerce["Zion Lodge"] = "hotel"
commerce["Red Pine Lodge"] = "hotel"
commerce["Ruthcliffe Lodge"] = "hotel"
commerce["Gatehouse Lodge"] = "hotel"
commerce["Allyn's Lodge"] = "hotel"
commerce["Gate House Lodge"] = "hotel"
commerce["Valley House Lodge"] = "hotel"
commerce["Suicide Six Base Lodge"] = "hotel"
commerce["Nature Lodge"] = "hotel"
commerce["Budget Lodge"] = "hotel"
commerce["Moose Lodge"] = "motel"
commerce["Stratford Motor Lodge"] = "hotel"
commerce["Soaring Eagle Lodge"] = "hotel"
commerce["Econo Lodge Coliseum"] = "motel"
commerce["Whitegrass Ski Lodge"] = "hotel"

commerce["Anchorage Baptist Temple"] = "church"
commerce["Idaho Falls Idaho Temple"] = "church"
commerce["Temple Beth El"] = "church"
commerce["Temple Beth Shalom"] = "church"

commerce["Nordstrom"] = "retail"

commerce["Golf Course Maintenance"] = "recreation"
commerce["Papio Bay Aquatic Center"] = "recreation"
commerce["Ice Arena"] = "recreation"
commerce["Boys and Girls Club"] = "recreation"
commerce["Fairbanks Curling Club"] = "recreation"
commerce["Crowne Plaza San Marcos Golf Resort"] = "recreation"
commerce["Nome Recreation Center"] = "recreation"
commerce["Cypress Woods Golf and Country Club"] = "recreation"
commerce["Pinecrest Municipal Golf Course Clubhouse"] = "recreation"
commerce["Burke Memorial Golf Course Tee House"] = "recreation"
commerce["Golf Course Maintenance"] = "recreation"
commerce["Golf USA"] = "recreation"
commerce["Golf Course Maintenance"] = "recreation"
commerce["Golf Clubhouse"] = "recreation"
commerce["Crowne Plaza San Marcos Golf Resort"] = "recreation"
commerce["Golf Course Maintenance"] = "recreation"
commerce["Fore Seasons Golf Club"] = "recreation"
commerce["Golf Course Maintenance"] = "recreation"
commerce["Elkhorn Ridge Golf Course"] = "recreation"
commerce["Stone Creek Golf Club"] = "recreation"
commerce["Eagle Run Golf Course"] = "recreation"
commerce["Pacific Springs Golf Course"] = "recreation"
commerce["Golf USA"] = "recreation"
commerce["Johnny Goodman Golf Course"] = "recreation"
commerce["Tara Hills Golf Course"] = "recreation"
commerce["Eagle Hills Golf Course"] = "recreation"
commerce["Papio Greens Golf Center"] = "recreation"
commerce["Golf Course Maintenance"] = "recreation"
commerce["Willow Run Golf Course"] = "recreation"
commerce["Hidden Valley Golf Course"] = "recreation"
commerce["Lakeview Golf Resort & Spa"] = "recreation"
commerce["Golf Clubhouse"] = "recreation"

commerce["Venus Condominiums"] = "apartments"
commerce["Park At Pearlridge Condominiums"] = "apartments"
commerce["Harbor Light Condominiums"] = "apartments"
commerce["Hillcrest Village Condominiums"] = "apartments"
commerce["Monroe House Condominium"] = "apartments"
commerce["SandCastle Condominiums"] = "apartments"
commerce["Condominio Rexville Park"] = "apartments"
commerce["Condominio Sol"] = "apartments"
commerce["Condominio Portales de Bayamon"] = "apartments"
commerce["Condominio Los Girasoles"] = "apartments"
commerce["Carolyn Condominium"] = "apartments"

commerce["Centennial Hall Convention Center"] = "civic"
commerce["Alaska State Capital"] = "government"
commerce["Hawaii Convention Center"] = "civic"
commerce["Jackson Convention Complex"] = "civic"
commerce["Mobile Convention Center"] = "civic"
commerce["Huntsville Visitors And Convention Center"] = "civic"
commerce["Convention Center"] = "civic"
commerce["Birmingham Jefferson Convention Complex Arena"] = "civic"
commerce["Centennial Hall Convention Center"] = "civic"
commerce["Phoenix Convention Center North"] = "civic"
commerce["Statehouse Convention Center"] = "civic"
commerce["Convention Center"] = "civic"
commerce["Connecticut Convention Center"] = "civic"
commerce["Las Vegas Convention Center"] = "civic"
commerce["Reno-Sparks Convention Center"] = "civic"
commerce["Mandalay Bay Convention Center"] = "civic"
commerce["Atlantic City Convention Center"] = "civic"
commerce["Las Cruces Convention Center"] = "civic"
commerce["Rhode Island Convention Center"] = "civic"
commerce["Spearfish Convention Center"] = "civic"
commerce["Greater Richmond Convention Center"] = "civic"
commerce["Convention Center Parking Deck"] = "parking"

commerce["National/Alamo"] = "commercial"

commerce["CVS pharmacy"] = "pharmacy"

commerce["Banco Popular"] = "bank"
commerce["TrustBank"] = "bank"
commerce["Bankers Trust"] = "bank"
commerce["MetaBank"] = "bank"
commerce["FirstBank"] = "bank"
commerce["1stBank"] = "bank"
commerce["USBank"] = "bank"
commerce["BankRI"] = "bank"
commerce["BankNewport"] = "bank"
commerce["BankWest"] = "bank"

commerce["Carls Jr"] = "fastfood"
commerce["Atlanta Bread Company"] = "fastfood"

commerce["Military and Naval Science Building"] = "military"

commerce["Anchorage Baptist Temple"] = "church"
commerce["Temple Sinai"] = "church"
commerce["Temple Beth El"] = "church"
commerce["Temple Israel"] = "church"

commerce["Homer Airport Terminal"] = "airport"
commerce["Hyatt Place Atlanta Airport North"] = "hotel"
commerce["Old Airport Control Tower"] = "airport"
commerce["Ohare Airport Structures"] = "airport"
commerce["O'Hare Airport Structures"] = "airport"
commerce["Wichita Mid-Continent Airport"] = "airport"
commerce["Cincinnati Airport Marriott"] = "hotel"
commerce["Ramada Shreveport Airport"] = "hotel"
commerce["Houlton International Airport Passenger Terminal"] = "airport"
commerce["Auburn-Lewiston Airport Air Service"] = "airport"
commerce["Biddeford Municipal Airport"] = "airport"
commerce["Knox County Regional Airport"] = "airport"
commerce["Wiscasset Airport"] = "airport"
commerce["Freeway Airport"] = "airport"
commerce["Missoula International Airport"] = "airport"
commerce["Montgomery Regional Airport Terminal"] = "airport"
commerce["Comfort Suites Airport South"] = "hotel"
commerce["Fairbanks International Airport"] = "airport"
commerce["Wiley Post-Will Rogers Memorial Airport Terminal"] = "airport"
commerce["Skagway Airport"] = "airport"
commerce["Unalaska Airport Terminal"] = "airport"
commerce["Airport maintenance Facility"] = "airport"
commerce["Travelodge Las Vegas Airport North/Near the Strip"] = "hotel"
commerce["Air Traffic Control, TF Green Airport"] = "airport"
commerce["Sioux Falls Regional Airport"] = "airport"
commerce["Burlington International Airport"] = "airport"
commerce["Chesapeake Airport L/H"] = "airport"
commerce["Morgantown Municipal Airport"] = "airport"

commerce["Sylvan Learning Center"] = "school"
commerce["Huntington Learning Center"] = "school"
commerce["(ILC) Interactive Learning Center"] = "school"
commerce["Childtime Learning Center"] = "school"
commerce["Littlest Angels Learning Center"] = "school"
commerce["The Learning Experience"] = "school"
commerce["The Learning Depot"] = "school"
commerce["Children's Learning Adventure"] = "school"
commerce["Learning Commons"] = "school"
commerce["Early Learning Center"] = "school"
commerce["Sylvan Learning Center"] = "school"
commerce["Children's World Learning Center"] = "school"
commerce["Santa Fe Institute Learning Lab"] = "school"
commerce["Ashe County Early Learning Center"] = "school"
commerce["Mathew Living Learning Center East"] = "school"
commerce["Mabee Learning Center"] = "school"
commerce["Cispus Learning Center"] = "school"

commerce["The Varsity"] = "restaurant"

commerce["Arizona National Guard"] = "military"
commerce["National/Alamo"] = "auto"
commerce["National Guard Armory"] = "military"
commerce["National Guard Armory"] = "military"
commerce["Craters of the Moon National Monument Visitor's Center"] = "park"
commerce["Bohemian National Cemetery"] = "cemetary"
commerce["National Guard Armory"] = "military"
commerce["National Simulation Center"] = "government"
commerce["National Weather Service"] = "government"
commerce["National Guard"] = "military"
commerce["Acadia National Park Headquarters"] = "park"
commerce["Air National Guard Recruitment Office"] = "military"
commerce["Arizona National Guard"] = "military"
commerce["Navajo National Monument Headquarters"] = "park"
commerce["National Guard"] = "military"
commerce["National Aeronautics and Space Administration Headquarters"] = "government"
commerce["Republican National Committee Offices"] = "commercial"
commerce["National Institute of Food and Agriculture"] = "government"
commerce["National Press Building"] = "government"
commerce["National Association of Black Social Workers"] = "commercial"
commerce["American Red Cross National Headquarters"] = "commercial"
commerce["East Wing National Gallery of Art"] = "civic"
commerce["Ohio National Guard"] = "military"
commerce["National Hardware"] = "hardware"
commerce["National Tire and Battery"] = "auto"

commerce["Peterson Senior Center"] = "civic"
commerce["Senior Citizens Center"] = "civic"
commerce["Riley County Seniors' Service Center"] = "civic"
commerce["Peterson Senior Center"] = "civic"
commerce["Senior Center"] = "civic"

commerce["Wiley (Harvey W.) Residence Hall (WILY)"] = "dormitory"
commerce["Mens Residence Hall"] = "dormitory"
commerce["Womens Residence Hall"] = "dormitory"
commerce["Park Manager's Residence"] = "dormitory"
commerce["Residence-Trailer"] = "dormitory"
commerce["Residence Garage"] = "dormitory"
commerce["Ranger Residence"] = "dormitory"
commerce["Residence (Birch)"] = "dormitory"
commerce["Arbol de la Vida Residence Hall"] = "dormitory"
commerce["Residence Hall"] = "dormitory"
commerce["Towers Residence Hall"] = "dormitory"
commerce["Harper Residence Hall"] = "dormitory"
commerce["Schramm Residence Hall"] = "dormitory"
commerce["Smith Residence Hall"] = "dormitory"
commerce["Tonopah Residence Complex"] = "dormitory"
commerce["Margie and Robert Falman Residence Hall"] = "dormitory"
commerce["Mitzi and Johnny Huges Residence Hall"] = "dormitory"
commerce["Corwin Residence Hall - L"] = "dormitory"
commerce["Rhodes-Garrett-Hamiel Residence Center"] = "dormitory"
commerce["Herdsman Residence"] = "dormitory"
commerce["Officer Residence"] = "dormitory"
commerce["Poteat Residence Hall"] = "dormitory"
commerce["Residence Life Facility Services"] = "dormitory"
commerce["Bishop's Residence"] = "dormitory"
commerce["Bridges Residence Hall"] = "dormitory"
commerce["Memorial Residence Hall"] = "dormitory"
commerce["Friend Residence Hall"] = "dormitory"
commerce["Reynolds Residence Hall"] = "dormitory"

commerce["Normal Park Elementary"] = "school"
commerce["Davis Elementary"] = "school"
commerce["Dildine Elementary"] = "school"
commerce["Henderson Elementary"] = "school"
commerce["Alta Vista Elementary"] = "school"
commerce["Sand Lake Elementary Classrooms"] = "school"
commerce["West Homer Elementary"] = "school"
commerce["Carrollwood Elementary"] = "school"
commerce["Manatee Elementary"] = "school"
commerce["Franklin D Roosevelt Elementary"] = "school"
commerce["Ballard West Elementary"] = "school"

commerce["Sears Hardware"] = "hardware"
commerce["ACE Hardware"] = "hardware"
commerce["Orchard Supply Hardware"] = "hardware"
commerce["ACE TrueValue Hardware"] = "hardware"
commerce["Ace Hardware - Wall Building Center"] = "hardware"
commerce["Heisler's Hardware"] = "hardware"
commerce["Harpeth True Value Hardware"] = "hardware"
commerce["Ridley's / Ace Hardware"] = "hardware"
commerce["Nichols Hardware"] = "hardware"
commerce["McLendon Hardware"] = "hardware"
commerce["CSC Home and Hardware"] = "hardware"
commerce["Auburn Hardware"] = "hardware"
commerce["Alaska Industrial Hardware"] = "hardware"
commerce["Skagway Hardware & Lumber Co"] = "hardware"
commerce["South Central Hardware"] = "hardware"
commerce["Orchard Supply Hardware"] = "hardware"
commerce["Elder's Ace Hardware"] = "hardware"
commerce["Rocknaks Hardware"] = "hardware"
commerce["Rocknack's Hardware Plus"] = "hardware"
commerce["Bloomington Hardware"] = "hardware"
commerce["O'Donnell Ace Hardware"] = "hardware"

commerce["Sigma Alpha Epsilon Fraternity house"] = "fraternity"
commerce["Pi Kappa Alpha Fraternity house (new)"] = "fraternity"
commerce["Kappa Alpha Order Fraternity house"] = "fraternity"
commerce["Pi Kappa Alpha Fraternity house (old)"] = "fraternity"
commerce["Kappa Sigma"] = "fraternity"
commerce["Sigma Alpha Epsilon Fraternity house"] = "fraternity"
commerce["Sigma Chi Fraternity house"] = "fraternity"
commerce["Sigma Nu Fraternity"] = "fraternity"
commerce["Sigma Kappa House"] = "fraternity"
commerce["Kappa Sigma House"] = "fraternity"
commerce["Phi Sigma Kappa House"] = "fraternity"
commerce["Kappa Sigma"] = "fraternity"
commerce["Sigma Nu"] = "fraternity"
commerce["Sigma Chi"] = "fraternity"
commerce["Theta Chi Fraternity house"] = "fraternity"
commerce["Phi Kappa Theta"] = "fraternity"
commerce["Beta Theta Pi"] = "fraternity"
commerce["Zeta Tau Alpha Sorority"] = "fraternity"
commerce["Alpha Delta Pi House"] = "fraternity"
commerce["Zeta Tau Alpha House"] = "fraternity"
commerce["Delta Zeta Sorority"] = "fraternity"

commerce["Rhode Island Mall"] = "mall"
commerce["Rhode Island Division of Motor Vehicles"] = "government"
commerce["Rhode Island Traffic Tribunal"] = "parking"
commerce["Kappa Delta Rho"] = "fraternity"
commerce["Beta Theta Pi"] = "fraternity"
commerce["Tau Kappa Epsilon Fraternity house"] = "fraternity"
commerce["Tau Kappa Epsilon"] = "fraternity"

commerce["Capital Tire"] = "auto"
commerce["Vermont Tire"] = "auto"
commerce["Sears Tire, Battery, & Auto Center"] = "auto"
commerce["Pomp's Tire"] = "auto"
commerce["Big O Tire"] = "auto"
commerce["Peerless Tire"] = "auto"
commerce["Tyrrell-Doyle Auto Center Chevrolet"] = "auto"
commerce["Cooper Automotive"] = "auto"
commerce["Auto Hobby Shop"] = "auto"

commerce["Christian Life Center"] = "church"
commerce["Eagle Point Christian Academy"] = "school"
commerce["Christ the Redeemer Lutheran"] = "church"
commerce["Christian Science Reading Room"] = "church"
commerce["Christian Campus Center"] = "school"
commerce["Happy Valley Christian Center"] = "church"
commerce["Christiana Commons Building"] = "school"
commerce["East Coast Christian Center"] = "school"
commerce["Christmas Tree Shops"] = "retail"
commerce["Christopher W. Klaus Advanced Computing Building"] = "school"
commerce["Christ the King Parish Center"] = "church"
commerce["Our Savior Lutheran"] = "church"
commerce["Temple Street Garage"] = "parking"
commerce["Bus Garage"] = "parking"
commerce["Fleet Garage"] = "parking"
commerce["Maintenence Garage"] = "parking"
commerce["Garage East (P1)"] = "parking"
commerce["Garage West (P2)"] = "parking"
commerce["Gold Garage"] = "parking"
commerce["Midtown Garage"] = "parking"
commerce["South Garage"] = "parking"
commerce["West Garage"] = "parking"
commerce["Waterfront Garage"] = "parking"
commerce["Bus Garage"] = "parking"
commerce["City of Macedonia Service Garage"] = "parking"

commerce["North Garage"] = "parking"
commerce["Garage A"] = "parking"
commerce["Garage B"] = "parking"
commerce["Garage C"] = "parking"
commerce["Lakeview Garage"] = "parking"
commerce["Water Street Garage"] = "parking"
commerce["East Street Garage"] = "parking"
commerce["Neon Garage"] = "parking"
commerce["Temple Street Garage"] = "parking"
commerce["Crown St Garage"] = "parking"
commerce["Webb Farm Garage"] = "parking"
commerce["3 Car Garage"] = "parking"
commerce["Stroud Farm Garage I"] = "parking"
commerce["44 Kent Way Garage"] = "parking"
commerce["2 Car Poultry Garage"] = "parking"
commerce["Bryan St. Garage"] = "parking"
commerce["Eastman Garage"] = "parking"
commerce["Capitol Terrace Garage"] = "parking"
commerce["Garages"] = "parking"
commerce["Burke Memorial Golf Course Maintenance Garage"] = "parking"

commerce["Battle Academy"] = "school"
commerce["The Nest Academy"] = "school"
commerce["Poder Academy"] = "school"

commerce["Ivan Smith Furniture"] = "retail"
commerce["Northern Mattress and Furniture"] = "retail"
commerce["Shunk Furniture"] = "retail"
commerce["Slumberland Furniture"] = "retail"
commerce["Ocean Springs Furniture"] = "retail"
commerce["OK Furniture"] = "retail"
commerce["Furniture Row"] = "retail"
commerce["Furniture Row"] = "retail"
commerce["Raymour & Flanigan Furniture"] = "retail"
commerce["Furniture Gallery"] = "retail"
commerce["Kimbrell's Furniture"] = "retail"
commerce["American Furniture Warehouse"] = "retail"
commerce["Furniture Row"] = "retail"
commerce["Furniture Store"] = "retail"
commerce["Furniture Row"] = "retail"
commerce["Value City Furniture"] = "retail"
commerce["Hoffman Furniture"] = "retail"
commerce["Wolf Furniture"] = "retail"
commerce["Cardi's Furniture"] = "retail"
commerce["Kimbrell's Furniture"] = "retail"
commerce["Slumberland Furniture"] = "retail"
commerce["Bassett Furniture"] = "retail"
commerce["Ashley Furniture"] = "retail"
commerce["Slumberland Furniture"] = "retail"
commerce["John Paras Furniture and Appliances"] = "retail"


commerce["Steak N' Shake"] = "restaurant"
commerce["Aaron's"] = "convenience"
commerce["Bath & Body Works"] = "retail"
commerce["The Vitamin Shoppe"] = "retail"
commerce["Norwalk Furniture"] = "retail"
commerce["Logan’s Roadhouse"] = "restaurant"
commerce["Lee’s Famous Recipe Chicken"] = "fastfood"
commerce["Curves"] = "recreation"
commerce["Phantom Fireworks"] = "retail"
commerce["Rocky Mountain Chocolate Factory"] = "restaurant"
commerce["LoanMax"] = "commercial"
commerce["Toys 'R' Us"] = "retail"

commerce["Northrop Grumman"] = "commercial"
commerce["SAIC"] = "commercial"

commerce["BLOC Coffee Company"] = "fastfood"
commerce["Blackbird Coffee"] = "fastfood"
commerce["The Coffee Mill"] = "fastfood"
commerce["Coal Creek Coffee Company"] = "fastfood"
commerce["Coffee Cat"] = "fastfood"
commerce["Captain's Coffee Roasting Company"] = "fastfood"
commerce["Coal Bay Coffee & Tea"] = "fastfood"
commerce["Greyhouse Coffee"] = "fastfood"
commerce["Scooter's Coffeehouse"] = "fastfood"
commerce["LaMar's Donut and Coffee"] = "fastfood"
commerce["Coffee House Waffle Shop"] = "fastfood"
commerce["Babb's Coffee House"] = "fastfood"

commerce["Carmike 10"] = "theatre"
commerce["Carmike 12"] = "theatre"
commerce["Regal Martinsburg Stadium 10"] = "theatre"
commerce["Regal Waterford 9"] = "theatre"
commerce["Regal Hollywood 24"] = "theatre"
commerce["Regal Louisiana Boardwalk Stadium 14 & IMAX"] = "theatre"

commerce["AMC"] = "theatre"
commerce["AMC Loews Plainville 20"] = "theatre"
commerce["AAMCO Transmissions"] = "auto"
commerce["AAMCO"] = "auto"
commerce["Cheyenne Automotive"] = "auto"
commerce["Mitchem Tire"] = "auto"
commerce["Adirondack Tire"] = "auto"
commerce["National Tire & Battery"] = "auto"
commerce["Eddie's Tire"] = "auto"

commerce["T.G.I. Friday’s"] = "restaurant"
commerce["Chili’s"] = "restaurant"

commerce["Hattie B. Strother Cafeteria"] = "restaurant"
commerce["Peachy's Smoothie Cafe"] = "restaurant"
commerce["Cafe Rio"] = "restaurant"
commerce["Birchwood Cafe"] = "restaurant"
commerce["Cafeteria"] = "restaurant"
commerce["Corner Cafe"] = "restaurant"
commerce["Eddie's Cafe"] = "restaurant"
commerce["Cafeteria"] = "restaurant"
commerce["Ray's Cafe"] = "restaurant"
commerce["VLA Old Cafeteria"] = "restaurant"
commerce["Rodeo Grocery and Cafe"] = "restaurant"
commerce["Delicias Cafe"] = "restaurant"
commerce["El Sombrero Patio Cafe"] = "restaurant"
commerce["Mountain View Cafe"] = "restaurant"
commerce["Wild Wing Cafe"] = "restaurant"
commerce["K&W Cafeteria"] = "restaurant"
commerce["Cafeteria"] = "restaurant"
commerce["J&S Cafeteria"] = "restaurant"
commerce["Fatz Cafe"] = "restaurant"
commerce["Clien's Cafe"] = "restaurant"
commerce["Cafeteria"] = "restaurant"
commerce["Taziki's Mediterranean Cafe"] = "restaurant"
commerce["Kneaders Bakery & Cafe"] = "restaurant"
commerce["Cafeteria"] = "restaurant"
commerce["The Oink Cafe"] = "restaurant"
commerce["Cafeteria"] = "restaurant"
commerce["Cafe Divan"] = "restaurant"
commerce["Cafeteria"] = "restaurant"
commerce["Laniakea Cafe"] = "restaurant"
commerce["Shari's Cafe and Pies"] = "restaurant"
commerce["Front Street Cafe"] = "restaurant"
commerce["Cafeteria"] = "restaurant"
commerce["Biscuits Cafe"] = "restaurant"
commerce["Cafe Yumm!"] = "restaurant"
commerce["Corner Bakery Cafe"] = "restaurant"
commerce["Wild Wing Cafe"] = "restaurant"
commerce["Cowboy Cafe"] = "restaurant"
commerce["Bay Leaf Cafe"] = "restaurant"
commerce["Rosa's Cafe"] = "restaurant"
commerce["Cotton Patch Cafe"] = "restaurant"
commerce["Luby's Cafeteria"] = "restaurant"
commerce["Cafeteria"] = "restaurant"
commerce["Cheddar's Casual Cafe"] = "restaurant"
commerce["Penny Cluse Cafe"] = "restaurant"
commerce["Tropical Smoothie Cafe"] = "restaurant"
commerce["Cafeteria"] = "restaurant"
commerce["Cheddar's Casual Cafe"] = "restaurant"
commerce["Cafeteria"] = "restaurant"
commerce["Rachel's Cafe and Hotspot"] = "restaurant"
commerce["Lotus Cafe Organic Food"] = "restaurant"
commerce["Prairie Rose Cafe"] = "restaurant"

commerce["Harvey Industries"] = "industrial"
commerce["Roush Industries"] = "industrial"
commerce["Polaris Industries"] = "industrial"
commerce["Harvey Industries"] = "industrial"
commerce["Building Industry Assoication of So. NM"] = "industrial"
commerce["Industrial Mechanical Engineering (IME)"] = "college"
commerce["Industrial Relations Building"] = "industrial"
commerce["Business and Industrial Institute"] = "industrial"
commerce["Shaw Industries"] = "industrial"
commerce["Deseret Industries"] = "industrial"
commerce["Varied Industries Building"] = "industrial"
commerce["Industrial Building"] = "industrial"
commerce["Cabanillas Industrial Park"] = "industrial"
commerce["Goodwill Industries of Middle Tennessee"] = "industrial"
commerce["Deseret Industries"] = "industrial"
commerce["Industrial"] = "industrial"

commerce["Fast Food Mart"] = "convenience"
commerce["Buy Quick Food Mart"] = "convenience"
commerce["Convenient Food Mart"] = "convenience"
commerce["Shell Food Mart"] = "convenience"

commerce["La Carreta Market"] = "grocery"
commerce["Community Markets"] = "grocery"
commerce["New Market"] = "grocery"
commerce["West End Market"] = "grocery"
commerce["Roy's Market"] = "grocery"
commerce["Teton Village Market"] = "grocery"

commerce["Crest Foods"] = "grocery"
commerce["Good Earth Natural Foods"] = "grocery"
commerce["BFS Foods"] = "grocery"
commerce["Festival Foods"] = "grocery"
commerce["EconoFoods"] = "grocery"
commerce["Super One Foods"] = "grocery"

commerce["Payne County Administration Building"] = "government"
commerce["US Social Security Administration"] = "government"
commerce["Planning and Codes Administration"] = "government"
commerce["SDSU Administration Building"] = "college"
commerce["TCAT Elizabethton Administration Building"] = "college"
commerce["US Social Security Administration"] = "government"
commerce["Federal Aviation Administration"] = "government"
commerce["Wyoming State Administration"] = "government"

commerce["Dairy Mart"] = "convenience"
commerce["Fiesta Mart"] = "convenience"
commerce["In'N'Out Mart"] = "convenience"
commerce["Dari Mart"] = "convenience"
commerce["Mini Pet Mart"] = "convenience"
commerce["Uni-Mart"] = "convenience"
commerce["Turkey Hill Minit Mart"] = "convenience"
commerce["Joe's Kwik Mart"] = "convenience"
commerce["Martin's BBQ"] = "restaurant"
commerce["Chinese American Mini Mart"] = "grocery"
commerce["Wal*Mart Supercenter"] = "grocery"
commerce["Ranch Mart"] = "convenience"
commerce["MAPCO Mart"] = "convenience"
commerce["Mapco Mart"] = "convenience"
commerce["Pet's Mart"] = "convenience"
commerce["Fiesta Mart"] = "convenience"
commerce["Wal-Mart Garden Center"] = "grocery"
commerce["Fas Mart"] = "convenience"
commerce["Miller Mart"] = "convenience"
commerce["H Mart"] = "grocery"
commerce["Handy Mart"] = "convenience"
commerce["GoMart"] = "convenience"
commerce["Go-Mart"] = "convenience"
commerce["Go Mart"] = "convenience"
commerce["Big K Mart"] = "retail"
commerce["Martindale's Western Store"] = "convenience"

commerce["Bill's Outdoor Sports"] = "retail"
commerce["Sportsman's Warehouse"] = "retail"
commerce["Institute for International Sport"] = "school"
commerce["The Tiger Sports Shop"] = "retail"
commerce["Rushmore Mountain Sports"] = "retail"
commerce["Bolton Valley Sports/Nordic Center"] = "retail"
commerce["Kevin Smith Sports"] = "retail"
commerce["Sportsman's Warehouse"] = "retail"
commerce["Pro Sports Club"] = "retail"
commerce["Olympic Sports & Spine Rehabilitation"] = "medical"
commerce["GCO Floor Covering & Dunhams Sports Store"] = "retail"
commerce["Smart Sports Medicine"] = "medical"
commerce["Olympic Sports Plaza"] = "recreation"

commerce["Hess Mart"] = "convenience"


_ = clock("Last Run")

# %%
from modelio import saveJoblib
saveJoblib(commerce, "buildingLookup.p")
_ = clock("Saving building lookup with {0} entries".format(len(commerce)))

saveJoblib(buildingMap, "buildingMap.p")
_ = clock("Saving building map with {0} entries".format(len(buildingMap)))

saveJoblib(buildingConv, "buildingConv.p")
_ = clock("Saving building type conversions with {0} entries".format(len(buildingConv)))


_ = clock("Last Run")
