# %%
## Basic stuff
#%load_ext autoreload
#%autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))


## Python Version
import sys
print("Python: {0}".format(sys.version))


## Install
import shapefile
import geohash
from timeUtils import clock, elapsed
from shapely.geometry.polygon import Polygon
from shapely.geometry import Point
from random import uniform
from fsUtils import isFile
from ioUtils import showSize, saveJoblib, loadJoblib
from webUtils import getWebData, getHTML, removeTag
from geoUtils import *
from geospatialUtils import saveGeoData, getBB, rmZipDir, getGeos
import pickle
from glob import glob
import geopy
import requests
from pandasUtils import getColData, castStr
from os.path import basename,splitext,join
from collections import Counter

import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# Python: 3.6.5 |Anaconda custom (x86_64)| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# Notebook Last Run Initiated: 2018-12-09 20:35:39.217660

# %%
# Global Params
basedir="/Users/tgadf/Downloads/fda"
prec=7
mainkey="FDA"

# %%
def saveCountyTypes(data):
    outfilename = "lookupCountyFDA.py"
    key = "county"
    import json
    print("def getCountyFDAData({0}):".format(key), file=open(outfilename, "w"))
    print("\tdata = {0}".format(json.dumps(data)), file=open(outfilename, "a"))
    print("\ttry:", file=open(outfilename, "a"))
    print("\t\tretval = data[{0}]".format(key), file=open(outfilename, "a"))
    print("\texcept:", file=open(outfilename, "a"))
    print("\t\tretval = None", file=open(outfilename, "a"))
    print("\treturn retval", file=open(outfilename, "a"))
    
    with open(outfilename) as f:
        newText=f.read().replace('null', 'None')
    with open(outfilename, "w") as f:
        f.write(newText)

    # %load_ext autoreload
    # %autoreload
    from lookupCountyFDA import getCountyFDAData
    print(getCountyFDAData('01001'))
    
def saveCountyAccess(data):
    outfilename = "lookupCountyFDAAccess.py"
    key = "county"
    import json
    print("def getCountyFDAAccessData({0}):".format(key), file=open(outfilename, "w"))
    print("\tdata = {0}".format(json.dumps(data)), file=open(outfilename, "a"))
    print("\ttry:", file=open(outfilename, "a"))
    print("\t\tretval = data[{0}]".format(key), file=open(outfilename, "a"))
    print("\texcept:", file=open(outfilename, "a"))
    print("\t\tretval = None", file=open(outfilename, "a"))
    print("\treturn retval", file=open(outfilename, "a"))
    
    with open(outfilename) as f:
        newText=f.read().replace('null', 'None')
    with open(outfilename, "w") as f:
        f.write(newText)

    # %load_ext autoreload
    # %autoreload
    from lookupCountyFDAAccess import getCountyFDAAccessData
    print(getCountyFDAAccessData('01001'))
    
def saveCountyAssitance(data):
    outfilename = "lookupCountyFDAAssistance.py"
    key = "county"
    import json
    print("def getCountyFDAAccessData({0}):".format(key), file=open(outfilename, "w"))
    print("\tdata = {0}".format(json.dumps(data)), file=open(outfilename, "a"))
    print("\ttry:", file=open(outfilename, "a"))
    print("\t\tretval = data[{0}]".format(key), file=open(outfilename, "a"))
    print("\texcept:", file=open(outfilename, "a"))
    print("\t\tretval = None", file=open(outfilename, "a"))
    print("\treturn retval", file=open(outfilename, "a"))
    
    with open(outfilename) as f:
        newText=f.read().replace('null', 'None')
    with open(outfilename, "w") as f:
        f.write(newText)
    
    # %load_ext autoreload
    # %autoreload
    from lookupCountyFDAAssistance import getCountyFDAAccessData
    print(getCountyFDAAccessData('01001'))
    
def saveCountyHealth(data):
    outfilename = "lookupCountyFDAHealth.py"
    key = "county"
    import json
    print("def getCountyFDAHealthData({0}):".format(key), file=open(outfilename, "w"))
    print("\tdata = {0}".format(json.dumps(data)), file=open(outfilename, "a"))
    print("\ttry:", file=open(outfilename, "a"))
    print("\t\tretval = data[{0}]".format(key), file=open(outfilename, "a"))
    print("\texcept:", file=open(outfilename, "a"))
    print("\t\tretval = None", file=open(outfilename, "a"))
    print("\treturn retval", file=open(outfilename, "a"))
    
    with open(outfilename) as f:
        newText=f.read().replace('null', 'None')
    with open(outfilename, "w") as f:
        f.write(newText)
    
    # %load_ext autoreload
    # %autoreload
    from lookupCountyFDAHealth import getCountyFDAHealthData
    print(getCountyFDAHealthData('01001'))
    
def saveCountyInsecurity(data):
    outfilename = "lookupCountyFDAInsecurity.py"
    key = "county"
    import json
    print("def getCountyFDAInsecurityData({0}):".format(key), file=open(outfilename, "w"))
    print("\tdata = {0}".format(json.dumps(data)), file=open(outfilename, "a"))
    print("\ttry:", file=open(outfilename, "a"))
    print("\t\tretval = data[{0}]".format(key), file=open(outfilename, "a"))
    print("\texcept:", file=open(outfilename, "a"))
    print("\t\tretval = None", file=open(outfilename, "a"))
    print("\treturn retval", file=open(outfilename, "a"))
    
    with open(outfilename) as f:
        newText=f.read().replace('null', 'None')
    with open(outfilename, "w") as f:
        f.write(newText)
    
    # %load_ext autoreload
    # %autoreload
    from lookupCountyFDAInsecurity import getCountyFDAInsecurityData
    print(getCountyFDAInsecurityData('01001'))
    
def saveCountyLocal(data):
    outfilename = "lookupCountyFDALocal.py"
    key = "county"
    import json
    print("def getCountyFDALocalData({0}):".format(key), file=open(outfilename, "w"))
    print("\tdata = {0}".format(json.dumps(data)), file=open(outfilename, "a"))
    print("\ttry:", file=open(outfilename, "a"))
    print("\t\tretval = data[{0}]".format(key), file=open(outfilename, "a"))
    print("\texcept:", file=open(outfilename, "a"))
    print("\t\tretval = None", file=open(outfilename, "a"))
    print("\treturn retval", file=open(outfilename, "a"))
    
    with open(outfilename) as f:
        newText=f.read().replace('null', 'None')
    with open(outfilename, "w") as f:
        f.write(newText)
    
    # %load_ext autoreload
    # %autoreload
    from lookupCountyFDALocal import getCountyFDALocalData
    print(getCountyFDALocalData('01001'))
    
def saveCountyRestaurants(data):
    outfilename = "lookupCountyFDARestaurants.py"
    key = "county"
    import json
    print("def getCountyFDARestaurantsData({0}):".format(key), file=open(outfilename, "w"))
    print("\tdata = {0}".format(json.dumps(data)), file=open(outfilename, "a"))
    print("\ttry:", file=open(outfilename, "a"))
    print("\t\tretval = data[{0}]".format(key), file=open(outfilename, "a"))
    print("\texcept:", file=open(outfilename, "a"))
    print("\t\tretval = None", file=open(outfilename, "a"))
    print("\treturn retval", file=open(outfilename, "a"))
    
    with open(outfilename) as f:
        newText=f.read().replace('null', 'None')
    with open(outfilename, "w") as f:
        f.write(newText)
    
    # %load_ext autoreload
    # %autoreload
    from lookupCountyFDARestaurants import getCountyFDARestaurantsData
    print(getCountyFDARestaurantsData('01001'))
    
def saveCountyStores(data):
    outfilename = "lookupCountyFDAStores.py"
    key = "county"
    import json
    print("def getCountyFDAStoresData({0}):".format(key), file=open(outfilename, "w"))
    print("\tdata = {0}".format(json.dumps(data)), file=open(outfilename, "a"))
    print("\ttry:", file=open(outfilename, "a"))
    print("\t\tretval = data[{0}]".format(key), file=open(outfilename, "a"))
    print("\texcept:", file=open(outfilename, "a"))
    print("\t\tretval = None", file=open(outfilename, "a"))
    print("\treturn retval", file=open(outfilename, "a"))
    
    with open(outfilename) as f:
        newText=f.read().replace('null', 'None')
    with open(outfilename, "w") as f:
        f.write(newText)
    
    # %load_ext autoreload
    # %autoreload
    from lookupCountyFDAStores import getCountyFDAStoresData
    print(getCountyFDAStoresData('01001'))
    
def saveCountyTaxes(data):
    outfilename = "lookupCountyFDATaxes.py"
    key = "county"
    import json
    print("def getCountyFDATaxesData({0}):".format(key), file=open(outfilename, "w"))
    print("\tdata = {0}".format(json.dumps(data)), file=open(outfilename, "a"))
    print("\ttry:", file=open(outfilename, "a"))
    print("\t\tretval = data[{0}]".format(key), file=open(outfilename, "a"))
    print("\texcept:", file=open(outfilename, "a"))
    print("\t\tretval = None", file=open(outfilename, "a"))
    print("\treturn retval", file=open(outfilename, "a"))
    
    with open(outfilename) as f:
        newText=f.read().replace('null', 'None')
    with open(outfilename, "w") as f:
        f.write(newText)
    
    # %load_ext autoreload
    # %autoreload
    from lookupCountyFDATaxes import getCountyFDATaxesData
    print(getCountyFDATaxesData('01001'))

# %%
from pandas import read_csv
from math import isnan
files = glob(join(basedir, "*taxes.csv"))
print(files)
#stores.csv', '/Users/tgadf/Downloads/fda/food_taxes
#local.csv', '/Users/tgadf/Downloads/fda/food_restaurants
#1/0
for filename in files:
    pdf = read_csv(filename)
    
    if basename(filename) == "food_taxes.csv":
        keep=['FIPS', 'MILK_PRICE10', 'SODA_PRICE10', 'MILK_SODA_PRICE10', 'SODATAX_STORES14', 'SODATAX_VENDM14', 'CHIPSTAX_STORES14', 'CHIPSTAX_VENDM14', 'FOOD_TAX14']
        pdf = getColData(pdf, colnames=keep)
        cols = [x.replace("PCT_", "") for x in list(pdf.columns)]
        pdf.columns = cols 
        counties = ["0"+x for x in castStr(pdf["FIPS"]) if len(x) == 4] + [x for x in castStr(pdf["FIPS"]) if len(x) == 5]
        pdf["FIPS"] = counties    
        data = {}
        cols = list(pdf.columns)
        for row in pdf.iterrows():
            rowvals = row[1].values
            county  = rowvals[0]
            data[county] = dict(zip(cols[1:], list(rowvals[1:])))
            for k in data[county].keys():
                if isnan(data[county][k]):
                    data[county][k] = None
        saveCountyTaxes(data)
    if basename(filename) == "food_stores.csv":
        keep=["FIPS", 'SNAPSPTH16', 'GROCPTH14', 'SUPERCPTH14', 'CONVSPTH14', 'SPECSPTH14']
        pdf = getColData(pdf, colnames=keep)
        cols = [x.replace("PCT_", "") for x in list(pdf.columns)]
        pdf.columns = cols 
        counties = ["0"+x for x in castStr(pdf["FIPS"]) if len(x) == 4] + [x for x in castStr(pdf["FIPS"]) if len(x) == 5]
        pdf["FIPS"] = counties    
        data = {}
        cols = list(pdf.columns)
        for row in pdf.iterrows():
            rowvals = row[1].values
            county  = rowvals[0]
            data[county] = dict(zip(cols[1:], list(rowvals[1:])))
            for k in data[county].keys():
                if isnan(data[county][k]):
                    data[county][k] = None
        saveCountyStores(data)
    if basename(filename) == "food_restaurants.csv":
        keep=["FIPS", 'FFRPTH14', 'FSRPTH14']
        pdf = getColData(pdf, colnames=keep)
        cols = [x.replace("PCT_", "") for x in list(pdf.columns)]
        pdf.columns = cols 
        counties = ["0"+x for x in castStr(pdf["FIPS"]) if len(x) == 4] + [x for x in castStr(pdf["FIPS"]) if len(x) == 5]
        pdf["FIPS"] = counties    
        data = {}
        cols = list(pdf.columns)
        for row in pdf.iterrows():
            rowvals = row[1].values
            county  = rowvals[0]
            data[county] = dict(zip(cols[1:], list(rowvals[1:])))
            for k in data[county].keys():
                if isnan(data[county][k]):
                    data[county][k] = None
        saveCountyRestaurants(data)
    if basename(filename) == "food_local.csv":    
        keep=['FIPS', 'PCT_LOCLFARM12', 'PCT_LOCLSALE12', 'PCT_FMRKT_SNAP16', 'PCT_FMRKT_WIC16', 'PCT_FMRKT_WICCASH16', 'PCT_FMRKT_SFMNP16', 'PCT_FMRKT_CREDIT16', 'PCT_FMRKT_FRVEG16', 'PCT_FMRKT_ANMLPROD16', 'PCT_FMRKT_BAKED16', 'PCT_FMRKT_OTHERFOOD16']
        pdf = getColData(pdf, colnames=keep)
        cols = [x.replace("PCT_", "") for x in list(pdf.columns)]
        pdf.columns = cols 
        counties = ["0"+x for x in castStr(pdf["FIPS"]) if len(x) == 4] + [x for x in castStr(pdf["FIPS"]) if len(x) == 5]
        pdf["FIPS"] = counties    
        data = {}
        cols = list(pdf.columns)
        for row in pdf.iterrows():
            rowvals = row[1].values
            county  = rowvals[0]
            data[county] = dict(zip(cols[1:], list(rowvals[1:])))
            for k in data[county].keys():
                if isnan(data[county][k]):
                    data[county][k] = None
        saveCountyLocal(data)
    if basename(filename) == "food_insecurity.csv":    
        keep=['FIPS', 'FOODINSEC_13_15', 'VLFOODSEC_13_15', 'FOODINSEC_CHILD_03_11']
        pdf = getColData(pdf, colnames=keep)
        cols = [x.replace("PCT_", "") for x in list(pdf.columns)]
        pdf.columns = cols 
        counties = ["0"+x for x in castStr(pdf["FIPS"]) if len(x) == 4] + [x for x in castStr(pdf["FIPS"]) if len(x) == 5]
        pdf["FIPS"] = counties    
        data = {}
        cols = list(pdf.columns)
        for row in pdf.iterrows():
            rowvals = row[1].values
            county  = rowvals[0]
            data[county] = dict(zip(cols[1:], list(rowvals[1:])))
            for k in data[county].keys():
                if isnan(data[county][k]):
                    data[county][k] = None
        saveCountyInsecurity(data)
    if basename(filename) == "food_health.csv":    
        keep=['FIPS', 'PCT_DIABETES_ADULTS13', 'PCT_OBESE_ADULTS13', 'PCT_HSPA15', 'RECFAC14', 'RECFACPTH14']
        pdf = getColData(pdf, colnames=keep)
        cols = [x.replace("PCT_", "") for x in list(pdf.columns)]
        pdf.columns = cols 
        counties = ["0"+x for x in castStr(pdf["FIPS"]) if len(x) == 4] + [x for x in castStr(pdf["FIPS"]) if len(x) == 5]
        pdf["FIPS"] = counties    
        data = {}
        cols = list(pdf.columns)
        for row in pdf.iterrows():
            rowvals = row[1].values
            county  = rowvals[0]
            data[county] = dict(zip(cols[1:], list(rowvals[1:])))
            for k in data[county].keys():
                if isnan(data[county][k]):
                    data[county][k] = None
        saveCountyHealth(data)
    if basename(filename) == "food_assistance.csv":
        keep = ['FIPS', 'PCT_SNAP12', 'PCT_SNAP16', 'PCT_NSLP09', 'PCT_NSLP15', 'PCT_FREE_LUNCH09', 'PCT_FREE_LUNCH14', 'PCT_REDUCED_LUNCH09', 'PCT_REDUCED_LUNCH14', 'PCT_SBP09', 'PCT_SBP15', 'PCT_SFSP09', 'PCT_SFSP15', 'PCT_WIC09', 'PCT_WIC15', 'PCT_CACFP09', 'PCT_CACFP15']
        pdf = getColData(pdf, colnames=keep)
        cols = [x.replace("PCT_", "") for x in list(pdf.columns)]
        pdf.columns = cols
        counties = ["0"+x for x in castStr(pdf["FIPS"]) if len(x) == 4] + [x for x in castStr(pdf["FIPS"]) if len(x) == 5]
        pdf["FIPS"] = counties
        
        data = {}
        cols = list(pdf.columns)
        for row in pdf.iterrows():
            rowvals = row[1].values
            county  = rowvals[0]
            data[county] = dict(zip(cols[1:], list(rowvals[1:])))
            for k in data[county].keys():
                if isnan(data[county][k]):
                    data[county][k] = None
        saveCountyAssitance(data)
    if basename(filename) == "food_access.csv":
        keep = ['FIPS','PCT_LACCESS_POP15','PCT_LACCESS_LOWI15','PCT_LACCESS_HHNV15','PCT_LACCESS_SNAP15','PCT_LACCESS_CHILD15','PCT_LACCESS_SENIORS15','PCT_LACCESS_WHITE15','PCT_LACCESS_BLACK15','PCT_LACCESS_HISP15','PCT_LACCESS_NHASIAN15','PCT_LACCESS_NHNA15','PCT_LACCESS_NHPI15','PCT_LACCESS_MULTIR15']
        pdf = getColData(pdf, colnames=keep)
        cols = [x.replace("PCT_", "") for x in list(pdf.columns)]
        pdf.columns = cols
        
        counties = ["0"+x for x in castStr(pdf["FIPS"]) if len(x) == 4] + [x for x in castStr(pdf["FIPS"]) if len(x) == 5]
        pdf["FIPS"] = counties
        
        data = {}
        cols = list(pdf.columns)
        for row in pdf.iterrows():
            rowvals = row[1].values
            data[rowvals[0]] = dict(zip(cols[1:], list(rowvals[1:])))
            
        saveCountyAccess(data)
    if basename(filename) == "county_types.csv":
        newcols = [x.replace("_2015_Update", "") for x in oldcols]
        newcols = [x.replace("_2015-Update", "") for x in newcols]
        newcols = [x.replace("_Loss_2010", "") for x in newcols]
        newcols = [x.replace("_2013", "") for x in newcols]
        newcols = [x.replace("_Cnty_2008_2012_25_64", "") for x in newcols]
        pdf.columns = newcols
        keep = ['FIPStxt', 'Farming', 'Mining', 'Manufacturing', 'Government', 'Recreation', 'Nonspecialized', 'Low_Education', 'Low_Employment', 'Pop', 'Retirement_Dest', 'Persistent_Poverty', 'Persistent_Related_Child_Poverty']
        pdf = getColData(pdf, colnames=keep)
        counties = ["0"+x for x in castStr(pdf["FIPStxt"]) if len(x) == 4] + [x for x in castStr(pdf["FIPStxt"]) if len(x) == 5]
        pdf["FIPStxt"] = counties
        
        data = {}
        cols = list(pdf.columns)
        for row in pdf.iterrows():
            rowvals = row[1].values
            data[rowvals[0]] = dict(zip(cols[1:], list(rowvals[1:])))
            
        saveCountyTypes(data)
# Out:
# ['/Users/tgadf/Downloads/fda/food_taxes.csv']
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'MILK_PRICE10': 0.9703046000000001, 'SODA_PRICE10': 0.9722158999999999, 'MILK_SODA_PRICE10': 0.9232891, 'SODATAX_STORES14': 4.0, 'SODATAX_VENDM14': 4.0, 'CHIPSTAX_STORES14': 4.0, 'CHIPSTAX_VENDM14': 4.0, 'FOOD_TAX14': 4.0}

# %%
", ".join([x for x in pdf.columns if (x.find("14") != -1 or x.find("10") != -1)])
# Out:
# 'MILK_PRICE10, SODA_PRICE10, MILK_SODA_PRICE10, SODATAX_STORES14, SODATAX_VENDM14, CHIPSTAX_STORES14, CHIPSTAX_VENDM14, FOOD_TAX14, Unnamed: 14'

# %%
# Out:
# '{"HI": null}'

# %%
pdf
# Out:
#        FIPS State       County  MILK_PRICE10  SODA_PRICE10  MILK_SODA_PRICE10  \
# 0     01001    AL      Autauga      0.970305      0.972216           0.923289
# 1     01003    AL      Baldwin      1.017690      1.001391           0.940165
# 2     01005    AL      Barbour      1.136671      0.992584           1.059400
# 3     01007    AL         Bibb      0.970305      0.972216           0.923289
# 4     01009    AL       Blount      0.970305      0.972216           0.923289
# 5     01011    AL      Bullock      0.970305      0.972216           0.923289
# 6     01013    AL       Butler      0.970305      0.972216           0.923289
# 7     01015    AL      Calhoun      0.970305      0.972216           0.923289
# 8     01017    AL     Chambers      0.856725      0.990880           0.799857
# 9     01019    AL     Cherokee      0.856725      0.990880           0.799857
# 10    01021    AL      Chilton      0.970305      0.972216           0.923289
# ...
