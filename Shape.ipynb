# %%
# %load_ext autoreload
# %autoreload
import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>
    div.output_area{
        max-height:10000px;
        overflow:scroll;
    }
</style>"""))

import uszipcode
import shapefile
from os.path import join
import numpy as np
import pygeohash as geohash
from timeUtils import clock, elapsed
from shapely.geometry.polygon import Polygon
from shapely.geometry import Point
from random import uniform
import folium

basedir="/Users/tgadf/Downloads"
# Out:
# Notebook Last Run Initiated: 2018-08-31 19:57:54.816569
# <style>.container { width:100% !important; }</style>
# <style>
#     div.output_area{
#         max-height:10000px;
#         overflow:scroll;
#     }
# </style>

# %%
def getBBox(shape):
    bbox = [float('%.6f' % coord) for coord in shape.bbox]
    return bbox

def getShapeGeos(poly, prec, geo, geos, ignores, depth, debug=False):
    if debug:
        print("getShapeGeos({0})".format(geo))
    if geo in ignores:
        return
    
    if depth > 150:
        return
    lat,long  = geohash.decode_exactly(geo)[:2]
    pnt  = Point(long,lat)
    if poly.contains(pnt) is False:
        if debug:
            print("    Adding {0} to list of ignores ({1})".format(geo, len(ignores)))
        ignores.add(geo)
        return
    else:
        geos.add(geo)
        ignores.add(geo)
        if debug:
            print("    Adding {0} to make {1} total geos".format(geo, len(geos)))
        dp = depth+1
        neighbors = set(geohash.neighbors(geo)).difference(ignores)
        #print(depth, len(geos), len(ignores), neighbors)
        for neighbor in list(neighbors):
            if debug:
                print("  Testing {0} from {1} at {2}".format(neighbor, geo, depth))
            getShapeGeos(poly=poly, prec=prec, geo=neighbor, geos=geos, ignores=ignores, depth=dp, debug=debug)
        return
    
def addGeos(geos, geo, init=False):
    nAdd  = 0
    nGeos = len(geos)
    geos.add(geo)
    neighbors = set(geohash.neighbors(geo)).difference(geos)
    for neighbor in list(neighbors):
        geos.add(neighbor)
        nneighbors = set(geohash.neighbors(neighbor)).difference(geos)
        for nneighbor in list(nneighbors):
            geos.add(nneighbor)
    dAdd = len(geos) - nGeos
    if dAdd > 0:
        return 0
    else:
        if init:
            return 0
        return 1
    
    
def addLinearGeos(irec, nshapes, shape, prec, maxmiss=None, debug=True):
    geos = set()
    for i,pnt in enumerate(shape.points):
        long,lat = pnt
        geo      = geohash.encode(latitude=lat, longitude=long, precision=prec)
        geos.add(geo)
    if debug:
        print("Added {0} geos (guess = N/A) from {1} points.".format(len(geos), len(shape.points)))
    return geos


def addShapeGeos(irec, nshapes, shape, prec, geos, maxmiss=None, debug=True):
    from random import random
    bbox = getBBox(shape)
    lng0      = min([bbox[0], bbox[2]])
    lngrange  = abs(bbox[0] - bbox[2])
    lat0      = min([bbox[1], bbox[3]])
    latrange  = abs(bbox[1] - bbox[3])
    dEW   = 111*latrange
    dNS   = 111*lngrange
    area  = dEW * dNS
    if prec == 5:
        geoarea = 4.9*4.9 / 2
    elif prec == 6:
        geoarea = 1.2*0.61
    elif prec == 7:
        geoarea = 0.152*0.152 / 2
    elif prec == 8:
        geoarea = 0.038*0.019 / 3
    else:
        raise ValueError("No idea about {0}".format(prec))
        geoarea = None
    from numpy import ceil
    ngeoguess = int(ceil(area / geoarea))
    minMR = 2500
    if maxmiss is None:
        maxmiss = min([max([ngeoguess,5]), minMR])

    nmiss=0
    nrounds   = 0
    maxR = 100000
    maxrounds = min([max([5*ngeoguess, 10]), maxR])
    if maxrounds == maxR and False:
        debug=True
    if debug:
        print("  addShapeGeos({0}/{1}\tKm EW = {2}, Km NS  = {3}, Sq Km = {4}, ngeos = {5})".format(irec, nshapes, round(dEW,1), round(dNS,1), round(area,1), ngeoguess), end="\t----> ")
    for i in range(maxrounds):
        nrounds += 1
        genlat = latrange*random() + lat0
        genlng = lngrange*random() + lng0
        geo    = geohash.encode(latitude=genlat, longitude=genlng, precision=prec)
        retval = addGeos(geos, geo)
        if retval == 0:
            nmiss = 0
        else:
            nmiss += 1
        if debug and False: print("\t",i,"\tMiss:\t",nmiss,"Ngeos:\t",len(geos))
        if nmiss > maxmiss:
            break
    if debug:
        print("Added {0} geos (guess = {1}) with {2} round and {3} misses in the end.".format(len(geos), ngeoguess, nrounds, nmiss))
    return

# %%
import gzip
import pickle

def save_zipped_pickle(obj, filename, protocol=-1):
    with gzip.open(filename, 'wb') as f:
        pickle.dump(obj, f, protocol)
        
def load_zipped_pickle(filename):
    with gzip.open(filename, 'rb') as f:
        loaded_object = pickle.load(f)
        return loaded_object

def saveGeoData(shapeData, geoShapeMap, Nshapes, ngeos, prefix):
    print("\n")
    import pickle
    fname = "{0}-data.p".format(prefix)
    print("There are {0} entries in the saved file.".format(len(shapeData)))
    pickle.dump(shapeData, open(fname, "wb"))
    print("Saved shape data to {0}".format(fname))
    print("\n")

    fname = "{0}-geos.p".format(prefix)
    print("There are {0} entries in the saved file.".format(ngeos))
    pickle.dump(geoShapeMap, open(fname, "wb"))
    print("Saved shape data to {0}".format(fname))
    print("\n")

# %%
geoID = 4
latID = 13
lngID = 14
wtrID = 11
lndID = 12
ids   = [geoID, latID, lngID, lndID, wtrID]

def splitGeoID(geoID):
    stateID  = geoID[:2]
    shape1ID = geoID[2:5]
    shape2ID = geoID[5:11]
    shape3ID = geoID[11:15]
    return [stateID, shape1ID, shape2ID, shape3ID]

def getRecordInfo(record):
    info = [record[x] for x in ids]
    info[1] = float(info[1])
    info[2] = float(info[2])
    return info

# %% [markdown]
# # HERE

# %%
from pandas import DataFrame
import pickle
here_data = pickle.load(open("here/HEREdata.p", "rb"))
here_data['lat'] = here_data['lat']/1e5
here_data['lon'] = here_data['lon']/1e5
use_here_data = here_data[here_data['iso_country_code'] == "USA"]

# %%
cats = {}
key  = None
for i,row in enumerate(open("here_cat_id.dat").readlines()):
    if i % 2 == 0:
        key = row.replace("\n", "")
        continue
    else:
        value = row.replace("\n", "")
        cats[key] = value
        key = None
for k,v in cats.items():
    print(k,v)
import pickle
pickle.dump(cats, open("here/catIDs.p", "wb"))
# Out:
# 2084 Winery
# 3578 ATM
# 4013 TrainStation
# 4100 CommuterRailStation
# 4170 BusStation
# 4482 FerryTerminal
# 4493 Marina
# 4580 PublicSportsAirport
# 4581 Airport
# 5000 BusinessFacility
# 5400 GroceryStore
# 5511 AutoDealerships
# 5512 AutoDealership-UsedCars
# 5540 PetrolandGasolineStation
# 5571 MotorcycleDealership
# 5800 Restaurant
# 5813 Nightlife
# 5999 HistoricalMonument
# 6000 Bank
# 6512 Shopping
# 7011 Hotel
# 7012 SkiResort
# 7013 OtherAccommodation
# 7014 SkiLift
# 7389 TouristInformation
# 7510 RentalCarAgency
# 7520 ParkingLot
# 7521 ParkingGarageandHouse
# 7522 ParkandRide
# 7538 AutoServiceandMaintenance
# 7832 Cinema
# 7897 RestArea
# 7929 PerformingArts
# 7933 BowlingCentre
# 7940 SportsComplex
# 7947 ParkandRecreationArea
# 7985 Casino
# 7990 ConventionandExhibitionCentre
# 7992 GolfCourse
# 7994 CivicandCommunityCentre
# 7996 AmusementPark
# 7997 SportsCentre
# 7998 IceSkatingRink
# 7999 TouristAttraction
# 8060 Hospital
# 8200 HigherEducation
# 8211 School
# 8231 Library
# 8410 Museum
# 8699 AutomobileClub
# 9050 BicycleSharingLocation
# 9051 BicycleParking
# 9052 Trailhead
# 9053 OutdoorService
# 9054 RangerStation
# 9055 RunningTrack
# 9056 Campsite
# 9057 BMXTrack
# 9059 BicycleService
# 9121 CityHall
# 9211 CourtHouse
# 9221 PoliceStation
# 9517 Campground
# 9525 GovernmentOffice
# 9527 FireDepartment
# 9530 PostOffice
# 9535 ConvenienceStore
# 9536 SpecialtyFoodStore
# 9537 ClothingStore
# 9522 TruckStopandPlaza
# 9545 DepartmentStore
# 9560 HomeSpecialtyStore
# 9565 Pharmacy
# 9567 SpecialtyStore
# 9568 SportingGoodStore
# 9572 RaceTrack
# 9573 GolfPracticeRange
# 9583 MedicalService
# 9589 PublicRestroom
# 9591 Cemetery
# 9592 HighwayExit
# 9593 TransportationService
# 9595 RepairServices
# 9596 TrainingCentreandInstitute
# 9710 WeighStation
# 9714 CargoCentre
# 9715 MilitaryBase
# 9717 Tollbooth
# 9718 AnimalPark
# 9719 TruckDealership
# 9720 TruckParking
# 9722 DeliveryEntrance
# 9723 Dock
# 9724 LoadingZone
# 9730 NamedIntersection
# 9986 HomeImprovementandHardwareStore
# 9987 ConsumerElectronicsStore
# 9988 OfficeSupplyandServiceStore
# 9989 TaxiStand
# 9991 IndustrialZone
# 9992 PlaceofWorship
# 9993 Embassy
# 9994 CountyCouncil
# 9995 Bookstore
# 9996 CoffeeShop
# 9999 BorderCrossing

# %%
shapeData   = {}
geoShapeMap = {}
ngeos = {}
shapeval = 'here'
Nshapes = 0
prec = 7
catIDs = pickle.load(open("here/catIDs.p", "rb"))
for row,rowdata in use_here_data.iterrows():
    if Nshapes % 250000 == 0 and Nshapes > 0:
        print(row,Nshapes)
    Nshapes += 1
    geo    = geohash.encode(latitude=rowdata['lat'], longitude=rowdata['lon'], precision=7)
    irec   = row
    catID  = str(int(rowdata['cat_id']))
    geoid  = catID
    name   = catIDs.get(catID)
    #geoid  = rowdata['poi_id']
    #htype  = rowdata['cat_id']
    
    if name is None:
        print(rowdata)
        1/0
    if shapeData.get(catID) is None:
        shapeData[catID] = {}
        shapeData[catID][geoid]   = {"Name": name}
        geoShapeMap[catID] = {}
        geoShapeMap[catID][geoid] = set()
    geoShapeMap[catID][geoid].add(geo)
    
for catID,catData in shapeData.items():
    shapeval = catIDs[catID]
    ngeos = len(geoShapeMap[catID][catID])
    print("Found {0} of type {1}".format(ngeos,shapeval))
    saveGeoData(shapeData[catID], geoShapeMap[catID], Nshapes, ngeos, "here/{0}-{1}".format(shapeval, prec))
# Out:
# 402753 250000
# 805836 500000
# 1209512 750000
# 1613642 1000000
# 2017407 1250000
# 2420441 1500000
# 2824037 1750000
# 3227998 2000000
# 3631825 2250000
# 4034628 2500000
# Found 235584 of type AutoServiceandMaintenance
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/AutoServiceandMaintenance-7-data.p
#
#
#
# There are 235584 entries in the saved file.
# Saved shape data to here/AutoServiceandMaintenance-7-geos.p
#
#
#
# Found 323799 of type Restaurant
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Restaurant-7-data.p
#
#
#
# There are 323799 entries in the saved file.
# Saved shape data to here/Restaurant-7-geos.p
#
#
#
# Found 67882 of type GroceryStore
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/GroceryStore-7-data.p
#
#
#
# There are 67882 entries in the saved file.
# Saved shape data to here/GroceryStore-7-geos.p
#
#
#
# Found 117064 of type SpecialtyStore
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/SpecialtyStore-7-data.p
#
#
#
# There are 117064 entries in the saved file.
# Saved shape data to here/SpecialtyStore-7-geos.p
#
#
#
# Found 3388 of type Marina
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Marina-7-data.p
#
#
#
# There are 3388 entries in the saved file.
# Saved shape data to here/Marina-7-geos.p
#
#
#
# Found 102068 of type ConvenienceStore
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/ConvenienceStore-7-data.p
#
#
#
# There are 102068 entries in the saved file.
# Saved shape data to here/ConvenienceStore-7-geos.p
#
#
#
# Found 112403 of type PetrolandGasolineStation
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/PetrolandGasolineStation-7-data.p
#
#
#
# There are 112403 entries in the saved file.
# Saved shape data to here/PetrolandGasolineStation-7-geos.p
#
#
#
# Found 6298 of type ParkingGarageandHouse
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/ParkingGarageandHouse-7-data.p
#
#
#
# There are 6298 entries in the saved file.
# Saved shape data to here/ParkingGarageandHouse-7-geos.p
#
#
#
# Found 11852 of type TransportationService
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/TransportationService-7-data.p
#
#
#
# There are 11852 entries in the saved file.
# Saved shape data to here/TransportationService-7-geos.p
#
#
#
# Found 16548 of type AutoDealerships
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/AutoDealerships-7-data.p
#
#
#
# There are 16548 entries in the saved file.
# Saved shape data to here/AutoDealerships-7-geos.p
#
#
#
# Found 37625 of type SportingGoodStore
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/SportingGoodStore-7-data.p
#
#
#
# There are 37625 entries in the saved file.
# Saved shape data to here/SportingGoodStore-7-geos.p
#
#
#
# Found 33400 of type CoffeeShop
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/CoffeeShop-7-data.p
#
#
#
# There are 33400 entries in the saved file.
# Saved shape data to here/CoffeeShop-7-geos.p
#
#
#
# Found 50084 of type ConsumerElectronicsStore
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/ConsumerElectronicsStore-7-data.p
#
#
#
# There are 50084 entries in the saved file.
# Saved shape data to here/ConsumerElectronicsStore-7-geos.p
#
#
#
# Found 29250 of type PostOffice
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/PostOffice-7-data.p
#
#
#
# There are 29250 entries in the saved file.
# Saved shape data to here/PostOffice-7-geos.p
#
#
#
# Found 121460 of type School
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/School-7-data.p
#
#
#
# There are 121460 entries in the saved file.
# Saved shape data to here/School-7-geos.p
#
#
#
# Found 64178 of type HomeImprovementandHardwareStore
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/HomeImprovementandHardwareStore-7-data.p
#
#
#
# There are 64178 entries in the saved file.
# Saved shape data to here/HomeImprovementandHardwareStore-7-geos.p
#
#
#
# Found 99003 of type Bank
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Bank-7-data.p
#
#
#
# There are 99003 entries in the saved file.
# Saved shape data to here/Bank-7-geos.p
#
#
#
# Found 121532 of type ATM
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/ATM-7-data.p
#
#
#
# There are 121532 entries in the saved file.
# Saved shape data to here/ATM-7-geos.p
#
#
#
# Found 3777 of type TruckParking
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/TruckParking-7-data.p
#
#
#
# There are 3777 entries in the saved file.
# Saved shape data to here/TruckParking-7-geos.p
#
#
#
# Found 10011 of type CityHall
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/CityHall-7-data.p
#
#
#
# There are 10011 entries in the saved file.
# Saved shape data to here/CityHall-7-geos.p
#
#
#
# Found 64110 of type ClothingStore
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/ClothingStore-7-data.p
#
#
#
# There are 64110 entries in the saved file.
# Saved shape data to here/ClothingStore-7-geos.p
#
#
#
# Found 66653 of type Hotel
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Hotel-7-data.p
#
#
#
# There are 66653 entries in the saved file.
# Saved shape data to here/Hotel-7-geos.p
#
#
#
# Found 78843 of type ParkandRecreationArea
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/ParkandRecreationArea-7-data.p
#
#
#
# There are 78843 entries in the saved file.
# Saved shape data to here/ParkandRecreationArea-7-geos.p
#
#
#
# Found 36844 of type HomeSpecialtyStore
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/HomeSpecialtyStore-7-data.p
#
#
#
# There are 36844 entries in the saved file.
# Saved shape data to here/HomeSpecialtyStore-7-geos.p
#
#
#
# Found 6001 of type HigherEducation
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/HigherEducation-7-data.p
#
#
#
# There are 6001 entries in the saved file.
# Saved shape data to here/HigherEducation-7-geos.p
#
#
#
# Found 2589 of type RestArea
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/RestArea-7-data.p
#
#
#
# There are 2589 entries in the saved file.
# Saved shape data to here/RestArea-7-geos.p
#
#
#
# Found 6461 of type RentalCarAgency
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/RentalCarAgency-7-data.p
#
#
#
# There are 6461 entries in the saved file.
# Saved shape data to here/RentalCarAgency-7-geos.p
#
#
#
# Found 15523 of type GolfCourse
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/GolfCourse-7-data.p
#
#
#
# There are 15523 entries in the saved file.
# Saved shape data to here/GolfCourse-7-geos.p
#
#
#
# Found 60378 of type Pharmacy
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Pharmacy-7-data.p
#
#
#
# There are 60378 entries in the saved file.
# Saved shape data to here/Pharmacy-7-geos.p
#
#
#
# Found 39672 of type HighwayExit
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/HighwayExit-7-data.p
#
#
#
# There are 39672 entries in the saved file.
# Saved shape data to here/HighwayExit-7-geos.p
#
#
#
# Found 2511 of type CommuterRailStation
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/CommuterRailStation-7-data.p
#
#
#
# There are 2511 entries in the saved file.
# Saved shape data to here/CommuterRailStation-7-geos.p
#
#
#
# Found 12906 of type PoliceStation
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/PoliceStation-7-data.p
#
#
#
# There are 12906 entries in the saved file.
# Saved shape data to here/PoliceStation-7-geos.p
#
#
#
# Found 44353 of type DepartmentStore
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/DepartmentStore-7-data.p
#
#
#
# There are 44353 entries in the saved file.
# Saved shape data to here/DepartmentStore-7-geos.p
#
#
#
# Found 4748 of type CourtHouse
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/CourtHouse-7-data.p
#
#
#
# There are 4748 entries in the saved file.
# Saved shape data to here/CourtHouse-7-geos.p
#
#
#
# Found 15431 of type TouristAttraction
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/TouristAttraction-7-data.p
#
#
#
# There are 15431 entries in the saved file.
# Saved shape data to here/TouristAttraction-7-geos.p
#
#
#
# Found 18534 of type OfficeSupplyandServiceStore
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/OfficeSupplyandServiceStore-7-data.p
#
#
#
# There are 18534 entries in the saved file.
# Saved shape data to here/OfficeSupplyandServiceStore-7-geos.p
#
#
#
# Found 7513 of type Hospital
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Hospital-7-data.p
#
#
#
# There are 7513 entries in the saved file.
# Saved shape data to here/Hospital-7-geos.p
#
#
#
# Found 8065 of type Dock
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Dock-7-data.p
#
#
#
# There are 8065 entries in the saved file.
# Saved shape data to here/Dock-7-geos.p
#
#
#
# Found 5719 of type Campground
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Campground-7-data.p
#
#
#
# There are 5719 entries in the saved file.
# Saved shape data to here/Campground-7-geos.p
#
#
#
# Found 8412 of type DeliveryEntrance
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/DeliveryEntrance-7-data.p
#
#
#
# There are 8412 entries in the saved file.
# Saved shape data to here/DeliveryEntrance-7-geos.p
#
#
#
# Found 15441 of type Library
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Library-7-data.p
#
#
#
# There are 15441 entries in the saved file.
# Saved shape data to here/Library-7-geos.p
#
#
#
# Found 6602 of type ParkingLot
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/ParkingLot-7-data.p
#
#
#
# There are 6602 entries in the saved file.
# Saved shape data to here/ParkingLot-7-geos.p
#
#
#
# Found 4399 of type Bookstore
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Bookstore-7-data.p
#
#
#
# There are 4399 entries in the saved file.
# Saved shape data to here/Bookstore-7-geos.p
#
#
#
# Found 9894 of type Museum
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Museum-7-data.p
#
#
#
# There are 9894 entries in the saved file.
# Saved shape data to here/Museum-7-geos.p
#
#
#
# Found 4425 of type Airport
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Airport-7-data.p
#
#
#
# There are 4425 entries in the saved file.
# Saved shape data to here/Airport-7-geos.p
#
#
#
# Found 2797 of type Winery
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Winery-7-data.p
#
#
#
# There are 2797 entries in the saved file.
# Saved shape data to here/Winery-7-geos.p
#
#
#
# Found 6223 of type Cinema
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Cinema-7-data.p
#
#
#
# There are 6223 entries in the saved file.
# Saved shape data to here/Cinema-7-geos.p
#
#
#
# Found 495 of type TaxiStand
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/TaxiStand-7-data.p
#
#
#
# There are 495 entries in the saved file.
# Saved shape data to here/TaxiStand-7-geos.p
#
#
#
# Found 1458 of type TruckStopandPlaza
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/TruckStopandPlaza-7-data.p
#
#
#
# There are 1458 entries in the saved file.
# Saved shape data to here/TruckStopandPlaza-7-geos.p
#
#
#
# Found 12789 of type BusinessFacility
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/BusinessFacility-7-data.p
#
#
#
# There are 12789 entries in the saved file.
# Saved shape data to here/BusinessFacility-7-geos.p
#
#
#
# Found 7492 of type Shopping
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Shopping-7-data.p
#
#
#
# There are 7492 entries in the saved file.
# Saved shape data to here/Shopping-7-geos.p
#
#
#
# Found 4495 of type PerformingArts
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/PerformingArts-7-data.p
#
#
#
# There are 4495 entries in the saved file.
# Saved shape data to here/PerformingArts-7-geos.p
#
#
#
# Found 648 of type CargoCentre
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/CargoCentre-7-data.p
#
#
#
# There are 648 entries in the saved file.
# Saved shape data to here/CargoCentre-7-geos.p
#
#
#
# Found 1075 of type ConventionandExhibitionCentre
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/ConventionandExhibitionCentre-7-data.p
#
#
#
# There are 1075 entries in the saved file.
# Saved shape data to here/ConventionandExhibitionCentre-7-geos.p
#
#
#
# Found 585 of type AnimalPark
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/AnimalPark-7-data.p
#
#
#
# There are 585 entries in the saved file.
# Saved shape data to here/AnimalPark-7-geos.p
#
#
#
# Found 601 of type TrainStation
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/TrainStation-7-data.p
#
#
#
# There are 601 entries in the saved file.
# Saved shape data to here/TrainStation-7-geos.p
#
#
#
# Found 2115 of type CivicandCommunityCentre
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/CivicandCommunityCentre-7-data.p
#
#
#
# There are 2115 entries in the saved file.
# Saved shape data to here/CivicandCommunityCentre-7-geos.p
#
#
#
# Found 1988 of type HistoricalMonument
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/HistoricalMonument-7-data.p
#
#
#
# There are 1988 entries in the saved file.
# Saved shape data to here/HistoricalMonument-7-geos.p
#
#
#
# Found 2351 of type SportsComplex
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/SportsComplex-7-data.p
#
#
#
# There are 2351 entries in the saved file.
# Saved shape data to here/SportsComplex-7-geos.p
#
#
#
# Found 1122 of type MotorcycleDealership
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/MotorcycleDealership-7-data.p
#
#
#
# There are 1122 entries in the saved file.
# Saved shape data to here/MotorcycleDealership-7-geos.p
#
#
#
# Found 383 of type SkiResort
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/SkiResort-7-data.p
#
#
#
# There are 383 entries in the saved file.
# Saved shape data to here/SkiResort-7-geos.p
#
#
#
# Found 1415 of type MilitaryBase
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/MilitaryBase-7-data.p
#
#
#
# There are 1415 entries in the saved file.
# Saved shape data to here/MilitaryBase-7-geos.p
#
#
#
# Found 3747 of type TouristInformation
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/TouristInformation-7-data.p
#
#
#
# There are 3747 entries in the saved file.
# Saved shape data to here/TouristInformation-7-geos.p
#
#
#
# Found 479 of type Embassy
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Embassy-7-data.p
#
#
#
# There are 479 entries in the saved file.
# Saved shape data to here/Embassy-7-geos.p
#
#
#
# Found 221 of type BicycleSharingLocation
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/BicycleSharingLocation-7-data.p
#
#
#
# There are 221 entries in the saved file.
# Saved shape data to here/BicycleSharingLocation-7-geos.p
#
#
#
# Found 1193 of type AmusementPark
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/AmusementPark-7-data.p
#
#
#
# There are 1193 entries in the saved file.
# Saved shape data to here/AmusementPark-7-geos.p
#
#
#
# Found 1626 of type ParkandRide
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/ParkandRide-7-data.p
#
#
#
# There are 1626 entries in the saved file.
# Saved shape data to here/ParkandRide-7-geos.p
#
#
#
# Found 1217 of type AutomobileClub
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/AutomobileClub-7-data.p
#
#
#
# There are 1217 entries in the saved file.
# Saved shape data to here/AutomobileClub-7-geos.p
#
#
#
# Found 479 of type BusStation
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/BusStation-7-data.p
#
#
#
# There are 479 entries in the saved file.
# Saved shape data to here/BusStation-7-geos.p
#
#
#
# Found 378 of type FerryTerminal
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/FerryTerminal-7-data.p
#
#
#
# There are 378 entries in the saved file.
# Saved shape data to here/FerryTerminal-7-geos.p
#
#
#
# Found 734 of type WeighStation
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/WeighStation-7-data.p
#
#
#
# There are 734 entries in the saved file.
# Saved shape data to here/WeighStation-7-geos.p
#
#
#
# Found 177 of type BorderCrossing
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/BorderCrossing-7-data.p
#
#
#
# There are 177 entries in the saved file.
# Saved shape data to here/BorderCrossing-7-geos.p
#
#
#
# Found 846 of type Casino
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Casino-7-data.p
#
#
#
# There are 846 entries in the saved file.
# Saved shape data to here/Casino-7-geos.p
#
#
#
# Found 43 of type BicycleParking
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/BicycleParking-7-data.p
#
#
#
# There are 43 entries in the saved file.
# Saved shape data to here/BicycleParking-7-geos.p
#
#
#
# Found 350 of type TruckDealership
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/TruckDealership-7-data.p
#
#
#
# There are 350 entries in the saved file.
# Saved shape data to here/TruckDealership-7-geos.p
#
#
#
# Found 2 of type Trailhead
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/Trailhead-7-data.p
#
#
#
# There are 2 entries in the saved file.
# Saved shape data to here/Trailhead-7-geos.p
#
#
#
# Found 1 of type BicycleService
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/BicycleService-7-data.p
#
#
#
# There are 1 entries in the saved file.
# Saved shape data to here/BicycleService-7-geos.p

# %%
import pickle
prec=7
from glob import glob
from os.path import basename,splitext
vals    = glob("here/*-{0}-geos.p".format(prec))
vals    = [splitext(basename(x))[0].split('-')[0] for x in vals]
geomap  = {}
records = {}
for mtype in vals:
    try:
        recdata = pickle.load(open("here/{0}-{1}-data.p".format(mtype, prec), "rb"))
        geodata = pickle.load(open("here/{0}-{1}-geos.p".format(mtype, prec), "rb"))
    except:
        continue
    ngeos = 0
    for geoid,geos in geodata.items():
        ngeos += len(geos)
        for geo in geos:
            if geomap.get(geo) is None:
                geomap[geo] = {}
            geomap[geo][mtype] = geoid

    for geoid,rec in recdata.items():
        records[geoid] = rec['Name']
        break
                
    print("{0}\t{1}\t---> {2} <---".format(mtype,ngeos,len(geomap)))
                
fname="geomap-{0}-HERE.p".format(prec)
print("Writing {0}".format(fname))
pickle.dump(geomap,  open(fname, "wb"))

fname="georec-{0}-HERE.p".format(prec)
print("Writing {0}".format(fname))
pickle.dump(records,  open(fname, "wb"))
# Out:
# Airport	4425	---> 4425 <---
# AmusementPark	1193	---> 5617 <---
# AnimalPark	585	---> 6197 <---
# ATM	121532	---> 127591 <---
# AutoDealerships	16548	---> 143006 <---
# AutomobileClub	1217	---> 143879 <---
# AutoServiceandMaintenance	235584	---> 354208 <---
# Bank	99003	---> 363865 <---
# BicycleParking	43	---> 363895 <---
# BicycleService	1	---> 363896 <---
# BicycleSharingLocation	221	---> 364049 <---
# Bookstore	4399	---> 366820 <---
# BorderCrossing	177	---> 366995 <---
# BusinessFacility	12789	---> 376850 <---
# BusStation	479	---> 377201 <---
# Campground	5719	---> 382773 <---
# CargoCentre	648	---> 383386 <---
# Casino	846	---> 384095 <---
# Cinema	6223	---> 388203 <---
# CityHall	10011	---> 396559 <---
# CivicandCommunityCentre	2115	---> 398392 <---
# ClothingStore	64110	---> 440864 <---
# CoffeeShop	33400	---> 456402 <---
# CommuterRailStation	2511	---> 457967 <---
# ConsumerElectronicsStore	50084	---> 480920 <---
# ConvenienceStore	102068	---> 543551 <---
# ConventionandExhibitionCentre	1075	---> 544359 <---
# CourtHouse	4748	---> 546464 <---
# DeliveryEntrance	8412	---> 552825 <---
# DepartmentStore	44353	---> 573869 <---
# Dock	8065	---> 576088 <---
# Embassy	479	---> 576255 <---
# FerryTerminal	378	---> 576587 <---
# GolfCourse	15523	---> 591951 <---
# GroceryStore	67882	---> 622557 <---
# HigherEducation	6001	---> 627098 <---
# HighwayExit	39672	---> 665542 <---
# HistoricalMonument	1988	---> 667043 <---
# HomeImprovementandHardwareStore	64178	---> 706241 <---
# HomeSpecialtyStore	36844	---> 722250 <---
# Hospital	7513	---> 729040 <---
# Hotel	66653	---> 776339 <---
# Library	15441	---> 785957 <---
# Marina	3388	---> 788873 <---
# MilitaryBase	1415	---> 790212 <---
# MotorcycleDealership	1122	---> 790706 <---
# Museum	9894	---> 796753 <---
# OfficeSupplyandServiceStore	18534	---> 802828 <---
# ParkandRecreationArea	78843	---> 874998 <---
# ParkandRide	1626	---> 876126 <---
# ParkingGarageandHouse	6298	---> 878570 <---
# ParkingLot	6602	---> 881602 <---
# PerformingArts	4495	---> 883433 <---
# PetrolandGasolineStation	112403	---> 904334 <---
# Pharmacy	60378	---> 920218 <---
# PoliceStation	12906	---> 925763 <---
# PostOffice	29250	---> 941946 <---
# RentalCarAgency	6461	---> 943800 <---
# RestArea	2589	---> 946311 <---
# Restaurant	323799	---> 1058886 <---
# School	121460	---> 1161253 <---
# Shopping	7492	---> 1163213 <---
# SkiResort	383	---> 1163492 <---
# SpecialtyStore	117064	---> 1196105 <---
# SportingGoodStore	37625	---> 1208948 <---
# SportsComplex	2351	---> 1210577 <---
# TaxiStand	495	---> 1210645 <---
# TouristAttraction	15431	---> 1216765 <---
# TouristInformation	3747	---> 1217761 <---
# Trailhead	2	---> 1217763 <---
# TrainStation	601	---> 1217981 <---
# TransportationService	11852	---> 1224896 <---
# TruckDealership	350	---> 1225073 <---
# TruckParking	3777	---> 1226385 <---
# TruckStopandPlaza	1458	---> 1226459 <---
# WeighStation	734	---> 1227170 <---
# Winery	2797	---> 1229515 <---
# Writing geomap-7-HERE.p
# Writing georec-7-HERE.p

# %%
geomap
# Out:
# {'dpme5s6': {'Airport': '4581'},
#  '9v1zzpn': {'Airport': '4581'},
#  'bd4pmre': {'Airport': '4581'},
#  'c87vnr6': {'Airport': '4581'},
#  'dr5rzjx': {'Airport': '4581'},
#  'dnt66hf': {'Airport': '4581'},
#  'dnx07hw': {'Airport': '4581'},
#  'djjutcy': {'Airport': '4581'},
#  'dn3kfev': {'Airport': '4581'},
#  'djbqxxy': {'Airport': '4581'},
#  'dr4r72q': {'Airport': '4581'},
#  'c22wnmu': {'Airport': '4581'},
#  'djg1xcm': {'Airport': '4581'},
#  'djdf8yj': {'Airport': '4581'},
#  '9vsmt4j': {'AnimalPark': '9718'},
#  '9yrujcc': {'AnimalPark': '9718'},
#  '9yk3wv4': {'AnimalPark': '9718'},
#  'dr760p7': {'AnimalPark': '9718'},
#  'dpmupb0': {'AnimalPark': '9718'},
#  'dq1wqzm': {'AnimalPark': '9718'},
#  '9zmkjw8': {'AnimalPark': '9718'},
#  'dpcq53w': {'AnimalPark': '9718'},
#  '9v1zx5m': {'AnimalPark': '9718'},
#  'cb8ykv0': {'AnimalPark': '9718'},
#  'dr7d8c2': {'AnimalPark': '9718'},
#  'djhzxhr': {'AnimalPark': '9718'},
#  '9w0hcm2': {'AnimalPark': '9718'},
#  '9ytxkqr': {'AnimalPark': '9718'},
#  '9ysfexx': {'AnimalPark': '9718'},
#  '9q61y0k': {'AnimalPark': '9718'},
#  'dhtyp16': {'AnimalPark': '9718'},
#  'cb3799v': {'AnimalPark': '9718'},
#  'dpe2q68': {'AnimalPark': '9718'},
#  'dr4vx3m': {'AnimalPark': '9718'},
#  'dr5xmv8': {'AnimalPark': '9718'},
#  'dhmgdqy': {'AnimalPark': '9718',
#   'GroceryStore': '5400',
#   'Museum': '8410',
#   'SpecialtyStore': '9567'},
#  'dp0wnwg': {'AnimalPark': '9718'},
#  'drk062e': {'ATM': '3578',
#   'Bank': '6000',
#   'ClothingStore': '9537',
#   'ConsumerElectronicsStore': '9987',
#   'GroceryStore': '5400',
#   'Pharmacy': '9565'},
#  'dr41su6': {'ATM': '3578'},
#  'drvpmj4': {'ATM': '3578', 'Bank': '6000'},
#  'dj8s76u': {'ATM': '3578', 'Bank': '6000'},
#  'cb4485d': {'ATM': '3578', 'Bank': '6000'},
#  'dn62utb': {'ATM': '3578', 'PostOffice': '9530'},
#  'djupxb3': {'ATM': '3578',
#   'ConvenienceStore': '9535',
#   'PetrolandGasolineStation': '5540'},
#  '9zzp8k2': {'ATM': '3578', 'Bank': '6000'},
#  '9vk4d22': {'ATM': '3578'},
#  '9vg5feh': {'ATM': '3578', 'Bank': '6000'},
#  'dqcw0ff': {'ATM': '3578', 'Bank': '6000'},
#  'dnfcbz7': {'ATM': '3578'},
#  'drk5z36': {'ATM': '3578'},
#  '9vqebcd': {'ATM': '3578', 'Bank': '6000'},
#  'dngzh0f': {'ATM': '3578', 'Bank': '6000'},
#  '9yzssu2': {'ATM': '3578', 'Bank': '6000'},
#  'dr4s1gc': {'ATM': '3578', 'Bank': '6000'},
#  'c22y8ey': {'ATM': '3578'},
#  '9zwewzr': {'ATM': '3578',
#   'AutoServiceandMaintenance': '7538',
#   'Bank': '6000'},
#  '9mupmzy': {'ATM': '3578', 'Bank': '6000'},
#  'dr1h72x': {'ATM': '3578', 'Bank': '6000'},
#  'dp0z5ws': {'ATM': '3578', 'Bank': '6000'},
#  '9rbmeq4': {'ATM': '3578', 'Bank': '6000'},
#  '9qcg8x1': {'ATM': '3578', 'Bank': '6000'},
#  '9yyme4c': {'ATM': '3578', 'Restaurant': '5800', 'SpecialtyStore': '9567'},
#  '9zvxy6x': {'ATM': '3578', 'Pharmacy': '9565'},
#  '9vgk3hm': {'ATM': '3578', 'Bank': '6000'},
#  'dr720cq': {'ATM': '3578', 'Bank': '6000'},
#  'dje4gn6': {'ATM': '3578'},
#  'dr5k6vg': {'ATM': '3578', 'Bank': '6000', 'Restaurant': '5800'},
#  'dq9cb4t': {'ATM': '3578', 'Bank': '6000', 'Restaurant': '5800'},
#  'dn3857q': {'ATM': '3578'},
#  'dpmgtb2': {'ATM': '3578', 'Bank': '6000'},
#  'dj75km6': {'ATM': '3578', 'Bank': '6000'},
#  '9y70d4u': {'ATM': '3578', 'Bank': '6000'},
#  'dp3kdwy': {'ATM': '3578', 'Bank': '6000'},
#  'dqchthc': {'ATM': '3578', 'Bank': '6000'},
#  '9yutsq1': {'ATM': '3578'},
#  'dn076zy': {'ATM': '3578',
#   'Bank': '6000',
#   'GroceryStore': '5400',
#   'Restaurant': '5800'},
#  'dr39k0q': {'ATM': '3578', 'Bookstore': '9995'},
#  '9q5c30w': {'ATM': '3578', 'Bank': '6000'},
#  'dpgdw0k': {'ATM': '3578', 'Bank': '6000', 'SpecialtyStore': '9567'},
#  '9qcetue': {'ATM': '3578', 'Bank': '6000'},
#  '9z7f8uz': {'ATM': '3578',
#   'ConvenienceStore': '9535',
#   'PetrolandGasolineStation': '5540'},
#  'dps8zc0': {'ATM': '3578'},
#  '9q94r7q': {'ATM': '3578', 'GroceryStore': '5400', 'SpecialtyStore': '9567'},
#  '9vhhvf2': {'ATM': '3578', 'Bank': '6000'},
#  'dn812fq': {'ATM': '3578', 'Bank': '6000'},
#  '9qcw9dh': {'ATM': '3578', 'GroceryStore': '5400'},
#  'dr4krg0': {'ATM': '3578'},
#  'dpt10z9': {'ATM': '3578'},
#  'djmgzt0': {'ATM': '3578', 'Bank': '6000'},
#  '9yutxnw': {'ATM': '3578',
#   'Cinema': '7832',
#   'ClothingStore': '9537',
#   'CoffeeShop': '9996',
#   'ConsumerElectronicsStore': '9987',
#   'DepartmentStore': '9545',
#   'GroceryStore': '5400',
#   'HomeSpecialtyStore': '9560',
#   'Restaurant': '5800',
#   'Shopping': '6512',
#   'SpecialtyStore': '9567',
#   'SportingGoodStore': '9568'},
#  '9ufw1dv': {'ATM': '3578'},
#  'dngpyu2': {'ATM': '3578', 'Bank': '6000'},
#  'dp3wjrx': {'ATM': '3578',
#   'Bank': '6000',
#   'BusinessFacility': '5000',
#   'CoffeeShop': '9996',
#   'Restaurant': '5800',
#   'School': '8211'},
#  '9q5ex15': {'ATM': '3578', 'SpecialtyStore': '9567'},
#  'dn8dzm7': {'ATM': '3578', 'Bank': '6000'},
#  '9tbnjuq': {'ATM': '3578'},
#  'dq1jq4t': {'ATM': '3578', 'Bank': '6000'},
#  'djq5bjn': {'ATM': '3578', 'Restaurant': '5800'},
#  '9vfcqpf': {'ATM': '3578', 'Bank': '6000'},
#  'c2kx2we': {'ATM': '3578',
#   'Bank': '6000',
#   'GroceryStore': '5400',
#   'PetrolandGasolineStation': '5540',
#   'Pharmacy': '9565'},
#  'dq294ru': {'ATM': '3578',
#   'Bank': '6000',
#   'ClothingStore': '9537',
#   'ConsumerElectronicsStore': '9987',
#   'SpecialtyStore': '9567'},
#  'dpqbmn0': {'ATM': '3578', 'Bank': '6000', 'HomeSpecialtyStore': '9560'},
#  'dqbqv8s': {'ATM': '3578', 'Bank': '6000'},
#  'dn5b9he': {'ATM': '3578', 'Bank': '6000'},
#  '9vrzkrm': {'ATM': '3578', 'Bank': '6000'},
#  '9xqd2zr': {'ATM': '3578', 'Bank': '6000', 'Restaurant': '5800'},
#  'dpkke3e': {'ATM': '3578', 'Bank': '6000'},
#  'dp9t0hf': {'ATM': '3578', 'GroceryStore': '5400'},
#  'dnu7vgs': {'ATM': '3578', 'Bank': '6000'},
#  '9murb32': {'ATM': '3578'},
#  '9qdk4qb': {'ATM': '3578', 'Bank': '6000'},
#  'dr5nb3w': {'ATM': '3578',
#   'ConvenienceStore': '9535',
#   'GroceryStore': '5400'},
#  'dngzq2d': {'ATM': '3578'},
#  'dng0g4s': {'ATM': '3578'},
#  '9zjcd6e': {'ATM': '3578', 'Bank': '6000'},
#  'dr72fbk': {'ATM': '3578', 'Bank': '6000'},
#  '9qnw870': {'ATM': '3578', 'Bank': '6000'},
#  'drmrwh3': {'ATM': '3578', 'Bank': '6000'},
#  '9ykvzcx': {'ATM': '3578', 'Bank': '6000'},
#  'dpjyqwk': {'ATM': '3578',
#   'ConvenienceStore': '9535',
#   'PetrolandGasolineStation': '5540'},
#  'dnm715e': {'ATM': '3578', 'Bank': '6000'},
#  'dpq81bx': {'ATM': '3578'},
#  'dr6nsmm': {'ATM': '3578'},
#  '9vfdmu8': {'ATM': '3578', 'Bank': '6000'},
#  'dr9v8vx': {'ATM': '3578',
#   'Bank': '6000',
#   'HomeImprovementandHardwareStore': '9986',
#   'SpecialtyStore': '9567'},
#  'dnn1pkz': {'ATM': '3578'},
#  'dr5r3en': {'ATM': '3578',
#   'Bank': '6000',
#   'CoffeeShop': '9996',
#   'GroceryStore': '5400',
#   'Pharmacy': '9565',
#   'Restaurant': '5800'},
#  'dq8bex2': {'ATM': '3578',
#   'ConvenienceStore': '9535',
#   'PetrolandGasolineStation': '5540'},
#  'dppne64': {'ATM': '3578',
#   'Bank': '6000',
#   'ConsumerElectronicsStore': '9987'},
#  '9zer8hn': {'ATM': '3578', 'Bank': '6000'},
#  'dr6vmc1': {'ATM': '3578'},
#  '9ynxs8t': {'ATM': '3578', 'Bank': '6000'},
#  'dr4sh32': {'ATM': '3578', 'Bank': '6000'},
#  'dprqe6p': {'ATM': '3578', 'Bank': '6000'},
#  'dpq4j7b': {'ATM': '3578', 'Bank': '6000'},
#  'dp481qs': {'ATM': '3578', 'ConsumerElectronicsStore': '9987'},
#  'dphgwbs': {'ATM': '3578', 'Bank': '6000', 'Pharmacy': '9565'},
#  'dpebqu3': {'ATM': '3578'},
#  'dn08ytj': {'ATM': '3578', 'Bank': '6000'},
#  'drsj9s3': {'ATM': '3578', 'Bank': '6000'},
#  'dpsf5kn': {'ATM': '3578', 'ConsumerElectronicsStore': '9987'},
#  'dpe2v31': {'ATM': '3578',
#   'ConvenienceStore': '9535',
#   'PetrolandGasolineStation': '5540'},
#  '9qc0n86': {'ATM': '3578',
#   'Bank': '6000',
#   'ClothingStore': '9537',
#   'HomeSpecialtyStore': '9560',
#   'Restaurant': '5800',
#   'SpecialtyStore': '9567',
#   'SportingGoodStore': '9568'},
#  'dp6tntc': {'ATM': '3578', 'Bank': '6000'},
#  'dr5r8m6': {'ATM': '3578', 'Bank': '6000'},
#  'dj2zzfu': {'ATM': '3578', 'Bank': '6000'},
#  'djck6p1': {'ATM': '3578', 'Bank': '6000'},
#  '9wk0kze': {'ATM': '3578', 'Bank': '6000'},
#  '9x03zj5': {'ATM': '3578', 'Bank': '6000'},
#  'dr72c56': {'ATM': '3578'},
#  'dpnxqkq': {'ATM': '3578', 'Bank': '6000', 'Restaurant': '5800'},
#  'drt3suv': {'ATM': '3578', 'Bank': '6000'},
#  '9r13uqp': {'ATM': '3578',
#   'AutoServiceandMaintenance': '7538',
#   'Bank': '6000',
#   'CoffeeShop': '9996',
#   'DepartmentStore': '9545',
#   'GroceryStore': '5400',
#   'HomeSpecialtyStore': '9560',
#   'OfficeSupplyandServiceStore': '9988',
#   'Pharmacy': '9565',
#   'Restaurant': '5800',
#   'SpecialtyStore': '9567'},
#  '9vqvxyq': {'ATM': '3578'},
#  '9qh41se': {'ATM': '3578', 'Bank': '6000', 'ConvenienceStore': '9535'},
#  'dqcjrw2': {'ATM': '3578', 'Restaurant': '5800'},
#  'dp3mymr': {'ATM': '3578', 'Bank': '6000'},
#  'djqhemt': {'ATM': '3578'},
#  'dhvx6uk': {'ATM': '3578'},
#  '9qh3duc': {'ATM': '3578', 'GroceryStore': '5400'},
#  '9yt8ez8': {'ATM': '3578', 'Bank': '6000'},
#  'c22vpdv': {'ATM': '3578', 'Bank': '6000'},
#  'dndydz4': {'ATM': '3578', 'Bank': '6000'},
#  'dq2frzr': {'ATM': '3578', 'Bank': '6000'},
#  'c2kzwmn': {'ATM': '3578', 'Bank': '6000'},
#  ...}

# %% [markdown]
# # Venues

# %%
from os.path import basename, dirname
shapeval = "Major_Sport_Venues"
try:
    sf = shapefile.Reader(join(basedir, shapeval, shapeval))
except:
    raise ValueError("No shapefile!")
fields      = sf.fields
shapeData   = {}
geoShapeMap = {}
Nshapes   = len(sf.shapes())
ngeos     = 0
totalgeos = 0
prec      = 7
show      = False

start,cmt = clock("Analyzing {0}\t{1}".format(shapeval, Nshapes))
if show:
    print("\n\nFields -> {0}".format(fields))


ivtype=None
for i,val in enumerate(fields):
    if val[0] == "NAICS_DESC":
        ivtype = i-1
        break

irec = -1
for shapeRec in sf.iterShapeRecords():
    irec += 1

    ## Record
    record = shapeRec.record
    if show: raise ValueError("Stopping here: {0}".format(record))
    geoid = record[1]
    name  = record[2]
    vtype = record[ivtype]
    shapeData[geoid] = {"Name": name, "Record": irec, "Type": vtype}

    geos  = getGeos(shapeRec.shape, irec, Nshapes, prec=7)
    
    if len(geos) > 0:
        newgeos = set()
        rad = 200
        long, lat = shapeRec.shape.points[0]
        nmiss = 0
        for i in range(10000):
            dLg = uniform(-rad, rad) / 111000
            dLa = uniform(-rad, rad) / 111000
            pnt = (lat + dLa, long + dLg)
            dist = haversine((lat, long), pnt)
            if dist < rad/1000:
                geo    = geohash.encode(latitude=pnt[0], longitude=pnt[1], precision=7)
                if geo not in newgeos:
                    newgeos.add(geo)
                    nmiss = 0
                else:
                    nmiss += 1

            if nmiss > 200:
                break

        geoShapeMap[geoid] = newgeos
        ngeos += len(newgeos)

print("Found {0} geos from {1}".format(ngeos, shapeval))
saveGeoData(shapeData, geoShapeMap, Nshapes, ngeos, "{0}-{1}".format(shapeval, prec))
# Out:
# Current Time is Mon Aug 13, 2018 11:40:23 for Analyzing Major_Sport_Venues	784
# Found 8935 geos from Major_Sport_Venues
#
#
#
# There are 784 entries in the saved file.
# Saved shape data to Major_Sport_Venues-7-data.p
#
#
#
# There are 8935 entries in the saved file.
# Saved shape data to Major_Sport_Venues-7-geos.p

# %% [markdown]
# # Airports (US)

# %%
from os.path import basename, dirname
shapeval = "Airports"
try:
    sf = shapefile.Reader(join(basedir, shapeval, shapeval))
except:
    raise ValueError("No shapefile!")
fields      = sf.fields
shapeData   = {}
geoShapeMap = {}
Nshapes   = len(sf.shapes())
ngeos     = 0
totalgeos = 0
prec      = 8
show      = False

start,cmt = clock("Analyzing {0}\t{1}".format(shapeval, Nshapes))
if show:
    print("\n\nFields -> {0}".format(fields))


iname=None
for i,val in enumerate(fields):
    if val[0] == "FullName":
        iname = i-1
        break
itype=None
for i,val in enumerate(fields):
    if val[0] == "OwnerType":
        itype = i-1
        break
iacres=None
for i,val in enumerate(fields):
    if val[0] == "Acres":
        iacres = i-1
        break

irec = -1
from numpy import sqrt
from haversine import haversine
from random import uniform
for shapeRec in sf.iterShapeRecords():
    irec += 1
    if irec % 1000 == 0:
        print(irec)

    ## Record
    record = shapeRec.record
    if show: raise ValueError("Stopping here: {0}".format(record))
    geoid = record[1]
    name  = record[iname]
    size  = record[iacres]
    atype = record[itype]
    shapeData[geoid] = {"Name": name, "Record": irec, "Type": atype, "Size": size}
        
    geos  = getGeos(shapeRec.shape, irec, Nshapes, prec=7)

    if size is not None:
        newgeos = set()
        rad = 63.6167*sqrt(size)/2
        long, lat = shapeRec.shape.points[0]
        nmiss = 0
        for i in range(10000):
            dLg = uniform(-rad, rad) / 111000
            dLa = uniform(-rad, rad) / 111000
            pnt = (lat + dLa, long + dLg)
            dist = haversine((lat, long), pnt)
            if dist < rad/1000:
                geo    = geohash.encode(latitude=pnt[0], longitude=pnt[1], precision=7)
                if geo not in newgeos:
                    newgeos.add(geo)
                    nmiss = 0
                else:
                    nmiss += 1

            if nmiss > 200:
                break
            
        geoShapeMap[geoid] = newgeos
        ngeos += len(newgeos)
    else:
        geoShapeMap[geoid] = geos
        ngeos += len(geos)

print("Found {0} geos from {1}".format(ngeos, shapeval))
saveGeoData(shapeData, geoShapeMap, Nshapes, ngeos, "{0}-{1}".format(shapeval, 7))
# Out:
# Current Time is Mon Aug 13, 2018 11:12:34 for Analyzing Airports	19460
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# Found 507046 geos from Airports
#
#
#
# There are 19460 entries in the saved file.
# Saved shape data to Airports-7-data.p
#
#
#
# There are 507046 entries in the saved file.
# Saved shape data to Airports-7-geos.p

# %%
# Metra Stations (Chicago)

# %% [markdown]
# # Metro Stations (DC)

# %%
savename = "Metro_Stations_Regional"
shapevals = ["Metro_Stations_Regional", "Kmlmetrastations"]
shapeData   = {}
geoShapeMap = {}
for shapeval in shapevals:
    from os.path import basename, dirname
    #shapeval = "Metro_Stations_Regional"
    try:
        sf = shapefile.Reader(join(basedir, shapeval, shapeval))
    except:
        raise ValueError("No shapefile!")
    fields      = sf.fields
    Nshapes   = len(sf.shapes())
    totalgeos = 0
    ngeos     = 0
    prec      = 7
    show      = False

    start,cmt = clock("Analyzing {0}\t{1}".format(shapeval, Nshapes))
    if show:
        print("\n\nFields -> {0}".format(fields))


    irec = -1
    for shapeRec in sf.iterShapeRecords():
        irec += 1

        ## Record
        record = shapeRec.record
        if show: raise ValueError("Stopping here: {0}".format(record))
        if shapeval == "Kmlmetrastations":
            name   = record[0]
            geoval = record[0]
        if shapeval == "Metro_Stations_Regional":
            name   = record[2]
            geoval = record[1]
        geoid = "{0}{1}".format(shapeval,geoval)
        shapeData[geoid] = {"Name": name, "Record": irec}

        if shapeval == "Metro_Stations_Regional":
            geos  = getGeos(shapeRec.shape, irec, Nshapes, prec)
        else:
            geos  = getGeos(shapeRec.shape, irec, Nshapes, prec)
        geoShapeMap[geoid] = geos
        ngeos += len(geos)
    print("Found {0} geos from {1}".format(ngeos, savename))
    
saveGeoData(shapeData, geoShapeMap, Nshapes, ngeos, "{0}-{1}".format(savename, prec))
# Out:
# Current Time is Tue Aug 21, 2018 11:12:46 for Analyzing Metro_Stations_Regional	91
# Found 91 geos from Metro_Stations_Regional
# Current Time is Tue Aug 21, 2018 11:12:46 for Analyzing Kmlmetrastations	247
# Found 247 geos from Metro_Stations_Regional
#
#
#
# There are 325 entries in the saved file.
# Saved shape data to Metro_Stations_Regional-7-data.p
#
#
#
# There are 247 entries in the saved file.
# Saved shape data to Metro_Stations_Regional-7-geos.p

# %% [markdown]
# # Amtrak Stations Data

# %%
from os.path import basename, dirname
shapeval = "Amtrak_Stations"
try:
    sf = shapefile.Reader(join(basedir, shapeval, shapeval))
except:
    raise ValueError("No shapefile!")
fields      = sf.fields
shapeData   = {}
geoShapeMap = {}
Nshapes   = len(sf.shapes())
ngeos     = 0
totalgeos = 0
prec      = 7
show      = False

start,cmt = clock("Analyzing {0}\t{1}".format(shapeval, Nshapes))
if show:
    print("\n\nFields -> {0}".format(fields))


irec = -1
for shapeRec in sf.iterShapeRecords():
    irec += 1

    ## Record
    record = shapeRec.record
    if show: raise ValueError("Stopping here: {0}".format(record))
    geoid = record[1]
    name  = record[2]
    shapeData[geoid] = {"Name": name, "Record": irec}
        
    geos  = getGeos(shapeRec.shape, irec, Nshapes, prec=7)

    
    if len(geos) > 0:
        newgeos = set()
        rad = 100
        long, lat = shapeRec.shape.points[0]
        nmiss = 0
        for i in range(10000):
            dLg = uniform(-rad, rad) / 111000
            dLa = uniform(-rad, rad) / 111000
            pnt = (lat + dLa, long + dLg)
            dist = haversine((lat, long), pnt)
            if dist < rad/1000:
                geo    = geohash.encode(latitude=pnt[0], longitude=pnt[1], precision=7)
                if geo not in newgeos:
                    newgeos.add(geo)
                    nmiss = 0
                else:
                    nmiss += 1

            if nmiss > 200:
                break

        geoShapeMap[geoid] = newgeos
        ngeos += len(newgeos)

print("Found {0} geos from {1}".format(ngeos, shapeval))
saveGeoData(shapeData, geoShapeMap, Nshapes, ngeos, "{0}-{1}".format(shapeval, 7))
# Out:
# Current Time is Mon Aug 13, 2018 11:37:01 for Analyzing Amtrak_Stations	529
# Found 2574 geos from Amtrak_Stations
#
#
#
# There are 529 entries in the saved file.
# Saved shape data to Amtrak_Stations-7-data.p
#
#
#
# There are 2574 entries in the saved file.
# Saved shape data to Amtrak_Stations-7-geos.p

# %% [markdown]
# # Combine Single Geo Data

# %%
import pickle
prec=7
vals    = ['Amtrak_Stations', 'Metro_Stations_Regional', 'Airports', 'Major_Sport_Venues'] #, 'alleys-and-parking']
geomap  = {}
records = {}
for mtype in vals:
    prec=7
    if mtype == "Airports":
        prec=7
    recdata = pickle.load(open("{0}-{1}-data.p".format(mtype, prec), "rb"))
    geodata = pickle.load(open("{0}-{1}-geos.p".format(mtype, prec), "rb"))
    ngeos = 0
    for geoid,geos in geodata.items():
        ngeos += len(geos)
        for geo in geos:
            if geomap.get(geo) is None:
                geomap[geo] = {}
            if geomap[geo].get(mtype) is None:
                geomap[geo][mtype] = set()
            geomap[geo][mtype].add(geoid)

    records[mtype] = {}
    for geoid,rec in recdata.items():
        records[mtype][geoid] = rec['Name']
                
    print("{0}\t{1}\t---> {2} <---".format(mtype,ngeos,len(geomap)))
                
fname="geomap-{0}-loc.p".format(prec)
print("Writing {0}".format(fname))
pickle.dump(geomap,  open(fname, "wb"))

fname="georec-{0}-loc.p".format(prec)
print("Writing {0}".format(fname))
pickle.dump(records,  open(fname, "wb"))
# Out:
# Amtrak_Stations	2574	---> 2568 <---
# Metro_Stations_Regional	325	---> 2885 <---
# Airports	507046	---> 509286 <---
# Major_Sport_Venues	8935	---> 517863 <---
# Writing geomap-7-loc.p
# Writing georec-7-loc.p

# %%
records
# Out:
# {'NYP': 'Name',
#  'WAS': 'Name',
#  'PHL': 'Name',
#  'CHI': 'Name',
#  'BOS': 'Name',
#  'LAX': 'Name',
#  'SAC': 'Name',
#  'BAL': 'Name',
#  'ALB': 'Name',
#  'PVD': 'Name',
#  'SAN': 'Name',
#  'WIL': 'Name',
#  'BWI': 'Name',
#  'NWK': 'Name',
#  'SEA': 'Name',
#  'NHV': 'Name',
#  'BBY': 'Name',
#  'MKE': 'Name',
#  'PDX': 'Name',
#  'EMY': 'Name',
#  'LNC': 'Name',
#  'HAR': 'Name',
#  'BFD': 'Name',
#  'RTE': 'Name',
#  'TRE': 'Name',
#  'BON': 'Name',
#  'STM': 'Name',
#  'SOL': 'Name',
#  'DAV': 'Name',
#  'MET': 'Name',
#  'FNO': 'Name',
#  'MTZ': 'Name',
#  'IRV': 'Name',
#  'RVR': 'Name',
#  'OKJ': 'Name',
#  'SBA': 'Name',
#  'STL': 'Name',
#  'OSD': 'Name',
#  'FUL': 'Name',
#  'SKN': 'Name',
#  'RIC': 'Name',
#  'OLT': 'Name',
#  'ANA': 'Name',
#  'LOR': 'Name',
#  'SFA': 'Name',
#  'BNL': 'Name',
#  'SJC': 'Name',
#  'SNC': 'Name',
#  'HUD': 'Name',
#  'RHI': 'Name',
#  'PAO': 'Name',
#  'HNF': 'Name',
#  'ALX': 'Name',
#  'NOL': 'Name',
#  'CLT': 'Name',
#  'NCR': 'Name',
#  'SUI': 'Name',
#  'POR': 'Name',
#  'SPI': 'Name',
#  'KIN': 'Name',
#  'CHM': 'Name',
#  'MKA': 'Name',
#  'NLC': 'Name',
#  'RGH': 'Name',
#  'GAC': 'Name',
#  'KCY': 'Name',
#  'BKY': 'Name',
#  'SNA': 'Name',
#  'PGH': 'Name',
#  'EWR': 'Name',
#  'HFD': 'Name',
#  'DEN': 'Name',
#  'CVS': 'Name',
#  'ORL': 'Name',
#  'EXT': 'Name',
#  'ARB': 'Name',
#  'SYR': 'Name',
#  'ROC': 'Name',
#  'MCD': 'Name',
#  'TAC': 'Name',
#  'MOD': 'Name',
#  'GRO': 'Name',
#  'KAL': 'Name',
#  'SLO': 'Name',
#  'BUF': 'Name',
#  'NPN': 'Name',
#  'TPA': 'Name',
#  'ELT': 'Name',
#  'FTW': 'Name',
#  'POU': 'Name',
#  'CDL': 'Name',
#  'GBB': 'Name',
#  'VAN': 'Name',
#  'MSP': 'Name',
#  'SPG': 'Name',
#  'EUG': 'Name',
#  'NRO': 'Name',
#  'CYN': 'Name',
#  'OXN': 'Name',
#  'BRP': 'Name',
#  'LYH': 'Name',
#  'EXR': 'Name',
#  'ATL': 'Name',
#  'DOW': 'Name',
#  'SVT': 'Name',
#  'GTA': 'Name',
#  'ABQ': 'Name',
#  'VNC': 'Name',
#  'DNC': 'Name',
#  'MEM': 'Name',
#  'OAC': 'Name',
#  'JAX': 'Name',
#  'RNO': 'Name',
#  'ARD': 'Name',
#  'MID': 'Name',
#  'MAC': 'Name',
#  'DER': 'Name',
#  'LNS': 'Name',
#  'VEC': 'Name',
#  'MIA': 'Name',
#  'DHM': 'Name',
#  'OLW': 'Name',
#  'OSB': 'Name',
#  'CHS': 'Name',
#  'CWT': 'Name',
#  'SLM': 'Name',
#  'BUR': 'Name',
#  'ALN': 'Name',
#  'WBG': 'Name',
#  'UCA': 'Name',
#  'JOL': 'Name',
#  'WLN': 'Name',
#  'FBG': 'Name',
#  'WPB': 'Name',
#  'SAV': 'Name',
#  'GLN': 'Name',
#  'TOL': 'Name',
#  'KWD': 'Name',
#  'SDY': 'Name',
#  'WFH': 'Name',
#  'RMT': 'Name',
#  'FAY': 'Name',
#  'DOV': 'Name',
#  'SAS': 'Name',
#  'MJY': 'Name',
#  'BEL': 'Name',
#  'DET': 'Name',
#  'SPK': 'Name',
#  'WEM': 'Name',
#  'HAY': 'Name',
#  'CLE': 'Name',
#  'PAR': 'Name',
#  'JAN': 'Name',
#  'NPV': 'Name',
#  'CML': 'Name',
#  'GSC': 'Name',
#  'FLO': 'Name',
#  'GDL': 'Name',
#  'CRT': 'Name',
#  'HHL': 'Name',
#  'OKC': 'Name',
#  'NFK': 'Name',
#  'SAO': 'Name',
#  'SIM': 'Name',
#  'SCC': 'Name',
#  'WLY': 'Name',
#  'RVM': 'Name',
#  'PJC': 'Name',
#  'BHM': 'Name',
#  'FTL': 'Name',
#  'DAL': 'Name',
#  'EVR': 'Name',
#  'QCY': 'Name',
#  'SLC': 'Name',
#  'FMT': 'Name',
#  'WAC': 'Name',
#  'FLG': 'Name',
#  'JEF': 'Name',
#  'ACA': 'Name',
#  'RSV': 'Name',
#  'BTL': 'Name',
#  'GRR': 'Name',
#  'SKT': 'Name',
#  'BFX': 'Name',
#  'KIS': 'Name',
#  'ABE': 'Name',
#  'MAT': 'Name',
#  'HMW': 'Name',
#  'SAR': 'Name',
#  'PCT': 'Name',
#  'HOM': 'Name',
#  'ALY': 'Name',
#  'KFS': 'Name',
#  'HPT': 'Name',
#  'CLB': 'Name',
#  'GJT': 'Name',
#  'KEL': 'Name',
#  'CPN': 'Name',
#  'AUS': 'Name',
#  'IND': 'Name',
#  'EDM': 'Name',
#  'COC': 'Name',
#  'PTB': 'Name',
#  'TUK': 'Name',
#  'OMA': 'Name',
#  'MOT': 'Name',
#  'FLN': 'Name',
#  'TRK': 'Name',
#  'NFL': 'Name',
#  'LVW': 'Name',
#  'WPK': 'Name',
#  'ASD': 'Name',
#  'WTN': 'Name',
#  'MDR': 'Name',
#  'TUS': 'Name',
#  'BRK': 'Name',
#  'LEE': 'Name',
#  'ROY': 'Name',
#  'LSE': 'Name',
#  'EFG': 'Name',
#  'CTL': 'Name',
#  'HOL': 'Name',
#  'MYS': 'Name',
#  'YNY': 'Name',
#  'DFB': 'Name',
#  'HEM': 'Name',
#  'BNC': 'Name',
#  'MDT': 'Name',
#  'TRM': 'Name',
#  'PSC': 'Name',
#  'JXN': 'Name',
#  'DLD': 'Name',
#  'JST': 'Name',
#  'ALT': 'Name',
#  'WTH': 'Name',
#  'SAL': 'Name',
#  'MSS': 'Name',
#  'FAR': 'Name',
#  'WOB': 'Name',
#  'SNS': 'Name',
#  'SOB': 'Name',
#  'EKH': 'Name',
#  'CEN': 'Name',
#  'LCN': 'Name',
#  'NBU': 'Name',
#  'WTI': 'Name',
#  'PTH': 'Name',
#  'KKI': 'Name',
#  'HOS': 'Name',
#  'GVB': 'Name',
#  'ESX': 'Name',
#  'WIN': 'Name',
#  'SRB': 'Name',
#  'QAN': 'Name',
#  'KAN': 'Name',
#  'MVW': 'Name',
#  'LAF': 'Name',
#  'LRK': 'Name',
#  'MDN': 'Name',
#  'MPK': 'Name',
#  'NHT': 'Name',
#  'KEE': 'Name',
#  'WNL': 'Name',
#  'NLS': 'Name',
#  'RAT': 'Name',
#  'SBG': 'Name',
#  'RLN': 'Name',
#  'ERI': 'Name',
#  'BER': 'Name',
#  'BRA': 'Name',
#  'OSC': 'Name',
#  'WAH': 'Name',
#  'ARN': 'Name',
#  'ORB': 'Name',
#  'GLP': 'Name',
#  'TPL': 'Name',
#  'COT': 'Name',
#  'SNP': 'Name',
#  'PON': 'Name',
#  'CLP': 'Name',
#  'WEN': 'Name',
#  'GWD': 'Name',
#  'ORC': 'Name',
#  'LNK': 'Name',
#  'TRU': 'Name',
#  'ELP': 'Name',
#  'LKL': 'Name',
#  'WDL': 'Name',
#  'RUD': 'Name',
#  'CBS': 'Name',
#  'GFK': 'Name',
#  'NFS': 'Name',
#  'WAR': 'Name',
#  'GPK': 'Name',
#  'NEW': 'Name',
#  'WRJ': 'Name',
#  'GNB': 'Name',
#  'MTP': 'Name',
#  'PLB': 'Name',
#  'DLB': 'Name',
#  'CIC': 'Name',
#  'SSM': 'Name',
#  'NRK': 'Name',
#  'PNT': 'Name',
#  'TOH': 'Name',
#  'RIV': 'Name',
#  'SJM': 'Name',
#  'DRD': 'Name',
#  'PAK': 'Name',
#  'GUA': 'Name',
#  'KTR': 'Name',
#  'HMD': 'Name',
#  'OTM': 'Name',
#  'LAG': 'Name',
#  'PRB': 'Name',
#  'GRV': 'Name',
#  'CIN': 'Name',
#  'SNB': 'Name',
#  'HAV': 'Name',
#  'NOR': 'Name',
#  'LAP': 'Name',
#  'CUM': 'Name',
#  'SCD': 'Name',
#  'FRE': 'Name',
#  'LMY': 'Name',
#  'RDD': 'Name',
#  'MRC': 'Name',
#  'SMT': 'Name',
#  'MRB': 'Name',
#  'SBY': 'Name',
#  'YEM': 'Name',
#  'HUN': 'Name',
#  'TCL': 'Name',
#  'CMO': 'Name',
#  'AMS': 'Name',
#  'TOP': 'Name',
#  'MEI': 'Name',
#  'CRV': 'Name',
#  'JSP': 'Name',
#  'FED': 'Name',
#  'WDB': 'Name',
#  'KNG': 'Name',
#  'SED': 'Name',
#  'CHW': 'Name',
#  'SKY': 'Name',
#  'HBG': 'Name',
#  'LEW': 'Name',
#  'LPE': 'Name',
#  'DWT': 'Name',
#  'WFD': 'Name',
#  'BRL': 'Name',
#  'ROM': 'Name',
#  'WND': 'Name',
#  'WIP': 'Name',
#  'DQN': 'Name',
#  'LOD': 'Name',
#  'LRC': 'Name',
#  'RDW': 'Name',
#  'WMJ': 'Name',
#  'NDL': 'Name',
#  'MHL': 'Name',
#  'IDP': 'Name',
#  'LPS': 'Name',
#  'LWA': 'Name',
#  'NBK': 'Name',
#  'PIT': 'Name',
#  'POG': 'Name',
#  'MPR': 'Name',
#  'DIL': 'Name',
#  'ENC': 'Name',
#  'ELK': 'Name',
#  'SPT': 'Name',
#  'GCK': 'Name',
#  'HFY': 'Name',
#  'HIN': 'Name',
#  'CBV': 'Name',
#  'ADM': 'Name',
#  'DAN': 'Name',
#  'SOP': 'Name',
#  'POI': 'Name',
#  'LAJ': 'Name',
#  'SMC': 'Name',
#  'LFT': 'Name',
#  'VRV': 'Name',
#  'FMD': 'Name',
#  'PLO': 'Name',
#  'GLE': 'Name',
#  'COX': 'Name',
#  'WGL': 'Name',
#  'STA': 'Name',
#  'BCV': 'Name',
#  'TXA': 'Name',
#  'WOR': 'Name',
#  'SPL': 'Name',
#  'MIN': 'Name',
#  'LAK': 'Name',
#  'HGD': 'Name',
#  'ELY': 'Name',
#  'SDL': 'Name',
#  'DUN': 'Name',
#  'HMI': 'Name',
#  'GFD': 'Name',
#  'BYN': 'Name',
#  'TRI': 'Name',
#  'CRF': 'Name',
#  'MCB': 'Name',
#  'WPT': 'Name',
#  'RTL': 'Name',
#  'WSP': 'Name',
#  'RKV': 'Name',
#  'PRO': 'Name',
#  'TAY': 'Name',
#  'WAB': 'Name',
#  'WSS': 'Name',
#  'MCG': 'Name',
#  'ALC': 'Name',
#  'ONA': 'Name',
#  'STN': 'Name',
#  'HAS': 'Name',
#  'GNS': 'Name',
#  'COV': 'Name',
#  'STW': 'Name',
#  'LIB': 'Name',
#  'ALP': 'Name',
#  'DLK': 'Name',
#  'DDG': 'Name',
#  'ATN': 'Name',
#  'LSV': 'Name',
#  'PBF': 'Name',
#  'GGW': 'Name',
#  'HAM': 'Name',
#  'HUT': 'Name',
#  'GRA': 'Name',
#  'LAB': 'Name',
#  'YUM': 'Name',
#  'WLO': 'Name',
#  'BLF': 'Name',
#  'CNV': 'Name',
#  'PVL': 'Name',
#  'BRH': 'Name',
#  'DVL': 'Name',
#  'OKE': 'Name',
#  'RUG': 'Name',
#  'DOA': 'Name',
#  'WNN': 'Name',
#  'BAM': 'Name',
#  'CRN': 'Name',
#  'CBR': 'Name',
#  'MAL': 'Name',
#  'YAZ': 'Name',
#  'SPB': 'Name',
#  'FTN': 'Name',
#  'BNG': 'Name',
#  'NBN': 'Name',
#  'LAU': 'Name',
#  'MCI': 'Name',
#  'FMG': 'Name',
#  'LCH': 'Name',
#  'EPH': 'Name',
#  'DNK': 'Name',
#  'CAM': 'Name',
#  'SAB': 'Name',
#  'WNR': 'Name',
#  'BMT': 'Name',
#  'BAR': 'Name',
#  'CSN': 'Name',
#  'DYE': 'Name',
#  'TYR': 'Name',
#  'MCK': 'Name',
#  'PSN': 'Name',
#  'ESM': 'Name',
#  'CWH': 'Name',
#  'PRC': 'Name',
#  'GRI': 'Name',
#  'CUT': 'Name',
#  'GLM': 'Name',
#  'TCA': 'Name',
#  'CLA': 'Name',
#  'PIC': 'Name',
#  'CLF': 'Name',
#  'POH': 'Name',
#  'AKY': 'Name',
#  'MAY': 'Name',
#  'FTC': 'Name',
#  'HLD': 'Name',
#  'HER': 'Name',
#  'BEN': 'Name',
#  'REN': 'Name',
#  'RPH': 'Name',
#  'DRT': 'Name',
#  'FRA': 'Name',
#  'LMR': 'Name',
#  'NIB': 'Name',
#  'WHL': 'Name',
#  'MVN': 'Name',
#  'POS': 'Name',
#  'PUR': 'Name',
#  'HOP': 'Name',
#  'ALI': 'Name',
#  'BRO': 'Name',
#  'HAZ': 'Name',
#  'SCH': 'Name',
#  'DEM': 'Name',
#  'GAS': 'Name',
#  'WIH': 'Name',
#  'RSP': 'Name',
#  'PHN': 'Name',
#  'HLK': 'Name',
#  'ARK': 'Name',
#  'WNM': 'Name',
#  'SPM': 'Name',
#  'MNG': 'Name',
#  'COI': 'Name',
#  'LDB': 'Name',
#  'PRK': 'Name',
#  'ALD': 'Name',
#  'THN': 'Name',
#  'SND': 'Name',
#  'ACD': 'Name',
#  'ATR': 'Name',
#  'BAS': 'Name',
#  'BIX': 'Name',
#  'CIP': 'Name',
#  'CSV': 'Name',
#  'GRE': 'Name',
#  'MDO': 'Name',
#  'MOE': 'Name',
#  'PNS': 'Name',
#  'TLH': 'Name',
#  'Metromstn_57': 'Name',
#  'Metromstn_58': 'Name',
#  'Metromstn_59': 'Name',
#  'Metromstn_60': 'Name',
#  'Metromstn_61': 'Name',
#  'Metromstn_62': 'Name',
#  'Metromstn_63': 'Name',
#  'Metromstn_64': 'Name',
#  'Metromstn_65': 'Name',
#  'Metromstn_66': 'Name',
#  'Metromstn_67': 'Name',
#  'Metromstn_68': 'Name',
#  'Metromstn_69': 'Name',
#  'Metromstn_70': 'Name',
#  'Metromstn_71': 'Name',
#  'Metromstn_72': 'Name',
#  'Metromstn_73': 'Name',
#  'Metromstn_74': 'Name',
#  'Metromstn_75': 'Name',
#  'Metromstn_76': 'Name',
#  'Metromstn_77': 'Name',
#  'Metromstn_78': 'Name',
#  'Metromstn_79': 'Name',
#  'Metromstn_80': 'Name',
#  'Metromstn_81': 'Name',
#  'Metromstn_82': 'Name',
#  'Metromstn_83': 'Name',
#  'Metromstn_84': 'Name',
#  'Metromstn_85': 'Name',
#  'Metromstn_86': 'Name',
#  'Metromstn_93': 'Name',
#  'Metromstn_94': 'Name',
#  'Metromstn_95': 'Name',
#  'Metromstn_96': 'Name',
#  'Metromstn_97': 'Name',
#  'Metromstn_1': 'Name',
#  'Metromstn_2': 'Name',
#  'Metromstn_3': 'Name',
#  'Metromstn_4': 'Name',
#  'Metromstn_5': 'Name',
#  'Metromstn_6': 'Name',
#  'Metromstn_7': 'Name',
#  'Metromstn_8': 'Name',
#  'Metromstn_9': 'Name',
#  'Metromstn_10': 'Name',
#  'Metromstn_11': 'Name',
#  'Metromstn_12': 'Name',
#  'Metromstn_13': 'Name',
#  'Metromstn_14': 'Name',
#  'Metromstn_15': 'Name',
#  'Metromstn_16': 'Name',
#  'Metromstn_17': 'Name',
#  'Metromstn_18': 'Name',
#  'Metromstn_19': 'Name',
#  'Metromstn_20': 'Name',
#  'Metromstn_21': 'Name',
#  'Metromstn_22': 'Name',
#  'Metromstn_23': 'Name',
#  'Metromstn_24': 'Name',
#  'Metromstn_25': 'Name',
#  'Metromstn_26': 'Name',
#  'Metromstn_27': 'Name',
#  'Metromstn_28': 'Name',
#  'Metromstn_29': 'Name',
#  'Metromstn_30': 'Name',
#  'Metromstn_31': 'Name',
#  'Metromstn_32': 'Name',
#  'Metromstn_33': 'Name',
#  'Metromstn_34': 'Name',
#  'Metromstn_35': 'Name',
#  'Metromstn_36': 'Name',
#  'Metromstn_37': 'Name',
#  'Metromstn_38': 'Name',
#  'Metromstn_39': 'Name',
#  'Metromstn_40': 'Name',
#  'Metromstn_41': 'Name',
#  'Metromstn_42': 'Name',
#  'Metromstn_43': 'Name',
#  'Metromstn_44': 'Name',
#  'Metromstn_45': 'Name',
#  'Metromstn_46': 'Name',
#  'Metromstn_47': 'Name',
#  'Metromstn_48': 'Name',
#  'Metromstn_49': 'Name',
#  'Metromstn_50': 'Name',
#  'Metromstn_51': 'Name',
#  'Metromstn_52': 'Name',
#  'Metromstn_53': 'Name',
#  'Metromstn_54': 'Name',
#  'Metromstn_55': 'Name',
#  'Metromstn_56': 'Name',
#  '51523.2*A': 'Name',
#  '51523.3*H': 'Name',
#  '51531.*A': 'Name',
#  '51531.01*H': 'Name',
#  '51531.02*H': 'Name',
#  '51531.1*H': 'Name',
#  '51533.*A': 'Name',
#  '51533.1*A': 'Name',
#  '02777.1*A': 'Name',
#  '02778.*H': 'Name',
#  '02780.*A': 'Name',
#  '02780.01*A': 'Name',
#  '02780.1*A': 'Name',
#  '02783.5*H': 'Name',
#  '02784.5*A': 'Name',
#  '02785.*A': 'Name',
#  '02785.01*H': 'Name',
#  '02785.02*H': 'Name',
#  '02785.11*H': 'Name',
#  '02788.*A': 'Name',
#  '02788.01*H': 'Name',
#  '02788.02*H': 'Name',
#  '02791.51*H': 'Name',
#  '02798.3*A': 'Name',
#  '02798.68*A': 'Name',
#  '02798.75*A': 'Name',
#  '02802.*A': 'Name',
#  '02802.02*H': 'Name',
#  '02803.*A': 'Name',
#  '02803.85*A': 'Name',
#  '02803.856*U': 'Name',
#  '02803.86*H': 'Name',
#  '02804.*A': 'Name',
#  '02804.01*H': 'Name',
#  '02804.02*A': 'Name',
#  '02806.*H': 'Name',
#  '02808.*A': 'Name',
#  '02809.2*A': 'Name',
#  '02809.4*A': 'Name',
#  '02810.1*A': 'Name',
#  '02810.2*A': 'Name',
#  '02810.21*H': 'Name',
#  '02810.51*H': 'Name',
#  '02810.52*H': 'Name',
#  '02810.53*C': 'Name',
#  '02810.8*C': 'Name',
#  '02810.81*H': 'Name',
#  '02812.*H': 'Name',
#  '02814.*H': 'Name',
#  '02814.01*H': 'Name',
#  '02816.49*H': 'Name',
#  '02816.5*H': 'Name',
#  '02817.*A': 'Name',
#  '02823.*A': 'Name',
#  '02825.5*H': 'Name',
#  '02825.51*H': 'Name',
#  '02827.*A': 'Name',
#  '02827.01*H': 'Name',
#  '02827.23*H': 'Name',
#  '02829.01*H': 'Name',
#  '02829.02*H': 'Name',
#  '02829.3*H': 'Name',
#  '02830.6*A': 'Name',
#  '02832.*A': 'Name',
#  '02832.01*A': 'Name',
#  '02834.*A': 'Name',
#  '02840.*C': 'Name',
#  '02843.3*A': 'Name',
#  '02843.4*A': 'Name',
#  '02843.7*H': 'Name',
#  '02844.*A': 'Name',
#  '02844.01*H': 'Name',
#  '02844.02*H': 'Name',
#  '02846.21*H': 'Name',
#  '02846.61*H': 'Name',
#  '02846.62*H': 'Name',
#  '02847.2*H': 'Name',
#  '02852.*A': 'Name',
#  '02852.01*H': 'Name',
#  '02853.6*H': 'Name',
#  '02856.01*H': 'Name',
#  '02858.*A': 'Name',
#  '02858.01*H': 'Name',
#  '02861.8*A': 'Name',
#  '02861.9*A': 'Name',
#  '02861.91*H': 'Name',
#  '02861.95*A': 'Name',
#  '02862.98*A': 'Name',
#  '02864.02*H': 'Name',
#  '02865.*H': 'Name',
#  '02865.11*H': 'Name',
#  '02865.12*H': 'Name',
#  '02865.13*H': 'Name',
#  '02865.14*H': 'Name',
#  '02866.*H': 'Name',
#  '02867.*A': 'Name',
#  '02870.3*A': 'Name',
#  '02880.*A': 'Name',
#  '02883.*H': 'Name',
#  '02884.01*H': 'Name',
#  '02886.1*A': 'Name',
#  '02887.1*H': 'Name',
#  '02888.*A': 'Name',
#  '02893.*H': 'Name',
#  '02895.*H': 'Name',
#  '02898.*A': 'Name',
#  '02903.*A': 'Name',
#  '02903.01*H': 'Name',
#  '02906.3*H': 'Name',
#  '02907.7*H': 'Name',
#  '02907.8*A': 'Name',
#  '02909.44*H': 'Name',
#  '02910.*H': 'Name',
#  '02912.3*A': 'Name',
#  '02913.5*H': 'Name',
#  '02914.*H': 'Name',
#  '02919.*H': 'Name',
#  '02921.*H': 'Name',
#  '02923.*A': 'Name',
#  '02928.11*H': 'Name',
#  '02928.16*H': 'Name',
#  '02930.*A': 'Name',
#  '02931.*A': 'Name',
#  '02932.1*A': 'Name',
#  '02932.12*H': 'Name',
#  '02944.*A': 'Name',
#  '02944.01*H': 'Name',
#  '02944.02*H': 'Name',
#  '02946.*A': 'Name',
#  '02946.1*H': 'Name',
#  '02948.1*C': 'Name',
#  '02970.71*H': 'Name',
#  '03001.*A': 'Name',
#  '03001.21*H': 'Name',
#  '03001.22*H': 'Name',
#  '03001.4*H': 'Name',
#  '03001.6*H': 'Name',
#  '03001.7*H': 'Name',
#  '03001.8*H': 'Name',
#  '03002.*A': 'Name',
#  '03003.*A': 'Name',
#  '03004.*H': 'Name',
#  '03005.*H': 'Name',
#  '03006.10*H': 'Name',
#  '03006.11*H': 'Name',
#  '03006.3*H': 'Name',
#  '03006.4*H': 'Name',
#  '03006.8*H': 'Name',
#  '02869.5*A': 'Name',
#  '02955.*A': 'Name',
#  '02963.*A': 'Name',
#  '02967.*A': 'Name',
#  '02967.1*A': 'Name',
#  '02967.2*A': 'Name',
#  '02967.3*H': 'Name',
#  '02967.4*H': 'Name',
#  '02967.5*H': 'Name',
#  '02967.6*H': 'Name',
#  '02967.7*H': 'Name',
#  '02968.5*A': 'Name',
#  '02968.51*A': 'Name',
#  '02969.*A': 'Name',
#  '02969.01*A': 'Name',
#  '02969.02*A': 'Name',
#  '02970.*A': 'Name',
#  '02971.5*A': 'Name',
#  '02973.*A': 'Name',
#  '02978.*A': 'Name',
#  '02978.5*A': 'Name',
#  '02981.*A': 'Name',
#  '02981.01*A': 'Name',
#  '02981.1*A': 'Name',
#  '02984.*A': 'Name',
#  '02984.2*A': 'Name',
#  '02987.*H': 'Name',
#  '02992.5*A': 'Name',
#  '02993.*A': 'Name',
#  '02995.1*A': 'Name',
#  '02995.11*A': 'Name',
#  '02995.12*A': 'Name',
#  '02997.*A': 'Name',
#  '02997.01*A': 'Name',
#  '02997.02*A': 'Name',
#  '02999.*A': 'Name',
#  '02999.02*H': 'Name',
#  '02999.03*H': 'Name',
#  '02999.12*H': 'Name',
#  '02999.23*H': 'Name',
#  '03000.5*A': 'Name',
#  '03010.*A': 'Name',
#  '03010.01*A': 'Name',
#  '03010.1*A': 'Name',
#  '03014.*A': 'Name',
#  '03014.5*H': 'Name',
#  '03015.*C': 'Name',
#  '03015.02*C': 'Name',
#  '03015.1*H': 'Name',
#  '03016.03*A': 'Name',
#  '03016.04*H': 'Name',
#  '03017.*A': 'Name',
#  '03025.*A': 'Name',
#  '03025.1*A': 'Name',
#  '03027.11*A': 'Name',
#  '03027.12*A': 'Name',
#  '03027.13*H': 'Name',
#  '03030.*A': 'Name',
#  '03030.01*H': 'Name',
#  '03030.02*A': 'Name',
#  '03030.11*A': 'Name',
#  '03030.13*A': 'Name',
#  '03030.14*A': 'Name',
#  '03030.15*A': 'Name',
#  '03033.2*A': 'Name',
#  '03033.21*A': 'Name',
#  '03033.23*H': 'Name',
#  '03038.*H': 'Name',
#  '03039.*H': 'Name',
#  '03040.*A': 'Name',
#  '03040.01*C': 'Name',
#  '03040.02*H': 'Name',
#  '03042.*A': 'Name',
#  '03042.1*A': 'Name',
#  '03043.*A': 'Name',
#  '03050.1*A': 'Name',
#  '03050.11*A': 'Name',
#  '03052.*A': 'Name',
#  '03052.01*H': 'Name',
#  '03052.02*H': 'Name',
#  '03052.03*H': 'Name',
#  '03052.04*H': 'Name',
#  '03053.6*A': 'Name',
#  '03053.61*A': 'Name',
#  '03053.63*A': 'Name',
#  '03053.64*A': 'Name',
#  '03054.*A': 'Name',
#  '03055.11*A': 'Name',
#  '03055.14*H': 'Name',
#  '03055.3*C': 'Name',
#  '03055.6*A': 'Name',
#  '03055.61*A': 'Name',
#  '03055.62*A': 'Name',
#  '03055.63*A': 'Name',
#  '03055.69*H': 'Name',
#  '03055.71*H': 'Name',
#  '03055.72*C': 'Name',
#  '03057.13*A': 'Name',
#  '03059.*H': 'Name',
#  '03060.*A': 'Name',
#  '03060.03*H': 'Name',
#  '03060.05*H': 'Name',
#  '03061.51*H': 'Name',
#  '03063.51*A': 'Name',
#  '03063.53*A': 'Name',
#  '03063.54*A': 'Name',
#  '03063.55*H': 'Name',
#  '03071.01*G': 'Name',
#  '03071.02*H': 'Name',
#  '03071.03*H': 'Name',
#  '03075.*H': 'Name',
#  '03075.01*H': 'Name',
#  '03075.02*H': 'Name',
#  '03075.71*A': 'Name',
#  '03075.72*H': 'Name',
#  '03075.81*A': 'Name',
#  '03075.82*A': 'Name',
#  '03075.83*A': 'Name',
#  '03075.85*A': 'Name',
#  '03075.86*A': 'Name',
#  '03083.*A': 'Name',
#  '03083.01*A': 'Name',
#  '03083.03*A': 'Name',
#  '03083.2*A': 'Name',
#  '03091.01*H': 'Name',
#  '03091.02*H': 'Name',
#  '03093.01*A': 'Name',
#  '03093.04*A': 'Name',
#  '03093.09*A': 'Name',
#  '03093.1*A': 'Name',
#  '03093.11*A': 'Name',
#  '03093.8*A': 'Name',
#  '03096.42*H': 'Name',
#  '03096.43*H': 'Name',
#  '03096.44*H': 'Name',
#  '03098.*A': 'Name',
#  '03098.1*A': 'Name',
#  '03098.4*C': 'Name',
#  '03102.*A': 'Name',
#  '03102.01*A': 'Name',
#  '03103.*H': 'Name',
#  '03104.*A': 'Name',
#  '03106.01*H': 'Name',
#  '03107.*A': 'Name',
#  '03107.01*A': 'Name',
#  '03107.03*A': 'Name',
#  '03107.04*A': 'Name',
#  '03107.05*A': 'Name',
#  '03108.02*H': 'Name',
#  '03108.03*A': 'Name',
#  '03109.41*A': 'Name',
#  '03110.*A': 'Name',
#  '03110.11*A': 'Name',
#  '03111.4*A': 'Name',
#  '03111.41*A': 'Name',
#  '03111.5*A': 'Name',
#  '03112.*A': 'Name',
#  '03112.01*H': 'Name',
#  '03115.*A': 'Name',
#  '03115.03*H': 'Name',
#  '03117.21*A': 'Name',
#  '03117.23*A': 'Name',
#  '03117.24*A': 'Name',
#  '03118.*A': 'Name',
#  '03120.12*H': 'Name',
#  '03120.13*C': 'Name',
#  '03121.*A': 'Name',
#  '03121.12*A': 'Name',
#  '03121.13*H': 'Name',
#  '03121.8*A': 'Name',
#  '03124.1*A': 'Name',
#  '03124.2*A': 'Name',
#  '03124.22*H': 'Name',
#  '03124.23*A': 'Name',
#  '03124.3*A': 'Name',
#  '03128.*H': 'Name',
#  '03128.01*A': 'Name',
#  '03128.1*A': 'Name',
#  '03128.2*A': 'Name',
#  '03132.*A': 'Name',
#  '03134.*A': 'Name',
#  '03135.*A': 'Name',
#  '03135.11*A': 'Name',
#  '03135.12*H': 'Name',
#  '03135.2*A': 'Name',
#  '03139.*A': 'Name',
#  '03140.*A': 'Name',
#  '03140.01*A': 'Name',
#  '03140.02*A': 'Name',
#  '03140.03*H': 'Name',
#  '03145.*H': 'Name',
#  '03146.7*A': 'Name',
#  '03147.*A': 'Name',
#  '03147.2*A': 'Name',
#  '03147.21*H': 'Name',
#  '03147.3*H': 'Name',
#  '03147.4*H': 'Name',
#  '03153.*A': 'Name',
#  '03153.1*A': 'Name',
#  '03153.11*A': 'Name',
#  '03153.12*A': 'Name',
#  '03153.13*H': 'Name',
#  '03153.14*A': 'Name',
#  '03153.2*A': 'Name',
#  '03156.*A': 'Name',
#  '03156.1*A': 'Name',
#  '03156.13*H': 'Name',
#  '03156.14*A': 'Name',
#  '03156.15*A': 'Name',
#  '03156.2*A': 'Name',
#  '03156.35*A': 'Name',
#  '03156.51*A': 'Name',
#  '03156.512*H': 'Name',
#  '03156.513*H': 'Name',
#  '03157.*A': 'Name',
#  '03157.01*H': 'Name',
#  '03157.03*H': 'Name',
#  '03157.04*H': 'Name',
#  '03164.*A': 'Name',
#  '03165.01*H': 'Name',
#  '03169.*A': 'Name',
#  '03169.01*A': 'Name',
#  '03170.5*H': 'Name',
#  '03171.*A': 'Name',
#  '03176.*A': 'Name',
#  '03178.*A': 'Name',
#  '03178.5*A': 'Name',
#  '03178.7*A': 'Name',
#  '03180.01*A': 'Name',
#  '03180.04*A': 'Name',
#  '03182.*A': 'Name',
#  '03182.1*A': 'Name',
#  ...}

# %% [markdown]
# # Parking (DC)

# %%
from os.path import basename, dirname
shapeval = "alleys-and-parking"
try:
    sf = shapefile.Reader(join(basedir, shapeval, shapeval))
except:
    raise ValueError("No shapefile!")
fields      = sf.fields
shapeData   = {}
geoShapeMap = {}
Nshapes   = len(sf.shapes())
ngeos     = 0
totalgeos = 0
prec      = 7
show      = False

start,cmt = clock("Analyzing {0}\t{1}".format(shapeval, Nshapes))
if show:
    print("\n\nFields -> {0}".format(fields))


irec = -1
for shapeRec in sf.iterShapeRecords():
    irec += 1

    ## Record
    record = shapeRec.record
    if show: raise ValueError("Stopping here: {0}".format(record))
    geoid = "Parking{0}".format(record[1])
    name  = record[3]
    shapeData[geoid] = {"Name": name, "Record": irec}
    
    geos  = getGeos(shapeRec.shape, irec, Nshapes, prec)
    geoShapeMap[geoid] = geos
    ngeos += len(geos)

print("Found {0} geos from {1}".format(ngeos, shapeval))
saveGeoData(shapeData, geoShapeMap, Nshapes, ngeos, "{0}-{1}".format(shapeval, prec))
# Out:
# Current Time is Mon Aug 20, 2018 14:41:05 for Analyzing alleys-and-parking	9429
#   addShapeGeos(0/9429	Km EW = 0.1, Km NS  = 0.1, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(500/9429	Km EW = 0.0, Km NS  = 0.0, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(1000/9429	Km EW = 0.1, Km NS  = 0.1, Sq Km = 0.0, ngeos = 2)	----> Added 25 geos (guess = 2) with 10 round and 9 misses in the end.
#   addShapeGeos(1500/9429	Km EW = 0.0, Km NS  = 0.1, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(2000/9429	Km EW = 0.0, Km NS  = 0.1, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(2500/9429	Km EW = 0.1, Km NS  = 0.2, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(3000/9429	Km EW = 0.0, Km NS  = 0.1, Sq Km = 0.0, ngeos = 1)	----> Added 30 geos (guess = 1) with 10 round and 8 misses in the end.
#   addShapeGeos(3500/9429	Km EW = 0.0, Km NS  = 0.1, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(4000/9429	Km EW = 0.0, Km NS  = 0.0, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(4500/9429	Km EW = 0.0, Km NS  = 0.0, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(5000/9429	Km EW = 0.0, Km NS  = 0.1, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(5500/9429	Km EW = 0.1, Km NS  = 0.1, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(6000/9429	Km EW = 0.0, Km NS  = 0.0, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(6500/9429	Km EW = 0.0, Km NS  = 0.1, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(7000/9429	Km EW = 0.0, Km NS  = 0.0, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(7500/9429	Km EW = 0.0, Km NS  = 0.2, Sq Km = 0.0, ngeos = 1)	----> Added 35 geos (guess = 1) with 10 round and 8 misses in the end.
#   addShapeGeos(8000/9429	Km EW = 0.0, Km NS  = 0.0, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(8500/9429	Km EW = 0.1, Km NS  = 0.1, Sq Km = 0.0, ngeos = 1)	----> Added 25 geos (guess = 1) with 10 round and 9 misses in the end.
#   addShapeGeos(9000/9429	Km EW = 0.1, Km NS  = 0.2, Sq Km = 0.0, ngeos = 2)	----> Added 25 geos (guess = 2) with 10 round and 9 misses in the end.
# Found 239321 geos from alleys-and-parking
#
#
#
# There are 96 entries in the saved file.
# Saved shape data to alleys-and-parking-7-data.p
#
#
#
# There are 239321 entries in the saved file.
# Saved shape data to alleys-and-parking-7-geos.p

# %% [markdown]
# # Building Data (from Microsoft)

# %%
import zipfile
from glob import glob
from os import mkdir
from os.path import splitext, basename, dirname, join, exists
zipfiles = glob(join(basedir, "buildings", "*.zip"))
for zipname in zipfiles:
    statedir = dirname(zipname)
    name     = splitext(basename(zipname))[0]
    dirval   = join(statedir, name)
    if exists(dirval):
        continue
    try:
        mkdir(dirval)
    except:
        pass
    print("Unzipping {0}".format(zipname))
    zip_ref = zipfile.ZipFile(zipname, 'r')
    zip_ref.extractall(dirval)
    zip_ref.close()
# Out:
# Unzipping /Users/tgadf/Downloads/buildings/DistrictofColumbia.zip
# Unzipping /Users/tgadf/Downloads/buildings/Illinois.zip
# Unzipping /Users/tgadf/Downloads/buildings/Maryland.zip
# Unzipping /Users/tgadf/Downloads/buildings/Virginia.zip

# %%
from os import mkdir
from json import load
from os.path import splitext, basename, dirname, join, exists, isdir
from collections import Counter
from glob import glob
from shapely.geometry import Polygon
files = glob(join(basedir, "buildings", "*", "*.geojson"))
for ifile in files:
    print("Reading {0}".format(ifile))
    geodata = load(open(ifile))
    gtype = geodata['type']
    geomtypes = Counter() 
    for i,feature in enumerate(geodata['features']):
        geom = feature.get('geometry')
        if geom is not None:
            geomtype = geom.get('type')
            geomtypes[geomtype] += 1
            if geomtype is not None:
                if geomtype == "Polygon":
                    points = geom.get('coordinates')
                    properties = geom.get('properties')
                    polygon = Polygon(points[0])
                    
                    print(points,properties)
    print(geomtypes.most_common())
    break
# Out:
# Reading /Users/tgadf/Downloads/buildings/DistrictofColumbia/DistrictofColumbia.geojson
# POLYGON ((-77.014904 38.816248, -77.014842 38.816395, -77.015056 38.816449, -77.015117 38.816302, -77.014904 38.816248))
# 3.47054999997643e-08
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-15-fdc6ad06016f> in <module>()
#      23                     print(polygon)
#      24                     print(polygon.area)
# ---> 25                     1/0
#      26
#      27                     print(points,properties)
#
# ZeroDivisionError: division by zero

# %%
x = [[[-77.014904, 38.816248], [-77.014842, 38.816395], [-77.015056, 38.816449], [-77.015117, 38.816302], [-77.014904, 38.816248]]]

# %%
import numpy as np
y = np.asarray(x[0])

# %%
y.shape
# Out:
# (5, 2)

# %% [markdown]
# # Load State-Level Data

# %%
import zipfile
from glob import glob
from os import mkdir
from os.path import splitext, basename, dirname, join, exists
zipfiles = glob(join(basedir, "stateshapes", "*Columbia*.zip"))
for zipname in zipfiles:
    statedir = dirname(zipname)
    name     = splitext(basename(zipname))[0]
    dirval   = join(statedir, name)
    if exists(dirval):
        continue
    try:
        mkdir(dirval)
    except:
        pass
    zip_ref = zipfile.ZipFile(zipname, 'r')
    zip_ref.extractall(dirval)
    zip_ref.close()

# %%
from collections import Counter
from os.path import basename, dirname, exists, splitext, isdir
from glob import glob
import zipfile
from os import mkdir
from shutil import rmtree

prec=7
shapevals = ["Trans_AirportPoint", "Trans_AirportRunway", "Trans_RailFeature", "Trans_RoadSegment2", "Trans_TrailSegment", "Trans_RoadSegment", "Trans_RoadSegment3"]
shapevals = ["Trans_AirportPoint", "Trans_AirportRunway"]

states = ["11", "17", "24", "51"]
states = ["10"]
states = [str(x) for x in range(20,80)]
basevals = ["TrailSegment", "RailFeature", "RoadSegment"]
show=False
for state in states:
    newdirname = None
    for baseval in basevals:
        shapevals     = ["{0}{1}".format(baseval, x) for x in range(20)]
        shapevals[0]  = baseval
        dirvals       = glob(join(basedir, "stateshapes", "TRAN_{0}_*_GU_STATEORTERRITORY".format(state), "Shape"))
        if len(dirvals) == 0:
            try:
                zipname = glob(join(basedir, "stateshapes", "TRAN_{0}_*_GU_STATEORTERRITORY.zip".format(state)))[0]
            except:
                continue
            if exists(zipname):
                print("Unzipping {0}".format(zipname))
                zip_ref = zipfile.ZipFile(zipname, 'r')
                dirval  = join(join(basedir, "stateshapes", splitext(basename(zipname))[0]))
                if exists(dirval):
                    pass
                else:
                    mkdir(dirval)
                newdirname = dirval
                print("    Unzipping to {0}".format(dirval))
                zip_ref.extractall(dirval)
                zip_ref.close()
                
        
        scntr = Counter()
        remainCntr = Counter()

        shapeData   = {}
        geoShapeMap = {}
        totalgeos   = 0
        keepFrac    = 0
        totalFrac   = 0

        for shapeval in shapevals:
            for dirval in dirvals:
                if newdirname is None:
                    newdirname = dirname(dirval)
                try:
                    sf = shapefile.Reader(join(dirval, "Trans_{0}".format(shapeval)))
                except:
                    continue
                fields = sf.fields
                shapes = sf.shapes()
                Nshapes = len(shapes)
                ngeos = 0

                start,cmt = clock("Analyzing {0}\t{1}\t{2}".format(state, shapeval, Nshapes))
                if show:
                    print("\n\nFields -> {0}".format(fields))

                maxmiss=None
                if shapeval.startswith("Airport"):
                    itype=None
                    for i,val in enumerate(fields):
                        if val[0] == "FAA_AIRPOR":
                            itype = i-1
                            break
                if shapeval.startswith("RailFeature"):
                    maxmiss=50 
                    itype=None
                    for i,val in enumerate(fields):
                        if val[0] == "LENGTHKM":
                            itype = i-1
                            break
                if shapeval.startswith("TrailSegment"):
                    itype=None
                    for i,val in enumerate(fields):
                        if val[0] == "SOURCE_D00":
                            itype = i-1
                            break
                if shapeval.startswith("RoadSegment"):
                    maxmiss=50
                    itype=None
                    for i,val in enumerate(fields):
                        if val[0] == "PERMANENT_":
                            itype = i-1
                            break
                    iint=None
                    for i,val in enumerate(fields):
                        if val[0] == "INTERSTATE":
                            iint = i-1
                            break



                irec = -1
                ngeos = 0
                for shapeRec in sf.iterShapeRecords():
                    totalFrac += 1
                    keep = True
                    irec += 1

                    if totalFrac % 50000 == 0 and totalFrac > 0:
                        print("\tKeeping {0} of {1} = {2}".format(keepFrac, totalFrac, round(100*keepFrac/totalFrac,1)))

                    if show:
                        print(len(shapeRec.shape.points), shapeRec.record)
                        #continue

                    ## Record
                    record = shapeRec.record
                    extra  = []
                    if shapeval.startswith("AirportPoint"):
                        geoid = record[itype]
                        name  = record[itype+1]
                        test  = record[itype+2]
                        try:
                            int(test)
                        except:
                            continue
                    elif shapeval.startswith("AirportRunway"):
                        geoid  = record[itype]
                        name   = record[itype+1]
                    elif shapeval.startswith("RailFeature"):
                        length = record[itype]
                        name   = record[itype+3]
                        geoid  = name
                    elif shapeval.startswith("TrailSegment"):
                        length = record[itype]
                        name   = record[itype+3]
                        geoid  = name
                    elif shapeval.startswith("RoadSegment"):
                        geoid  = record[itype]
                        name   = record[itype+21]
                        inter  = "-".join(record[iint:iint+4])
                        usrte  = "-".join(record[iint+4:iint+8])
                        strte  = "-".join(record[iint+8:iint+12])
                        ctrte  = record[iint+12]
                        street = record[iint+15]
                        scntr[street] += 1
                        extra  = [inter, usrte, strte, ctrte, street]

                        ## Interstate
                        isInterstate = False
                        if inter != '---':
                            isInterstate = True

                        ## USRte
                        isUSRte = False
                        if usrte != '---':
                            isUSRte = True

                        ## StateRte
                        isStateRte = False
                        if strte != '---':
                            isStateRte = True

                        ## Highway
                        isHighway = False
                        try:
                            if any([street.find(" {0}".format(x)) != -1 for x in ['Hw ', 'Hwy', 'Pkwy', 'Hwy', 'Fwy', 'Tollway', 'Expy']]):
                                isHighway = True
                        except:
                            pass

                        ## Major Road
                        isMajorRd = False
                        try:
                            if any([street.find(" {0}".format(x)) != -1 for x in ['Ave', 'Blvd']]):
                                isMajorRd = True
                        except:
                            pass

                        ## Connections
                        isConnection = False
                        try:
                            if any([street.find(" {0}".format(x)) != -1 for x in ['Bridge ', ' Bdg']]):
                                isConnection = True
                        except:
                            pass
                    else:
                        print(record)
                        1/0

                    
                    if shapeval.startswith("TrailSegment"):
                        geos = addLinearGeos(irec, Nshapes, shapeRec.shape, prec, debug=False)
                        ngeos += len(geos)
                        totalgeos += ngeos
                        catID = "Trail"
                        geoid = catID
                        name  = catID
                        if shapeData.get(catID) is None:
                            shapeData[catID] = {}
                            shapeData[catID][geoid]   = {"Name": name}
                            geoShapeMap[catID] = {}
                            geoShapeMap[catID][geoid] = set()
                        for geo in geos:
                            geoShapeMap[catID][geoid].add(geo)

                    
                    if shapeval.startswith("RailFeature"):
                        geos = addLinearGeos(irec, Nshapes, shapeRec.shape, prec, debug=False)
                        ngeos += len(geos)
                        totalgeos += ngeos
                        catID = "Rail"
                        geoid = catID
                        name  = catID
                        if shapeData.get(catID) is None:
                            shapeData[catID] = {}
                            shapeData[catID][geoid]   = {"Name": name}
                            geoShapeMap[catID] = {}
                            geoShapeMap[catID][geoid] = set()
                        for geo in geos:
                            geoShapeMap[catID][geoid].add(geo)


                    if shapeval.startswith("RoadSegment"):                
                        if not any([isInterstate, isUSRte, isStateRte, isHighway, isMajorRd, isConnection]):       
                            continue
                        else:
                            keepFrac += 1

                        geos = addLinearGeos(irec, Nshapes, shapeRec.shape, prec, debug=False)
                        ngeos += len(geos)
                        totalgeos += ngeos
                        if isInterstate:
                            catID = "Interstate"
                            geoid = catID
                            name  = catID
                            if shapeData.get(catID) is None:
                                shapeData[catID] = {}
                                shapeData[catID][geoid]   = {"Name": name}
                                geoShapeMap[catID] = {}
                                geoShapeMap[catID][geoid] = set()
                            for geo in geos:
                                geoShapeMap[catID][geoid].add(geo)
                        if isUSRte:
                            catID = "USRte"
                            geoid = catID
                            name  = catID
                            if shapeData.get(catID) is None:
                                shapeData[catID] = {}
                                shapeData[catID][geoid]   = {"Name": name}
                                geoShapeMap[catID] = {}
                                geoShapeMap[catID][geoid] = set()
                            for geo in geos:
                                geoShapeMap[catID][geoid].add(geo)
                        if isStateRte:
                            catID = "StateRte"
                            geoid = catID
                            name  = catID
                            if shapeData.get(catID) is None:
                                shapeData[catID] = {}
                                shapeData[catID][geoid]   = {"Name": name}
                                geoShapeMap[catID] = {}
                                geoShapeMap[catID][geoid] = set()
                            for geo in geos:
                                geoShapeMap[catID][geoid].add(geo)
                        if isHighway:
                            catID = "Highway"
                            geoid = catID
                            name  = catID
                            if shapeData.get(catID) is None:
                                shapeData[catID] = {}
                                shapeData[catID][geoid]   = {"Name": name}
                                geoShapeMap[catID] = {}
                                geoShapeMap[catID][geoid] = set()
                            for geo in geos:
                                geoShapeMap[catID][geoid].add(geo)
                        if isMajorRd:
                            catID = "MajorRd"
                            geoid = catID
                            name  = catID
                            if shapeData.get(catID) is None:
                                shapeData[catID] = {}
                                shapeData[catID][geoid]   = {"Name": name}
                                geoShapeMap[catID] = {}
                                geoShapeMap[catID][geoid] = set()
                            for geo in geos:
                                geoShapeMap[catID][geoid].add(geo)
                        if isConnection:
                            catID = "Connection"
                            geoid = catID
                            name  = catID
                            if shapeData.get(catID) is None:
                                shapeData[catID] = {}
                                shapeData[catID][geoid]   = {"Name": name}
                                geoShapeMap[catID] = {}
                                geoShapeMap[catID][geoid] = set()
                            for geo in geos:
                                geoShapeMap[catID][geoid].add(geo)

                print("Found {0} geos from {1}-{2}".format(ngeos, state, shapeval))


        for catID,catData in shapeData.items():
            shapeval = catID
            ngeos = len(geoShapeMap[catID][catID])
            print("Found {0} of type {1}/{2}".format(ngeos,baseval,shapeval))
            saveGeoData(shapeData[catID], geoShapeMap[catID], 0, ngeos, "roads/{0}-{1}-{2}-{3}".format(baseval, shapeval, state, prec))
            
    if newdirname is not None:
        if isdir(newdirname):
            print("--->>> Removing {0} directory <<<---".format(newdirname))
            rmtree(newdirname)
# Out:
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_20_Kansas_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_20_Kansas_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:30:01 for Analyzing 20	RailFeature	6276
# Found 39609 geos from 20-RailFeature
# Found 27299 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-20-7-data.p
#
#
# There are 27299 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-20-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:30:07 for Analyzing 20	RoadSegment	250000
# 	Keeping 8067 of 50000 = 16.1
# 	Keeping 14341 of 100000 = 14.3
# 	Keeping 22407 of 150000 = 14.9
# 	Keeping 29447 of 200000 = 14.7
# 	Keeping 36399 of 250000 = 14.6
# Found 106296 geos from 20-RoadSegment
# Current Time is Fri Aug 31, 2018 21:30:36 for Analyzing 20	RoadSegment2	250000
# 	Keeping 44370 of 300000 = 14.8
# 	Keeping 50781 of 350000 = 14.5
# 	Keeping 58712 of 400000 = 14.7
# 	Keeping 65144 of 450000 = 14.5
# 	Keeping 72749 of 500000 = 14.5
# Found 106158 geos from 20-RoadSegment2
# Current Time is Fri Aug 31, 2018 21:31:03 for Analyzing 20	RoadSegment3	187478
# 	Keeping 80423 of 550000 = 14.6
# 	Keeping 86998 of 600000 = 14.5
# 	Keeping 94966 of 650000 = 14.6
# Found 78398 geos from 20-RoadSegment3
# Found 46592 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-20-7-data.p
#
#
# There are 46592 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-20-7-geos.p
#
#
# Found 59228 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-20-7-data.p
#
#
# There are 59228 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-20-7-geos.p
#
#
# Found 9846 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-20-7-data.p
#
#
# There are 9846 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-20-7-geos.p
#
#
# Found 45417 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-20-7-data.p
#
#
# There are 45417 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-20-7-geos.p
#
#
# Found 95096 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-20-7-data.p
#
#
# There are 95096 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-20-7-geos.p
#
#
# Found 102 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-20-7-data.p
#
#
# There are 102 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-20-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_20_Kansas_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_21_Kentucky_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_21_Kentucky_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:31:33 for Analyzing 21	RailFeature	3965
# Found 34262 geos from 21-RailFeature
# Found 26834 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-21-7-data.p
#
#
# There are 26834 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-21-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:31:39 for Analyzing 21	RoadSegment	250000
# 	Keeping 13315 of 50000 = 26.6
# 	Keeping 26660 of 100000 = 26.7
# 	Keeping 39613 of 150000 = 26.4
# 	Keeping 52836 of 200000 = 26.4
# 	Keeping 66188 of 250000 = 26.5
# Found 265643 geos from 21-RoadSegment
# Current Time is Fri Aug 31, 2018 21:32:19 for Analyzing 21	RoadSegment2	233123
# 	Keeping 79433 of 300000 = 26.5
# 	Keeping 92767 of 350000 = 26.5
# 	Keeping 106032 of 400000 = 26.5
# 	Keeping 119315 of 450000 = 26.5
# Found 248352 geos from 21-RoadSegment2
# Found 45183 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-21-7-data.p
#
#
# There are 45183 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-21-7-geos.p
#
#
# Found 124274 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-21-7-data.p
#
#
# There are 124274 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-21-7-geos.p
#
#
# Found 280609 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-21-7-data.p
#
#
# There are 280609 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-21-7-geos.p
#
#
# Found 11169 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-21-7-data.p
#
#
# There are 11169 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-21-7-geos.p
#
#
# Found 26958 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-21-7-data.p
#
#
# There are 26958 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-21-7-geos.p
#
#
# Found 2189 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-21-7-data.p
#
#
# There are 2189 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-21-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_21_Kentucky_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_22_Louisiana_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_22_Louisiana_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:33:04 for Analyzing 22	RailFeature	4191
# Found 27333 geos from 22-RailFeature
# Found 19679 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-22-7-data.p
#
#
# There are 19679 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-22-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:33:10 for Analyzing 22	RoadSegment	250000
# 	Keeping 11396 of 50000 = 22.8
# 	Keeping 23650 of 100000 = 23.6
# 	Keeping 35301 of 150000 = 23.5
# 	Keeping 47584 of 200000 = 23.8
# 	Keeping 59159 of 250000 = 23.7
# Found 165600 geos from 22-RoadSegment
# Current Time is Fri Aug 31, 2018 21:33:41 for Analyzing 22	RoadSegment2	250000
# 	Keeping 71217 of 300000 = 23.7
# 	Keeping 82985 of 350000 = 23.7
# 	Keeping 95193 of 400000 = 23.8
# 	Keeping 106775 of 450000 = 23.7
# 	Keeping 119122 of 500000 = 23.8
# Found 165657 geos from 22-RoadSegment2
# Current Time is Fri Aug 31, 2018 21:34:08 for Analyzing 22	RoadSegment3	31609
# Found 20615 geos from 22-RoadSegment3
# Found 9299 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-22-7-data.p
#
#
# There are 9299 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-22-7-geos.p
#
#
# Found 24393 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-22-7-data.p
#
#
# There are 24393 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-22-7-geos.p
#
#
# Found 28259 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-22-7-data.p
#
#
# There are 28259 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-22-7-geos.p
#
#
# Found 138062 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-22-7-data.p
#
#
# There are 138062 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-22-7-geos.p
#
#
# Found 39203 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-22-7-data.p
#
#
# There are 39203 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-22-7-geos.p
#
#
# Found 1259 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-22-7-data.p
#
#
# There are 1259 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-22-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_22_Louisiana_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_23_Maine_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_23_Maine_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:34:18 for Analyzing 23	RailFeature	1588
# Found 15701 geos from 23-RailFeature
# Found 12745 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-23-7-data.p
#
#
# There are 12745 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-23-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:34:23 for Analyzing 23	RoadSegment	250000
# 	Keeping 8134 of 50000 = 16.3
# 	Keeping 16072 of 100000 = 16.1
# 	Keeping 24047 of 150000 = 16.0
# 	Keeping 32113 of 200000 = 16.1
# 	Keeping 40211 of 250000 = 16.1
# Found 130988 geos from 23-RoadSegment
# Current Time is Fri Aug 31, 2018 21:34:50 for Analyzing 23	RoadSegment2	19842
# Found 10022 geos from 23-RoadSegment2
# Found 17078 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-23-7-data.p
#
#
# There are 17078 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-23-7-geos.p
#
#
# Found 4818 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-23-7-data.p
#
#
# There are 4818 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-23-7-geos.p
#
#
# Found 66216 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-23-7-data.p
#
#
# There are 66216 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-23-7-geos.p
#
#
# Found 11783 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-23-7-data.p
#
#
# There are 11783 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-23-7-geos.p
#
#
# Found 1220 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-23-7-data.p
#
#
# There are 1220 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-23-7-geos.p
#
#
# Found 1125 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-23-7-data.p
#
#
# There are 1125 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-23-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_23_Maine_GU_STATEORTERRITORY directory <<<---
# Current Time is Fri Aug 31, 2018 21:34:53 for Analyzing 24	TrailSegment	347
# Found 38765 geos from 24-TrailSegment
# Found 37978 of type TrailSegment/Trail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/TrailSegment-Trail-24-7-data.p
#
#
# There are 37978 entries in the saved file.
# Saved shape data to roads/TrailSegment-Trail-24-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:34:56 for Analyzing 24	RailFeature	1944
# Found 13166 geos from 24-RailFeature
# Found 9617 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-24-7-data.p
#
#
# There are 9617 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-24-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:35:01 for Analyzing 24	RoadSegment	250000
# 	Keeping 9535 of 50000 = 19.1
# 	Keeping 18667 of 100000 = 18.7
# 	Keeping 28147 of 150000 = 18.8
# 	Keeping 37764 of 200000 = 18.9
# 	Keeping 46731 of 250000 = 18.7
# Found 114495 geos from 24-RoadSegment
# Current Time is Fri Aug 31, 2018 21:35:31 for Analyzing 24	RoadSegment2	225939
# 	Keeping 56329 of 300000 = 18.8
# 	Keeping 65990 of 350000 = 18.9
# 	Keeping 74837 of 400000 = 18.7
# 	Keeping 84424 of 450000 = 18.8
# Found 104084 geos from 24-RoadSegment2
# Found 7401 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-24-7-data.p
#
#
# There are 7401 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-24-7-geos.p
#
#
# Found 17565 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-24-7-data.p
#
#
# There are 17565 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-24-7-geos.p
#
#
# Found 11630 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-24-7-data.p
#
#
# There are 11630 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-24-7-geos.p
#
#
# Found 2323 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-24-7-data.p
#
#
# There are 2323 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-24-7-geos.p
#
#
# Found 51896 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-24-7-data.p
#
#
# There are 51896 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-24-7-geos.p
#
#
# Found 37856 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-24-7-data.p
#
#
# There are 37856 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-24-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_24_Maryland_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_25_Massachusetts_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_25_Massachusetts_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:36:05 for Analyzing 25	RailFeature	1767
# Found 15865 geos from 25-RailFeature
# Found 12615 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-25-7-data.p
#
#
# There are 12615 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-25-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:36:10 for Analyzing 25	RoadSegment	250000
# 	Keeping 9225 of 50000 = 18.4
# 	Keeping 18073 of 100000 = 18.1
# 	Keeping 27130 of 150000 = 18.1
# 	Keeping 36018 of 200000 = 18.0
# 	Keeping 45068 of 250000 = 18.0
# Found 108400 geos from 25-RoadSegment
# Current Time is Fri Aug 31, 2018 21:36:40 for Analyzing 25	RoadSegment2	208431
# 	Keeping 53788 of 300000 = 17.9
# 	Keeping 62664 of 350000 = 17.9
# 	Keeping 71817 of 400000 = 18.0
# 	Keeping 80799 of 450000 = 18.0
# Found 88715 geos from 25-RoadSegment2
# Found 45441 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-25-7-data.p
#
#
# There are 45441 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-25-7-geos.p
#
#
# Found 8425 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-25-7-data.p
#
#
# There are 8425 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-25-7-geos.p
#
#
# Found 10709 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-25-7-data.p
#
#
# There are 10709 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-25-7-geos.p
#
#
# Found 45485 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-25-7-data.p
#
#
# There are 45485 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-25-7-geos.p
#
#
# Found 8826 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-25-7-data.p
#
#
# There are 8826 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-25-7-geos.p
#
#
# Found 621 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-25-7-data.p
#
#
# There are 621 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-25-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_25_Massachusetts_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_26_Michigan_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_26_Michigan_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:37:20 for Analyzing 26	RailFeature	4965
# Found 33943 geos from 26-RailFeature
# Found 24967 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-26-7-data.p
#
#
# There are 24967 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-26-7-geos.p
# Current Time is Fri Aug 31, 2018 21:37:25 for Analyzing 26	RoadSegment	250000
# 	Keeping 8452 of 50000 = 16.9
# 	Keeping 16967 of 100000 = 17.0
# 	Keeping 25270 of 150000 = 16.8
# 	Keeping 33683 of 200000 = 16.8
# 	Keeping 42387 of 250000 = 17.0
# Found 110038 geos from 26-RoadSegment
# Current Time is Fri Aug 31, 2018 21:37:55 for Analyzing 26	RoadSegment2	250000
# 	Keeping 51274 of 300000 = 17.1
# 	Keeping 60021 of 350000 = 17.1
# 	Keeping 68745 of 400000 = 17.2
# 	Keeping 77569 of 450000 = 17.2
# 	Keeping 86268 of 500000 = 17.3
# Found 113688 geos from 26-RoadSegment2
# Current Time is Fri Aug 31, 2018 21:38:25 for Analyzing 26	RoadSegment3	250000
# 	Keeping 95124 of 550000 = 17.3
# 	Keeping 103687 of 600000 = 17.3
# 	Keeping 112458 of 650000 = 17.3
# 	Keeping 121245 of 700000 = 17.3
# 	Keeping 129992 of 750000 = 17.3
# Found 112575 geos from 26-RoadSegment3
# Current Time is Fri Aug 31, 2018 21:38:51 for Analyzing 26	RoadSegment4	87979
# 	Keeping 138641 of 800000 = 17.3
# Found 37702 geos from 26-RoadSegment4
# Found 48229 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-26-7-data.p
#
#
# There are 48229 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-26-7-geos.p
#
#
# Found 66006 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-26-7-data.p
#
#
# There are 66006 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-26-7-geos.p
#
#
# Found 26007 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-26-7-data.p
#
#
# There are 26007 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-26-7-geos.p
#
#
# Found 16195 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-26-7-data.p
#
#
# There are 16195 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-26-7-geos.p
#
#
# Found 1639 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-26-7-data.p
#
#
# There are 1639 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-26-7-geos.p
#
#
# Found 107406 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-26-7-data.p
#
#
# There are 107406 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-26-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_26_Michigan_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_27_Minnesota_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_27_Minnesota_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:39:18 for Analyzing 27	RailFeature	5528
# Found 40386 geos from 27-RailFeature
# Found 29785 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-27-7-data.p
#
#
# There are 29785 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-27-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:39:24 for Analyzing 27	RoadSegment	250000
# 	Keeping 15144 of 50000 = 30.3
# 	Keeping 30105 of 100000 = 30.1
# 	Keeping 45129 of 150000 = 30.1
# 	Keeping 60288 of 200000 = 30.1
# 	Keeping 75422 of 250000 = 30.2
# Found 240731 geos from 27-RoadSegment
# Current Time is Fri Aug 31, 2018 21:39:57 for Analyzing 27	RoadSegment2	250000
# 	Keeping 90483 of 300000 = 30.2
# 	Keeping 105592 of 350000 = 30.2
# 	Keeping 120810 of 400000 = 30.2
# 	Keeping 135895 of 450000 = 30.2
# 	Keeping 150960 of 500000 = 30.2
# Found 238595 geos from 27-RoadSegment2
# Current Time is Fri Aug 31, 2018 21:40:30 for Analyzing 27	RoadSegment3	250000
# 	Keeping 166055 of 550000 = 30.2
# 	Keeping 180982 of 600000 = 30.2
# 	Keeping 196008 of 650000 = 30.2
# 	Keeping 210945 of 700000 = 30.1
# 	Keeping 226144 of 750000 = 30.2
# Found 238035 geos from 27-RoadSegment3
# Current Time is Fri Aug 31, 2018 21:40:59 for Analyzing 27	RoadSegment4	27138
# Found 22495 geos from 27-RoadSegment4
# Found 10712 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-27-7-data.p
#
#
# There are 10712 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-27-7-geos.p
#
#
# Found 38177 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-27-7-data.p
#
#
# There are 38177 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-27-7-geos.p
#
#
# Found 296559 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-27-7-data.p
#
#
# There are 296559 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-27-7-geos.p
#
#
# Found 82227 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-27-7-data.p
#
#
# There are 82227 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-27-7-geos.p
#
#
# Found 181184 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-27-7-data.p
#
#
# There are 181184 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-27-7-geos.p
#
#
# Found 464 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-27-7-data.p
#
#
# There are 464 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-27-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_27_Minnesota_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_28_Mississippi_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_28_Mississippi_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:41:15 for Analyzing 28	RailFeature	6126
# Found 31857 geos from 28-RailFeature
# Found 20553 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-28-7-data.p
#
#
# There are 20553 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-28-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:41:21 for Analyzing 28	RoadSegment	250000
# 	Keeping 8403 of 50000 = 16.8
# 	Keeping 17301 of 100000 = 17.3
# 	Keeping 25984 of 150000 = 17.3
# 	Keeping 34557 of 200000 = 17.3
# 	Keeping 43742 of 250000 = 17.5
# Found 127420 geos from 28-RoadSegment
# Current Time is Fri Aug 31, 2018 21:41:52 for Analyzing 28	RoadSegment2	250000
# 	Keeping 52096 of 300000 = 17.4
# 	Keeping 60814 of 350000 = 17.4
# 	Keeping 69490 of 400000 = 17.4
# 	Keeping 77719 of 450000 = 17.3
# 	Keeping 86533 of 500000 = 17.3
# Found 124246 geos from 28-RoadSegment2
# Current Time is Fri Aug 31, 2018 21:42:20 for Analyzing 28	RoadSegment3	79179
# 	Keeping 95227 of 550000 = 17.3
# Found 40146 geos from 28-RoadSegment3
# Found 96059 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-28-7-data.p
#
#
# There are 96059 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-28-7-geos.p
#
#
# Found 8630 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-28-7-data.p
#
#
# There are 8630 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-28-7-geos.p
#
#
# Found 32081 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-28-7-data.p
#
#
# There are 32081 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-28-7-geos.p
#
#
# Found 94975 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-28-7-data.p
#
#
# There are 94975 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-28-7-geos.p
#
#
# Found 27863 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-28-7-data.p
#
#
# There are 27863 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-28-7-geos.p
#
#
# Found 2234 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-28-7-data.p
#
#
# There are 2234 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-28-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_28_Mississippi_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_29_Missouri_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_29_Missouri_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:42:51 for Analyzing 29	RailFeature	7015
# Found 50266 geos from 29-RailFeature
# Found 35484 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-29-7-data.p
#
#
# There are 35484 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-29-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:42:57 for Analyzing 29	RoadSegment	250000
# 	Keeping 8924 of 50000 = 17.8
# 	Keeping 18581 of 100000 = 18.6
# 	Keeping 28137 of 150000 = 18.8
# 	Keeping 37625 of 200000 = 18.8
# 	Keeping 46355 of 250000 = 18.5
# Found 146277 geos from 29-RoadSegment
# Current Time is Fri Aug 31, 2018 21:43:29 for Analyzing 29	RoadSegment2	250000
# 	Keeping 55395 of 300000 = 18.5
# 	Keeping 65065 of 350000 = 18.6
# 	Keeping 74396 of 400000 = 18.6
# 	Keeping 83932 of 450000 = 18.7
# 	Keeping 92071 of 500000 = 18.4
# Found 144734 geos from 29-RoadSegment2
# Current Time is Fri Aug 31, 2018 21:44:01 for Analyzing 29	RoadSegment3	250000
# 	Keeping 102144 of 550000 = 18.6
# 	Keeping 111699 of 600000 = 18.6
# 	Keeping 121038 of 650000 = 18.6
# 	Keeping 130046 of 700000 = 18.6
# 	Keeping 138979 of 750000 = 18.5
# Found 146968 geos from 29-RoadSegment3
# Current Time is Fri Aug 31, 2018 21:44:32 for Analyzing 29	RoadSegment4	250000
# 	Keeping 148757 of 800000 = 18.6
# 	Keeping 158358 of 850000 = 18.6
# 	Keeping 167597 of 900000 = 18.6
# 	Keeping 176342 of 950000 = 18.6
# 	Keeping 185425 of 1000000 = 18.5
# Found 145870 geos from 29-RoadSegment4
# Current Time is Fri Aug 31, 2018 21:45:00 for Analyzing 29	RoadSegment5	16571
# Found 8709 geos from 29-RoadSegment5
# Found 17042 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-29-7-data.p
#
#
# There are 17042 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-29-7-geos.p
#
#
# Found 263945 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-29-7-data.p
#
#
# There are 263945 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-29-7-geos.p
#
#
# Found 48767 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-29-7-data.p
#
#
# There are 48767 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-29-7-geos.p
#
#
# Found 104335 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-29-7-data.p
#
#
# There are 104335 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-29-7-geos.p
#
#
# Found 84366 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-29-7-data.p
#
#
# There are 84366 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-29-7-geos.p
#
#
# Found 1728 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-29-7-data.p
#
#
# There are 1728 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-29-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_29_Missouri_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_30_Montana_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_30_Montana_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:45:13 for Analyzing 30	RailFeature	2318
# Found 33161 geos from 30-RailFeature
# Found 28056 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-30-7-data.p
#
#
# There are 28056 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-30-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:45:19 for Analyzing 30	RoadSegment	250000
# 	Keeping 5846 of 50000 = 11.7
# 	Keeping 11710 of 100000 = 11.7
# 	Keeping 17520 of 150000 = 11.7
# 	Keeping 23294 of 200000 = 11.6
# 	Keeping 29250 of 250000 = 11.7
# Found 116617 geos from 30-RoadSegment
# Current Time is Fri Aug 31, 2018 21:45:49 for Analyzing 30	RoadSegment2	157155
# 	Keeping 35352 of 300000 = 11.8
# 	Keeping 41213 of 350000 = 11.8
# 	Keeping 47018 of 400000 = 11.8
# Found 75042 geos from 30-RoadSegment2
# Found 64165 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-30-7-data.p
#
#
# There are 64165 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-30-7-geos.p
#
#
# Found 65997 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-30-7-data.p
#
#
# There are 65997 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-30-7-geos.p
#
#
# Found 34250 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-30-7-data.p
#
#
# There are 34250 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-30-7-geos.p
#
#
# Found 16442 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-30-7-data.p
#
#
# There are 16442 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-30-7-geos.p
#
#
# Found 2005 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-30-7-data.p
#
#
# There are 2005 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-30-7-geos.p
#
#
# Found 22342 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-30-7-data.p
#
#
# There are 22342 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-30-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_30_Montana_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_31_Nebraska_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_31_Nebraska_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:46:18 for Analyzing 31	RailFeature	4668
# Found 36870 geos from 31-RailFeature
# Found 26612 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-31-7-data.p
#
#
# There are 26612 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-31-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:46:23 for Analyzing 31	RoadSegment	250000
# 	Keeping 7365 of 50000 = 14.7
# 	Keeping 14008 of 100000 = 14.0
# 	Keeping 21173 of 150000 = 14.1
# 	Keeping 30021 of 200000 = 15.0
# 	Keeping 37612 of 250000 = 15.0
# Found 124331 geos from 31-RoadSegment
# Current Time is Fri Aug 31, 2018 21:46:53 for Analyzing 31	RoadSegment2	250000
# 	Keeping 44507 of 300000 = 14.8
# 	Keeping 51212 of 350000 = 14.6
# 	Keeping 59852 of 400000 = 15.0
# 	Keeping 67762 of 450000 = 15.1
# 	Keeping 75273 of 500000 = 15.1
# Found 123667 geos from 31-RoadSegment2
# Current Time is Fri Aug 31, 2018 21:47:19 for Analyzing 31	RoadSegment3	23908
# Found 12140 geos from 31-RoadSegment3
# Found 31275 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-31-7-data.p
#
#
# There are 31275 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-31-7-geos.p
#
#
# Found 5335 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-31-7-data.p
#
#
# There are 5335 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-31-7-geos.p
#
#
# Found 56530 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-31-7-data.p
#
#
# There are 56530 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-31-7-geos.p
#
#
# Found 90666 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-31-7-data.p
#
#
# There are 90666 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-31-7-geos.p
#
#
# Found 29472 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-31-7-data.p
#
#
# There are 29472 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-31-7-geos.p
#
#
# Found 120 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-31-7-data.p
#
#
# There are 120 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-31-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_31_Nebraska_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_32_Nevada_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_32_Nevada_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:47:30 for Analyzing 32	RailFeature	1757
# Found 16948 geos from 32-RailFeature
# Found 12473 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-32-7-data.p
#
#
# There are 12473 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-32-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:47:35 for Analyzing 32	RoadSegment	250000
# 	Keeping 6995 of 50000 = 14.0
# 	Keeping 13671 of 100000 = 13.7
# 	Keeping 22179 of 150000 = 14.8
# 	Keeping 29810 of 200000 = 14.9
# 	Keeping 36727 of 250000 = 14.7
# Found 117018 geos from 32-RoadSegment
# Current Time is Fri Aug 31, 2018 21:48:03 for Analyzing 32	RoadSegment2	68527
# 	Keeping 43673 of 300000 = 14.6
# Found 31678 geos from 32-RoadSegment2
# Found 34697 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-32-7-data.p
#
#
# There are 34697 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-32-7-geos.p
#
#
# Found 33807 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-32-7-data.p
#
#
# There are 33807 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-32-7-geos.p
#
#
# Found 19964 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-32-7-data.p
#
#
# There are 19964 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-32-7-geos.p
#
#
# Found 7885 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-32-7-data.p
#
#
# There are 7885 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-32-7-geos.p
#
#
# Found 34304 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-32-7-data.p
#
#
# There are 34304 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-32-7-geos.p
#
#
# Found 161 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-32-7-data.p
#
#
# There are 161 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-32-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_32_Nevada_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_33_New_Hampshire_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_33_New_Hampshire_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:48:15 for Analyzing 33	RailFeature	378
# Found 4742 geos from 33-RailFeature
# Found 4067 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-33-7-data.p
#
#
# There are 4067 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-33-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:48:18 for Analyzing 33	RoadSegment	186949
# 	Keeping 7798 of 50000 = 15.6
# 	Keeping 15550 of 100000 = 15.6
# 	Keeping 23383 of 150000 = 15.6
# Found 82979 geos from 33-RoadSegment
# Found 34901 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-33-7-data.p
#
#
# There are 34901 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-33-7-geos.p
#
#
# Found 3061 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-33-7-data.p
#
#
# There are 3061 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-33-7-geos.p
#
#
# Found 6311 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-33-7-data.p
#
#
# There are 6311 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-33-7-geos.p
#
#
# Found 9349 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-33-7-data.p
#
#
# There are 9349 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-33-7-geos.p
#
#
# Found 1539 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-33-7-data.p
#
#
# There are 1539 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-33-7-geos.p
#
#
# Found 8564 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-33-7-data.p
#
#
# There are 8564 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-33-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_33_New_Hampshire_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_34_New_Jersey_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_34_New_Jersey_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:48:58 for Analyzing 34	RailFeature	5898
# Found 23149 geos from 34-RailFeature
# Found 12680 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-34-7-data.p
#
#
# There are 12680 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-34-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:49:03 for Analyzing 34	RoadSegment	250000
# 	Keeping 14852 of 50000 = 29.7
# 	Keeping 30092 of 100000 = 30.1
# 	Keeping 45742 of 150000 = 30.5
# 	Keeping 61672 of 200000 = 30.8
# 	Keeping 77827 of 250000 = 31.1
# Found 169376 geos from 34-RoadSegment
# Current Time is Fri Aug 31, 2018 21:49:35 for Analyzing 34	RoadSegment2	250000
# 	Keeping 93874 of 300000 = 31.3
# 	Keeping 109323 of 350000 = 31.2
# 	Keeping 124305 of 400000 = 31.1
# 	Keeping 139561 of 450000 = 31.0
# 	Keeping 155091 of 500000 = 31.0
# Found 167502 geos from 34-RoadSegment2
# Current Time is Fri Aug 31, 2018 21:50:06 for Analyzing 34	RoadSegment3	250000
# 	Keeping 170916 of 550000 = 31.1
# 	Keeping 186918 of 600000 = 31.2
# 	Keeping 203127 of 650000 = 31.3
# 	Keeping 218760 of 700000 = 31.3
# 	Keeping 233864 of 750000 = 31.2
# Found 169114 geos from 34-RoadSegment3
# Current Time is Fri Aug 31, 2018 21:50:37 for Analyzing 34	RoadSegment4	177194
# 	Keeping 248994 of 800000 = 31.1
# 	Keeping 264284 of 850000 = 31.1
# 	Keeping 280338 of 900000 = 31.1
# Found 119771 geos from 34-RoadSegment4
# Found 18092 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-34-7-data.p
#
#
# There are 18092 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-34-7-geos.p
#
#
# Found 96527 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-34-7-data.p
#
#
# There are 96527 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-34-7-geos.p
#
#
# Found 6401 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-34-7-data.p
#
#
# There are 6401 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-34-7-geos.p
#
#
# Found 14444 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-34-7-data.p
#
#
# There are 14444 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-34-7-geos.p
#
#
# Found 9818 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-34-7-data.p
#
#
# There are 9818 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-34-7-geos.p
#
#
# Found 1956 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-34-7-data.p
#
#
# There are 1956 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-34-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_34_New_Jersey_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_35_New_Mexico_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_35_New_Mexico_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:51:12 for Analyzing 35	RailFeature	2472
# Found 20214 geos from 35-RailFeature
# Found 15219 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-35-7-data.p
#
#
# There are 15219 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-35-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:51:17 for Analyzing 35	RoadSegment	250000
# 	Keeping 5778 of 50000 = 11.6
# 	Keeping 10976 of 100000 = 11.0
# 	Keeping 16327 of 150000 = 10.9
# 	Keeping 22251 of 200000 = 11.1
# 	Keeping 28170 of 250000 = 11.3
# Found 97298 geos from 35-RoadSegment
# Current Time is Fri Aug 31, 2018 21:51:47 for Analyzing 35	RoadSegment2	250000
# 	Keeping 32756 of 300000 = 10.9
# 	Keeping 39105 of 350000 = 11.2
# 	Keeping 44928 of 400000 = 11.2
# 	Keeping 50295 of 450000 = 11.2
# 	Keeping 55460 of 500000 = 11.1
# Found 96572 geos from 35-RoadSegment2
# Current Time is Fri Aug 31, 2018 21:52:12 for Analyzing 35	RoadSegment3	58103
# 	Keeping 61419 of 550000 = 11.2
# Found 20679 geos from 35-RoadSegment3
# Found 71094 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-35-7-data.p
#
#
# There are 71094 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-35-7-geos.p
#
#
# Found 76799 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-35-7-data.p
#
#
# There are 76799 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-35-7-geos.p
#
#
# Found 11142 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-35-7-data.p
#
#
# There are 11142 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-35-7-geos.p
#
#
# Found 33691 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-35-7-data.p
#
#
# There are 33691 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-35-7-geos.p
#
#
# Found 31689 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-35-7-data.p
#
#
# There are 31689 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-35-7-geos.p
#
#
# Found 95 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-35-7-data.p
#
#
# There are 95 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-35-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_35_New_Mexico_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_36_New_York_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_36_New_York_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 21:52:42 for Analyzing 36	RailFeature	5588
# Found 47866 geos from 36-RailFeature
# Found 37395 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-36-7-data.p
#
#
# There are 37395 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-36-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 21:52:49 for Analyzing 36	RoadSegment	250000
# 	Keeping 12602 of 50000 = 25.2
# 	Keeping 23827 of 100000 = 23.8
# 	Keeping 37578 of 150000 = 25.1
# 	Keeping 51004 of 200000 = 25.5
# 	Keeping 63538 of 250000 = 25.4
# Found 165636 geos from 36-RoadSegment
# Current Time is Fri Aug 31, 2018 21:53:19 for Analyzing 36	RoadSegment2	250000
# 	Keeping 75046 of 300000 = 25.0
# 	Keeping 88267 of 350000 = 25.2
# 	Keeping 102038 of 400000 = 25.5
# 	Keeping 114469 of 450000 = 25.4
# 	Keeping 125967 of 500000 = 25.2
# Found 164039 geos from 36-RoadSegment2
# Current Time is Fri Aug 31, 2018 21:53:49 for Analyzing 36	RoadSegment3	250000
# 	Keeping 138950 of 550000 = 25.3
# 	Keeping 152855 of 600000 = 25.5
# 	Keeping 165512 of 650000 = 25.5
# 	Keeping 177245 of 700000 = 25.3
# 	Keeping 189883 of 750000 = 25.3
# Found 166717 geos from 36-RoadSegment3
# Current Time is Fri Aug 31, 2018 21:54:19 for Analyzing 36	RoadSegment4	250000
# 	Keeping 203847 of 800000 = 25.5
# 	Keeping 216712 of 850000 = 25.5
# 	Keeping 228518 of 900000 = 25.4
# 	Keeping 240775 of 950000 = 25.3
# 	Keeping 254690 of 1000000 = 25.5
# Found 165744 geos from 36-RoadSegment4
# Current Time is Fri Aug 31, 2018 21:54:45 for Analyzing 36	RoadSegment5	54978
# 	Keeping 267638 of 1050000 = 25.5
# Found 35253 geos from 36-RoadSegment5
# Found 24624 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-36-7-data.p
#
#
# There are 24624 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-36-7-geos.p
#
#
# Found 143079 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-36-7-data.p
#
#
# There are 143079 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-36-7-geos.p
#
#
# Found 44289 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-36-7-data.p
#
#
# There are 44289 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-36-7-geos.p
#
#
# Found 19706 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-36-7-data.p
#
#
# There are 19706 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-36-7-geos.p
#
#
# Found 116742 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-36-7-data.p
#
#
# There are 116742 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-36-7-geos.p
#
#
# Found 2873 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-36-7-data.p
#
#
# There are 2873 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-36-7-geos.p
#
#
# ...
# Saved shape data to roads/RailFeature-Rail-51-7-data.p
#
#
# There are 34925 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-51-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 22:19:40 for Analyzing 51	RoadSegment	250000
# 	Keeping 5845 of 50000 = 11.7
# 	Keeping 12305 of 100000 = 12.3
# 	Keeping 18857 of 150000 = 12.6
# 	Keeping 25105 of 200000 = 12.6
# 	Keeping 30972 of 250000 = 12.4
# Found 84516 geos from 51-RoadSegment
# Current Time is Fri Aug 31, 2018 22:20:09 for Analyzing 51	RoadSegment2	250000
# 	Keeping 37909 of 300000 = 12.6
# 	Keeping 44682 of 350000 = 12.8
# 	Keeping 50332 of 400000 = 12.6
# 	Keeping 56675 of 450000 = 12.6
# 	Keeping 63457 of 500000 = 12.7
# Found 86582 geos from 51-RoadSegment2
# Current Time is Fri Aug 31, 2018 22:20:38 for Analyzing 51	RoadSegment3	250000
# 	Keeping 70059 of 550000 = 12.7
# 	Keeping 75464 of 600000 = 12.6
# 	Keeping 82247 of 650000 = 12.7
# 	Keeping 88952 of 700000 = 12.7
# 	Keeping 94931 of 750000 = 12.7
# Found 84839 geos from 51-RoadSegment3
# Current Time is Fri Aug 31, 2018 22:21:07 for Analyzing 51	RoadSegment4	250000
# 	Keeping 101087 of 800000 = 12.6
# 	Keeping 107729 of 850000 = 12.7
# 	Keeping 114485 of 900000 = 12.7
# 	Keeping 120279 of 950000 = 12.7
# 	Keeping 126739 of 1000000 = 12.7
# Found 85595 geos from 51-RoadSegment4
# Current Time is Fri Aug 31, 2018 22:21:35 for Analyzing 51	RoadSegment5	104535
# 	Keeping 133543 of 1050000 = 12.7
# 	Keeping 139683 of 1100000 = 12.7
# Found 36273 geos from 51-RoadSegment5
# Found 65374 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-51-7-data.p
#
#
# There are 65374 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-51-7-geos.p
#
#
# Found 16105 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-51-7-data.p
#
#
# There are 16105 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-51-7-geos.p
#
#
# Found 59314 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-51-7-data.p
#
#
# There are 59314 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-51-7-geos.p
#
#
# Found 56054 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-51-7-data.p
#
#
# There are 56054 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-51-7-geos.p
#
#
# Found 51038 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-51-7-data.p
#
#
# There are 51038 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-51-7-geos.p
#
#
# Found 5873 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-51-7-data.p
#
#
# There are 5873 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-51-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_51_Virginia_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_53_Washington_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_53_Washington_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 22:22:01 for Analyzing 53	RailFeature	8739
# Found 49768 geos from 53-RailFeature
# Found 31487 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-53-7-data.p
#
#
# There are 31487 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-53-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 22:22:07 for Analyzing 53	RoadSegment	250000
# 	Keeping 10455 of 50000 = 20.9
# 	Keeping 21647 of 100000 = 21.6
# 	Keeping 33295 of 150000 = 22.2
# 	Keeping 43755 of 200000 = 21.9
# 	Keeping 54213 of 250000 = 21.7
# Found 140916 geos from 53-RoadSegment
# Current Time is Fri Aug 31, 2018 22:22:38 for Analyzing 53	RoadSegment2	250000
# 	Keeping 64745 of 300000 = 21.6
# 	Keeping 75631 of 350000 = 21.6
# 	Keeping 87205 of 400000 = 21.8
# 	Keeping 98101 of 450000 = 21.8
# 	Keeping 108547 of 500000 = 21.7
# Found 139804 geos from 53-RoadSegment2
# Current Time is Fri Aug 31, 2018 22:23:06 for Analyzing 53	RoadSegment3	177302
# 	Keeping 118917 of 550000 = 21.6
# 	Keeping 129100 of 600000 = 21.5
# 	Keeping 140417 of 650000 = 21.6
# Found 98732 geos from 53-RoadSegment3
# Found 55001 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-53-7-data.p
#
#
# There are 55001 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-53-7-geos.p
#
#
# Found 46944 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-53-7-data.p
#
#
# There are 46944 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-53-7-geos.p
#
#
# Found 21322 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-53-7-data.p
#
#
# There are 21322 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-53-7-geos.p
#
#
# Found 10360 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-53-7-data.p
#
#
# There are 10360 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-53-7-geos.p
#
#
# Found 134438 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-53-7-data.p
#
#
# There are 134438 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-53-7-geos.p
#
#
# Found 1009 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-53-7-data.p
#
#
# There are 1009 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-53-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_53_Washington_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_54_West_Virginia_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_54_West_Virginia_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 22:23:35 for Analyzing 54	RailFeature	2672
# Found 33924 geos from 54-RailFeature
# Found 28551 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-54-7-data.p
#
#
# There are 28551 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-54-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 22:23:40 for Analyzing 54	RoadSegment	250000
# 	Keeping 7887 of 50000 = 15.8
# 	Keeping 15582 of 100000 = 15.6
# 	Keeping 23362 of 150000 = 15.6
# 	Keeping 31285 of 200000 = 15.6
# 	Keeping 39071 of 250000 = 15.6
# Found 123193 geos from 54-RoadSegment
# Current Time is Fri Aug 31, 2018 22:24:12 for Analyzing 54	RoadSegment2	155075
# 	Keeping 46747 of 300000 = 15.6
# 	Keeping 54473 of 350000 = 15.6
# 	Keeping 62120 of 400000 = 15.5
# Found 73548 geos from 54-RoadSegment2
# Found 25974 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-54-7-data.p
#
#
# There are 25974 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-54-7-geos.p
#
#
# Found 35722 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-54-7-data.p
#
#
# There are 35722 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-54-7-geos.p
#
#
# Found 8111 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-54-7-data.p
#
#
# There are 8111 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-54-7-geos.p
#
#
# Found 56121 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-54-7-data.p
#
#
# There are 56121 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-54-7-geos.p
#
#
# Found 20242 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-54-7-data.p
#
#
# There are 20242 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-54-7-geos.p
#
#
# Found 405 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-54-7-data.p
#
#
# There are 405 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-54-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_54_West_Virginia_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_55_Wisconsin_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_55_Wisconsin_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 22:24:44 for Analyzing 55	RailFeature	4639
# Found 32915 geos from 55-RailFeature
# Found 24529 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-55-7-data.p
#
#
# There are 24529 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-55-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 22:24:49 for Analyzing 55	RoadSegment	250000
# 	Keeping 11190 of 50000 = 22.4
# 	Keeping 21909 of 100000 = 21.9
# 	Keeping 32357 of 150000 = 21.6
# 	Keeping 43930 of 200000 = 22.0
# 	Keeping 54824 of 250000 = 21.9
# Found 183356 geos from 55-RoadSegment
# Current Time is Fri Aug 31, 2018 22:25:19 for Analyzing 55	RoadSegment2	250000
# 	Keeping 65419 of 300000 = 21.8
# 	Keeping 76218 of 350000 = 21.8
# 	Keeping 87601 of 400000 = 21.9
# 	Keeping 98522 of 450000 = 21.9
# 	Keeping 108923 of 500000 = 21.8
# Found 178573 geos from 55-RoadSegment2
# Current Time is Fri Aug 31, 2018 22:25:48 for Analyzing 55	RoadSegment3	128764
# 	Keeping 119935 of 550000 = 21.8
# 	Keeping 131267 of 600000 = 21.9
# Found 92708 geos from 55-RoadSegment3
# Found 89688 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-55-7-data.p
#
#
# There are 89688 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-55-7-geos.p
#
#
# Found 147863 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-55-7-data.p
#
#
# There are 147863 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-55-7-geos.p
#
#
# Found 125198 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-55-7-data.p
#
#
# There are 125198 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-55-7-geos.p
#
#
# Found 9151 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-55-7-data.p
#
#
# There are 9151 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-55-7-geos.p
#
#
# Found 31600 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-55-7-data.p
#
#
# There are 31600 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-55-7-geos.p
#
#
# Found 983 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-55-7-data.p
#
#
# There are 983 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-55-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_55_Wisconsin_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_56_Wyoming_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_56_Wyoming_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 22:26:09 for Analyzing 56	RailFeature	2315
# Found 20958 geos from 56-RailFeature
# Found 15932 of type RailFeature/Rail
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-56-7-data.p
#
#
# There are 15932 entries in the saved file.
# Saved shape data to roads/RailFeature-Rail-56-7-geos.p
#
#
# Current Time is Fri Aug 31, 2018 22:26:14 for Analyzing 56	RoadSegment	250000
# 	Keeping 4568 of 50000 = 9.1
# 	Keeping 8953 of 100000 = 9.0
# 	Keeping 13761 of 150000 = 9.2
# 	Keeping 18480 of 200000 = 9.2
# 	Keeping 23064 of 250000 = 9.2
# Found 101188 geos from 56-RoadSegment
# Current Time is Fri Aug 31, 2018 22:26:40 for Analyzing 56	RoadSegment2	45611
# Found 17839 geos from 56-RoadSegment2
# Found 12049 of type RoadSegment/Interstate
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-56-7-data.p
#
#
# There are 12049 entries in the saved file.
# Saved shape data to roads/RoadSegment-Interstate-56-7-geos.p
#
#
# Found 34485 of type RoadSegment/USRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-56-7-data.p
#
#
# There are 34485 entries in the saved file.
# Saved shape data to roads/RoadSegment-USRte-56-7-geos.p
#
#
# Found 50315 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-56-7-data.p
#
#
# There are 50315 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-56-7-geos.p
#
#
# Found 38593 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-56-7-data.p
#
#
# There are 38593 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-56-7-geos.p
#
#
# Found 10698 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-56-7-data.p
#
#
# There are 10698 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-56-7-geos.p
#
#
# Found 232 of type RoadSegment/Connection
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-56-7-data.p
#
#
# There are 232 entries in the saved file.
# Saved shape data to roads/RoadSegment-Connection-56-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_56_Wyoming_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_60_American_Samoa_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_60_American_Samoa_GU_STATEORTERRITORY
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_60_American_Samoa_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_66_Guam_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_66_Guam_GU_STATEORTERRITORY
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_66_Guam_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_69_Northern_Mariana_Islands_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_69_Northern_Mariana_Islands_GU_STATEORTERRITORY
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_69_Northern_Mariana_Islands_GU_STATEORTERRITORY directory <<<---
# Unzipping /Users/tgadf/Downloads/stateshapes/TRAN_72_Puerto_Rico_GU_STATEORTERRITORY.zip
#     Unzipping to /Users/tgadf/Downloads/stateshapes/TRAN_72_Puerto_Rico_GU_STATEORTERRITORY
# Current Time is Fri Aug 31, 2018 22:26:56 for Analyzing 72	RoadSegment	247827
# 	Keeping 6346 of 50000 = 12.7
# 	Keeping 12601 of 100000 = 12.6
# 	Keeping 18783 of 150000 = 12.5
# 	Keeping 25184 of 200000 = 12.6
# Found 77884 geos from 72-RoadSegment
# Found 41817 of type RoadSegment/StateRte
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-72-7-data.p
#
#
# There are 41817 entries in the saved file.
# Saved shape data to roads/RoadSegment-StateRte-72-7-geos.p
#
#
# Found 260 of type RoadSegment/MajorRd
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-72-7-data.p
#
#
# There are 260 entries in the saved file.
# Saved shape data to roads/RoadSegment-MajorRd-72-7-geos.p
#
#
# Found 132 of type RoadSegment/Highway
#
#
# There are 1 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-72-7-data.p
#
#
# There are 132 entries in the saved file.
# Saved shape data to roads/RoadSegment-Highway-72-7-geos.p
#
#
# --->>> Removing /Users/tgadf/Downloads/stateshapes/TRAN_72_Puerto_Rico_GU_STATEORTERRITORY directory <<<---

# %%
if False:
    # Ave, Pkwy, Blvd, Hwy, Fwy
    cnts = Counter()
    for item in remainCntr.most_common():
        for val in item[0].split():
            cnts[val] += 1
        #print(item)

    for item in cnts.most_common(100):
        print(item)

# %% [markdown]
# # Create State Data

# %%
import pickle
prec=7
from glob import glob
from os.path import basename,splitext
vals     = glob("roads/*-{0}-geos.p".format(prec))
basevals = set([splitext(basename(x))[0].split('-')[0] for x in vals])
mtypes   = set([splitext(basename(x))[0].split('-')[1] for x in vals])
states   = set([splitext(basename(x))[0].split('-')[2] for x in vals])
geomap   = {}
records  = {}
ngeos    = 0
totalgeos = 0
for mtype in mtypes:
    for state in states:
        for baseval in basevals:
            try:
                recname = "roads/{0}-{1}-{2}-{3}-data.p".format(baseval, mtype, state, prec)
                recdata = pickle.load(open(recname, "rb"))
            except:
                print("Could not open {0}".format(recname))
                continue
            try:
                geoname = "roads/{0}-{1}-{2}-{3}-geos.p".format(baseval, mtype, state, prec)
                geodata = pickle.load(open(geoname, "rb"))
            except:
                print("Could not open {0}".format(geoname))
                continue
            ngeos = 0

            for geoid,geos in geodata.items():
                ngeos += len(geos)
                totalgeos += ngeos
                for geo in geos:
                    if geomap.get(geo) is None:
                        geomap[geo] = {}
                    geomap[geo][mtype] = geoid

            for geoid,rec in recdata.items():
                records[geoid] = rec['Name']
                break

    print("{0}\t{1}\t---> {2} <---".format(mtype,ngeos,len(geomap)))
         
print("Found {0} geos in total".format(totalgeos))
fname="geomap-{0}-Roads.p".format(prec)
print("Writing {0}".format(fname))
pickle.dump(geomap,  open(fname, "wb"))

fname="georec-{0}-Roads.p".format(prec)
print("Writing {0}".format(fname))
pickle.dump(records,  open(fname, "wb"))
# Out:
# Could not open roads/TrailSegment-MajorRd-33-7-data.p
# Could not open roads/RailFeature-MajorRd-33-7-data.p
# Could not open roads/TrailSegment-MajorRd-46-7-data.p
# Could not open roads/RailFeature-MajorRd-46-7-data.p
# Could not open roads/TrailSegment-MajorRd-19-7-data.p
# Could not open roads/RailFeature-MajorRd-19-7-data.p
# Could not open roads/TrailSegment-MajorRd-22-7-data.p
# Could not open roads/RailFeature-MajorRd-22-7-data.p
# Could not open roads/TrailSegment-MajorRd-72-7-data.p
# Could not open roads/RailFeature-MajorRd-72-7-data.p
# Could not open roads/TrailSegment-MajorRd-56-7-data.p
# Could not open roads/RailFeature-MajorRd-56-7-data.p
# Could not open roads/TrailSegment-MajorRd-35-7-data.p
# Could not open roads/RailFeature-MajorRd-35-7-data.p
# Could not open roads/TrailSegment-MajorRd-11-7-data.p
# Could not open roads/RailFeature-MajorRd-11-7-data.p
# Could not open roads/TrailSegment-MajorRd-25-7-data.p
# Could not open roads/RailFeature-MajorRd-25-7-data.p
# Could not open roads/TrailSegment-MajorRd-31-7-data.p
# Could not open roads/RailFeature-MajorRd-31-7-data.p
# Could not open roads/TrailSegment-MajorRd-38-7-data.p
# Could not open roads/RailFeature-MajorRd-38-7-data.p
# Could not open roads/TrailSegment-MajorRd-17-7-data.p
# Could not open roads/RailFeature-MajorRd-17-7-data.p
# Could not open roads/TrailSegment-MajorRd-28-7-data.p
# Could not open roads/RailFeature-MajorRd-28-7-data.p
# Could not open roads/TrailSegment-MajorRd-54-7-data.p
# Could not open roads/RailFeature-MajorRd-54-7-data.p
# Could not open roads/TrailSegment-MajorRd-26-7-data.p
# Could not open roads/RailFeature-MajorRd-26-7-data.p
# Could not open roads/TrailSegment-MajorRd-20-7-data.p
# Could not open roads/RailFeature-MajorRd-20-7-data.p
# Could not open roads/TrailSegment-MajorRd-48-7-data.p
# Could not open roads/RailFeature-MajorRd-48-7-data.p
# Could not open roads/TrailSegment-MajorRd-1-7-data.p
# Could not open roads/RailFeature-MajorRd-1-7-data.p
# Could not open roads/TrailSegment-MajorRd-45-7-data.p
# Could not open roads/RailFeature-MajorRd-45-7-data.p
{'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm1ze': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqchzff': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm1wv': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0kg': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqchzg1': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm1zd': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm0kd': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm0k9': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm2bv': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0tg': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm2b4': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0hq': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcjtug': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0t0': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm373': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcjmnu': {'StateRte': 'StateRte',
#   'Connection': 'Connection',
#   'Highway': 'Highway'},
#  'dqcm05c': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm34k': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0td': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm2bt': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0z8': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm0ws': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm318': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0k8': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcjxy4': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0hr': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm2by': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0xx': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcjxuu': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm34t': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm34w': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcjxru': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0wv': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm379': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcjxvc': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm14c': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm059': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm372': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm08y': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm34m': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcjxrv': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm2cp': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm37d': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm31g': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0hh': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm0fr': {'StateRte': 'StateRte'},
#  'dqcm0t3': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm0te': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm0t2': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcjwn5': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0c2': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm312': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcjxv2': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm3be': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm0hn': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm2cn': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcjxuy': {'StateRte': 'StateRte'},
#  'dqcm0mj': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqchzfc': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm0hj': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm0zc': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm0mp': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm0xm': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcjz42': {'StateRte': 'StateRte'},
#  'dqcm35p': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm2b5': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm05g': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm0kc': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm37f': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm34h': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcjxx0': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm319': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0xn': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm313': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm3k5': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm1z9': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm0t1': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm0fq': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm3k7': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm0xj': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcjtue': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm2bk': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcjyfr': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm37g': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcjz0y': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd', 'USRte': 'USRte'},
#  'dqcm0w5': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcjntb': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqchzfd': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcjmnv': {'StateRte': 'StateRte', 'Connection': 'Connection'},
#  'dqcjxus': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0kf': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm0wk': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcjxuv': {'StateRte': 'StateRte'},
#  'dqcm34y': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0h5': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm31f': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm345': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm1wy': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm370': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0ku': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm2b7': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0xq': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm052': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway',
#   'Interstate': 'Interstate'},
#  'dqcm34z': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm2cr': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0z9': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm0wh': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm83f': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0t6': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm05f': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcm0mh': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcjxv8': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm2bs': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0wt': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcjtez': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm0zf': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm3b7': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqf0mr2': {'StateRte': 'StateRte'},
#  'dqcy9m4': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcvg7z': {'StateRte': 'StateRte'},
#  'dqckbgt': {'StateRte': 'StateRte'},
#  'dppcs16': {'StateRte': 'StateRte'},
#  'dqfn13j': {'StateRte': 'StateRte'},
#  'dr09vgt': {'StateRte': 'StateRte'},
#  'dqcxczf': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcqy8t': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqf3hm7': {'StateRte': 'StateRte'},
#  'dqcusd6': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqfj9he': {'StateRte': 'StateRte'},
#  'dqcxv4t': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqbzxr9': {'StateRte': 'StateRte'},
#  'dqc61pc': {'StateRte': 'StateRte'},
#  'dqcjv92': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr0cqw9': {'StateRte': 'StateRte'},
#  'dqcnw8e': {'StateRte': 'StateRte'},
#  'dqf6m14': {'StateRte': 'StateRte'},
#  'dr18rc1': {'StateRte': 'StateRte'},
#  'dqcpg9s': {'StateRte': 'StateRte'},
#  'dqcsxt2': {'StateRte': 'StateRte'},
#  'dqcddxq': {'StateRte': 'StateRte'},
#  'dr18jxf': {'StateRte': 'StateRte'},
#  'dqc3w6n': {'StateRte': 'StateRte'},
#  'dqfhemj': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcz76s': {'StateRte': 'StateRte'},
#  'dr18c0f': {'StateRte': 'StateRte'},
#  'dqc8ykb': {'StateRte': 'StateRte'},
#  'dqcnpur': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcw91z': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr19dxb': {'StateRte': 'StateRte'},
#  'dr184v1': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqf58xc': {'StateRte': 'StateRte'},
#  'dr0cekc': {'StateRte': 'StateRte'},
#  'dr13ctx': {'StateRte': 'StateRte'},
#  'dr12pkk': {'StateRte': 'StateRte'},
#  'dqcmswj': {'StateRte': 'StateRte'},
#  'dppbfr2': {'StateRte': 'StateRte'},
#  'dqcmg67': {'StateRte': 'StateRte'},
#  'dqf1mx5': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'USRte': 'USRte',
#   'Highway': 'Highway'},
#  'dqck5gj': {'StateRte': 'StateRte'},
#  'dqc9b6c': {'StateRte': 'StateRte'},
#  'dr11h57': {'StateRte': 'StateRte'},
#  'dr194zr': {'StateRte': 'StateRte'},
#  'dqckcnk': {'StateRte': 'StateRte'},
#  'dqc6u5c': {'StateRte': 'StateRte'},
#  'dqc3z1k': {'StateRte': 'StateRte'},
#  'dqc9eeu': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcw97b': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf61vs': {'StateRte': 'StateRte'},
#  'dqbzepr': {'StateRte': 'StateRte'},
#  'dqfh570': {'StateRte': 'StateRte'},
#  'dr10ry4': {'StateRte': 'StateRte'},
#  'dqc9bdj': {'StateRte': 'StateRte'},
#  'dr1czen': {'StateRte': 'StateRte'},
#  'dr13gjy': {'StateRte': 'StateRte'},
#  'dqcxbq5': {'StateRte': 'StateRte'},
#  'dr09jkb': {'StateRte': 'StateRte'},
#  'dqf14z8': {'StateRte': 'StateRte'},
#  'dqck0xt': {'StateRte': 'StateRte'},
#  'dqc3zr0': {'StateRte': 'StateRte'},
#  'dr1c86t': {'StateRte': 'StateRte'},
#  'dqcnwhp': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcrymu': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr018w1': {'StateRte': 'StateRte'},
#  'dqcrxqe': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr4167n': {'StateRte': 'StateRte'},
#  'dr09j8y': {'StateRte': 'StateRte'},
#  'dqcmtnv': {'StateRte': 'StateRte'},
#  'dqc6mfy': {'StateRte': 'StateRte'},
#  'dqczs8f': {'StateRte': 'StateRte'},
#  'dqckjx5': {'StateRte': 'StateRte'},
#  'dr0c6pr': {'StateRte': 'StateRte'},
#  'dqf60xt': {'StateRte': 'StateRte'},
#  'dqcz4u5': {'StateRte': 'StateRte'},
#  'dqcnn06': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr08yve': {'StateRte': 'StateRte'},
#  'dqcdm59': {'StateRte': 'StateRte'},
#  'dqc9mm9': {'StateRte': 'StateRte'},
#  'dqf07v4': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcvrve': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcnejk': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcm9jr': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcx1hx': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr1ckwj': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcq88f': {'StateRte': 'StateRte'},
#  'dqfpc2n': {'StateRte': 'StateRte'},
#  'dqce413': {'StateRte': 'StateRte'},
#  'dqcnpz9': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqf29cb': {'StateRte': 'StateRte'},
#  'dqcnwc3': {'StateRte': 'StateRte'},
#  'dqctgpx': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqc5wps': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcntds': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr13jnt': {'StateRte': 'StateRte'},
#  'dr10990': {'StateRte': 'StateRte'},
#  'dqckmny': {'StateRte': 'StateRte'},
#  'dqcyccx': {'StateRte': 'StateRte'},
#  'dr09nh7': {'StateRte': 'StateRte'},
#  'dqf2u2c': {'StateRte': 'StateRte'},
#  'dr1c00c': {'StateRte': 'StateRte'},
#  'dqcnens': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcxdcm': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqce30w': {'StateRte': 'StateRte'},
#  'dqcutng': {'StateRte': 'StateRte'},
#  'dr1crbu': {'StateRte': 'StateRte'},
#  'dr13fge': {'StateRte': 'StateRte'},
#  'dr03vd2': {'StateRte': 'StateRte'},
#  'dr1c4kc': {'StateRte': 'StateRte'},
#  'dqcx8ee': {'StateRte': 'StateRte'},
#  'dqcdbky': {'StateRte': 'StateRte'},
#  'dqc7hqj': {'StateRte': 'StateRte'},
#  'dqcebx5': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcrms9': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcku3d': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqf3d38': {'StateRte': 'StateRte'},
#  'dqf01vr': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcjv8v': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dr1c2sw': {'StateRte': 'StateRte'},
#  'dr0be8z': {'StateRte': 'StateRte'},
#  'dr1ck5k': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqfpdy9': {'StateRte': 'StateRte'},
#  'dqfp0jn': {'StateRte': 'StateRte'},
#  'dr12p7x': {'StateRte': 'StateRte'},
#  'dqcsrrd': {'StateRte': 'StateRte'},
#  'dqctf4m': {'StateRte': 'StateRte'},
#  'dqcphx9': {'StateRte': 'StateRte'},
#  'dr10f7r': {'StateRte': 'StateRte'},
#  'dqcpv6s': {'StateRte': 'StateRte'},
#  'dr11hc9': {'StateRte': 'StateRte'},
#  'dpp8k6y': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf14vp': {'StateRte': 'StateRte'},
#  'dqfn3my': {'StateRte': 'StateRte'},
#  'dqfn88b': {'StateRte': 'StateRte'},
#  'dqcwb82': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcubdu': {'StateRte': 'StateRte'},
#  'dqcx0k1': {'StateRte': 'StateRte'},
#  'dqcncb1': {'StateRte': 'StateRte'},
#  'dqcz4ex': {'StateRte': 'StateRte'},
#  'dqcjggc': {'StateRte': 'StateRte'},
#  'dqcd1ub': {'StateRte': 'StateRte'},
#  'dqcs3wy': {'StateRte': 'StateRte'},
#  'dr41c5q': {'StateRte': 'StateRte'},
#  'dr190t0': {'StateRte': 'StateRte'},
#  'dr117p8': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf5eed': {'StateRte': 'StateRte'},
#  'dr11uvn': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqc6h1g': {'StateRte': 'StateRte'},
#  'dr10zrm': {'StateRte': 'StateRte'},
#  'dqcmzj9': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcpnx3': {'StateRte': 'StateRte'},
#  'dqcy9j5': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr09tz6': {'StateRte': 'StateRte'},
#  'dr0cq79': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqfj95s': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqctqmx': {'StateRte': 'StateRte'},
#  'dr128mv': {'StateRte': 'StateRte'},
#  'dqce8de': {'StateRte': 'StateRte'},
#  'dpp81mn': {'StateRte': 'StateRte'},
#  'dqcx85u': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dpp9wm8': {'StateRte': 'StateRte'},
#  'dqc5479': {'StateRte': 'StateRte'},
#  'dr412ct': {'StateRte': 'StateRte'},
#  'dr401th': {'StateRte': 'StateRte'},
#  'dqcwbbh': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqczmqg': {'StateRte': 'StateRte'},
#  'dr189xe': {'StateRte': 'StateRte'},
#  'dqcjzww': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Interstate': 'Interstate'},
#  'dqcju93': {'StateRte': 'StateRte'},
#  'dqcs681': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcjsx1': {'StateRte': 'StateRte'},
#  'dr09ut9': {'StateRte': 'StateRte'},
#  'dqcztx6': {'StateRte': 'StateRte'},
#  'dr0c6ny': {'StateRte': 'StateRte'},
#  'dqcqgzz': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcvz8m': {'StateRte': 'StateRte'},
#  'dqcyw1m': {'StateRte': 'StateRte'},
#  'dqct36f': {'StateRte': 'StateRte'},
#  'dqc3z7m': {'StateRte': 'StateRte'},
#  'dr01267': {'StateRte': 'StateRte'},
#  'dr12dus': {'StateRte': 'StateRte'},
#  'dqc6e02': {'StateRte': 'StateRte'},
#  'dr00gqk': {'StateRte': 'StateRte'},
#  'dqf4tgk': {'StateRte': 'StateRte'},
#  'dqc7qh8': {'StateRte': 'StateRte'},
#  'dqcjus9': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqctz22': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf1s02': {'StateRte': 'StateRte'},
#  'dr09vkj': {'StateRte': 'StateRte'},
#  'dr13ctz': {'StateRte': 'StateRte'},
#  'dqc93y3': {'StateRte': 'StateRte'},
#  'dr40239': {'StateRte': 'StateRte'},
#  'dqc7y0g': {'StateRte': 'StateRte'},
#  'dqcrfcn': {'StateRte': 'StateRte'},
#  'dqctxpr': {'StateRte': 'StateRte'},
#  'dqcz5fq': {'StateRte': 'StateRte'},
#  'dr40249': {'StateRte': 'StateRte'},
#  'dqcx0xy': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqfpckk': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqckxvh': {'StateRte': 'StateRte'},
#  'dr4175b': {'StateRte': 'StateRte'},
#  'dppcvgs': {'StateRte': 'StateRte'},
#  'dqcqpy8': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqc6wcb': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf3sgg': {'StateRte': 'StateRte'},
#  'dr190jz': {'StateRte': 'StateRte'},
#  'dqfn52t': {'StateRte': 'StateRte'},
#  'dpp9wk8': {'StateRte': 'StateRte'},
#  'dqct1ez': {'StateRte': 'StateRte'},
#  'dqcnp60': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcgxss': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf6pfj': {'StateRte': 'StateRte'},
#  'dr13d5z': {'StateRte': 'StateRte'},
#  'dqcxb7k': {'StateRte': 'StateRte'},
#  'dr13ppg': {'StateRte': 'StateRte'},
#  'dr0cbbf': {'StateRte': 'StateRte'},
#  'dqc55pp': {'StateRte': 'StateRte'},
#  'dqc6n82': {'StateRte': 'StateRte'},
#  'dqcpxuz': {'StateRte': 'StateRte'},
#  'dqcquz5': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqf6shr': {'StateRte': 'StateRte'},
#  'dqcs97v': {'StateRte': 'StateRte'},
#  'dqfpb2d': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf58mh': {'StateRte': 'StateRte'},
#  'dqcqwuq': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcdk9g': {'StateRte': 'StateRte'},
#  'dqcx7p3': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqf67zz': {'StateRte': 'StateRte'},
#  'dr1csbt': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr419y9': {'StateRte': 'StateRte'},
#  'dr19dqg': {'StateRte': 'StateRte'},
#  'dqfh57h': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqc5mcs': {'StateRte': 'StateRte'},
#  'dqcju85': {'StateRte': 'StateRte'},
#  'dr1364r': {'StateRte': 'StateRte'},
#  'dqc6p1m': {'StateRte': 'StateRte'},
#  'dr09den': {'StateRte': 'StateRte'},
#  'dqf64gb': {'StateRte': 'StateRte'},
#  'dqcntb4': {'StateRte': 'StateRte'},
#  'dqck3x4': {'StateRte': 'StateRte'},
#  'dqcdkry': {'StateRte': 'StateRte'},
#  'dr012nk': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqc46fs': {'StateRte': 'StateRte'},
#  'dqcju4n': {'StateRte': 'StateRte'},
#  'dqcw3tx': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcjtxy': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dppcxcb': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'USRte': 'USRte',
#   'Highway': 'Highway',
#   'Interstate': 'Interstate'},
#  'dqfd2ub': {'StateRte': 'StateRte'},
#  'dqct3vn': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcgkhb': {'StateRte': 'StateRte'},
#  'dr12qxv': {'StateRte': 'StateRte'},
#  'dqcvy20': {'StateRte': 'StateRte'},
#  'dr10zc4': {'StateRte': 'StateRte'},
#  'dqcyj9j': {'StateRte': 'StateRte'},
#  'dqfp2ge': {'StateRte': 'StateRte'},
#  'dr18c8n': {'StateRte': 'StateRte'},
#  'dr1bcuy': {'StateRte': 'StateRte'},
#  'dqc9sq1': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcp9x8': {'StateRte': 'StateRte'},
#  'dqcwbz0': {'StateRte': 'StateRte'},
#  'dqf3vtq': {'StateRte': 'StateRte'},
#  'dqcmsmj': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr11ncu': {'StateRte': 'StateRte'},
#  'dqce2zf': {'StateRte': 'StateRte'},
#  'dqchp8z': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr13pds': {'StateRte': 'StateRte'},
#  'dqcyj6d': {'StateRte': 'StateRte'},
#  'dqcrmkx': {'StateRte': 'StateRte'},
#  'dqcq1hn': {'StateRte': 'StateRte'},
#  'dqcg19b': {'StateRte': 'StateRte'},
#  'dqcd88s': {'StateRte': 'StateRte'},
#  'dqfp24y': {'StateRte': 'StateRte'},
#  'dr0c92t': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqc5mev': {'StateRte': 'StateRte'},
#  'dr00vw8': {'StateRte': 'StateRte'},
#  'dppcqpw': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqbyy6d': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr40dtq': {'StateRte': 'StateRte'},
#  'dr12e9n': {'StateRte': 'StateRte'},
#  'dqcnezz': {'StateRte': 'StateRte'},
#  'dr184c5': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqfjep3': {'StateRte': 'StateRte'},
#  'dqc705x': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr1buqz': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcgku2': {'StateRte': 'StateRte'},
#  'dqczqnd': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcp2qh': {'StateRte': 'StateRte'},
#  'dr1ctzb': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcm8vq': {'StateRte': 'StateRte'},
#  'dqcdbz9': {'StateRte': 'StateRte'},
#  'dqck5s3': {'StateRte': 'StateRte'},
#  'dqct3sb': {'StateRte': 'StateRte'},
#  'dqckch4': {'StateRte': 'StateRte'},
#  'dqcmf20': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf45hh': {'StateRte': 'StateRte'},
#  'dqcq84c': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcxv3t': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr101yr': {'StateRte': 'StateRte'},
#  'dqcqc2m': {'StateRte': 'StateRte'},
#  'dqck102': {'StateRte': 'StateRte'},
#  'dr1858v': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr03y32': {'StateRte': 'StateRte'},
#  'dqcqw0e': {'StateRte': 'StateRte'},
#  'dqfh53z': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf15rw': {'StateRte': 'StateRte'},
#  'dqcn57n': {'StateRte': 'StateRte'},
#  'dqcx2s4': {'StateRte': 'StateRte'},
#  'dr124k0': {'StateRte': 'StateRte'},
#  'dqfh82t': {'StateRte': 'StateRte'},
#  'dqctxxb': {'StateRte': 'StateRte'},
#  'dqce12k': {'StateRte': 'StateRte'},
#  'dr12nh2': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqbzmnp': {'StateRte': 'StateRte'},
#  'dr12jt7': {'StateRte': 'StateRte'},
#  'dqck0mq': {'StateRte': 'StateRte'},
#  'dr13j96': {'StateRte': 'StateRte'},
#  'dqcnqfb': {'StateRte': 'StateRte'},
#  'dr19udd': {'StateRte': 'StateRte'},
#  'dqcyzb8': {'StateRte': 'StateRte'},
#  'dqcr948': {'StateRte': 'StateRte'},
#  'dr12vrj': {'StateRte': 'StateRte'},
#  'dqbz9tc': {'StateRte': 'StateRte'},
#  'dr0bnyk': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcx0g2': {'StateRte': 'StateRte'},
#  'dqcky94': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr0c8b9': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcp9j7': {'StateRte': 'StateRte'},
#  'dqc8yq3': {'StateRte': 'StateRte'},
#  'dqcm9e6': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqczvjs': {'StateRte': 'StateRte'},
#  'dqckcrx': {'StateRte': 'StateRte'},
#  'dr10mxd': {'StateRte': 'StateRte'},
#  'dqckpxk': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcxg2e': {'StateRte': 'StateRte'},
#  'dqc5x8d': {'StateRte': 'StateRte'},
#  'dr1816p': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqckrs9': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcmq9s': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dppcknq': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dppc4pn': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcjfzv': {'StateRte': 'StateRte'},
#  'dqf1g4r': {'StateRte': 'StateRte'},
#  'dqcg1gr': {'StateRte': 'StateRte'},
#  'dqcuvh0': {'StateRte': 'StateRte'},
#  'dqcnsum': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqce65n': {'StateRte': 'StateRte'},
#  'dqfjeuw': {'StateRte': 'StateRte'},
#  'dqcm8j3': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqc5r85': {'StateRte': 'StateRte'},
#  'dqcwd54': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqf67uv': {'StateRte': 'StateRte'},
#  'dqcq6yr': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcqb1n': {'StateRte': 'StateRte'},
#  'dr0b1uz': {'StateRte': 'StateRte'},
#  'dqcyfh5': {'StateRte': 'StateRte'},
#  'dqcnree': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr08x0j': {'StateRte': 'StateRte'},
#  'dqc96dc': {'StateRte': 'StateRte'},
#  'dr13zuh': {'StateRte': 'StateRte'},
#  'dppc7sw': {'StateRte': 'StateRte'},
#  'dqfngx1': {'StateRte': 'StateRte'},
#  'dr1cz73': {'StateRte': 'StateRte'},
#  'dr10651': {'StateRte': 'StateRte'},
#  'dr18x2x': {'StateRte': 'StateRte'},
#  'dqce8kf': {'StateRte': 'StateRte'},
#  'dqcussx': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr11mmk': {'StateRte': 'StateRte'},
#  'dqcg508': {'StateRte': 'StateRte'},
#  'dppcsv9': {'StateRte': 'StateRte'},
#  'dqc7y1m': {'StateRte': 'StateRte'},
#  'dr0cdfw': {'StateRte': 'StateRte'},
#  'dr10evd': {'StateRte': 'StateRte'},
#  'dqc4uvd': {'StateRte': 'StateRte'},
#  'dpp8vnb': {'StateRte': 'StateRte'},
#  'dqbztem': {'StateRte': 'StateRte'},
#  'dqcsfd1': {'StateRte': 'StateRte'},
#  'dqcnw1e': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqc6qdm': {'StateRte': 'StateRte'},
#  'dr12e56': {'StateRte': 'StateRte'},
#  'dppcz0p': {'StateRte': 'StateRte'},
#  'dqfpb9h': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr1823r': {'StateRte': 'StateRte'},
#  'dqcrxvb': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr19pb5': {'StateRte': 'StateRte'},
#  'dqcpx64': {'StateRte': 'StateRte'},
#  'dqf5kby': {'StateRte': 'StateRte'},
#  'dqf66uv': {'StateRte': 'StateRte'},
#  'dqctcc2': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr41ce6': {'StateRte': 'StateRte'},
#  'dr097x3': {'StateRte': 'StateRte'},
#  'dqczr6q': {'StateRte': 'StateRte'},
#  'dr1299e': {'StateRte': 'StateRte'},
#  'dqcu7p0': {'StateRte': 'StateRte'},
#  'dqcq77f': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqf5h22': {'StateRte': 'StateRte'},
#  'dqcxb9n': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr18re5': {'StateRte': 'StateRte', 'USRte': 'USRte', 'Highway': 'Highway'},
#  'dqcmfhq': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Interstate': 'Interstate'},
#  'dr11hcn': {'StateRte': 'StateRte'},
#  'dqcsxws': {'StateRte': 'StateRte'},
#  'dqc3see': {'StateRte': 'StateRte'},
#  'dr03fqj': {'StateRte': 'StateRte',
#   'USRte': 'USRte',
#   'Highway': 'Highway',
#   'Interstate': 'Interstate'},
#  'dqcrk0t': {'StateRte': 'StateRte'},
#  'dqc7c74': {'StateRte': 'StateRte'},
#  'dqc98w9': {'StateRte': 'StateRte'},
#  'dqc94dm': {'StateRte': 'StateRte'},
#  'dqcjgv5': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqfh4uv': {'StateRte': 'StateRte'},
#  'dqf6b2s': {'StateRte': 'StateRte'},
#  'dr13hg5': {'StateRte': 'StateRte'},
#  'dr114nw': {'StateRte': 'StateRte'},
#  'dpp84x2': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr10zm7': {'StateRte': 'StateRte'},
#  'dr12r2c': {'StateRte': 'StateRte'},
#  'dr405qg': {'StateRte': 'StateRte'},
#  'dqcvrd2': {'StateRte': 'StateRte'},
#  'dqcf67d': {'StateRte': 'StateRte'},
#  'dqcwf75': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcsb43': {'StateRte': 'StateRte'},
#  'dqc947x': {'StateRte': 'StateRte'},
#  'dqcr5km': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf3cjp': {'StateRte': 'StateRte'},
#  'dr12e4y': {'StateRte': 'StateRte'},
#  'dqcnee6': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcphsf': {'StateRte': 'StateRte'},
#  'dqcnj7b': {'StateRte': 'StateRte'},
#  'dr0cbby': {'StateRte': 'StateRte'},
#  'dqckxmt': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr4038r': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqfpe55': {'StateRte': 'StateRte'},
#  'dqcm6sb': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcnqvt': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dpp8m49': {'StateRte': 'StateRte'},
#  'dqcmc5d': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcjvtf': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr0c90z': {'StateRte': 'StateRte'},
#  'dr18ujs': {'StateRte': 'StateRte'},
#  'dr01u5c': {'StateRte': 'StateRte'},
#  'dqf1j98': {'StateRte': 'StateRte'},
#  'dqcmf54': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqf2df0': {'StateRte': 'StateRte'},
#  'dr12xvb': {'StateRte': 'StateRte'},
#  'dr11e30': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqc69cy': {'StateRte': 'StateRte'},
#  'dr1cphy': {'StateRte': 'StateRte'},
#  'dqcxucj': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqfd027': {'StateRte': 'StateRte'},
#  'dqf39v4': {'StateRte': 'StateRte'},
#  'dr40f2z': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dppcg60': {'StateRte': 'StateRte'},
#  'dqcvsvd': {'StateRte': 'StateRte'},
#  'dqcmwkb': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr18pxh': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcxvjr': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcmsrb': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqctgsx': {'StateRte': 'StateRte'},
#  'dqbz7v8': {'StateRte': 'StateRte'},
#  'dr00gye': {'StateRte': 'StateRte'},
#  'dqce8qn': {'StateRte': 'StateRte'},
#  'dqfjdyj': {'StateRte': 'StateRte'},
#  'dqcx82u': {'StateRte': 'StateRte'},
#  'dr13hqn': {'StateRte': 'StateRte'},
#  'dqcrrxk': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr13ppw': {'StateRte': 'StateRte'},
#  'dr19jhj': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcvny0': {'StateRte': 'StateRte', 'Connection': 'Connection'},
#  'dqfd8zt': {'StateRte': 'StateRte'},
#  'dqcr6r9': {'StateRte': 'StateRte'},
#  'dqc7tzy': {'StateRte': 'StateRte'},
#  'dqcques': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr1cpzm': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcnbtn': {'StateRte': 'StateRte'},
#  'dqcrvhc': {'StateRte': 'StateRte'},
#  'dqcs1p8': {'StateRte': 'StateRte'},
#  'dqc7k1u': {'StateRte': 'StateRte'},
#  'dqcvhcc': {'StateRte': 'StateRte'},
#  'dqbzgjn': {'StateRte': 'StateRte'},
#  'dpp8kwt': {'StateRte': 'StateRte'},
#  'dqctdq8': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dpp98j0': {'StateRte': 'StateRte'},
#  'dr09y41': {'StateRte': 'StateRte'},
#  'dr0b2tm': {'StateRte': 'StateRte'},
#  'dr12zfv': {'StateRte': 'StateRte'},
#  'dqf4v42': {'StateRte': 'StateRte'},
#  'dqf6nfh': {'StateRte': 'StateRte'},
#  'dr10t05': {'StateRte': 'StateRte'},
#  'dr00und': {'StateRte': 'StateRte'},
#  'dqczke7': {'StateRte': 'StateRte'},
#  'dqcjz82': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcryez': {'StateRte': 'StateRte'},
#  'dqcs9g3': {'StateRte': 'StateRte'},
#  'dqcfbh4': {'StateRte': 'StateRte'},
#  'dqf3n56': {'StateRte': 'StateRte'},
#  'dqfp2t8': {'StateRte': 'StateRte'},
#  'dqcmc53': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr0cpq4': {'StateRte': 'StateRte'},
#  'dr11m13': {'StateRte': 'StateRte'},
#  'dqc6d1h': {'StateRte': 'StateRte'},
#  'dqcw9d0': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr10e4y': {'StateRte': 'StateRte'},
#  'dqf4hqd': {'StateRte': 'StateRte'},
#  'dqcx7n7': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcu9mw': {'StateRte': 'StateRte'},
#  'dr09j64': {'StateRte': 'StateRte'},
#  'dr08mem': {'StateRte': 'StateRte'},
#  'dqck0bj': {'StateRte': 'StateRte'},
#  'dqcmtx3': {'StateRte': 'StateRte'},
#  'dqcy3q1': {'StateRte': 'StateRte'},
#  'dqf28jx': {'StateRte': 'StateRte'},
#  'dr10923': {'StateRte': 'StateRte'},
#  'dqck0wv': {'StateRte': 'StateRte'},
#  'dqf3k02': {'StateRte': 'StateRte'},
#  'dqczxxm': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dpp8wvq': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqc61df': {'StateRte': 'StateRte'},
#  'dqctb3c': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqc3z4x': {'StateRte': 'StateRte'},
#  'dr1353n': {'StateRte': 'StateRte'},
#  'dqc9g3d': {'StateRte': 'StateRte'},
#  'dpp936q': {'StateRte': 'StateRte'},
#  'dr1332c': {'StateRte': 'StateRte'},
#  'dnzxd3q': {'StateRte': 'StateRte'},
#  'dqc6pn3': {'StateRte': 'StateRte'},
#  'dqfj4y0': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcpf3f': {'StateRte': 'StateRte'},
#  'dqfj6tm': {'StateRte': 'StateRte'},
#  'dr180xf': {'StateRte': 'StateRte'},
#  'dqcuhvy': {'StateRte': 'StateRte'},
#  'dqc98bp': {'StateRte': 'StateRte'},
#  'dqcjgvr': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcutth': {'StateRte': 'StateRte'},
#  'dqcr0kw': {'StateRte': 'StateRte'},
#  'dqcjxx5': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr1cz4c': {'StateRte': 'StateRte'},
#  'dr08zt7': {'StateRte': 'StateRte'},
#  'dqcqy4c': {'StateRte': 'StateRte'},
#  'dqf67yj': {'StateRte': 'StateRte'},
#  'dqcp6g0': {'StateRte': 'StateRte'},
#  'dqf1fhg': {'StateRte': 'StateRte'},
#  'dqfj3bv': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqc9e0y': {'StateRte': 'StateRte'},
#  'dqfn5wy': {'StateRte': 'StateRte'},
#  'dqc5wnm': {'StateRte': 'StateRte'},
#  'dr0cfu0': {'StateRte': 'StateRte'},
#  'dqcs3c3': {'StateRte': 'StateRte'},
#  'dr199j7': {'StateRte': 'StateRte'},
#  'dqcrkes': {'StateRte': 'StateRte'},
#  'dqck45x': {'StateRte': 'StateRte'},
#  'dr1ckwq': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcnfd4': {'StateRte': 'StateRte'},
#  'dnzxdqn': {'StateRte': 'StateRte'},
#  'dqc7f09': {'StateRte': 'StateRte'},
#  'dqcmr46': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Connection': 'Connection'},
#  'dqcdm5x': {'StateRte': 'StateRte'},
#  'dr1bdhw': {'StateRte': 'StateRte'},
#  'dqfncts': {'StateRte': 'StateRte'},
#  'dqcs0u3': {'StateRte': 'StateRte'},
#  'dr0c38f': {'StateRte': 'StateRte'},
#  'dqcg1gj': {'StateRte': 'StateRte'},
#  'dqcme1j': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcub6d': {'StateRte': 'StateRte'},
#  'dqct0c2': {'StateRte': 'StateRte'},
#  'dqcpnhv': {'StateRte': 'StateRte'},
#  'dqfj68m': {'StateRte': 'StateRte'},
#  'dr11h5k': {'StateRte': 'StateRte'},
#  'dr09gek': {'StateRte': 'StateRte'},
#  'dr10d0n': {'StateRte': 'StateRte'},
#  'dqcdk3m': {'StateRte': 'StateRte'},
#  'dqc70jd': {'StateRte': 'StateRte'},
#  'dqc6tx7': {'StateRte': 'StateRte'},
#  'dr0cc89': {'StateRte': 'StateRte'},
#  'dr09t91': {'StateRte': 'StateRte'},
#  'dpp9937': {'StateRte': 'StateRte'},
#  'dqc5t1r': {'StateRte': 'StateRte'},
#  'dr193u8': {'StateRte': 'StateRte'},
#  'dr10075': {'StateRte': 'StateRte'},
#  'dqcyd1h': {'StateRte': 'StateRte'},
#  'dr41509': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr12h01': {'StateRte': 'StateRte'},
#  'dqf631u': {'StateRte': 'StateRte'},
#  'dqcm0bh': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqf5c5d': {'StateRte': 'StateRte'},
#  'dqcx72x': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqfn0f0': {'StateRte': 'StateRte'},
#  'dqfd377': {'StateRte': 'StateRte'},
#  'dppbd05': {'StateRte': 'StateRte'},
#  'dqc986y': {'StateRte': 'StateRte'},
#  'dqcqyx2': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqfj6fe': {'StateRte': 'StateRte'},
#  'dr0cvn8': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcwd9k': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqctf0y': {'StateRte': 'StateRte',
#   'USRte': 'USRte',
#   'Highway': 'Highway',
#   'Interstate': 'Interstate'},
#  'dpp9yth': {'StateRte': 'StateRte'},
#  'dqcn5zd': {'StateRte': 'StateRte'},
#  'dqcebbc': {'StateRte': 'StateRte'},
#  'dqce0y9': {'StateRte': 'StateRte'},
#  'dqcq7mb': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd', 'USRte': 'USRte'},
#  'dqcs36w': {'StateRte': 'StateRte'},
#  'dppckpm': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqc9b94': {'StateRte': 'StateRte'},
#  'dqctdzt': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqc9e17': {'StateRte': 'StateRte', 'Connection': 'Connection'},
#  'dqcpcsj': {'StateRte': 'StateRte'},
#  'dqfne7v': {'StateRte': 'StateRte'},
#  'dr10wwd': {'StateRte': 'StateRte'},
#  'dqfp0r7': {'StateRte': 'StateRte'},
#  'dqbzxpw': {'StateRte': 'StateRte'},
#  'dpp9bhw': {'StateRte': 'StateRte'},
#  'dqcd7mb': {'StateRte': 'StateRte'},
#  'dr10d5d': {'StateRte': 'StateRte'},
#  'dr1csvu': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqc6m1q': {'StateRte': 'StateRte'},
#  'dqcnuz7': {'StateRte': 'StateRte'},
#  'dr12jkt': {'StateRte': 'StateRte'},
#  'dqcxu17': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcebju': {'StateRte': 'StateRte'},
#  'dqc9esj': {'StateRte': 'StateRte'},
#  'dqc691j': {'StateRte': 'StateRte'},
#  'dqfp2xg': {'StateRte': 'StateRte'},
#  'dqcjyrf': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqc54e6': {'StateRte': 'StateRte'},
#  'dqcterf': {'StateRte': 'StateRte'},
#  'dr1c02y': {'StateRte': 'StateRte'},
#  'dqfd34k': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcs27f': {'StateRte': 'StateRte'},
#  'dqcvhf1': {'StateRte': 'StateRte'},
#  'dr12f8j': {'StateRte': 'StateRte'},
#  'dqcpcdu': {'StateRte': 'StateRte'},
#  'dqc3fmr': {'StateRte': 'StateRte'},
#  'dr09yh2': {'StateRte': 'StateRte'},
#  'dqbzfuz': {'StateRte': 'StateRte'},
#  'dqcndw6': {'StateRte': 'StateRte'},
#  'dr1bgvj': {'StateRte': 'StateRte', 'USRte': 'USRte', 'Highway': 'Highway'},
#  'dr19jh1': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqceft8': {'StateRte': 'StateRte'},
#  'dqc6xng': {'StateRte': 'StateRte'},
#  'dqc7pfj': {'StateRte': 'StateRte'},
#  'dqcz76w': {'StateRte': 'StateRte'},
#  'dqctc9r': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcqzg6': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcmq0u': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'USRte': 'USRte',
#   'Highway': 'Highway'},
#  'dqf59yb': {'StateRte': 'StateRte'},
#  'dqcqqg0': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcrqq5': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqckzyq': {'StateRte': 'StateRte'},
#  'dqcyhvk': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr11q4v': {'StateRte': 'StateRte'},
#  'dqc7f1e': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr41e6f': {'StateRte': 'StateRte'},
#  'dqckze4': {'StateRte': 'StateRte'},
#  'dqcxvd4': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dpp9jh3': {'StateRte': 'StateRte'},
#  'dqf5g3p': {'StateRte': 'StateRte'},
#  'dqf4hn9': {'StateRte': 'StateRte'},
#  'dqcnnhg': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqc7dnb': {'StateRte': 'StateRte'},
#  'dqcxhjc': {'StateRte': 'StateRte'},
#  'dqcqezv': {'StateRte': 'StateRte'},
#  'dr01487': {'StateRte': 'StateRte'},
#  'dqcn8b3': {'StateRte': 'StateRte'},
#  'dqc4f2e': {'StateRte': 'StateRte'},
#  'dr12zv7': {'StateRte': 'StateRte'},
#  'dr10rdg': {'StateRte': 'StateRte'},
#  'dr18jq8': {'StateRte': 'StateRte'},
#  'dqcynkq': {'StateRte': 'StateRte'},
#  'dr109yk': {'StateRte': 'StateRte'},
#  'dqcu86j': {'StateRte': 'StateRte'},
#  'dqc9d15': {'StateRte': 'StateRte'},
#  'dqf66kh': {'StateRte': 'StateRte'},
#  'dqf6hbj': {'StateRte': 'StateRte'},
#  'dqfjdz6': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr1cpu4': {'StateRte': 'StateRte'},
#  'dqcqkmp': {'StateRte': 'StateRte'},
#  'dqcdd03': {'StateRte': 'StateRte'},
#  'dppcw25': {'StateRte': 'StateRte'},
#  'dppcebj': {'StateRte': 'StateRte'},
#  'dqcynez': {'StateRte': 'StateRte'},
#  'dqcre1y': {'StateRte': 'StateRte'},
#  'dqf4t9e': {'StateRte': 'StateRte'},
#  'dqfp221': {'StateRte': 'StateRte'},
#  'dqcmk3m': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr09p0f': {'StateRte': 'StateRte'},
#  'dr1131q': {'StateRte': 'StateRte'},
#  'dr10m37': {'StateRte': 'StateRte'},
#  'dqcuktd': {'StateRte': 'StateRte'},
#  'dqcwew1': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqc5zh1': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr0cduk': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqfh9wc': {'StateRte': 'StateRte'},
#  'dqcg950': {'StateRte': 'StateRte'},
#  'dqcn7ns': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqc6n78': {'StateRte': 'StateRte'},
#  'dqcsrvt': {'StateRte': 'StateRte'},
#  'dqckgce': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcw6j6': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcd4pj': {'StateRte': 'StateRte'},
#  'dqcnxf4': {'StateRte': 'StateRte'},
#  'dqcqy2s': {'StateRte': 'StateRte'},
#  'dqcpuq5': {'StateRte': 'StateRte'},
#  'dqf1bb7': {'StateRte': 'StateRte'},
#  'dr08xdj': {'StateRte': 'StateRte'},
#  'dqcnxj1': {'StateRte': 'StateRte'},
#  'dqc93wq': {'StateRte': 'StateRte'},
#  'dqc9j9h': {'StateRte': 'StateRte'},
#  'dr40dhw': {'StateRte': 'StateRte'},
#  'dqcm1de': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqce9v9': {'StateRte': 'StateRte'},
#  'dr115uh': {'StateRte': 'StateRte'},
#  'dr10d76': {'StateRte': 'StateRte'},
#  'dr1c0xt': {'StateRte': 'StateRte'},
#  'dqf67sz': {'StateRte': 'StateRte'},
#  'dqcr9wq': {'StateRte': 'StateRte'},
#  'dqc6q57': {'StateRte': 'StateRte'},
#  'dqcebwt': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqfd6h7': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcwbc9': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dr19yz0': {'StateRte': 'StateRte'},
#  'dqc3g04': {'StateRte': 'StateRte'},
#  'dqczxxy': {'StateRte': 'StateRte'},
#  'dqcusg1': {'StateRte': 'StateRte'},
#  'dqc783m': {'StateRte': 'StateRte'},
#  'dqcygqm': {'StateRte': 'StateRte'},
#  'dr1crbw': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr19ude': {'StateRte': 'StateRte'},
#  'dqcxvk0': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqckt37': {'StateRte': 'StateRte'},
#  'dqc61pj': {'StateRte': 'StateRte'},
#  'dqfp0jp': {'StateRte': 'StateRte'},
#  'dr12jkr': {'StateRte': 'StateRte'},
#  'dr1c4s0': {'StateRte': 'StateRte'},
#  'dqcvsbc': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr121p3': {'StateRte': 'StateRte'},
#  'dr11p1v': {'StateRte': 'StateRte'},
#  'dqcp9qk': {'StateRte': 'StateRte'},
#  'dqcrhby': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf44fm': {'StateRte': 'StateRte'},
#  'dqcjum9': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr010gn': {'StateRte': 'StateRte'},
#  'dqcrbef': {'StateRte': 'StateRte'},
#  'dqcq00z': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcmffh': {'StateRte': 'StateRte'},
#  'dqcwbx7': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqc7ty4': {'StateRte': 'StateRte'},
#  'dqcx5yg': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Interstate': 'Interstate'},
#  'dqf0sym': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr1bg6s': {'StateRte': 'StateRte'},
#  'dqcnn0v': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcmb06': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr101b3': {'StateRte': 'StateRte'},
#  'dqcqe0j': {'StateRte': 'StateRte'},
#  'dqfd87d': {'StateRte': 'StateRte', 'USRte': 'USRte', 'Highway': 'Highway'},
#  'dqcjz8n': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr0b8zy': {'StateRte': 'StateRte'},
#  'dqc7771': {'StateRte': 'StateRte'},
#  'dqc9g6f': {'StateRte': 'StateRte'},
#  'dr12y5f': {'StateRte': 'StateRte'},
#  'dqctnwt': {'StateRte': 'StateRte'},
#  'dqf5jjp': {'StateRte': 'StateRte'},
#  'dqc6k37': {'StateRte': 'StateRte'},
#  'dqcz4d7': {'StateRte': 'StateRte'},
#  'dqc700s': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcw8zs': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr104pc': {'StateRte': 'StateRte'},
#  'dqc9snp': {'StateRte': 'StateRte'},
#  'dqcnt8g': {'StateRte': 'StateRte'},
#  'dqcmd61': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqf2kwp': {'StateRte': 'StateRte'},
#  'dqcs2d8': {'StateRte': 'StateRte'},
#  'dqbzxps': {'StateRte': 'StateRte'},
#  'dppb9d0': {'StateRte': 'StateRte'},
#  'dr0b2ey': {'StateRte': 'StateRte'},
#  'dr09xu7': {'StateRte': 'StateRte'},
#  'dqc6m9d': {'StateRte': 'StateRte'},
#  'dqfn9xu': {'StateRte': 'StateRte'},
#  'dqcpk7u': {'StateRte': 'StateRte'},
#  'dqcpjtv': {'StateRte': 'StateRte'},
#  'dqc5td7': {'StateRte': 'StateRte'},
#  'dr0bdun': {'StateRte': 'StateRte'},
#  'dqf57wv': {'StateRte': 'StateRte'},
#  'dr10mtx': {'StateRte': 'StateRte'},
#  'dr0brwm': {'StateRte': 'StateRte'},
#  'dqc67zg': {'StateRte': 'StateRte'},
#  'dqc79sg': {'StateRte': 'StateRte'},
#  'dqczz7n': {'StateRte': 'StateRte'},
#  'dqcgm36': {'StateRte': 'StateRte'},
#  'dqckgd6': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqczj18': {'StateRte': 'StateRte'},
#  'dqcg6yz': {'StateRte': 'StateRte'},
#  'dr13f9u': {'StateRte': 'StateRte'},
#  'dqfp3ge': {'StateRte': 'StateRte'},
#  'dqcpf4p': {'StateRte': 'StateRte'},
#  'dqfncj7': {'StateRte': 'StateRte'},
#  'dr136f7': {'StateRte': 'StateRte'},
#  'dqcwd5p': {'StateRte': 'StateRte'},
#  'dr18v35': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr012md': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Highway': 'Highway'},
#  'dqcqvmk': {'StateRte': 'StateRte'},
#  'dqfh1hj': {'StateRte': 'StateRte'},
#  'dr12jcu': {'StateRte': 'StateRte', 'Interstate': 'Interstate'},
#  'dqc3ent': {'StateRte': 'StateRte'},
#  'dqfnkje': {'StateRte': 'StateRte'},
#  'dr19b71': {'StateRte': 'StateRte'},
#  'dr190ub': {'StateRte': 'StateRte'},
#  'dr1291d': {'StateRte': 'StateRte'},
#  'dr09gvm': {'StateRte': 'StateRte'},
#  'dqcu542': {'StateRte': 'StateRte'},
#  'dr1cwet': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf3ck3': {'StateRte': 'StateRte'},
#  'dr413ux': {'StateRte': 'StateRte'},
#  'dr110cr': {'StateRte': 'StateRte'},
#  'dqcvgs9': {'StateRte': 'StateRte'},
#  'dqc4uqr': {'StateRte': 'StateRte'},
#  'dqc730p': {'StateRte': 'StateRte'},
#  'dqcrg67': {'StateRte': 'StateRte'},
#  'dr18h2t': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcrntc': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'Interstate': 'Interstate'},
#  'dqfhe25': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcs66p': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcqevw': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqcxv5n': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqczxz3': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dr0be7e': {'StateRte': 'StateRte'},
#  'dqcvkv4': {'StateRte': 'StateRte'},
#  'dqcndvc': {'StateRte': 'StateRte'},
#  'dqckbfc': {'StateRte': 'StateRte'},
#  'dr08qwd': {'StateRte': 'StateRte'},
#  'dqcm0b5': {'StateRte': 'StateRte'},
#  'dr19mqd': {'StateRte': 'StateRte'},
#  'dr010fu': {'StateRte': 'StateRte'},
#  'dr00vyj': {'StateRte': 'StateRte'},
#  'dqc6d25': {'StateRte': 'StateRte'},
#  'dqckfx0': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcmeu1': {'StateRte': 'StateRte'},
#  'dr1c5du': {'StateRte': 'StateRte'},
#  'dqcns0c': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqfndvm': {'StateRte': 'StateRte'},
#  'dqcdhq8': {'StateRte': 'StateRte'},
#  'dr1123g': {'StateRte': 'StateRte'},
#  'dqcmbcd': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr10vzr': {'StateRte': 'StateRte'},
#  'dqck0mj': {'StateRte': 'StateRte'},
#  'dpp81se': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqcuj4t': {'StateRte': 'StateRte'},
#  'dqcr2qf': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqce349': {'StateRte': 'StateRte'},
#  'dqcqz3r': {'StateRte': 'StateRte'},
#  'dqcqbgj': {'StateRte': 'StateRte'},
#  'dqc4e3y': {'StateRte': 'StateRte'},
#  'dqcnm1b': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqc7ty2': {'StateRte': 'StateRte'},
#  'dqcvv5g': {'StateRte': 'StateRte'},
#  'dqcqwph': {'StateRte': 'StateRte'},
#  'dr11mgx': {'StateRte': 'StateRte'},
#  'dqcpwzr': {'StateRte': 'StateRte'},
#  'dqc9bd4': {'StateRte': 'StateRte'},
#  'dr19vw3': {'StateRte': 'StateRte'},
#  'dqfj2u8': {'StateRte': 'StateRte', 'Highway': 'Highway'},
#  'dqf3hr0': {'StateRte': 'StateRte'},
#  'dqcp4mm': {'StateRte': 'StateRte'},
#  'dr0c1rw': {'StateRte': 'StateRte'},
#  'dr405qw': {'StateRte': 'StateRte'},
#  'dqbz9sc': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr187sq': {'StateRte': 'StateRte'},
#  'dqcs04e': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dr11bv8': {'StateRte': 'StateRte',
#   'MajorRd': 'MajorRd',
#   'USRte': 'USRte',
#   'Highway': 'Highway'},
#  'dr115un': {'StateRte': 'StateRte'},
#  'dqcm725': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqfd04x': {'StateRte': 'StateRte', 'MajorRd': 'MajorRd'},
#  'dqc797y': {'StateRte': 'StateRte'},
#  'dqf5gc3': {'StateRte': 'StateRte'},
#  'dqfhhj4': {'StateRte': 'StateRte'},
#  'dr1842f': {'StateRte': 'StateRte'},
#  'dqc6gs9': {'StateRte': 'StateRte'},
#  'dqce1mr': {'StateRte': 'StateRte'},
#  'dqcmhfw': {'StateRte': 'StateRte'},
#  'dqc3fc6': {'StateRte': 'StateRte'},
#  'dr123rj': {'StateRte': 'StateRte'},
#  'dqc9n1m': {'StateRte': 'StateRte'},
#  'dqcdhy7': {'StateRte': 'StateRte'},
#  'dqc6y3z': {'StateRte': 'StateRte'},
#  'dqcgku1': {'StateRte': 'StateRte'},
#  ...}

# %%
import pickle
prec=7

show=False
from os.path import basename, dirname
from glob import glob
mtype = "Road"
geofiles = glob(join(basedir, "Trans_RoadSegment*-*_Illinois-{0}-geos.p".format(prec)))
recfiles = glob(join(basedir, "Trans_RoadSegment*-*_Illinois-{0}-data.p".format(prec)))
print("Found {0} and {1} files".format(len(geofiles), len(recfiles)))

geomap  = {}
records = {"Interstate": {}, "StateRte": {}, "USRte": {}, "Highway": {}, "MajorRd": {}, "Connection": {}}

from collections import Counter
cnt = Counter()
for recfile in recfiles:
    recdata = pickle.load(open(recfile, "rb"))
    print(recfile)
    for geoid,recdata in recdata.items():
        if recdata[0]:
            records["Interstate"][geoid]  = "Interstate"
        if recdata[1]:
            records["USRte"][geoid]  = "USRte"
        if recdata[2]:
            records["StateRte"][geoid]  = "StateRte"
        if recdata[3]:
            records["Highway"][geoid]  = "Highway"
        if recdata[4]:
            records["MajorRd"][geoid]  = "MajorRd"
        if recdata[5]:
            records["Connection"][geoid]  = "Connection"
    print("Found {0} roads".format(len(records)))
     

ngeos = 0
for geofile in geofiles:
    geodata = pickle.load(open(geofile, "rb"))
    print(geofile)
    for geoid,geos in geodata.items():
        if not any([records["Interstate"].get(geoid), records["USRte"].get(geoid), records["StateRte"].get(geoid), records["CountyRd"].get(geoid), records["LocalRd"].get(geoid)]):
            continue
        ngeos += len(geos)
        for geo in geos:
            if geomap.get(geo) is None:
                geomap[geo] = {}
            for k in records.keys():
                if records[k].get(geoid) is not None:
                    geomap[geo][k] = geoid
    print("Found {0} roads".format(len(geomap)))


                
fname="geomap-{0}-{1}.p".format(prec, mtype)
print("Writing {0}".format(fname))
pickle.dump(geomap,  open(fname, "wb"))

fname="georec-{0}-{1}.p".format(prec, mtype)
print("Writing {0}".format(fname))
pickle.dump(records,  open(fname, "wb"))
# Out:
# Found 0 and 0 files
# Writing geomap-7-Road.p
# Writing georec-7-Road.p

# %% [markdown]
# # Create Individual Records

# %%
prec = 6
stdirs=[]
if True:
    #stdirs.append("County_2010Census_DP1")
    #stdirs.append("CBSA_2010Census_DP1")
    #stdirs.append("CSA_2010Census_DP1")
    #stdirs.append("Place_2010Census_DP1")
    stdirs.append("MetDiv_2010Census_DP1")
    #stdirs.append("CouSub_2010Census_DP1")
    stdirs.append("ZCTA_2010Census_DP1")
    #stdirs.append("Tract_2010Census_DP1")

# %%
# %load_ext autoreload
# %autoreload
from timeUtils import clock, elapsed
show=False


names=set()

#stdirs.append("CD111_2010Census_DP1")
#stdirs.append("SLDL_2010Census_DP1")
#stdirs.append("SLDU_2010Census_DP1")

#stdirs.append("ELSD_2010Census_DP1")
#stdirs.append("SCSD_2010Census_DP1")
#stdirs.append("UNSD_2010Census_DP1")
#stdirs.append("SubMCD_2010Census_DP1")

for stdir in stdirs:
    start,cmt = clock("Analyzing {0}".format(stdir))
    print("Loading shape file")
    sf = shapefile.Reader(join(basedir, stdir, stdir))
        
    mtype=stdir.split("_")[0]

    shapes = sf.shapes()
    Nshapes = len(shapes)
    modval  = 500
    if Nshapes > 10000:
        modval = 1000
    elif Nshapes > 5000:
        modval = 250
    elif Nshapes > 1000:
        modval = 100
    else:
        if Nshapes < 500:
            modval = 10
        else:
            modval = 50
    print("There are {0} shapes in this file.".format(len(shapes)))

    fields = sf.fields
    if show:
        print("Fields -> {0}".format(fields))

    ipop=None
    for i,val in enumerate(fields):
        if val[0] == "DP0010001":
            ipop = i-1
            break

    ihouse=None
    for i,val in enumerate(fields):
        if val[0] == "DP0130001":
            ihouse = i-1
            break

    ihouseocc=None
    for i,val in enumerate(fields):
        if val[0] == "DP0180001":
            ihouseocc = i-1
            break
            
    print("  Pop       -> {0}".format(ipop))
    print("  House     -> {0}".format(ihouse))
    print("  Occupancy -> {0}".format(ihouseocc))
    elapsed(start, cmt)
    
    geoShapeMap = {}
    shapeData   = {}
    import pickle
    from numpy import linspace
    start,_ = clock("Analyzing shape files")
    irec  = 0
    for shapeRec in sf.iterShapeRecords():
        ## Record
        record = shapeRec.record
        geoid = record[0]
        name  = record[1]
        memi  = record[2]
        area  = record[-1]
        pops  = record[ipop:ipop+19]
        house = record[ihouse:ihouse+15]
        occpy = record[ihouseocc:ihouseocc+9]
        
        #names.add(name)
        #continue
        
        if mtype == "CBSA":
            ptype = None
            if not isinstance(name,str):
                continue
            if name.find("Metro Area") != -1:
                memi = "Metro"
                name = name.replace("Metro Area", "").strip()
            elif name.find("Micro Area") != -1:
                memi = "Micro"
                name = name.replace("Micro Area", "").strip()
            else:
                print(name)
                1/0
        
        if mtype == "CSA":
            ptype = None
            if not isinstance(name,str):
                continue
            if name.find(" CSA") != -1:
                name = name.replace(" CSA", "").strip()
            else:
                print(name)
                1/0
        
        if mtype == "Place":
            ptype = None
            if not isinstance(name,str):
                continue
            name = name.replace("(balance)", "").strip()
            if name.endswith(" city"):
                memi = "City"
                name = name[:-5]
            elif name.endswith(" municipality"):
                memi = "Municipality"
                name = name[:-13]
            elif name.endswith(" borough"):
                memi = "Borough"
                name = name[:-8]
            elif name.endswith(" city and borough"):
                memi = "City/Borough"
                name = name[:-17]
            elif name.endswith(" town"):
                memi = "Town"
                name = name[:-5]
            elif name.endswith(" CDP"):
                memi = "CDP"
                name = name[:-4]
            elif name.endswith(" village"):
                memi = "Village"
                name = name[:-8]
            elif name.endswith(" unified government"):
                memi = "Unified Government"
                name = name[:-19]
            elif name.endswith(" consolidated government"):
                memi = "Consolidated Government"
                name = name[:-24]
            elif name.endswith(" metro government"):
                memi = "Metro Government"
                name = name[:-17]
            elif name.endswith(" metropolitan government"):
                memi = "Metropolitan Government"
                name = name[:-24]
            elif name.endswith(" urban county"):
                memi = "Urban County"
                name = name[:-13]
            elif name.endswith(" County"):
                memi = "County"
            else:
                continue
                
        
        if mtype == "MetDiv":
            ptype = None
            if not isinstance(name,str):
                continue
            if name.find("Metro Area") != -1:
                memi = "Metro"
                name = name.replace("Metro Area", "").strip()
            elif name.find("Micro Area") != -1:
                memi = "Micro"
                name = name.replace("Micro Area", "").strip()
            else:
                print(name)
                
        
        pop    = pops[0]
        try:
            young  = round(float(sum(pops[1:5]))/pop,2)
            adult  = round(float(sum(pops[5:12]))/pop,2)
            old    = round(float(sum(pops[12:]))/pop,2)
        except:
            young = 0.0
            adult = 0.0
            old   = 0.0
        
        nhouse  = house[0]
        try:
            ffamily = round(float(house[1])/nhouse,2)
        except:
            ffamily = 0.0
        nhouseunits = occpy[0]
        try:
            foccpy = round(float(occpy[1])/nhouseunits,2)
        except:
            foccpy = 0.0
        
        if show:
            print(record)
            print(pops)
            print(pop,young,adult,old)
            print(house)
            print(nhouse,ffamily)
            print(occpy)
            print(nhouseunits,foccpy)
            #print(pop)
            #print(young)
            #print(adult)
            #print(old)

        try:
            float(memi)
            shapeData[geoid] = {"Name": name, "Record": irec, "Area": area, "Type": None, "Housing": [nhouse,ffamily], "Occupancy": [nhouseunits, foccpy], "Pop": [pop,young,adult,old]}
        except:
            shapeData[geoid] = {"Name": name, "Record": irec, "Area": area, "Type": memi, "Housing": [nhouse,ffamily], "Occupancy": [nhouseunits, foccpy], "Pop": [pop,young,adult,old]}
            
            
        if show:
            print(shapeData[geoid])
            1/0
        Nsd = len(shapeData)
        if irec % modval == 0:
            elapsed(start, "{0}/{1}\t{2}".format(irec,Nshapes,name), showTime=False)


    if len(names) == 0:
        fname = "{0}-{1}-data.p".format(stdir, prec)
        elapsed(start, "Analyzed {0} shapes".format(Nshapes))
        print("There are {0} entries in the saved file.".format(len(shapeData)))
        pickle.dump(shapeData, open(fname, "wb"))
        print("Saved shape data to {0}".format(fname))
        print("\n\n")
    
for name in names:
    print(name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-31-8c8f402966f1> in <module>()
#       2 get_ipython().run_line_magic('autoreload', '')
#       3 from timeUtils import clock, elapsed
# ----> 4 1/0
#       5 show=False
#       6
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # Create Individual Geos

# %%
for stdir in stdirs:
    start,cmt = clock("Analyzing {0}".format(stdir))
    print("Loading shape file")
    sf = shapefile.Reader(join(basedir, stdir, stdir))
    skips=set()
        
    mtype=stdir.split("_")[0]

    shapes = sf.shapes()
    Nshapes = len(shapes)
    modval  = 500
    if Nshapes > 10000:
        modval = 1000
    elif Nshapes > 5000:
        modval = 500
    elif Nshapes > 1000:
        modval = 200
    else:
        if Nshapes < 500:
            modval = 10
        else:
            modval = 50
    print("There are {0} shapes in this file.".format(len(shapes)))
    irec  = 0
    geoShapeMap={}
    ngeos = 0
    for shapeRec in sf.iterShapeRecords():
        ## Record
        record = shapeRec.record
        geoid = record[0]
        
        ## Shape
        shape   = shapeRec.shape
        poly    = Polygon(shape.points)
        center  = poly.centroid
        pnt     = center
        long0   = center.x
        lat0    = center.y
        geo     = geohash.encode(latitude=lat0, longitude=long0, precision=prec)
        geos    = set([geo])
        ignores = set()
        debug=False
        if irec % 100 == 0:
            debug=True
        addShapeGeos(irec, Nshapes, shape, prec, geos, debug=debug)
        nAddGeos = len(geos)
        irec += 1
        
        if irec % modval == 0:
            elapsed(start, "{0}/{1}\t{2} ({3})".format(irec,Nshapes,ngeos,len(skips)), showTime=False)

        new = False
        n   = 0
        if False:
            for geoval,gval in lookup.items():
                if poly.contains(Point(gval[1],gval[0])) is True:
                    dn = len(geos)
                    addGeos(geos, geo)
                    n += len(geos) - dn
                    new = True
                    skips.add(geo)
            if new:
                print("  Added {0} unknown geohashs to {1}".format(n, geoid))
            
        if False:
            if groupings.get(geo[:3]) is not None:
                if groupings[geo[:3]].get(geo[:4]) is not None:
                    print("  Checking {0}".format(geo[:4]))
                    for geoval in groupings[geo[:3]][geo[:4]]:
                        gval = lookup[geoval]
                        #print(gval[1],gval[0])
                        if poly.contains(Point(gval[1],gval[0])) is True:
                            dn = len(geos)
                            addGeos(geos, geo)
                            n += len(geos) - dn
                            new = True
                            skips.add(geo)
            if new:
                print("  Added {0} unknown geohashs to {1}".format(n, geoid))
                            
        geoShapeMap[geoid] = geos
        ngeos += len(geos)
        
    fname = "{0}-{1}-geos.p".format(stdir, prec)
    elapsed(start, "Analyzed {0} shapes".format(Nshapes))
    print("There are {0} entries in the saved file.".format(len(geoShapeMap)))
    print("There are {0} geos in the saved file.".format(ngeos))
    pickle.dump(geoShapeMap, open(fname, "wb"))
    print("Saved shape data to {0}".format(fname))
    print("\n\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-03b386d64458> in <module>()
# ----> 1 for stdir in stdirs:
#       2     start,cmt = clock("Analyzing {0}".format(stdir))
#       3     print("Loading shape file")
#       4     sf = shapefile.Reader(join(basedir, stdir, stdir))
#       5     skips=set()
#
# NameError: name 'stdirs' is not defined

# %% [markdown]
# # Create Final Geo Record Data

# %%
geomap={}
from os.path import exists
import pickle
missings={}
for stdir in stdirs:
    print("---> {0}".format(stdir))
    fname = '{0}-{1}-data.p'.format(stdir, prec)
    print(exists(fname))
    data = {}
    statedata = {}
    try:
        stdata = pickle.load(open(fname, 'rb'))
    except:
        print("Could not open {0}".format(fname))
        continue
        
    mtype=stdir.split("_")[0]

    for geoid,geodata in stdata.items():
        pop     = geodata["Pop"]
        name    = geodata["Name"]
        area    = geodata["Area"]
        ptype   = geodata["Type"]
        housing = geodata["Housing"]
        occupy  = geodata["Occupancy"]
        
        data[geoid] = {"Name": name, "Area": area, "Type": ptype, "Housing": housing, "Occupancy": occupy, "Population": pop}
        if mtype == "County":
            statedata[geoid[:2]] = {"Name": name}
            
    print(len(data))
    fname="geo{0}-{1}.p".format(mtype,prec)
    print("Writing {0}".format(fname))
    #saveJoblib(data, fname)
    pickle.dump(data,  open(fname, "wb"))
    
    if len(statedata) > 0:
        print(len(statedata))
        fname="geo{0}-{1}.p".format("State",prec)
        print("Writing {0}".format(fname))
        #saveJoblib(data, fname)
        pickle.dump(statedata,  open(fname, "wb"))
# Out:
# ---> Tract_2010Census_DP1
# True
# 74002
# Writing geoTract-5.p
# ---> ZCTA_2010Census_DP1
# True
# 33120
# Writing geoZCTA-5.p
# ---> County_2010Census_DP1
# True
# 3221
# Writing geoCounty-5.p
# 52
# Writing geoState-5.p
# ---> CBSA_2010Census_DP1
# True
# 951
# Writing geoCBSA-5.p
# ---> CSA_2010Census_DP1
# True
# 127
# Writing geoCSA-5.p
# ---> Place_2010Census_DP1
# True
# 29246
# Writing geoPlace-5.p
# ---> MetDiv_2010Census_DP1
# True
# 29
# Writing geoMetDiv-5.p
# ---> CouSub_2010Census_DP1
# True
# 36642
# Writing geoCouSub-5.p

# %% [markdown]
# # Create Final Merged GeoMap

# %%
geomap={}
for stdir in stdirs:
    fname = '{0}-{1}-geos.p'.format(stdir, prec)
    data = {}
    statedata = {}
    try:
        stdata = pickle.load(open(fname, 'rb'))
    except:
        print("Could not open {0}".format(fname))
        continue
        
    mtype=stdir.split("_")[0]

    print("{0}\t{1}".format(mtype,len(stdata)))
    ngeos = 0
    for geoid, geos in stdata.items():
        ngeos += len(geos)
        for geo in geos:
            if geomap.get(geo) is None:
                geomap[geo] = {}
            if geomap[geo].get(mtype) is None:
                geomap[geo][mtype] = set()
            if mtype == "County":
                geomap[geo]["State"] = set()
            geomap[geo][mtype].add(geoid)
            if mtype == "County":                
                geomap[geo]["State"].add(geoid[:2])

    print("{0}\t{1}\t---> {2} <---".format(mtype,ngeos,len(geomap)))
                
fname="geomap-{0}.p".format(prec)
print("Writing {0}".format(fname))
pickle.dump(geomap,  open(fname, "wb"))
# Out:
# County	3221
# County	2417994	---> 1745966 <---
# CBSA	955
# CBSA	632680	---> 1749584 <---
# CSA	128
# CSA	184734	---> 1751589 <---
# Place	29514
# Place	824825	---> 1751713 <---
# MetDiv	29
# MetDiv	23493	---> 1751726 <---
# CouSub	36642
# CouSub	3442709	---> 1901975 <---
# ZCTA	33120
# ZCTA	2322527	---> 1902131 <---
# Tract	74002
# Tract	4394178	---> 1928486 <---
# Writing geomap-5.p

# %% [markdown]
# # Rerun Geos for overlapping geohashs

# %%
fname="geomap-{0}.p".format(prec)
import pickle
geomap = pickle.load(open(fname, "rb"))
overlaps = {}
for geo,geodata in geomap.items():
    for mtype,geoids in geodata.items():
        if len(geoids) > 1:
            for geoid in geoids:
                if overlaps.get(mtype) is None:
                    overlaps[mtype] = set()
                overlaps[mtype].add(geoid)
# Out:
# 174949

# %%
help(shapely)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b1a3b2ca7eac> in <module>()
# ----> 1 help(shapely)
#
# NameError: name 'shapely' is not defined
